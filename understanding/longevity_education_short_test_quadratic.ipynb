# %% [markdown]
# # Introduction
#
# First we create a Pomegranate Bayesian Network using the protobuf interface and our utility package, bayesnet, that enables one to conveniently create a Bayesian network by hand, and in accord with common statistics and rules, without having to fill in every probability.  The same Baysian network can start with our hand entered rules, but can later learn from data.  Any amount of questions can be answered, including no questions, to get the probabilities .  The file the Bayesian net is written in is longevity_bayes.py.  Our utility package can then be used to query the network with different evidence of states.  This is convenient for tuning hand entered parameters.
#
# ## Longevity net
# Here put the name of the network you have written with the protobuf and bayes utilities.  Our example is printed out.  We created 4 functions in our utility package: any_of, all_of, if_the_else, and avg, which can together be used to express almost any set of rules, documented elsewhere.  We also implemented a dependency rule with which one can enter statistics from Systematic Reviews and Meta analyses easily.  The last lines implement the creation of the description of the network,  bayesianNetwork , with the protobuf utilities, and then the creation of the Pomegranate network with the description.
#
# ## Timing:  compiling, computation, explaning
# It takes about 1 hour and 16 minutes to compile the file.  However, the user does not experience this delay, just the programmer.  Later this notebook you will see that the computation time, to get to the answer when it is running, is about 7 seconds.  Times to get an explanation depend on how many possible explanations we want to cover: for example, if there are 60 things to check, it takes 16 seconds.  We have made a way to retrieve the answers gradually over that time, if necessary.
#
# ## Variables to connect to , in order to fill in the health recommendations
#
# 1. diet:  "poor_diet".  upshot will not include socioeconomic status in recommendations and will recommend to increase or decrease things in diet, including calories
# 2. supplements:  "poor_diet_flag".  This shows area of deficiency that may need supplementation over and above diet
# 3. sleep hygiene:  "poor_sleep"
# 4. body weight: "obesity"
# 5. exercise: "lack_of_exercise"
# 6. lifestyle:   - "poor_diet_quantity"(water caffine sodium alcohol) + "psychological_disorders"(anxiety and marital status) + "smoking".  Just add to each other, do not rank with the same numbers to each.
#
#
# ## Variables to conect to, in order to fill in the hallmarks
#
# 1. "hallmark_1_genomic_instability"
# 2. "hallmark_2_telomere_attrition"
# 3. "hallmark_3_epigenetic_alterations"
# 4. "hallmark_4_loss_of_proteostasis"
# 5. "hallmark_5_deregulated_nutrient_sensing"
# 6. "hallmark_6_mitochondrial_dysfunction"
# 7. "hallmark_7_cellular_senescence"
# 8. "hallmark_8_stem_cell_exhaustion"
# 9. "hallmark_9_altered_intercellular_communication"
# 10. "hallmark_10_extracellular_matrix_dysfunction"
#
#
# ## Testing the Bayesian Network
#
# Here we use our query util to enter patient states as evidence (evidence), and then see the probabilities of particular variables we are interested in (outvars), in this case, the output variables. The query function needs the compiled Pomegranate Bayesian network as well as the description of the network. In the following examples, we enter a particular patients state , one question at a time, to get a continual change in probability of all states.Adding more risk factors increases risk more. We test the bayesian net through the internal query, as it is done for efficiency in the app. Note the internal query sends back all states not just the requested ones. We also use query, so that we can see the results clearly in this notbook. If most persons are of low socioeconomic status to begin with (65% in Nhanes data), then that would explain why the values only went up slightly even though the relative risk of poor diet given low socioeconomic status is 2.66.
#
# ## Testing explanations
# The explain function will tell you which nodes, whether inner or leaf, when changed, change the output variable.  A variable is on the reverse explain list if we want to know what changes to other variables will increase it.  Otherwise we look to
# changes that decrease the variable to be explained.  One may select which explanations are relevant for their purposes, as this is just a measure of dependence. The point is to find out which variables help a situation, where the output variables are the goals.  At default values,  we want to find out how to decrease an output_variables probability, when we move a variable from where it is to one value to the right.  Our present rules, in longevity_bayes.py, are designed so that one value to the right is an improvement.  The explanation output tells you the change in the probability of the output variable when this happens.  Those explanations with the greatest values tell the variables that when you improve them decrease the probability of the output variable the most, and are thus the most helpful in decreasing the chance of a bad thing.  However, some variables could possibly need to additionally be on the reverse_explain_list because they are not bad things, they are good things, so as a goal, you would want to know how to increase their probability not decrease it.  So, to find an explanation for why an indicator is so good, you have to enter all the nodes of the net into reverse_evidence that were not in reverse_evidence when explainng why an indicator is doing poorly.
#
# Although we need the explain function for complex rule sets in which the direction of the rules  changes at times because there are different and multiple goals, we have made two wrapper functions that only apply for rulesets in which all the rules are in the same direction, for example the covid ruleset and the longevity ruleset.  One wrapper is explain_why_bad, which takes on the default of the explain function, and has no reverse_explain_list or reverse_evidence.  The other is explain_why_good, explained below.  explain_why_good (and explain using reverse evidence and explain vars only works when the result is actually good, and explain_why_bad (and the explain default) only works when a result is actually bad.  Below we show only the explain why good and explain why bad functions for explanations, because the longevity_bayes.py file only has rules that are expressed as negative states.
#
# ## Explanations
#
# To pull out explanations, the algorithm has changed as a result of the new less computationally complex algorithm.  First, find the majority explanation value for an output variable, and then get rid of all candidate explanations that have that value or below. Then, of the remaining, use a threshold of 0.1 and above to include an explanation.  Then you can rank them by the magnitude, to find the stronger explanations, perhaps to show those nearer to the top.  Below, for example, we have preinted out the why bad, and then the why good. Typically if the results are good, and you ask why they are bad, you will not get an answer and visa versa.  We see that cancer is an explaination fo rwhy hallmark 7 and 9 are bad, and frailty explains 8 and 5.
#
# ## Realistic survey answers
#
# The above example is simple for understanding's sake, it just has 2 inputs, one of which is in the questions (cancer) and one which is not, but is affected by the questions that are inputs (frailty).  So next we will have the input that is more like the answers to the surveys, and see if they still produce correct results

# %% [markdown]
# # Requirements

# %% [raw]
# import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -e ../bayesnet
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install networkx
# !{sys.executable} -m pip install graphviz
# !{sys.executable} -m pip install datetime
# !{sys.executable} -m pip install grpcio
# !{sys.executable} -m pip install --no-cache-dir --upgrade numpy
# !{sys.executable} -m pip install pomegranate==0.14.0
# !{sys.executable} -m pip install qpsolvers
# !{sys.executable} -m pip install osqp

# %% [raw]
# !{sys.executable} -m pip install -r requirements.txt
# !sh buildproto.sh

# %% [raw]
# pip install protobuf==3.20.0

# %% [markdown]
# # Imports

# %%
import qpsolvers
from os.path import exists
import pickle

import sn_bayes
from sn_bayes import longevity_bayes
from sn_bayes.utils import complexity_check
from sn_bayes.utils import get_var_positions
from sn_bayes.utils import get_var_val_positions
from sn_bayes.utils import make_tree
from sn_bayes.utils import bayesInitialize
from sn_bayes.utils import query
from sn_bayes.utils import internal_query
from sn_bayes.utils import internal_query
from sn_bayes.utils import explain_why_bad
from sn_bayes.utils import explain_why_good
from sn_bayes.utils import create_query

import sn_service.service_spec.bayesian_pb2
from sn_service.service_spec.bayesian_pb2 import Query
import sn_service.service_spec.bayesian_pb2_grpc as grpc_bayes_grpc
import sn_service.service_spec.bayesian_pb2
from sn_service.service_spec.bayesian_pb2 import BayesianNetworkQuery
from sn_service.service_spec.bayesian_pb2 import QueryId
from sn_service.service_spec.bayesian_pb2 import Id

import grpc
import pandas as pd
import networkx as nx
import time
import re

import matplotlib.pyplot as plt
# Out:
# C:\Users\Osvaldo\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Osvaldo\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Longevity net

# %%
if exists("bayesianNetwork.pkl"):
        infile = open("bayesianNetwork.pkl",'rb')
        bayesianNetwork = pickle.load(infile)
        infile.close()
else:
        # %time bayesianNetwork,outstr = longevity_bayes.longevity_bayes()
        print (outstr)
        outfile = open("bayesianNetwork.pkl",'wb')
        pickle.dump(bayesianNetwork,outfile)
        outfile.close()

# %%
path = './sn_bayes'
text_file = open(f'{path}/longevity_bayes.py')
#text_file = open('./sn_bayes/longevity_bayes_short.py')
file_content = text_file.read()
#print(file_content)
text_file.close()

# %% [markdown]
# ## Timing:  compiling, computation, explaning

# %%
print(qpsolvers.available_solvers)
# Out:
# ['daqp', 'ecos', 'osqp', 'scs']

# %%
#
complexity_check(bayesianNetwork)
#
var_positions = get_var_positions(bayesianNetwork)
#
var_val_positions = get_var_val_positions(bayesianNetwork)

# %%
# We create a spreadsheet of the above for reference
rows_list = []
outname = "varvals.csv"
for var, valdict in var_val_positions.items():
    rowdict = {} 
    rows_list.append(rowdict)
    varstr= var +"("
    for val, pos in valdict.items():
        varstr += val
        varstr+= ","
            
    varstr=varstr[:-1]+")"
    rowdict["variable"] = varstr        
#
df = pd.DataFrame(rows_list)      
# df.to_csv(outname, index = False)

# %% [markdown]
# ## Variables to connect to , in order to fill in the health recommendations

# %% [markdown]
# ## Variables to conect to, in order to fill in the hallmarks

# %%
'''Here we create a spreadsheet that makes a Cartesian product of desired outputs with 
the remainder of the variables. This can be used to, for example, fill in a treatment 
recommendation for variables that are returned as causing the output in the explanation module'''
#cols = ["leaves","internal","output"]
desired_output =["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
rows_list = []
outname = "upshot.csv"
#put leaves in the first column, then internal vars along with the vars that feed them in the second.  
#and do a cartesian product with the outvars that are also internal vars (should be all of them)
for output in desired_output:
    for dist in bayesianNetwork.discreteDistributions:
        #print(dist.name)
        rowdict = {} 
        rowdict["leaves"]= dist.name
        rowdict["internal"]=""
        rowdict["output"]= output
        rows_list.append(rowdict)
    for table in bayesianNetwork.conditionalProbabilityTables:
        #print ("table: {}".format(table.name))
        rowdict = {}
        rowdict["leaves"]=""
        internal_str = table.name + " ("
        for var in table.randomVariables:
            #print(var.name)
            internal_str += var.name
            internal_str+= ","         
        internal_str=internal_str[:-1]+")"
        rowdict["internal"] = internal_str
        rowdict["output"]= output
        rows_list.append(rowdict)
for dist in bayesianNetwork.discreteDistributions:
    #print(dist.name)
    rowdict = {} 
    rowdict["leaves"]= dist.name
    rowdict["internal"]=""
    rowdict["output"]= ""
    rows_list.append(rowdict)
for table in bayesianNetwork.conditionalProbabilityTables:
    #print ("table: {}".format(table.name))
    rowdict = {}
    rowdict["leaves"]=""
    internal_str = table.name + " ("
    for var in table.randomVariables:
        #print(var.name)
        internal_str += var.name
        internal_str+= ","         
    internal_str=internal_str[:-1]+")"
    rowdict["internal"] = internal_str
    rowdict["output"]= ""
    rows_list.append(rowdict) 
#
df = pd.DataFrame(rows_list)      
# df.to_csv(outname, index = False)

# %%
# Another csv that uses a utility function to express the net in  a tree form, in a data frame and then prints it out
df = make_tree(bayesianNetwork)
# df.to_csv("tree.csv" , index = False)

# %%
G = nx.DiGraph()
regex = re.compile(r'^([a-z_]*)\(.*')
for index, row in df.iterrows():
    for col in df.columns:
        if row[col] is not None:
            node = row[col][:-1] if col == "level0" else row[col]
            G.add_node(node)           
for node1 in G.nodes:
    for node2 in G.nodes:
        match = regex.match(node1)
        if (node1+',' in node2) or (match is not None and match.group(1)+"," in node2): 
            G.add_edge(node1,node2)
            if match is not None and match.group(1)+"," in node2:
                print (node1)
                print(node2)
# Out:
# angina(age)
# reported_heart_symptoms(daily_asprin_prescription,daily_aspirin_compliance,angina,chest_pain,blood_relative_heart_attack_before_age_50)
# daily_asprin_prescription(angina)
# reported_heart_symptoms(daily_asprin_prescription,daily_aspirin_compliance,angina,chest_pain,blood_relative_heart_attack_before_age_50)
# lack_of_exercise(lack_of_exercise_signal,lack_of_exercise_reported)
# sleep_anomaly(lack_of_exercise,oxygen_anomaly)
# obesity(bmi,obesity_factors)
# oxygen_anomaly(obesity,heart_rate_anomaly)
# obesity(bmi,obesity_factors)
# inflammation_from_illness(blood_illness_indicators,obesity,asthma_attack_last_year,fatiqued_in_2_weeks)
# obesity(bmi,obesity_factors)
# cardiovascular_disease_from_behavior(age,obesity,daily_time_sitting,workday_sleep_hours_per_night,daily_fruit_vegetable_servings)
# poor_sleep(poor_sleep_schedule,sleep_anomaly)
# inflammation_from_behavior(uv_exposure,poor_oral_health,toxin_labs,poor_sleep,lack_of_exercise)
# poor_sleep(poor_sleep_schedule,sleep_anomaly)
# hallmark_3_epigenetic_alterations(liver_disorders,poor_sleep,folate_labs,frailty)
# inflammation_from_behavior(uv_exposure,poor_oral_health,toxin_labs,poor_sleep,lack_of_exercise)
# inflammation(c_reactive_protein,inflammation_from_behavior,inflammation_from_diet,fake_variable)
# inflammation(c_reactive_protein,inflammation_from_behavior,inflammation_from_diet,fake_variable)
# psychological_disorders(anxious_how_often,marital_status,inflammation,heart_rate_variability_anomaly)
# inflammation(c_reactive_protein,inflammation_from_behavior,inflammation_from_diet,fake_variable)
# hallmark_10_extracellular_matrix_dysfunction(cancer,inflammation,cardiovascular_disease,hypertension)
# hypertension_from_behavior(daily_time_sitting,workday_sleep_hours_per_night,dietary_sodium,inflammation)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# kidney_disease(blood_kidney_disorder_indicators,hypertension,obesity)
# kidney_disease(blood_kidney_disorder_indicators,hypertension,obesity)
# lung_or_kidney_or_liver_disease(lung_disease,kidney_disease,liver_disorders)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# metabolic_disease(cardiovascular_disease,diabetes,hypertension)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# hallmark_10_extracellular_matrix_dysfunction(cancer,inflammation,cardiovascular_disease,hypertension)
# metabolic_disease(cardiovascular_disease,diabetes,hypertension)
# comorbidities(chronic_conditions,metabolic_disease,obesity)
# comorbidities(chronic_conditions,metabolic_disease,obesity)
# frailty(how_healthy_diet,dietary_d,frailty_measures,comorbidities,hallmark_1_genomic_instability)
# frailty(how_healthy_diet,dietary_d,frailty_measures,comorbidities,hallmark_1_genomic_instability)
# hallmark_8_stem_cell_exhaustion(frailty,inflammation)
# cancer(cancer_from_behavior,micro_nucleus_frequency,hallmark_2_telomere_attrition,age,hallmark_1_genomic_instability,hallmark_3_epigenetic_alterations)
# hallmark_7_cellular_senescence(cancer,inflammation)
# cancer(cancer_from_behavior,micro_nucleus_frequency,hallmark_2_telomere_attrition,age,hallmark_1_genomic_instability,hallmark_3_epigenetic_alterations)
# hallmark_9_altered_intercellular_communication(cancer,inflammation)
# cancer(cancer_from_behavior,micro_nucleus_frequency,hallmark_2_telomere_attrition,age,hallmark_1_genomic_instability,hallmark_3_epigenetic_alterations)
# hallmark_10_extracellular_matrix_dysfunction(cancer,inflammation,cardiovascular_disease,hypertension)
# greatest_weight(weight_at_25)
# weight(greatest_weight,bmi)
# teeth_health(times_brush_teeth_daily,floss_days_per_week)
# poor_oral_health(teeth_health,gum_disease,floss_days_per_week,times_brush_teeth_daily,mouth_pain_last_year)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# c_reactive_protein(ten_minutes_daily_workout,nigella_sativa_supplementation,coq10_supplementation,inflammation_from_illness)
# inflammation(c_reactive_protein,inflammation_from_behavior,inflammation_from_diet,fake_variable)
# c_reactive_protein(ten_minutes_daily_workout,nigella_sativa_supplementation,coq10_supplementation,inflammation_from_illness)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# frailty_measures(inactivated_sirtuins,micro_nucleus_frequency,hallmark_2_telomere_attrition,frailty_signs)
# frailty(how_healthy_diet,dietary_d,frailty_measures,comorbidities,hallmark_1_genomic_instability)
# psychological_disorders(anxious_how_often,marital_status,inflammation,heart_rate_variability_anomaly)
# age_acceleration_from_behavior(psychological_disorders,smoking,alcohol_consumption_last_year,marital_status)
# age_acceleration_from_behavior(psychological_disorders,smoking,alcohol_consumption_last_year,marital_status)
# age_acceleration(age_acceleration_from_nutrition,age_acceleration_from_movement,age_acceleration_from_behavior,workday_sleep_hours_per_night)
# lung_or_kidney_or_liver_disease(lung_disease,kidney_disease,liver_disorders)
# chronic_conditions(lung_or_kidney_or_liver_disease,immunocompromised,psychological_disorders)
# chronic_conditions(lung_or_kidney_or_liver_disease,immunocompromised,psychological_disorders)
# comorbidities(chronic_conditions,metabolic_disease,obesity)
# chest_pain(angina)
# reported_heart_symptoms(daily_asprin_prescription,daily_aspirin_compliance,angina,chest_pain,blood_relative_heart_attack_before_age_50)
# gum_disease(times_brush_teeth_daily,floss_days_per_week)
# mouth_pain_last_year(gum_disease,teeth_health)
# gum_disease(times_brush_teeth_daily,floss_days_per_week)
# poor_oral_health(teeth_health,gum_disease,floss_days_per_week,times_brush_teeth_daily,mouth_pain_last_year)
# blood_metabolism_disorder_indicators(total_cholesterol,triglycerides,a1c,direct_HDL)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# blood_metabolism_disorder_indicators(total_cholesterol,triglycerides,a1c,direct_HDL)
# inflammation_from_diet(omega_3,poor_diet,blood_metabolism_disorder_indicators,dietary_carbohydrate,water_drank_yesterday)
# poor_oral_health(teeth_health,gum_disease,floss_days_per_week,times_brush_teeth_daily,mouth_pain_last_year)
# inflammation_from_behavior(uv_exposure,poor_oral_health,toxin_labs,poor_sleep,lack_of_exercise)
# inflammation_from_diet(omega_3,poor_diet,blood_metabolism_disorder_indicators,dietary_carbohydrate,water_drank_yesterday)
# inflammation(c_reactive_protein,inflammation_from_behavior,inflammation_from_diet,fake_variable)
# diabetes(diabetes_from_behavior,a1c,age,hypertension)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# diabetes(diabetes_from_behavior,a1c,age,hypertension)
# metabolic_disease(cardiovascular_disease,diabetes,hypertension)
# diabetes(diabetes_from_behavior,a1c,age,hypertension)
# mitochondrial_dysfunction_or_cellular_senescence(diabetes,hallmark_6_mitochondrial_dysfunction,hallmark_7_cellular_senescence)
# weight(greatest_weight,bmi)
# weight(greatest_weight,bmi)
# weight(greatest_weight,bmi)
# sarcopenia_function(chore_difficulty,social_activity_difficulty,work_limiting_problem,birth_weight,lack_of_exercise)
# resting_heart_rate(heart_rate_anomaly,lack_of_exercise)
# signal_heart_disorder_indicators(resting_heart_rate,heart_rate_variability_anomaly,heart_rate_anomaly)
# poor_diet(low_socioeconomic_status,diet_quality,poor_diet_flag)
# inflammation_from_diet(omega_3,poor_diet,blood_metabolism_disorder_indicators,dietary_carbohydrate,water_drank_yesterday)
# poor_diet(low_socioeconomic_status,diet_quality,poor_diet_flag)
# cancer_from_behavior(soy_isoflavones_supplementation,daily_time_sitting,uv_exposure,poor_diet,smoking)
# lung_disease(soy_isoflavones_supplementation,daily_plant_protein_servings,micro_nucleus_frequency)
# lung_or_kidney_or_liver_disease(lung_disease,kidney_disease,liver_disorders)
# poor_diet_quantity(poor_diet_substances,poor_diet_supplements,poor_diet_basics)
# poor_diet_flag(poor_diet_quantity,poor_diet_food)
# diet_quality(diet_quantity,diet_quality_food)
# poor_diet(low_socioeconomic_status,diet_quality,poor_diet_flag)
# sarcopenia(age,sarcopenia_reported,frailty_signals,lack_of_exercise)
# frailty_signs(general_aging_signs,sarcopenia,blood_age_indicators)
# lack_of_exercise_signal(workout_anomaly,walking_speed_anomaly,steps_anomaly)
# lack_of_exercise(lack_of_exercise_signal,lack_of_exercise_reported)
# sarcopenia_reported(sarcopenia_movement,sarcopenia_function)
# sarcopenia(age,sarcopenia_reported,frailty_signals,lack_of_exercise)
# inactivated_sirtuins(dietary_energy,diet_quality)
# frailty_measures(inactivated_sirtuins,micro_nucleus_frequency,hallmark_2_telomere_attrition,frailty_signs)
# cancer_from_behavior(soy_isoflavones_supplementation,daily_time_sitting,uv_exposure,poor_diet,smoking)
# cancer(cancer_from_behavior,micro_nucleus_frequency,hallmark_2_telomere_attrition,age,hallmark_1_genomic_instability,hallmark_3_epigenetic_alterations)
# workday_sleep_hours_per_night(ten_minutes_daily_workout)
# obesity_factors(daily_time_sitting,workday_sleep_hours_per_night,cumin_supplementation,dietary_energy,lack_of_exercise)
# workday_sleep_hours_per_night(ten_minutes_daily_workout)
# hypertension_from_behavior(daily_time_sitting,workday_sleep_hours_per_night,dietary_sodium,inflammation)
# workday_sleep_hours_per_night(ten_minutes_daily_workout)
# cardiovascular_disease_from_behavior(age,obesity,daily_time_sitting,workday_sleep_hours_per_night,daily_fruit_vegetable_servings)
# workday_sleep_hours_per_night(ten_minutes_daily_workout)
# poor_sleep_schedule(work_schedule,workday_sleep_hours_per_night,weekend_sleep_hours_per_night)
# workday_sleep_hours_per_night(ten_minutes_daily_workout)
# diabetes_from_behavior(dietary_caffeine,daily_time_sitting,workday_sleep_hours_per_night,bmi)
# reported_heart_symptoms(daily_asprin_prescription,daily_aspirin_compliance,angina,chest_pain,blood_relative_heart_attack_before_age_50)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# cardiovascular_disease_from_behavior(age,obesity,daily_time_sitting,workday_sleep_hours_per_night,daily_fruit_vegetable_servings)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# dna_methylation(dietary_folate,age)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# dna_methylation(dietary_folate,age)
# a1c(micro_nucleus_frequency,nigella_sativa_supplementation,ginger_supplementation,dna_methylation,fasting_glucose)
# dna_methylation(dietary_folate,age)
# LDL(garlic_supplementation,nigella_sativa_supplementation,dna_methylation,age)
# dietary_sodium(salt_how_often)
# hypertension_from_behavior(daily_time_sitting,workday_sleep_hours_per_night,dietary_sodium,inflammation)
# dietary_sodium(salt_how_often)
# poor_diet_substances(dietary_caffeine,dietary_sodium,alcohol_consumption_last_year,num_alcoholic_drinks_when_drinking)
# dietary_sodium(salt_how_often)
# diet_substances(dietary_caffeine,dietary_sodium,alcohol_consumption_last_year,num_alcoholic_drinks_when_drinking)
# low_socioeconomic_status(low_socioeconomic_status_health,low_socioeconomic_status_demography)
# poor_diet(low_socioeconomic_status,diet_quality,poor_diet_flag)
# diet_quantity(diet_substances,diet_supplements,diet_basics)
# poor_diet_flag(poor_diet_quantity,poor_diet_food)
# diet_quantity(diet_substances,diet_supplements,diet_basics)
# diet_quality(diet_quantity,diet_quality_food)
# floss_days_per_week(times_brush_teeth_daily,last_dentist_visit)
# poor_oral_health(teeth_health,gum_disease,floss_days_per_week,times_brush_teeth_daily,mouth_pain_last_year)
# age_acceleration_from_movement(daily_time_sitting,steps_anomaly,walking_speed_anomaly,lack_of_exercise)
# age_acceleration(age_acceleration_from_nutrition,age_acceleration_from_movement,age_acceleration_from_behavior,workday_sleep_hours_per_night)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# cardiovascular_disease(cardiovascular_disease_from_behavior,micro_nucleus_frequency,heart_disorder_indicators,diabetes,hypertension)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# cancer(cancer_from_behavior,micro_nucleus_frequency,hallmark_2_telomere_attrition,age,hallmark_1_genomic_instability,hallmark_3_epigenetic_alterations)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# frailty_measures(inactivated_sirtuins,micro_nucleus_frequency,hallmark_2_telomere_attrition,frailty_signs)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# cognitive_impairment(micro_nucleus_frequency,workday_sleep_hours_per_night)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# a1c(micro_nucleus_frequency,nigella_sativa_supplementation,ginger_supplementation,dna_methylation,fasting_glucose)
# poor_diet_substances(dietary_caffeine,dietary_sodium,alcohol_consumption_last_year,num_alcoholic_drinks_when_drinking)
# poor_diet_quantity(poor_diet_substances,poor_diet_supplements,poor_diet_basics)
# total_cholesterol(garlic_supplementation,dietary_cholesterol)
# blood_metabolism_disorder_indicators(total_cholesterol,triglycerides,a1c,direct_HDL)
# liver_disorders(severe_blood_liver_disorder_indicators,blood_mild_liver_disorder_indicators,liver_condition)
# hallmark_3_epigenetic_alterations(liver_disorders,poor_sleep,folate_labs,frailty)
# times_brush_teeth_daily(last_dentist_visit)
# teeth_health(times_brush_teeth_daily,floss_days_per_week)
# times_brush_teeth_daily(last_dentist_visit)
# gum_disease(times_brush_teeth_daily,floss_days_per_week)
# times_brush_teeth_daily(last_dentist_visit)
# poor_oral_health(teeth_health,gum_disease,floss_days_per_week,times_brush_teeth_daily,mouth_pain_last_year)
# times_brush_teeth_daily(last_dentist_visit)
# floss_days_per_week(times_brush_teeth_daily,last_dentist_visit)
# reported_hypertension(diastolic,systolic,medicated_hypertension)
# hypertension(hypertension_from_behavior,c_reactive_protein,dna_methylation,reported_hypertension,age)
# diet_substances(dietary_caffeine,dietary_sodium,alcohol_consumption_last_year,num_alcoholic_drinks_when_drinking)
# poor_diet_quantity(poor_diet_substances,poor_diet_supplements,poor_diet_basics)
# diet_substances(dietary_caffeine,dietary_sodium,alcohol_consumption_last_year,num_alcoholic_drinks_when_drinking)
# diet_quantity(diet_substances,diet_supplements,diet_basics)
# smoking(second_hand_smoke,five_days_smoke_cigarettes,ever_vaped,cotinine)
# age_acceleration_from_behavior(psychological_disorders,smoking,alcohol_consumption_last_year,marital_status)
# smoking(second_hand_smoke,five_days_smoke_cigarettes,ever_vaped,cotinine)
# micro_nucleus_frequency(daily_fruit_vegetable_servings,smoking,age)
# smoking(second_hand_smoke,five_days_smoke_cigarettes,ever_vaped,cotinine)
# hallmark_2_telomere_attrition(smoking,gender)
# toxin_labs(toxic_metal_labs,toxic_compound_labs)
# inflammation_from_behavior(uv_exposure,poor_oral_health,toxin_labs,poor_sleep,lack_of_exercise)
# blood_age_indicators(red_blood_age_indicators,white_blood_age_indicators)
# hallmark_1_genomic_instability(blood_age_indicators,age,poor_diet)
# blood_age_indicators(red_blood_age_indicators,white_blood_age_indicators)
# blood_age_indicators(red_blood_age_indicators,white_blood_age_indicators)
# poor_sleep_schedule(work_schedule,workday_sleep_hours_per_night,weekend_sleep_hours_per_night)
# poor_sleep(poor_sleep_schedule,sleep_anomaly)
# heart_rate_variability_anomaly(heart_rate_anomaly)
# signal_heart_disorder_indicators(resting_heart_rate,heart_rate_variability_anomaly,heart_rate_anomaly)
# low_socioeconomic_status_health(low_socioeconomic_status_health_insurance,low_socioeconomic_status_healthcare)
# low_socioeconomic_status(low_socioeconomic_status_health,low_socioeconomic_status_demography)
# blood_illness_indicators(nucleated_red_blood_cells,globulin,white_blood_cell_count)
# inflammation_from_illness(blood_illness_indicators,obesity,asthma_attack_last_year,fatiqued_in_2_weeks)
# poor_diet_minerals(poor_diet_minerals_1,poor_diet_minerals_2)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# blood_heart_disorder_indicators(creatine_phosphokinase,sodium,chloride)
# heart_disorder_indicators(blood_heart_disorder_indicators,blood_metabolism_disorder_indicators,reported_heart_symptoms,signal_heart_disorder_indicators)
# poor_diet_vitamin_b(poor_diet_vitamin_b_1,poor_diet_vitamin_b_2)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# blood_mild_liver_disorder_indicators(alkaline_phosphatase,aspartate_aminotransferase,alanine_aminotransferase)
# liver_disorders(severe_blood_liver_disorder_indicators,blood_mild_liver_disorder_indicators,liver_condition)
# poor_diet_fats(omega_3,dietary_fat,dietary_cholesterol)
# poor_diet_food(poor_diet_fats,poor_diet_vitamins_and_minerals)
# severe_blood_liver_disorder_indicators(bilirubin,total_protein,gamma_glutamyl_transferase)
# liver_disorders(severe_blood_liver_disorder_indicators,blood_mild_liver_disorder_indicators,liver_condition)
# diet_minerals(diet_minerals_1,diet_minerals_2)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# diet_minerals(diet_minerals_1,diet_minerals_2)
# diet_vitamins_and_minerals(diet_minerals,diet_vitamin_a,diet_vitamin_b,diet_vitamin_other)
# blood_kidney_disorder_indicators(creatinine,albumin_creatinine_ratio,uric_acid,blood_urea_nitrogen)
# kidney_disease(blood_kidney_disorder_indicators,hypertension,obesity)
# diet_vitamin_b(diet_vitamin_b_1,diet_vitamin_b_2)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# diet_vitamin_b(diet_vitamin_b_1,diet_vitamin_b_2)
# diet_vitamins_and_minerals(diet_minerals,diet_vitamin_a,diet_vitamin_b,diet_vitamin_other)
# general_aging_signs(urine_leakage_bother,osteoporosis,artificial_joints,dental_bone_loss,hearing_difficulty)
# frailty_signs(general_aging_signs,sarcopenia,blood_age_indicators)
# uv_exposure(sun_exposure_half_hour,time_spent_outdoors,sun_exposure_use_sunscreen,sunburn_last_year)
# inflammation_from_behavior(uv_exposure,poor_oral_health,toxin_labs,poor_sleep,lack_of_exercise)
# uv_exposure(sun_exposure_half_hour,time_spent_outdoors,sun_exposure_use_sunscreen,sunburn_last_year)
# cancer_from_behavior(soy_isoflavones_supplementation,daily_time_sitting,uv_exposure,poor_diet,smoking)
# folate_labs(folate,folate_mefox)
# hallmark_3_epigenetic_alterations(liver_disorders,poor_sleep,folate_labs,frailty)
# folate_labs(folate,folate_mefox)
# vitamin_and_mineral_labs(vitamin_C,folate_labs,mineral_labs,iron_labs)
# diabetes_from_behavior(dietary_caffeine,daily_time_sitting,workday_sleep_hours_per_night,bmi)
# diabetes(diabetes_from_behavior,a1c,age,hypertension)
# mineral_labs(cobalt,manganese,chromium,selenium)
# vitamin_and_mineral_labs(vitamin_C,folate_labs,mineral_labs,iron_labs)
# toxic_metal_labs(lead,mercury,cadmium)
# toxin_labs(toxic_metal_labs,toxic_compound_labs)
# red_blood_age_indicators(mchc,red_cell_distribution_width,hemoglobin,mean_cell_volume)
# blood_age_indicators(red_blood_age_indicators,white_blood_age_indicators)
# low_socioeconomic_status_health_insurance(have_health_insurance,prescription_health_insurance)
# low_socioeconomic_status_health(low_socioeconomic_status_health_insurance,low_socioeconomic_status_healthcare)
# poor_diet_vitamin_a(dietary_retinol,dietary_alpha_carotene,dietary_beta_carotene)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# poor_diet_vitamin_other(dietary_vitamin_C,dietary_alpha_tocopherol,dietary_calcium)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# poor_diet_supplements(dietary_lycopene,dietary_lutein,dietary_selenium,dietary_choline)
# poor_diet_quantity(poor_diet_substances,poor_diet_supplements,poor_diet_basics)
# diet_vitamin_a(dietary_retinol,dietary_alpha_carotene,dietary_beta_carotene)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# diet_vitamin_a(dietary_retinol,dietary_alpha_carotene,dietary_beta_carotene)
# diet_vitamins_and_minerals(diet_minerals,diet_vitamin_a,diet_vitamin_b,diet_vitamin_other)
# diet_vitamin_other(dietary_vitamin_C,dietary_alpha_tocopherol,dietary_calcium)
# poor_diet_vitamins_and_minerals(poor_diet_minerals,poor_diet_vitamin_a,poor_diet_vitamin_b,poor_diet_vitamin_other,vitamin_and_mineral_labs)
# diet_fats(dietary_epa,dietary_pfa,dietary_fat,dietary_cholesterol)
# poor_diet_food(poor_diet_fats,poor_diet_vitamins_and_minerals)
# diet_fats(dietary_epa,dietary_pfa,dietary_fat,dietary_cholesterol)
# diet_quality_food(how_healthy_diet,eat_out_how_many_times_per_week,diet_fats,diet_vitamins_and_minerals)
# diet_supplements(dietary_lycopene,dietary_lutein,dietary_selenium,dietary_choline)
# poor_diet_quantity(poor_diet_substances,poor_diet_supplements,poor_diet_basics)
# diet_supplements(dietary_lycopene,dietary_lutein,dietary_selenium,dietary_choline)
# diet_quantity(diet_substances,diet_supplements,diet_basics)
# age_acceleration_from_nutrition(daily_fruit_vegetable_servings,daily_wholegrain_servings,weekly_nut_servings,weekly_fish_servings,weekly_processed_meat_servings)
# age_acceleration(age_acceleration_from_nutrition,age_acceleration_from_movement,age_acceleration_from_behavior,workday_sleep_hours_per_night)
# sarcopenia_movement(walking_difficulty,two_hour_standing_difficulty,stand_from_sit_difficulty,ten_stairs_difficulty,two_hour_sitting_difficulty)
# sarcopenia_reported(sarcopenia_movement,sarcopenia_function)
# frailty_signals(step_variability_anomaly,double_support_stepping_anomaly,step_asymmetry_anomaly,stride_variability_anomaly,walking_speed_variability_anomaly)
# sarcopenia(age,sarcopenia_reported,frailty_signals,lack_of_exercise)

# %% [raw]
# plt.figure(3,figsize=(12,12))
# #nx.draw(G, with_labels=True)
# #nx.draw_random(G, with_labels=True)
# nx.draw_circular(G, with_labels=True)
# #nx.draw_spectral(G, with_labels=True)
# #nx.draw_spring(G, with_labels=True)

# %% [raw]
# # Description of the Bayesian network in protobuf that we just created with the running
# # of the python file.  The "leaves" have initial probabilities (DiscreteDistribution),
# # and the conditional probabilities (ConditionalProbabilityTable) are to be computed:
# bayesianNetwork

# %%
# Pomegranate net we just made with the description. Compile the net so we can compute probabilities with it.
longevity = bayesInitialize(bayesianNetwork)
#
longevity.bake()
# Calls a Pomegranate routine that shows the computed probabilities of every variable. 
longevity.predict_proba({}) # We have our own utility that pulls out particular variables.
# Out:
# array([{
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "fake_variable_1" : 0.04999999717381816,
#                    "fake_variable_2" : 0.25000005288880306,
#                    "fake_variable_3" : 0.2999997861930073,
#                    "fake_variable_4" : 0.20000016274835297,
#                    "fake_variable_5" : 0.20000000099601853
#                }
#            ],
#            "frozen" : false
#        }                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "elderly" : 0.04996686518206734,
#                    "adult" : 0.24996741459510588,
#                    "young_adult" : 0.30006699469307413,
#                    "teen" : 0.1999993644402695,
#                    "child" : 0.19999936108948324
#                }
#            ],
#            "frozen" : false
#        }                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "daily_aspirin_compliance_no" : 0.30000001474153526,
#                    "daily_aspirin_compliance_yes" : 0.6999999852584647
#                }
#            ],
#            "frozen" : false
#        }                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "high_blood_pressure_patient_prescription_yes" : 0.14991550717565108,
#                    "high_blood_pressure_patient_prescription_no" : 0.8500844928243488
#                }
#            ],
#            "frozen" : false
#        }                                                                                ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "high_blood_pressure_medication_compliance_no" : 0.2698935353346,
#                    "high_blood_pressure_medication_compliance_yes" : 0.7301064646654
#                }
#            ],
#            "frozen" : false
#        }                                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "diastolic_120_or_higher_crisis" : 0.009989234017310882,
#                    "diastolic_90_to_119_high_stage_2" : 0.05993633062062136,
#                    "diastolic_80_to_89_high_stage_1" : 0.1699099561695418,
#                    "diastolic_less_than_80_normal" : 0.7601644791925259
#                }
#            ],
#            "frozen" : false
#        }                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "systolic_180_over_crisis" : 0.0199797259840648,
#                    "systolic_140_to_179_high_stage_2" : 0.17985828506643128,
#                    "systolic_130_to_139_high_stage_1" : 0.1399804843300055,
#                    "systolic_120_to_129_elevated" : 0.1599811213536949,
#                    "systolic_less_than_120_normal" : 0.5002003832658036
#                }
#            ],
#            "frozen" : false
#        }                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "sun_exposure_half_hour_severe_sunburn_blisters" : 0.019999989832878463,
#                    "sun_exposure_half_hour_severe_sunburn_peeling" : 0.07999995933151252,
#                    "sun_exposure_half_hour_mild_burn_tanning" : 0.21999989188694719,
#                    "sun_exposure_half_hour_darker_no_burn" : 0.2400000534699105,
#                    "sun_exposure_half_hour_no_tan_or_burn" : 0.44000010547875124,
#                    "" : 0.0
#                }
#            ],
#            "frozen" : false
#        }                                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "time_spent_outdoors_none" : 0.20999992127924078,
#                    "time_spent_outdoors_a_half_hour_per_day" : 0.1599999414414365,
#                    "time_spent_outdoors_1_hour_per_day" : 0.1599999414414365,
#                    "time_spent_outdoors_2_or_3_hours_per_day" : 0.18000007690402026,
#                    "time_spent_outdoors_4_to_6_hours_per_day" : 0.11000004202984576,
#                    "time_spent_outdoors_7_or_more_hours_per_day" : 0.18000007690402026
#                }
#            ],
#            "frozen" : false
#        }                                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "sun_exposure_use_sunscreen_never" : 0.3999999108556602,
#                    "sun_exposure_use_sunscreen_rarely" : 0.17999996435539461,
#                    "sun_exposure_use_sunscreen_sometimes" : 0.2100000202839432,
#                    "sun_exposure_use_sunscreen_most_of_the_time" : 0.12000005652403643,
#                    "sun_exposure_use_sunscreen_always" : 0.09000004798096563
#                }
#            ],
#            "frozen" : false
#        }                                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "sunburn_last_year_yes" : 0.3299998416215648,
#                    "sunburn_last_year_no" : 0.6700001583784351
#                }
#            ],
#            "frozen" : false
#        }                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "weight_at_25_above_300.00" : 0.04999999995863677,
#                    "weight_at_25_above_180.00_to_300.00_and_below" : 0.199999999833079,
#                    "weight_at_25_above_150.00_to_180.00_and_below" : 0.250000000069428,
#                    "weight_at_25_above_125.00_to_150.00_and_below" : 0.250000000069428,
#                    "weight_at_25_125.00_and_below" : 0.250000000069428
#                }
#            ],
#            "frozen" : false
#        }                                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "bmi_over_40_high_risk" : 0.07999640916764782,
#                    "bmi_35_to_39_moderate_risk" : 0.09999622016965404,
#                    "bmi_30_to_34_low_risk" : 0.19999973859164727,
#                    "bmi_25_to_29_overweight" : 0.30000299161178,
#                    "bmi_under_25_healthy" : 0.32000464045927085
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "dietary_energy_above_3939.00" : 0.04999949625392475,
#                    "dietary_energy_above_2612.00_to_3939.00_and_below" : 0.19999868218369074,
#                    "dietary_energy_above_1930.00_to_2612.00_and_below" : 0.25000193329490145,
#                    "dietary_energy_above_1399.00_to_1930.00_and_below" : 0.2500023258306245,
#                    "dietary_energy_1399.00_and_below" : 0.24999756243685867
#                }
#            ],
#            "frozen" : false
#        }                                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "shortness_of_breath_exertion_yes" : 0.3799990761306549,
#                    "shortness_of_breath_exertion_no" : 0.6200009238693451
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "daily_walk_or_bicycle_travel_less_than_30_minutes" : 0.33999970054546536,
#                    "daily_walk_or_bicycle_travel_30_to_59_minutes" : 0.3000001361156976,
#                    "daily_walk_or_bicycle_travel_60_minutes_or_more" : 0.36000016333883705
#                }
#            ],
#            "frozen" : false
#        }                                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "daily_time_sitting_12_or_more_hours" : 0.08079325009070619,
#                    "daily_time_sitting_over_6_but_less_than_12_hours" : 0.3636432350619233,
#                    "daily_time_sitting_over_2_but_less_than_6_hours" : 0.49495618858518353,
#                    "daily_time_sitting_less_than_2_hours" : 0.060607326262186845
#                }
#            ],
#            "frozen" : false
#        }                                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "physical_work_no" : 0.7599998952797686,
#                    "physical_work_yes" : 0.2400001047202313
#                }
#            ],
#            "frozen" : false
#        }                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "ten_minutes_daily_workout_no" : 0.5999826227425853,
#                    "ten_minutes_daily_workout_yes" : 0.40001737725741476
#                }
#            ],
#            "frozen" : false
#        }                                                                ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "heart_rate_anomaly" : 0.029999998858495597,
#                    "no_heart_rate_anomaly" : 0.9700000011415044
#                }
#            ],
#            "frozen" : false
#        }                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "steps_anomaly" : 0.04999992326401926,
#                    "no_steps_anomaly" : 0.9500000767359807
#                }
#            ],
#            "frozen" : false
#        }                                                  ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "workout_anomaly" : 0.04999992305196908,
#                    "no_workout_anomaly" : 0.9500000769480309
#                }
#            ],
#            "frozen" : false
#        }                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "walking_speed_anomaly" : 0.04999992371332587,
#                    "no_walking_speed_anomaly" : 0.950000076286674
#                }
#            ],
#            "frozen" : false
#        }                                                         ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "walking_speed_variability_anomaly" : 0.050000001619041196,
#                    "no_walking_speed_variability_anomaly" : 0.9499999983809587
#                }
#            ],
#            "frozen" : false
#        }                                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "stride_variability_anomaly" : 0.050000001619041196,
#                    "no_stride_variability_anomaly" : 0.9499999983809587
#                }
#            ],
#            "frozen" : false
#        }                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "step_asymmetry_anomaly" : 0.050000001619041196,
#                    "no_step_asymmetry_anomaly" : 0.9499999983809587
#                }
#            ],
#            "frozen" : false
#        }                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "double_support_stepping__anomaly" : 0.05000000130385202,
#                    "no_double_support_stepping_anomaly" : 0.9499999986961479
#                }
#            ],
#            "frozen" : false
#        }                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "step_variability_anomaly" : 0.050000001619041196,
#                    "no_step_variability_anomaly" : 0.9499999983809587
#                }
#            ],
#            "frozen" : false
#        }                                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cumin_supplementation_yes" : 0.010000097925375467,
#                    "cumin_supplementation_no" : 0.9899999020746245
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "anxious_daily" : 0.15000000601810942,
#                    "anxious_weekly" : 0.1399999996146403,
#                    "anxious_monthly" : 0.11999999679870685,
#                    "anxious_a_few_times_per_year" : 0.3399999948024604,
#                    "anxious_never" : 0.250000002766083
#                }
#            ],
#            "frozen" : false
#        }                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "widowed" : 0.08000000065083457,
#                    "separated" : 0.040000000001391534,
#                    "divorced" : 0.11000000134640617,
#                    "never_married" : 0.18000001158602746,
#                    "living_with_partner_or_married" : 0.5899999864153402
#                }
#            ],
#            "frozen" : false
#        }                                                                ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "birth_weight_under_5_lbs" : 0.21649484136172595,
#                    "birth_weight_5_to_6_lbs" : 0.23711340938628803,
#                    "birth_weight_7_to_8_lbs" : 0.22680411790661753,
#                    "birth_weight_9_to_11_lbs" : 0.14432989753139155,
#                    "birth_weight_above_11_lbs" : 0.1752577338139769
#                }
#            ],
#            "frozen" : false
#        }                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "asthma_attack_last_year_yes" : 0.41413406794143287,
#                    "asthma_attack_last_year_no" : 0.5858659320585673
#                }
#            ],
#            "frozen" : false
#        }                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "liver_condition_yes" : 0.05000000155189996,
#                    "liver_condition_no" : 0.9499999984481
#                }
#            ],
#            "frozen" : false
#        }                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "fatiqued_in_2_weeks_nearly_everyday" : 0.07999798764063958,
#                    "fatiqued_in_2_weeks_more_than_half_the_days" : 0.08999774168351447,
#                    "fatiqued_in_2_weeks_several_days" : 0.3200016458074955,
#                    "fatiqued_in_2_weeks_none" : 0.5100026248683505
#                }
#            ],
#            "frozen" : false
#        }                                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "osteoporosis_yes" : 0.12999999690641562,
#                    "osteoporosis_no" : 0.8700000030935844
#                }
#            ],
#            "frozen" : false
#        }                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "artificial_joints_yes" : 0.30000001531844567,
#                    "artificial_joints_no" : 0.6999999846815543
#                }
#            ],
#            "frozen" : false
#        }                                                         ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "lymphocite_number_below_normal_under_1" : 0.008928571131335156,
#                    "lymphocite_number_low_normal_1_to 1.9" : 0.32142858068496294,
#                    "lymphocite_number_mid_normal_2_to_2.9" : 0.4196428514545552,
#                    "lymphocite_number_high_normal_3_to_4.8" : 0.12499999836457328,
#                    "lymphocite_number_above_normal_above_4.8" : 0.12499999836457328
#                }
#            ],
#            "frozen" : false
#        }                                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "mchc_34.6_and_above" : 0.139999998734185,
#                    "mchc_34.0_to_34.5" : 0.20000000032042994,
#                    "mchc_33.4_to_33.9" : 0.3000000074600046,
#                    "mchc_33.0_to_33.3" : 0.15999999379324448,
#                    "mchc_below_33" : 0.19999999969213594
#                }
#            ],
#            "frozen" : false
#        }                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "nucleated_red_blood_cells_high_0.2" : 0.0927815815502306,
#                    "nucleated_red_blood_cells_high_normal_0.1" : 0.5773208173269638,
#                    "nucleated_red_blood_cells_low_normal_0.0" : 0.32989760112280553
#                }
#            ],
#            "frozen" : false
#        }                                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "blood_urea_nitrogen_20.0_and_above" : 0.12000000036775084,
#                    "blood_urea_nitrogen_15.0_to_19.0" : 0.2800000025922904,
#                    "blood_urea_nitrogen_10.0_to_14" : 0.44999999032938826,
#                    "blood_urea_nitrogen_below_9.0" : 0.15000000671057057
#                }
#            ],
#            "frozen" : false
#        }                                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "chloride_normal_low_96.0_to_99.0" : 0.24489795545993473,
#                    "chloride_normal_medium_100.0_to_103.0" : 0.5714285779451137,
#                    "chloride_normal_high_104.0_to_106.0" : 0.16326530363995664,
#                    "chloride_high_above_106.0" : 0.020408162954994973
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "globulin_high_3.6 and_higher" : 0.13131039942144504,
#                    "globulin_3.1_to_3.5" : 0.38383958640279325,
#                    "globulin_2.6_TO_3.0" : 0.404041680988422,
#                    "globulin_low_2.5_and_below" : 0.08080833318733971
#                }
#            ],
#            "frozen" : false
#        }                                                                ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "bilirubin_0.6_and_above" : 0.25999999086060926,
#                    "bilirubin_0.4_to_0.5" : 0.3300000136173536,
#                    "bilirubin_0.3" : 0.2199999983240766,
#                    "bilirubin_below_0.2" : 0.18999999719796065
#                }
#            ],
#            "frozen" : false
#        }                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "total_protein_below_6.9" : 0.2200000021375572,
#                    "total_protein_6.9_to_7.1" : 0.25999999439829763,
#                    "total_protein_7.2_to_7.4" : 0.2800000053040385,
#                    "total_protein_7.5_and_above" : 0.23999999816010678
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "toxins_in_blood_above_0.006" : 0.07070707059304321,
#                    "toxins_in_blood_0.005_to_0.006" : 0.05050505096116234,
#                    "toxins_in_blood_0.004_and_below" : 0.8787878784457945
#                }
#            ],
#            "frozen" : false
#        }                                                                  ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "segmented_neutrophils_high_above_6" : 0.11999999669551559,
#                    "segmented_neutrophils_normal_2.5_to_6" : 0.7400000042367061,
#                    "segmented_neutrophils_low_under_2.5" : 0.1399999990677784
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cadmium_high_above_5" : 0.0,
#                    "cadmium_high_normal_2_to_5" : 0.01999999977648299,
#                    "cadmium_normal" : 0.22000000126659883,
#                    "cadmium_low" : 0.7599999989569179
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cobalt_high_above_0.3" : 0.09999999955232125,
#                    "cobalt_high_normal_0.12_to_0.3" : 0.7999999999999995,
#                    "cobalt_normal_below_0.12" : 0.10000000044767934
#                }
#            ],
#            "frozen" : false
#        }                                                                 ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "chromium_0.29_and_below" : 0.09090909140062689,
#                    "chromium_above_0.29_to_0.29_and_below" : 0.4545454542996865,
#                    "chromium_above_0.29" : 0.4545454542996865
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "mercury_above_4.04" : 0.04999986824475453,
#                    "mercury_above_1.07_to_4.04_and_below" : 0.20000003009076175,
#                    "mercury_above_0.42_to_1.07_and_below" : 0.2500000338881612,
#                    "mercury_above_0.18_to_0.42_and_below" : 0.2500000338881612,
#                    "mercury_0.18_and_below" : 0.2500000338881612
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "manganese_high_above_36.6" : 0.0,
#                    "manganese_normal_high_18.3_to_36.6" : 0.029999999180657606,
#                    "manganese_normal_4.7_to_below_18.3" : 0.940000001370077,
#                    "manganese_low_below_4.7" : 0.029999999449265072
#                }
#            ],
#            "frozen" : false
#        }                                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "lead_above_2.95" : 0.04999986824475454,
#                    "lead_above_1.38_to_2.95_and_below" : 0.20000003009076175,
#                    "lead_above_0.83_to_1.38_and_below" : 0.2500000338881612,
#                    "lead_above_0.48_to_0.83_and_below" : 0.2500000338881612,
#                    "lead_0.48_and_below" : 0.2500000338881612
#                }
#            ],
#            "frozen" : false
#        }                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "selenium_152.66_and_below" : 0.050000000278994455,
#                    "selenium_above_152.66_to_173.56_and_below" : 0.20000000111597652,
#                    "selenium_above_173.56_to_188.11_and_below" : 0.24999999878887783,
#                    "selenium_above_188.11_to_204.17_and_below" : 0.2499999999080756,
#                    "selenium_above_204.17" : 0.2499999999080756
#                }
#            ],
#            "frozen" : false
#        }                                                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cotinine_above_323.00" : 0.04999996816730425,
#                    "cotinine_above_1.01_to_323.00_and_below" : 0.1999998726692157,
#                    "cotinine_above_0.03_to_1.01_and_below" : 0.24999996667718866,
#                    "cotinine_above_0.01_to_0.03_and_below" : 0.2500000962431457,
#                    "cotinine_0.01_and_below" : 0.2500000962431457
#                }
#            ],
#            "frozen" : false
#        }                                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "eosinophils_percent_above_6.70" : 0.05000000066993035,
#                    "eosinophils_percent_above_3.50_to_6.70_and_below" : 0.20000000267972007,
#                    "eosinophils_percent_above_2.30_to_3.50_and_below" : 0.249999999586012,
#                    "eosinophils_percent_above_1.50_to_2.30_and_below" : 0.24999999853216887,
#                    "eosinophils_percent_1.50_and_below" : 0.24999999853216887
#                }
#            ],
#            "frozen" : false
#        }                                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "ferritin_low_below_11" : 0.05000000055879392,
#                    "ferritin_normal_11_to_336" : 0.8700000015273682,
#                    "ferritin_high_above_336" : 0.07999999791383777
#                }
#            ],
#            "frozen" : false
#        }                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hemoglobin_severe_amemia_below_8" : 0.0,
#                    "hemoglobin_moderate_amemia_8_tto_10" : 0.010204081606198782,
#                    "hemoglobin_slight_anemia_above_10_to_12" : 0.08163265259314066,
#                    "hemoglobin_normal_above_12" : 0.9081632658006603
#                }
#            ],
#            "frozen" : false
#        }                                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "serum_iron_35.00_and_below" : 0.04999999921392512,
#                    "serum_iron_above_35.00_to_61.00_and_below" : 0.20000000251830444,
#                    "serum_iron_above_61.00_to_82.00_and_below" : 0.24999999942259016,
#                    "serum_iron_above_82.00_to_106.00_and_below" : 0.24999999942259016,
#                    "serum_iron_above_106.00" : 0.24999999942259016
#                }
#            ],
#            "frozen" : false
#        }                                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "lymphocyte_18.00_and_below" : 0.05000000066993035,
#                    "lymphocyte_above_18.00_to_25.60_and_below" : 0.20000000267972004,
#                    "lymphocyte_above_25.60_to_31.30_and_below" : 0.24999999958601196,
#                    "lymphocyte_above_31.30_to_37.40_and_below" : 0.24999999853216878,
#                    "lymphocyte_above_37.40" : 0.24999999853216878
#                }
#            ],
#            "frozen" : false
#        }                                                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "mean_cell_volume_77.40_and_below" : 0.05000000065696477,
#                    "mean_cell_volume_above_77.40_to_84.80_and_below" : 0.20000000262785775,
#                    "mean_cell_volume_above_84.80_to_88.40_and_below" : 0.24999999916684817,
#                    "mean_cell_volume_above_88.40_to_91.70_and_below" : 0.24999999877416462,
#                    "mean_cell_volume_above_91.70" : 0.24999999877416462
#                }
#            ],
#            "frozen" : false
#        }                                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "segmented_neutrophils_percent_above_71.90" : 0.0500000006699304,
#                    "segmented_neutrophils_percent_above_63.10_to_71.90_and_below" : 0.20000000267972026,
#                    "segmented_neutrophils_percent_above_57.00_to_63.10_and_below" : 0.24999999958601196,
#                    "segmented_neutrophils_percent_above_50.40_to_57.00_and_below" : 0.24999999853216873,
#                    "segmented_neutrophils_percent_50.40_and_below" : 0.24999999853216873
#                }
#            ],
#            "frozen" : false
#        }                                                                                                ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "red_cell_distribution_width_above_16.30" : 0.050000000656964784,
#                    "red_cell_distribution_width_above_14.20_to_16.30_and_below" : 0.2000000026278578,
#                    "red_cell_distribution_width_above_13.50_to_14.20_and_below" : 0.24999999916684817,
#                    "red_cell_distribution_width_above_13.00_to_13.50_and_below" : 0.24999999877416465,
#                    "red_cell_distribution_width_13.00_and_below" : 0.24999999877416465
#                }
#            ],
#            "frozen" : false
#        }                                                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "alkaline_phosphatase_high_above_147" : 0.07000000256384865,
#                    "alkaline_phosphatase_normal_147_to_44" : 0.8999999973986849,
#                    "alkaline_phosphatase_low_below_44" : 0.030000000037466275
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "aspartate_aminotransferase_high_above_33" : 0.0700000003473009,
#                    "aspartate_aminotransferase_normal_8_to_33" : 0.929999999652699,
#                    "aspartate_aminotransferase_low_below_8" : 0.0
#                }
#            ],
#            "frozen" : false
#        }                                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "alanine_aminotransferase_high_above_36" : 0.11000000194008128,
#                    "alanine_aminotransferase_medium_4_to_36" : 0.8899999980599186,
#                    "alanine_aminotransferase_low_below_4" : 0.0
#                }
#            ],
#            "frozen" : false
#        }                                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "creatine_phosphokinase_high_above_192" : 0.23000000724000866,
#                    "creatine_phosphokinase_normal_26_to_192" : 0.7699999927599912,
#                    "creatine_phosphokinase_low_under_26" : 0.0
#                }
#            ],
#            "frozen" : false
#        }                                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "creatinine_high_above_1.2" : 0.07999999845702807,
#                    "creatinine_normal_0.6_to_1.2" : 0.7900000084515851,
#                    "creatinine_low_below_0.6" : 0.12999999309138674
#                }
#            ],
#            "frozen" : false
#        }                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "gamma_glutamyl_transferase_high_above_30" : 0.2500000060351784,
#                    "gamma_glutamyl_transferase_normal_30_to_10" : 0.7499999939648215,
#                    "gamma_glutamyl_transferase_low_below_10" : 0.0
#                }
#            ],
#            "frozen" : false
#        }                                                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "iron_36.00_and_below" : 0.049999999213925124,
#                    "iron_above_36.00_to_62.00_and_below" : 0.20000000251830446,
#                    "iron_above_62.00_to_83.00_and_below" : 0.24999999942259016,
#                    "iron_above_83.00_to_107.00_and_below" : 0.24999999942259016,
#                    "iron_above_107.00" : 0.24999999942259016
#                }
#            ],
#            "frozen" : false
#        }                                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "triglycerides_high_above_199" : 0.15999997642161262,
#                    "triglycerides_medium_199_to_150" : 0.13999999581368688,
#                    "triglycerides_low_below_150" : 0.7000000277647005
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "uric_acid_high_above_8.5" : 0.0300000005389729,
#                    "uric_acid_medium_2.7_to_8.5" : 0.9599999994665831,
#                    "uric_acid_low_below_2.7" : 0.009999999994444014
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "benzonitrile_above_0.17" : 0.06666666732894086,
#                    "benzonitrile_above_0.11_to_0.17_and_below" : 0.2666666693157619,
#                    "benzonitrile_above_0.11_to_0.11_and_below" : 0.3333333316776486,
#                    "benzonitrile_0.11_and_below" : 0.3333333316776486
#                }
#            ],
#            "frozen" : false
#        }                                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "vitamin_C_low_below_0.6" : 0.2799999967900719,
#                    "vitamin_C_medium_0.6_to_2" : 0.7000000032242434,
#                    "vitamin_C_high_above_2" : 0.019999999985684806
#                }
#            ],
#            "frozen" : false
#        }                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "white_blood_cell_count_low_below_3.4" : 0.010000030723680327,
#                    "white_blood_cell_count_normal_3.4_to_9.6" : 0.860002675764187,
#                    "white_blood_cell_count_high_above_9.6" : 0.12999729351213266
#                }
#            ],
#            "frozen" : false
#        }                                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "albumin_creatinine_ratio_high_above_300" : 0.019999999837774757,
#                    "albumin_creatinine_ratio_elevated_30_to_300" : 0.10999999895384065,
#                    "albumin_creatinine_ratio_normal_below_30" : 0.8700000012083846
#                }
#            ],
#            "frozen" : false
#        }                                                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "volitile_organic_compound_above_309028.71" : 0.05000000055879389,
#                    "volitile_organic_compound_above_93803.69_to_309028.71_and_below" : 0.20000000223517425,
#                    "volitile_organic_compound_above_51906.89_to_93803.69_and_below" : 0.24999999906867734,
#                    "volitile_organic_compound_above_29036.52_to_51906.89_and_below" : 0.24999999906867734,
#                    "volitile_organic_compound_29036.52_and_below" : 0.24999999906867734
#                }
#            ],
#            "frozen" : false
#        }                                                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "work_limiting_problem_yes" : 0.25999999263341833,
#                    "work_limiting_problem_no" : 0.7400000073665817
#                }
#            ],
#            "frozen" : false
#        }                                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "ten_stairs_difficulty_unable" : 0.010101009843173303,
#                    "ten_stairs_difficulty_much" : 0.030303029529519014,
#                    "ten_stairs_difficulty_some" : 0.15151515484677053,
#                    "ten_stairs_difficulty_none" : 0.8080808057805372
#                }
#            ],
#            "frozen" : false
#        }                                                                 ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "chore_difficulty_unable" : 0.030000000309973487,
#                    "chore_difficulty_much" : 0.07000000258591609,
#                    "chore_difficulty_some" : 0.2599999965143145,
#                    "chore_difficulty_none" : 0.640000000589796
#                }
#            ],
#            "frozen" : false
#        }                                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "walking_difficulty_unable" : 0.010000000139884741,
#                    "walking_difficulty_much" : 0.030000000419653335,
#                    "walking_difficulty_some" : 0.12999999806158435,
#                    "walking_difficulty_none" : 0.8300000013788775
#                }
#            ],
#            "frozen" : false
#        }                                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "stand_from_sit_difficulty_unable" : 0.01999999982502381,
#                    "stand_from_sit_difficulty_much" : 0.059999999475070544,
#                    "stand_from_sit_difficulty_some" : 0.23999999435169517,
#                    "stand_from_sit_difficulty_none" : 0.6800000063482105
#                }
#            ],
#            "frozen" : false
#        }                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "two_hour_standing_difficulty_unable" : 0.10000000187309618,
#                    "two_hour_standing_difficulty_much" : 0.15999999703648912,
#                    "two_hour_standing_difficulty_some" : 0.2700000076470676,
#                    "two_hour_standing_difficulty_none" : 0.46999999344334714
#                }
#            ],
#            "frozen" : false
#        }                                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "two_hour_sitting_difficulty_unable" : 0.01999999944828574,
#                    "two_hour_sitting_difficulty_much" : 0.07999999779314163,
#                    "two_hour_sitting_difficulty_some" : 0.2299999995459896,
#                    "two_hour_sitting_difficulty_none" : 0.670000003212583
#                }
#            ],
#            "frozen" : false
#        }                                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "social_activity_difficulty_unable" : 0.02999999885677784,
# ...
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "age_acceleration_from_nutrition" : 0.4998804973106839,
#                    "no_age_acceleration_from_nutrition" : 0.500119502689316
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_age_acceleration" : 0.6090383857167684,
#                    "age_acceleration" : 0.3909616142832317
#                }
#            ],
#            "frozen" : false
#        }                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hearing_difficulty" : 0.8115841516582195,
#                    "hearing_difficulty" : 0.1884158483417806
#                }
#            ],
#            "frozen" : false
#        }                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "general_aging_signs" : 0.2246932759110462,
#                    "no_general_aging_signs" : 0.7753067240889537
#                }
#            ],
#            "frozen" : false
#        }                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_sarcopenia_movement" : 0.8959191930526906,
#                    "sarcopenia_movement" : 0.1040808069473094
#                }
#            ],
#            "frozen" : false
#        }                                                         ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_sarcopenia_function" : 0.739753552966387,
#                    "sarcopenia_function" : 0.260246447033613
#                }
#            ],
#            "frozen" : false
#        }                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "sarcopenia_reported" : 0.02708666044959337,
#                    "no_sarcopenia_reported" : 0.9729133395504066
#                }
#            ],
#            "frozen" : false
#        }                                                        ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_frailty_signals" : 0.8145062443591276,
#                    "frailty_signals" : 0.18549375564087245
#                }
#            ],
#            "frozen" : false
#        }                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "sarcopenia" : 0.0699113108116587,
#                    "no_sarcpenia" : 0.9300886891883412
#                }
#            ],
#            "frozen" : false
#        }                                              ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "inactivated_sirtuins" : 0.8015747312781509,
#                    "no_inactivated_sirtuins" : 0.19842526872184912
#                }
#            ],
#            "frozen" : false
#        }                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_frailty_signs" : 0.8568915856123139,
#                    "frailty_signs" : 0.14310841438768598
#                }
#            ],
#            "frozen" : false
#        }                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hallmark_1_genomic_instability" : 0.09999759517120932,
#                    "no_hallmark_1_genomic_instability" : 0.9000024048287908
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hallmark_2_telomere_attrition" : 0.9000332353280492,
#                    "hallmark_2_telomere_attrition" : 0.09996676467195081
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_age_related_macular_degeneration" : 0.9749996372401752,
#                    "age_related_macular_degeneration" : 0.025000362759824764
#                }
#            ],
#            "frozen" : false
#        }                                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "diabetes_from_behavior" : 0.09999123734967366,
#                    "no_diabetes_from_behavior" : 0.9000087626503264
#                }
#            ],
#            "frozen" : false
#        }                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "diabetes" : 0.10942717469356013,
#                    "no_diabetes" : 0.8905728253064399
#                }
#            ],
#            "frozen" : false
#        }                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hallmark_6_mitochondrial_dysfunction" : 0.06901167524573124,
#                    "no_hallmark_6_mitochondrial_dysfunction" : 0.9309883247542687
#                }
#            ],
#            "frozen" : false
#        }                                                                         ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_cardiovascular_disease_from_behavior" : 0.9128740470542158,
#                    "cardiovascular_disease_from_behavior" : 0.08712595294578417
#                }
#            ],
#            "frozen" : false
#        }                                                                          ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cardiovascular_disease" : 0.0863791818882244,
#                    "no_cardiovascular_disease" : 0.9136208181117755
#                }
#            ],
#            "frozen" : false
#        }                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_metabolic_disease" : 0.8711390201303414,
#                    "metabolic_disease" : 0.12886097986965864
#                }
#            ],
#            "frozen" : false
#        }                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_lung_or_kidney_or_liver_disease" : 0.5493828519554179,
#                    "lung_or_kidney_or_liver_disease" : 0.45061714804458214
#                }
#            ],
#            "frozen" : false
#        }                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "chronic_conditions" : 0.5135599320096947,
#                    "no_chronic_conditions" : 0.4864400679903052
#                }
#            ],
#            "frozen" : false
#        }                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "comorbidities" : 0.3408045124714265,
#                    "no_comorbidities" : 0.6591954875285735
#                }
#            ],
#            "frozen" : false
#        }                                                  ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_frailty_measures" : 0.8500484272892435,
#                    "frailty_measures" : 0.1499515727107565
#                }
#            ],
#            "frozen" : false
#        }                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "frailty" : 0.14963436011492043,
#                    "no_frailty" : 0.8503656398850795
#                }
#            ],
#            "frozen" : false
#        }                                            ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hallmark_3_epigenetic_alterations" : 0.18270553121513056,
#                    "no_hallmark_3_epigenetic_alterations" : 0.8172944687848694
#                }
#            ],
#            "frozen" : false
#        }                                                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "cancer_from_behavior" : 0.3499999890929107,
#                    "no_cancer_from_behavior" : 0.6500000109070893
#                }
#            ],
#            "frozen" : false
#        }                                                         ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_cancer" : 0.950143123847116,
#                    "cancer" : 0.049856876152884005
#                }
#            ],
#            "frozen" : false
#        }                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hallmark_7_cellular_senescence" : 0.8845721551472142,
#                    "hallmark_7_cellular_senescence" : 0.11542784485278584
#                }
#            ],
#            "frozen" : false
#        }                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "mitochondrial_dysfunction_or_cellular_senescence" : 0.26658981279501603,
#                    "no_mitochondrial_dysfunction_or_cellular_senescence" : 0.7334101872049839
#                }
#            ],
#            "frozen" : false
#        }                                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hallmark_4_loss_of_proteostasis" : 0.9136208181117752,
#                    "hallmark_4_loss_of_proteostasis" : 0.08637918188822481
#                }
#            ],
#            "frozen" : false
#        }                                                                     ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "alzheimers_disease" : 0.009988526962930273,
#                    "no_alzheimers_disease" : 0.9900114730370698
#                }
#            ],
#            "frozen" : false
#        }                                                       ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hallmark_5_deregulated_nutrient_sensing" : 0.1496343601149209,
#                    "no_hallmark_5_deregulated_nutrient_sensing" : 0.850365639885079
#                }
#            ],
#            "frozen" : false
#        }                                                                           ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "hallmark_8_stem_cell_exhaustion" : 0.10932301768032594,
#                    "no_hallmark_8_stem_cell_exhaustion" : 0.890676982319674
#                }
#            ],
#            "frozen" : false
#        }                                                                   ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hallmark_9_altered_intercellular_communication" : 0.9405657243006923,
#                    "hallmark_9_altered_intercellular_communication" : 0.05943427569930765
#                }
#            ],
#            "frozen" : false
#        }                                                                                    ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "no_hallmark_10_extracellular_matrix_dysfunction" : 0.9009939205003333,
#                    "hallmark_10_extracellular_matrix_dysfunction" : 0.09900607949966661
#                }
#            ],
#            "frozen" : false
#        }                                                                                  ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "parkinsons_disease" : 0.001499788111907678,
#                    "no_parkinsons_disease" : 0.9985002118880923
#                }
#            ],
#            "frozen" : false
#        }                                                       ],
#       dtype=object)

# %% [markdown]
# ## Testing the Bayesian Network

# %%
# Testing the Bayesian Network
evidence = {}
outvars1 = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results1 = query(longevity,bayesianNetwork,evidence,outvars1)

# %%
#
evidence["low_socioeconomic_status"] = "low_socioeconomic_status"
results2 = query(longevity,bayesianNetwork,evidence,outvars1)

# %%
# Tests of increasingly poor patient state, showing gradual change of hallmarks
evidence = {}
# %time internal_query_result1 =  internal_query(longevity,bayesianNetwork,evidence)
# Out:
# Wall time: 3.44 s

# %%
#
evidence["low_socioeconomic_status"] = "low_socioeconomic_status"
internal_query_result2 =  internal_query(longevity,bayesianNetwork,evidence)

# %%
#
evidence = {}
evidence["frailty"] = "frailty"
internal_query_result3 =  internal_query(longevity,bayesianNetwork,evidence)

# %%
#
evidence["cancer"] = "cancer"
internal_query_result4 =  internal_query(longevity,bayesianNetwork,evidence)
# we show some of the same results as in the last cell for clarity
results3 = query(longevity,bayesianNetwork,evidence,outvars1)

# %% [markdown]
# ## Testing Explanations

# %%
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
# include_list = ["heart_rate_variability_anomaly","oxygen_anomaly","lack_of_exercise","uv_exposure",
#                 "blood_age_indicators","poor_sleep","inflammation_from_behavior","poor_diet","smoking",
#                 "frailty_signals","cancer","frailty","liver_disorders","cardiovascular_disease",
#                 "inactivated_sirtuins","inflammation","sarcopenia","comorbidities","general_aging_signs",
#                 "blood_metabolism_disorder_indicators","obesity","hypertension","diabetes","metabolic_disease",
#                 "gender"]
include_list = ["age_related_macular_degeneration","alzheimers_disease","parkinsons_disease",
                "anxious_how_often","daily_time_sitting","daily_walk_or_bicycle_travel","dietary_fiber",
                "eat_out_how_many_times_per_week","five_days_smoke_cigarettes","gender","heart_rate_anomaly",
                "marital_status","step_variability_anomaly","steps_anomaly","ten_minutes_daily_workout",
                "workout_anomaly","blood_age_indicators","c_reactive_protein","cancer",
                "cardiovascular_disease","chronic_conditions","comorbidities","diabetes","diet_quality",
                "frailty","frailty_signals","frailty_signs","heart_rate_variability_anomaly","hypertension",
                "inactivated_sirtuins","inflammation","inflammation_from_behavior","inflammation_from_diet",
                "kidney_disease","lack_of_exercise","lung_or_kidney_or_liver_disease","metabolic_disease",
                "oxygen_anomaly","poor_diet","poor_diet_flag","poor_oral_health","poor_sleep",
                "psychological_disorders","sarcopenia","sleep_anomaly","smoking","uv_exposure",
                "liver_disorders","heart_disorder_indicators","inflammation_from_illness",
                "poor_diet_quantity","general_aging_signs","lack_of_exercise_reported","diet_basics",
                "diet_fats","diet_quality_food","diet_quantity","diet_vitamins_and_minerals",
                "blood_metabolism_disorder_indicators","obesity","poor_sleep_schedule"]
# First try calling everyones result first, and sending it through for a check of the explanations one by one.
# you can call good and bad at the same time. 
# Also check if it is indeed bad or good before you send it in one of the explanations
print("start timing...")
tic = time.perf_counter()
internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
# for check_if_explains in include_list:
#     checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result,include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# start timing...
# Explanations took 13.6226251 seconds

# %% [markdown]
# ## Explanations

# %% [raw]
# print(why_bad)
# print(why_good)

# %%
evidence = {}
evidence1 = evidence.copy()
evidence1['a1c'] =  'a1c_diabetes_5.7_and_above'
# %time internal_query_result5 =  internal_query(longevity,bayesianNetwork,evidence1)
# Out:
# Wall time: 3.71 s

# %% [markdown]
# ## Realistic survey answers

# %%
evidence = {"age":"adult",
"daily_aspirin_compliance":"daily_aspirin_compliance_yes",
"high_blood_pressure_patient_prescription":"high_blood_pressure_patient_prescription_no",
"high_blood_pressure_medication_compliance":"high_blood_pressure_medication_compliance_yes",
"diastolic":"diastolic_80_to_89_high_stage_1",
"systolic":"systolic_less_than_120_normal",
"sun_exposure_half_hour":"sun_exposure_half_hour_mild_burn_tanning",
"time_spent_outdoors":"time_spent_outdoors_none",
"sun_exposure_use_sunscreen":"sun_exposure_use_sunscreen_sometimes",
"sunburn_last_year":"sunburn_last_year_yes",
"weight_at_25":"weight_at_25_above_125.00_to_150.00_and_below",
"bmi":"bmi_over_40_high_risk",
"dietary_energy":"dietary_energy_above_2612.00_to_3939.00_and_below",
"shortness_of_breath_exertion":"shortness_of_breath_exertion_yes",
"daily_walk_or_bicycle_travel":"daily_walk_or_bicycle_travel_less_than_30_minutes",
"daily_time_sitting":"daily_time_sitting_12_or_more_hours",
"physical_work":"physical_work_no",
"ten_minutes_daily_workout":"ten_minutes_daily_workout_no",
"heart_rate_anomaly":"heart_rate_anomaly",
"steps_anomaly":"steps_anomaly",
"workout_anomaly":"workout_anomaly",
"walking_speed_anomaly":"walking_speed_anomaly",
"walking_speed_variability_anomaly":"walking_speed_variability_anomaly",
"stride_variability_anomaly":"no_stride_variability_anomaly",
"step_asymmetry_anomaly":"no_step_asymmetry_anomaly",
"double_support_stepping_anomaly":"double_support_stepping__anomaly",
"step_variability_anomaly":"step_variability_anomaly",
"anxious_how_often":"anxious_daily",
"marital_status":"divorced",
"asthma_attack_last_year":"asthma_attack_last_year_no",
"liver_condition":"liver_condition_yes",
"fatiqued_in_2_weeks":"fatiqued_in_2_weeks_nearly_everyday",
"osteoporosis":"osteoporosis_no",
"artificial_joints":"artificial_joints_no",
"work_limiting_problem":"work_limiting_problem_yes",
"ten_stairs_difficulty":"ten_stairs_difficulty_some",
"chore_difficulty":"chore_difficulty_some",
"walking_difficulty":"walking_difficulty_much",
"stand_from_sit_difficulty":"stand_from_sit_difficulty_much",
"two_hour_standing_difficulty":"two_hour_standing_difficulty_much",
"two_hour_sitting_difficulty":"two_hour_sitting_difficulty_none",
"social_activity_difficulty":"social_activity_difficulty_much",
"urine_leakage_bother":"urine_leakage_bother_somewhat",
"hearing_difficulty_how_often":"hearing_difficulty_usually",
"hearing_frustration_how_often":"hearing_frustration_usually",
"wear_hearing_aid":"wear_hearing_aid_no",
"loud_noise_job":"loud_noise_job_no",
"loud_music":"loud_music_yes",
"second_hand_smoke":"second_hand_smoke_no",
"five_days_smoke_cigarettes":"five_days_smoke_cigarettes_no",
"ever_vaped":"ever_vaped_no",
"gender":"female",
"work_schedule":"work_schedule_evenings_or_nights",
"workday_sleep_hours_per_night":"workday_sleep_under_5",
"weekend_sleep_hours_per_night":"weekend_sleep_5.0_to_6.5",
"fish_last_month":"fish_last_month_no",
"tuna_eaten_times_per_month":"tuna_eaten_per_month_0_or_1",
"eat_out_how_many_times_per_week":"eat_out_more_than_7_times_per_week",
"how_healthy_diet":"how_healthy_diet_fair",
"alcohol_consumption_last_year":"alcohol_never",
"race":"race_white",
"education_level":"education_level_at_least_some_college",
"have_health_insurance":"have_health_insurance_yes",
"prescription_health_insurance":"prescription_health_insurance_yes",
"how_many_times_saw_doctor_last_year":"saw_doctor_1_or_2_times_last_year",
"how_long_since_saw_doctor":"saw_doctor_less_than_6_months_ago",
"what_is_your_annual_household_income":"over_100K",
"employment":"employment_working",
"age_at_first_child":"age_at_first_child_20_through_24",
"last_dentist_visit":"last_dentist_visit_6_months_or_less",
"dental_bone_loss":"dental_bone_loss_no",
                "daily_walk_or_bicycle_travel","dietary_fiber","eat_out_how_many_times_per_week",
                "five_days_smoke_cigarettes","gender","heart_rate_anomaly","marital_status",
                "step_variability_anomaly","steps_anomaly","ten_minutes_daily_workout","workout_anomaly",
                "blood_age_indicators","c_reactive_protein","cancer","cancer_related","cardiovascular_disease",
                "chronic_conditions","comorbidities","diabetes","diet_quality","frailty","frailty_signals",
                "frailty_signs","heart_rate_variability_anomaly","hypertension","inactivated_sirtuins",
                "inflammation","inflammation_from_behavior","inflammation_from_diet","kidney_disease",
                "lack_of_exercise","lung_or_kidney_or_liver_disease","metabolic_disease","oxygen_anomaly",
                "poor_diet","poor_diet_flag","poor_oral_health","poor_sleep","psychological_disorders",
                "sarcopenia","sleep_anomaly","smoking","uv_exposure","liver_disorders","heart_disorder_indicators",
                "inflammation_from_illness","poor_diet_quantity","general_aging_signs","lack_of_exercise_reported",
                "diet_basics","diet_fats","diet_quality_food","diet_quantity","diet_vitamins_and_minerals",
                "blood_metabolism_disorder_indicators","obesity","poor_sleep_schedule"]
#first, biometric survey                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
evidence = {"age": "adult",
        "bmi": "bmi_over_40_high_risk",
        "cancer": "no_cancer",
        "gender": "female",
        "height": "no_height_above_173.40",
        "weight": "weight_above_92.60",
        "diabetes": "no_diabetes",
        "systolic": "systolic_130_to_139_high_stage_1",
        "diastolic": "diastolic_80_to_89_high_stage_1",
        "hypertension": "no_hypertension",
        "lung_disease": "no_lung_disease",
        "kidney_disease": "no_kidney_disease",
        "immunocompromised": "not_immunocompromised",
        "alzheimers_disease": "no_alzheimers_disease",
        "parkinsons_disease": "no_parkinsons_disease",
        "resting_heart_rate": "no_resting_heart_rate_very_high_91_and_above",
        "cardiovascular_disease": "no_cardiovascular_disease",
        "psychological_disorders": "no_psychological_disorders",
        "age_related_macular_degeneration": "no_age_related_macular_degeneration"}          
#
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# Out:
# Wall time: 5.17 s

# %%
print("start timing...")
tic = time.perf_counter()
#internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#for check_if_explains in include_list:
    #checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# start timing...
# Explanations took 6.5588403 seconds

# %%
print(why_bad) 
print(why_good)
# Out:
# {'lack_of_exercise': {'bmi': 0.2127478043739296, 'obesity': 0.2127478043739296, 'diet_fats': 0.2127478043739296, 'diet_quality_food': 0.2127478043739296, 'diet_quantity': 0.2127478043739296, 'diet_quality': 0.2127478043739296, 'inactivated_sirtuins': 0.2127478043739296}, 'obesity': {'bmi': 0.6155373925543947, 'diet_fats': -0.009812653609235777, 'diet_quality_food': -0.009812653609235777, 'diet_quantity': -0.009812653609235777, 'diet_quality': -0.009812653609235777, 'inactivated_sirtuins': -0.009812653609235777}, 'smoking': {'bmi': 0.23925414734464112, 'obesity': 0.23925414734464112, 'diet_fats': 0.23925414734464112, 'diet_quality_food': 0.23925414734464112, 'diet_quantity': 0.23925414734464112, 'diet_quality': 0.23925414734464112, 'inactivated_sirtuins': 0.23925414734464112}, 'poor_sleep': {'bmi': 0.5106373051398501, 'obesity': 0.5106373051398501, 'diet_fats': 0.5106373051398501, 'diet_quality_food': 0.5106373051398501, 'diet_quantity': 0.5106373051398501, 'diet_quality': 0.5106373051398501, 'inactivated_sirtuins': 0.5106373051398501}, 'poor_diet_quantity': {'bmi': 0.2667864961008253, 'obesity': 0.2667864
 'diet_quantity': 0.0373263799909459, 'diet_quality': 0.0373263799909459, 'poor_diet': 0.0373263799909459, 'inflammation_from_diet': 0.0373263799909459, 'inflammation': 0.0373263799909459, 'general_aging_signs': 0.0373263799909459, 'frailty_signals': 0.0373263799909459, 'sarcopenia': 0.0373263799909459, 'frailty_signs': 0.0373263799909459, 'metabolic_disease': 0.03732638161987001, 'lung_or_kidney_or_liver_disease': 0.0373263799909459, 'chronic_conditions': 0.03732638161987001, 'comorbidities': -0.02097260726197525, 'frailty': 0.0373263799909459}, 'smoking': {'cancer': 0.2427978989173386, 'gender': 0.24279790077998398, 'diabetes': 0.2427978989173386, 'hypertension': 0.2427978989173386, 'kidney_disease': 0.2427978989173386, 'cardiovascular_disease': 0.2427978989173386, 'psychological_disorders': 0.24279789798601614, 'dietary_energy': 0.2427978989173386, 'marital_status': 0.24279790077998387, 'lack_of_exercise': 0.2427978989173386, 'heart_rate_variability_anomaly': 0.2427978989173386, 'oxygen_anomaly': 0.2427978989173386, 'sleep_anomaly': 0.2427978989173386, 'blood_metaboli ...

# %%
#add general medical history survey
evidence.update(
    {
        "how_long_since_saw_doctor":"saw_doctor_6_to_12_months_ago",
        "how_many_times_saw_doctor_last_year":"saw_doctor_1_or_2_times_last_year",
        "birth_weight":"birth_weight_7_to_8_lbs",
        "greatest_weight":"greatest_weight_above_230.00",
        "weight_at_25":"weight_at_25_above_125.00_to_150.00_and_below",
        "daily_asprin_prescription":"daily_asprin_prescription_no",
        "daily_aspirin_compliance":"daily_aspirin_compliance_no",
        "shortness_of_breath_exertion":"shortness_of_breath_exertion_yes",
        "work_limiting_problem":"work_limiting_problem_no",
        "anxious_how_often":"anxious_daily",
        "fatiqued_in_2_weeks":"fatiqued_in_2_weeks_more_than_half_the_days",
        "chest_pain":"chest_pain_no",
        "liver_condition":"liver_condition_yes",
        "osteoporosis":"osteoporosis_no",
        "asthma_attack_last_year":"asthma_attack_last_year_no",
        "high_blood_pressure_patient_prescription":"high_blood_pressure_patient_prescription_no",
        "blood_relative_heart_attack_before_age_50":"blood_relative_heart_attack_before_50_no",
        "urine_leakage_bother":"urine_leakage_bother_somewhat",
        "artificial_joints":"artificial_joints_yes",
        "hearing_difficulty_how_often":"hearing_difficulty_usually",
        "hearing_frustration_how_often":"hearing_frustration_usually",
        "wear_hearing_aid":"wear_hearing_aid_no",
        "loud_noise_job":"loud_noise_job_no",
        "loud_music":"loud_music_yes",
        "age_at_first_child":"age_at_first_child_20_through_24",
        "last_dentist_visit":"last_dentist_visit_7_months_to_a_year",
        "times_brush_teeth_daily":"no_times_brush_teeth_daily_1_or_less",
        "floss_days_per_week":"no_floss_days_per_week_3_or_less",
        "teeth_health":"no_teeth_health_poor",
        "gum_disease":"gum_disease_yes",
        "oral_cancer_exam":"oral_cancer_exam_no",
        "dental_bone_loss":"dental_bone_loss_no",
        "mouth_pain_last_year":"mouth_pain_last_year_fairly_often"
        
    }
)
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# First try calling everyones result first, and sending it through for a check of the explanations one by one.
# you can call good and bad at the same time.
# Also check if it is indeed bad or good before you send it in one of the explanations
print("start timing...")
tic = time.perf_counter()
#internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#for check_if_explains in include_list:
    #checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# Wall time: 4.99 s
# start timing...
# Explanations took 7.764888499999984 seconds

# %%
print(why_bad) 
print(why_good)
# Out:
# {'lack_of_exercise': {
 'blood_age_indicators': 0.2272931047174559, 'poor_diet_quantity': 0.2272931047174559, 'poor_diet_flag': 0.2272931047174559, 'diet_vitamins_and_minerals': 0.2272931047174559, 'diet_fats': 0.2272931047174559, 'diet_basics': 0.2272931047174559, 'diet_quality_food': 0.2272931047174559, 'diet_quantity': 0.2272931047174559, 'diet_quality': 0.2272931047174559, 'poor_diet': 0.22729 ...

# %%
evidence1 = evidence.copy()
evidence1['age']=  'elderly'
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence1)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence1,outvars)
# Out:
# Wall time: 5.61 s

# %%
evidence ={}
evidence['age']= 'elderly'
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# Out:
# Wall time: 3.76 s

# %%
evidence ={}
evidence['lack_of_exercise_reported']= 'no_lack_of_exercise_reported'
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# Out:
# Wall time: 3.44 s

# %% [markdown]
# ## Beta Tester Surveys

# %%
tester1_4 =  {"age": "elderly", "bmi": "bmi_under_25_healthy", "gender": "male", "physical_work": "physical_work_no", "fish_last_month": "fish_last_month_yes", "chore_difficulty": "chore_difficulty_some", "how_healthy_diet": "how_healthy_diet_excellent", "daily_time_sitting": "daily_time_sitting_12_or_more_hours", "walking_difficulty": "walking_difficulty_none", "ten_stairs_difficulty": "ten_stairs_difficulty_much", "water_drank_yesterday": "water_drank_yesterday_above_1633.50", "stand_from_sit_difficulty": "stand_from_sit_difficulty_much", "ten_minutes_daily_workout": "ten_minutes_daily_workout_no", "social_activity_difficulty": "social_activity_difficulty_some", "tuna_eaten_times_per_month": "tuna_eaten_per_month_8_or_more", "two_hour_sitting_difficulty": "two_hour_sitting_difficulty_none", "daily_walk_or_bicycle_travel": "daily_walk_or_bicycle_travel_less_than_30_minutes", "two_hour_standing_difficulty": "two_hour_standing_difficulty_some", "weekend_sleep_hours_per_night": "weekend_sleep_7.0_or_more", "workday_sleep_hours_per_night": "workday_sleep_under_5_no", "eat_out_how_many_times_per_week": "eat_out_1_or_2_times_per_week"}
evidence = tester1_4               
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)        
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# First try calling everyones result first, and sending it through for a check of the explanations one by one.
# you can call good and bad at the same time.
# Also check if it is indeed bad or good before you send it in one of the explanations
print("start timing...")
tic = time.perf_counter()
#internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#for check_if_explains in include_list:
    #checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# Wall time: 3.26 s
# start timing...
# Explanations took 6.928539300000011 seconds

# %%
print(why_bad) 
print(why_good)
# Out:
# {'lack_of_exercise': {'gender': 0.02499977858625846, 'daily_time_sitting': 0.024999771694471096, 'ten_minutes_daily_workout': 0.02499977858625846, 'daily_walk_or_bicycle_travel': 0.02499977858625846, 'eat_out_how_many_times_per_week': 0.02499977858625846, 'lack_of_exercise_reported': 0.27499978072698067, 'obesity': 0.02499977858625846, 'c_reactive_protein': 0.02499977858625846, 'diet_fats': 0.02499977858625846, 'diet_quality_food': 0.02499977858625846, 'hypertension': 0.02499977858625846, 'inactivated_sirtuins': 0.02499977858625846, 'chronic_conditions': 0.02499977858625846, 'comorbidities': 0.02499977858625846}, 'obesity': {'gender': 0.23816800937486549, 'daily_time_sitting': 0.2381680142970522, 'ten_minutes_daily_workout': 0.23816800937486549, 'daily_walk_or_bicycle_travel': 0.23816800937486549, 'eat_out_how_many_times_per_week': 0.23816800937486549, 'lack_of_exercise_reported': 0.23816800937486549, 'lack_of_exercise': 0.23816800937486549, 'c_reactive_protein': 0.23816800937486549, 'diet_fats': 0.23816800937486549, 'diet_quality_food': 0.23816800937486549, 'hypertension': 0.2381680024017674, 'inactivated_sirtu
_week': 0.23124998316768808, 'heart_rate_variability_anomaly': 0.23124998316768808, 'oxygen_anomaly': 0.23124998316768808, 'sleep_anomaly': 0.23124998316768808, 'blood_metabolism_disorder_indicators': 0.23124998316768808, 'heart_disorder_indicators': 0.23124998316768808, 'liver_disorders': 0.23124998316768808, 'uv_exposure': 0.2312500064238205, 'blood_age_indicators': 0.23124998316768808, 'poor_oral_health': 0.23124998316768808, 'inflammation_from_illness': 0.23124998316768808, 'poor_sleep_schedule': 0.23124998316768808, 'poor_sleep': 0.23124998316768808, 'inflammation_from_behavior': 0.23124998316768808, 'poor_diet_quantity': 0.2312499 ...

# %%
tester1_3= {"age": "elderly", "bmi": "bmi_under_25_healthy", "gender": "male", "physical_work": "physical_work_no", "chore_difficulty": "chore_difficulty_some", "daily_time_sitting": "daily_time_sitting_12_or_more_hours", "walking_difficulty": "walking_difficulty_none", "ten_stairs_difficulty": "ten_stairs_difficulty_much", "stand_from_sit_difficulty": "stand_from_sit_difficulty_much", "ten_minutes_daily_workout": "ten_minutes_daily_workout_no", "social_activity_difficulty": "social_activity_difficulty_some", "two_hour_sitting_difficulty": "two_hour_sitting_difficulty_none", "daily_walk_or_bicycle_travel": "daily_walk_or_bicycle_travel_less_than_30_minutes", "two_hour_standing_difficulty": "two_hour_standing_difficulty_some", "weekend_sleep_hours_per_night": "weekend_sleep_7.0_or_more", "workday_sleep_hours_per_night": "workday_sleep_under_5_no"} 
evidence = tester1_3
# %time internal_query_result = internal_query(longevity,bayesianNetwork,evidence)
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
# Out:
# Wall time: 3.32 s

# %%
# First try calling everyones result first, and sending it through for a check of the explanations one by one.
# you can call good and bad at the same time.
# Also check if it is indeed bad or good before you send it in one of the explanations
print("start timing...")
tic = time.perf_counter()
#internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#for check_if_explains in include_list:
    #checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# start timing...
# Explanations took 7.183924200000007 seconds

# %%
print(why_bad) 
print(why_good)
# Out:
# {'lack_of_exercise': {'gender': 0.02499978087073873, 'daily_time_sitting': 0.024999773978951367, 'ten_minutes_daily_workout': 0.02499978087073873, 'daily_walk_or_bicycle_travel': 0.02499978087073873, 'lack_of_exercise_reported': 0.27499978301146094, 'obesity': 0.02499978087073873, 'c_reactive_protein': 0.02499978087073873, 'diet_fats': 0.02499978087073873, 'diet_basics': 0.02499978087073873, 'diet_quality_food': 0.02499978087073873, 'diet_quantity': 0.02499978087073873, 'diet_quality': 0.02499978087073873, 'hypertension': 0.02499978087073873, 'inactivated_sirtuins': 0.02499978087073873, 'chronic_conditions': 0.02499978087073873, 'comorbidities': 0.02499978087073873}, 'obesity': {'gender': 0.23816803735352754, 'daily_time_sitting': 0.23816804227571425, 'ten_minutes_daily_workout': 0.23816803735352754, 'daily_walk_or_bicycle_travel': 0.23816803735352754, 'lack_of_exercise_reported': 0.23816803735352754, 'lack_of_exercise': 0.23816803735352754, 'c_reactive_protein': 0.23816803735352754, 'diet_fats': 0.23816803735352754, 'diet_basics': 0.23816803735352754, 'diet_quality_food': 0.23816803735352754, 'diet_quantity': 0.23816803735352754, 'diet_quality': 0.23816803735352754, 'hypertension': 0.23816803038042944, 'inactivated_sirtuins': 0.23816803735352754, 'chronic_conditions': 0.23816803407206977, 'comorbidities': 0.3698295631751426}, 'smoking': {'gender': 0.2312499808172287, 'daily_time_sitting': 0.2312500059019456, 'ten_minutes_daily_workout': 0.23124998267987396, 'daily_walk_or_bicycle_travel': 0.23124998267
420973855300813, 'uv_exposure': 0.22420973855300813, 'blood_age_indicators': 0.22420973855300813, 'poor_oral_health': 0.22420973855300813, 'inflammation_from_illness': 0.10370359342809204, 'poor_sleep_schedule': 0.22420973855300813, 'poor_sleep': 0.22420973855300813, 'inflammation_from_behavior': 0.22420973855300813, 'poor_diet_quantity': 0.22420973855300813, 'poor_diet_flag': 0.22420973855300813, 'diet_vitamins_and_minerals': 0.22420973855300813, 'diet_fats': 0.22420973855300813, 'diet_basics': 0.22420973855300813, 'diet_quality_food': 0.22420973855300813, 'diet_quantity': 0.22420973855300813, 'diet_quality': 0.22420973855300813, 'poor_diet': 0.22420973855300813, 'inflammation_from_diet': 0.22420973855300813, 'inflammation': 0.22420973855300813, 'kidney_disease': 0.1282735633901385, 'psychological_disorders': 0.22420973855300813, 'general_aging_signs': 0.22420973855300813, 'frailty_signals': 0.22420973855300813, 'sarcopenia': 0.22420973855300813, 'frailty_signs': 0.22420973855300813, 'diabetes': 0.22420973855300813, 'cardiovascular_disease': 0.22420973855300813, 'metabolic_disease': 0.22420974183446585, 'lung_or_kidney_or_liver_disease': 0.22420973855300813, 'frailty': 0.22420973855300813, 'cancer': 0.22420973855300813}, 'smoking': {'bmi': 0.23124998255989437, 'heart_rate_variability_anomaly': 0.23124998255989437, 'oxygen_anomaly': 0.23124998255989437, 'sleep_anomaly': 0.23124998255989437, 'blood_metabolism_disorder_indicators': 0.23124998255989437, 'heart_disorder_indicators': 0.23124998255989437, 'liver_disorders': 0.23124998255989437, 'uv_exposure': 0.23125000581602678, 'blood_age_indicators': 0.23124998255989437, 'poor_oral_health': 0.23124998255989437, 'inflammation_from_illness': 0.23124998255989437, 'poor_sleep_schedule': 0.23124998255989437, 'poor_sleep': 0.23124998255989437, 'inflammation_from_behavior': 0.23124998255989437, 'poor_diet_quantity': 0.23124998255989437, 'poor_diet_flag': 0.23124998255989437, 'diet_vitamins_and_minerals': 0.23124998255989437, 'diet_fats': 0.23124998255989437, 'di ...

# %%
tester1_5= {"age": "elderly", "gender": "male"}
evidence = tester1_5 
# %time internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
internal_query_result
#we show some of the same results as in the last cell for clarity
outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations",
"hallmark_4_loss_of_proteostasis","hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction",
"hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion","hallmark_9_altered_intercellular_communication",
"hallmark_10_extracellular_matrix_dysfunction","poor_diet","poor_diet_flag","poor_sleep","psychological_disorders",
"obesity","lack_of_exercise","poor_diet_quantity","smoking"]
results = query(longevity,bayesianNetwork,evidence,outvars)
print("start timing...")
tic = time.perf_counter()
#internal_query_result =  internal_query(longevity,bayesianNetwork,evidence)
#for check_if_explains in include_list:
    #checklist = [check_if_explains]
checklist = include_list
why_bad = explain_why_bad(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
why_good = explain_why_good(longevity,bayesianNetwork,evidence,outvars,internal_query_result=internal_query_result, include_list = checklist)
toc = time.perf_counter()
diff = toc - tic
print (f"Explanations took {diff} seconds")
# Out:
# Wall time: 3.34 s
# start timing...
# Explanations took 6.53426840000003 seconds

# %%
print(why_bad) 
print(why_good)
# Out:
or_sleep_schedule': 0.19796870905154046, 'poor_sleep': 0.19796870905154046, 'inflammation_from_behavior': 0.19796870905154046, 'poor_diet_quantity': 0.19796870905154046, 'poor_diet_flag': 0.19796870905154046, 'diet_vitamins_and_minerals': 0.19796870905154046, 'diet_fats': 0.19796870905154046, 'diet_basics': 0.19796870905154046, 'diet_quality_food': 0.19796870905154046, 'diet_quantity': 0.19796870905154046, 'diet_quality': 0.19796870905154046, 'poor_diet': 0.19796870905154046, 'inflammation_from_diet': 0.19796870905154046, 'inflammation': 0.19796870905154046, 'hypertension': 0.1979687013277978, 'kidney_disease': 0.29377477058675683, 'psychological_disorders': 0.19796870905154046, 'general_aging_signs': 0.19796870905154046, 'frailty_signals': 0.19796870905154046, 'sarcopenia': 0.19796870905154046, 'frailty_signs': 0.19796870905154046, 'diabetes': 0.19796870905154046, 'cardiovascular_disease': 0.19796870905154046, 'metabolic_disease': 0.1979687054168381, 'lung_or_kidney_or_liver_disease': 0.19796870905154046, 'comorbidities': 0.3525475770434047, 'frailty': 0.19796870905154046, 'cancer': 0.19796870905154046}, 'smoking': {'lack_of_exercise': 0.23125000808079138, 'obesity': 0.23125000808079138, 'heart_rate_variability_anomaly': 0.23125000808079138, 'oxygen_anomaly': 0.23125000808079138, 'sleep_anomaly': 0.23125000808079138, 'blood_metabolism_disorder_indicators': 0.23125000808079138, 'heart_disorder_indicators': 0.23125000808079138, 'liver_disorders': 0.23125000808079138, 'uv_exposure': 0.23125001990155536, 'blood_age_indicators': 0.23125000808079138, 'poor_oral_health': 0.23125000808079138, 'inflammation_from_illness': 0.23125000808079138, 'c_reactive_protein': 0.23125000808079138,  ...

# %% [markdown]
# ## Take a signal and put a fake anomaly at the end to test the sensitivity to wearables in the rules
#
# We find that lack of exercise signal explains why lack of exersize is off track, even more so than obesity does.

# %%
# %run wearables_query.py

# %%
evidence
# Out:
# {'age': 'adult',
#  'bmi': 'bmi_over_40_high_risk',
#  'gender': 'female',
#  'height': 'no_height_above_173.40',
#  'weight': 'weight_above_92.60',
#  'systolic': 'systolic_130_to_139_high_stage_1',
#  'diastolic': 'diastolic_80_to_89_high_stage_1',
#  'resting_heart_rate': 'no_resting_heart_rate_very_high_91_and_above'}

# %%
outvars
# Out:
# ['hallmark_1_genomic_instability',
#  'hallmark_2_telomere_attrition',
#  'hallmark_3_epigenetic_alterations',
#  'hallmark_4_loss_of_proteostasis',
#  'hallmark_5_deregulated_nutrient_sensing',
#  'hallmark_6_mitochondrial_dysfunction',
#  'hallmark_7_cellular_senescence',
#  'hallmark_8_stem_cell_exhaustion',
#  'hallmark_9_altered_intercellular_communication',
#  'hallmark_10_extracellular_matrix_dysfunction',
#  'poor_diet',
#  'poor_diet_flag',
#  'poor_sleep',
#  'psychological_disorders',
#  'obesity',
#  'lack_of_exercise',
#  'poor_diet_quantity',
#  'smoking']

# %%
include_list = ["dietary_energy", "bmi", "lack_of_exercise","anxious_how_often","daily_time_sitting","daily_walk_or_bicycle_travel","dietary_fiber","eat_out_how_many_times_per_week","five_days_smoke_cigarettes","gender","heart_rate_anomaly","marital_status","step_variability_anomaly","steps_anomaly","ten_minutes_daily_workout","workout_anomaly","blood_age_indicators","c_reactive_protein","cancer","cancer_related","cardiovascular_disease","chronic_conditions","comorbidities","diabetes","diet_quality","frailty","frailty_signals","frailty_signs","heart_rate_variability_anomaly","hypertension","inactivated_sirtuins","inflammation","inflammation_from_behavior","inflammation_from_diet","kidney_disease","lack_of_exercise","lung_or_kidney_or_liver_disease","metabolic_disease","oxygen_anomaly","poor_diet","poor_diet_flag","poor_oral_health","poor_sleep","psychological_disorders","sarcopenia","sleep_anomaly","smoking","uv_exposure","liver_disorders","heart_disorder_indicators","inflammation_from_illness","poor_diet_quantity","general_aging_signs","lack_of_exercise_reported","diet_basics","diet_fats","diet_quality_food","diet_quantity","diet_vitamins_and_minerals","blood_metabolism_disorder_indicators","obesity","poor_sleep_schedule"]
outvars.extend(include_list)

# %%
outvars.extend(["lack_of_exercise_signal","resting_heart_rate","signal_heart_disorders_indicators","steps_anomaly","workout_anomaly","heart_rate_anomaly","step_asymmetry_anomaly","step_variability_anomaly",
 "stride_variability_anomaly","heart_rate_variability_anomaly","walking_speed_variability_anomaly"])

# %%
data
# Out:
# {'steps_anomaly': {'data': [{'value': 4825.0,
#     'record_date': '2022-03-23 23:29:20',
#     'interval_in_second': 0},
#    {'value': 7783.0,
#     'record_date': '2022-03-24 23:53:48',
#     'interval_in_second': 87868},
#    {'value': 7594.0,
#     'record_date': '2022-03-25 22:49:15',
#     'interval_in_second': 82527},
#    {'value': 1137.0,
#     'record_date': '2022-03-26 22:55:13',
#     'interval_in_second': 86758},
#    {'value': 987.0,
#     'record_date': '2022-03-27 23:42:13',
#     'interval_in_second': 89220},
#    {'value': 3667.0,
#     'record_date': '2022-03-28 23:16:25',
#     'interval_in_second': 84852},
#    {'value': 6247.0,
#     'record_date': '2022-03-29 23:06:16',
#     'interval_in_second': 85791},
#    {'value': 5142.0,
#     'record_date': '2022-03-31 21:47:23',
#     'interval_in_second': 168067},
#    {'value': 4973.0,
#     'record_date': '2022-04-01 22:37:50',
#     'interval_in_second': 89427},
#    {'value': 3428.0,
#     'record_date': '2022-04-02 23:32:48',
#     'interval_in_second': 89698},
#    {'value': 6857.0,
#     'record_date': '2022-04-03 23:15:58',
#     'interval_in_second': 85390},
#    {'value': 4291.0,
#     'record_date': '2022-04-04 23:17:48',
#     'interval_in_second': 86510},
#    {'value': 9153.0,
#     'record_date': '2022-04-05 23:46:29',
#     'interval_in_second': 88121},
#    {'value': 3425.0,
#     'record_date': '2022-04-06 23:35:08',
#     'interval_in_second': 85719},
#    {'value': 2222.0,
#     'record_date': '2022-04-07 23:44:18',
#     'interval_in_second': 86950},
#    {'value': 3564.0,
#     'record_date': '2022-04-08 23:48:32',
#     'interval_in_second': 86654},
#    {'value': 7436.0,
#     'record_date': '2022-04-09 22:25:19',
#     'interval_in_second': 81407},
#    {'value': 3215.0,
#     'record_date': '2022-04-10 23:49:43',
#     'interval_in_second': 91464},
#    {'value': 3649.0,
#     'record_date': '2022-04-11 23:51:33',
#     'interval_in_second': 86510},
#    {'value': 2310.0,
#     'record_date': '2022-04-12 23:56:29',
#     'interval_in_second': 86696},
#    {'value': 8051.0,
#     'record_date': '2022-04-13 23:46:39',
#     'interval_in_second': 85810},
#    {'value': 4107.0,
#     'record_date': '2022-04-14 22:46:11',
#     'interval_in_second': 82772},
#    {'value': 4090.0,
#     'record_date': '2022-04-15 21:02:20',
#     'interval_in_second': 80169},
#    {'value': 11381.0,
#     'record_date': '2022-04-16 23:32:35',
#     'interval_in_second': 95415},
#    {'value': 10472.0,
#     'record_date': '2022-04-17 22:42:47',
#     'interval_in_second': 83412},
#    {'value': 4433.0,
#     'record_date': '2022-04-18 23:55:57',
#     'interval_in_second': 90790},
#    {'value': 2541.0,
#     'record_date': '2022-04-19 23:48:57',
#     'interval_in_second': 85980},
#    {'value': 4907.0,
#     'record_date': '2022-04-20 23:31:56',
#     'interval_in_second': 85379},
#    {'value': 2395.0,
#     'record_date': '2022-04-21 23:28:33',
#     'interval_in_second': 86197},
#    {'value': 39.0,
#     'record_date': '2022-04-22 00:31:33',
#     'interval_in_second': 3780}],
#   'application': 'HEALTHKIT'},
#  'workout_anomaly': {'data': [{'value': 1800.0,
#     'record_date': '2022-03-23 23:03:00',
#     'interval_in_second': 0},
#    {'value': 2100.0,
#     'record_date': '2022-03-24 21:10:00',
#     'interval_in_second': 79620},
#    {'value': 1800.0,
#     'record_date': '2022-03-25 20:40:00',
#     'interval_in_second': 84600},
#    {'value': 60.0,
#     'record_date': '2022-03-26 02:58:00',
#     'interval_in_second': 22680},
#    {'value': 60.0,
#     'record_date': '2022-03-27 20:17:00',
#     'interval_in_second': 148740},
#    {'value': 780.0,
#     'record_date': '2022-03-28 20:31:00',
#     'interval_in_second': 87240},
#    {'value': 1860.0,
#     'record_date': '2022-03-29 23:00:00',
#     'interval_in_second': 95340},
#    {'value': 2460.0,
#     'record_date': '2022-03-30 23:54:00',
#     'interval_in_second': 89640},
#    {'value': 1800.0,
#     'record_date': '2022-03-31 14:18:00',
#     'interval_in_second': 51840},
#    {'value': 1800.0,
#     'record_date': '2022-04-01 20:25:00',
#     'interval_in_second': 108420},
#    {'value': 900.0,
#     'record_date': '2022-04-02 22:50:00',
#     'interval_in_second': 95100},
#    {'value': 2460.0,
#     'record_date': '2022-04-03 22:47:00',
#     'interval_in_second': 86220},
#    {'value': 1560.0,
#     'record_date': '2022-04-04 20:06:00',
#     'interval_in_second': 76740},
#    {'value': 2340.0,
#     'record_date': '2022-04-05 22:43:00',
#     'interval_in_second': 95820},
#    {'value': 1200.0,
#     'record_date': '2022-04-06 23:04:00',
#     'interval_in_second': 87660},
#    {'value': 720.0,
#     'record_date': '2022-04-07 18:10:00',
#     'interval_in_second': 68760},
#    {'value': 480.0,
#     'record_date': '2022-04-08 19:45:00',
#     'interval_in_second': 92100},
#    {'value': 2820.0,
#     'record_date': '2022-04-09 20:03:00',
#     'interval_in_second': 87480},
#    {'value': 420.0,
#     'record_date': '2022-04-10 22:28:00',
#     'interval_in_second': 95100},
#    {'value': 1380.0,
#     'record_date': '2022-04-11 21:54:00',
#     'interval_in_second': 84360},
#    {'value': 180.0,
#     'record_date': '2022-04-12 23:05:00',
#     'interval_in_second': 90660},
#    {'value': 2760.0,
#     'record_date': '2022-04-13 23:21:00',
#     'interval_in_second': 87360},
#    {'value': 1560.0,
#     'record_date': '2022-04-14 17:04:00',
#     'interval_in_second': 63780},
#    {'value': 1800.0,
#     'record_date': '2022-04-15 19:01:00',
#     'interval_in_second': 93420},
#    {'value': 4320.0,
#     'record_date': '2022-04-16 18:16:00',
#     'interval_in_second': 83700},
#    {'value': 2760.0,
#     'record_date': '2022-04-17 22:02:00',
#     'interval_in_second': 99960},
#    {'value': 1440.0,
#     'record_date': '2022-04-18 23:58:00',
#     'interval_in_second': 93360},
#    {'value': 480.0,
#     'record_date': '2022-04-19 23:48:00',
#     'interval_in_second': 85800},
#    {'value': 1320.0,
#     'record_date': '2022-04-20 23:35:00',
#     'interval_in_second': 85620},
#    {'value': 540.0,
#     'record_date': '2022-04-21 17:13:00',
#     'interval_in_second': 63480}],
#   'application': 'HEALTHKIT'},
#  'heart_rate_anomaly': {'data': [{'value': 94.53697710698194,
#     'record_date': '2022-03-23 23:56:02',
#     'interval_in_second': 0},
#    {'value': 90.43693361513698,
#     'record_date': '2022-03-24 23:57:21',
#     'interval_in_second': 86479},
#    {'value': 89.28541496691231,
#     'record_date': '2022-03-25 23:59:26',
#     'interval_in_second': 86525},
#    {'value': 82.42018996528957,
#     'record_date': '2022-03-26 08:50:31',
#     'interval_in_second': 31865},
#    {'value': 94.99578684680868,
#     'record_date': '2022-03-27 23:56:31',
#     'interval_in_second': 140760},
#    {'value': 85.72321275190873,
#     'record_date': '2022-03-28 23:52:22',
#     'interval_in_second': 86151},
#    {'value': 85.9781117117478,
#     'record_date': '2022-03-29 23:51:29',
#     'interval_in_second': 86347},
#    {'value': 86.36439629604942,
#     'record_date': '2022-03-30 23:54:14',
#     'interval_in_second': 86565},
#    {'value': 86.76026297128328,
#     'record_date': '2022-03-31 14:15:12',
#     'interval_in_second': 51658},
#    {'value': 92.2828233873522,
#     'record_date': '2022-04-01 23:56:45',
#     'interval_in_second': 121293},
#    {'value': 83.23304676256681,
#     'record_date': '2022-04-02 23:58:35',
#     'interval_in_second': 86510},
#    {'value': 83.7270129891329,
#     'record_date': '2022-04-03 23:59:07',
#     'interval_in_second': 86432},
#    {'value': 86.94314529549362,
#     'record_date': '2022-04-04 23:56:52',
#     'interval_in_second': 86265},
#    {'value': 93.31917185297354,
#     'record_date': '2022-04-05 23:56:48',
#     'interval_in_second': 86396},
#    {'value': 90.24194194514575,
#     'record_date': '2022-04-06 23:56:55',
#     'interval_in_second': 86407},
#    {'value': 88.85833568911946,
#     'record_date': '2022-04-07 23:55:59',
#     'interval_in_second': 86344},
#    {'value': 88.22179653651595,
#     'record_date': '2022-04-08 23:57:12',
#     'interval_in_second': 86473},
#    {'value': 89.95833621412943,
#     'record_date': '2022-04-09 23:56:29',
#     'interval_in_second': 86357},
#    {'value': 84.48041782957135,
#     'record_date': '2022-04-10 23:58:41',
#     'interval_in_second': 86532},
#    {'value': 88.00585879569067,
#     'record_date': '2022-04-11 23:47:30',
#     'interval_in_second': 85729},
#    {'value': 88.18604102113699,
#     'record_date': '2022-04-12 23:58:48',
#     'interval_in_second': 87078},
#    {'value': 94.60328479785824,
#     'record_date': '2022-04-13 23:58:02',
#     'interval_in_second': 86354},
#    {'value': 90.29940159600756,
#     'record_date': '2022-04-14 23:55:33',
#     'interval_in_second': 86251},
#    {'value': 90.15767366973012,
#     'record_date': '2022-04-15 23:37:30',
#     'interval_in_second': 85317},
#    {'value': 95.76173940539104,
#     'record_date': '2022-04-16 23:59:41',
#     'interval_in_second': 87731},
#    {'value': 89.28097031195833,
#     'record_date': '2022-04-17 23:59:55',
#     'interval_in_second': 86414},
#    {'value': 84.03759565268497,
#     'record_date': '2022-04-18 23:54:41',
#     'interval_in_second': 86086},
#    {'value': 84.53218005229387,
#     'record_date': '2022-04-19 23:59:55',
#     'interval_in_second': 86714},
#    {'value': 86.03901691124088,
#     'record_date': '2022-04-20 23:59:55',
#     'interval_in_second': 86400},
#    {'value': 79.875,
#     'record_date': '2022-04-22 00:42:05',
#     'interval_in_second': 88930}],
#   'application': 'HEALTHKIT'},
#  'step_asymmetry_anomaly': {'data': [{'value': 0.245,
#     'record_date': '2022-03-24 18:09:44',
#     'interval_in_second': 0},
#    {'value': 0.045,
#     'record_date': '2022-03-25 17:27:56',
#     'interval_in_second': 83892},
#    {'value': 0.225,
#     'record_date': '2022-03-30 19:48:08',
#     'interval_in_second': 440412},
#    {'value': 0.10666666666666667,
#     'record_date': '2022-03-31 16:29:56',
#     'interval_in_second': 74508},
#    {'value': 0.09,
#     'record_date': '2022-04-01 20:05:22',
#     'interval_in_second': 99326},
#    {'value': 0.62,
#     'record_date': '2022-04-02 09:42:38',
#     'interval_in_second': 49036},
#    {'value': 0.11333333333333331,
#     'record_date': '2022-04-03 10:55:51',
#     'interval_in_second': 90793},
#    {'value': 0.0,
#     'record_date': '2022-04-04 10:39:28',
#     'interval_in_second': 85417},
#    {'value': 0.385,
#     'record_date': '2022-04-05 19:14:44',
#     'interval_in_second': 117316},
#    {'value': 0.18,
#     'record_date': '2022-04-06 17:25:51',
#     'interval_in_second': 79867},
#    {'value': 0.315,
#     'record_date': '2022-04-09 13:33:47',
#     'interval_in_second': 245276},
#    {'value': 0.55,
#     'record_date': '2022-04-14 09:50:21',
#     'interval_in_second': 418594},
#    {'value': 0.5385714285714286,
#     'record_date': '2022-04-16 17:26:03',
#     'interval_in_second': 200142},
#    {'value': 0.6,
#     'record_date': '2022-04-17 15:56:12',
#     'interval_in_second': 81009},
#    {'value': 0.36,
#     'record_date': '2022-04-19 10:06:29',
#     'interval_in_second': 151817}],
#   'application': 'HEALTHKIT'},
#  'step_variability_anomaly': {'data': [{'value': 299.0,
#     'record_date': '2022-03-24 17:34:37',
#     'interval_in_second': 0},
#    {'value': 639.0,
#     'record_date': '2022-03-24 17:40:52',
#     'interval_in_second': 375},
#    {'value': 464.0,
#     'record_date': '2022-03-24 17:44:38',
#     'interval_in_second': 226},
#    {'value': 233.0,
#     'record_date': '2022-03-24 17:51:38',
#     'interval_in_second': 420},
#    {'value': 295.0,
#     'record_date': '2022-03-24 17:57:13',
#     'interval_in_second': 335},
#    {'value': 684.0,
#     'record_date': '2022-03-24 18:02:57',
#     'interval_in_second': 344},
#    {'value': 355.0,
#     'record_date': '2022-03-24 18:07:47',
#     'interval_in_second': 290},
#    {'value': 64.0,
#     'record_date': '2022-03-24 18:12:57',
#     'interval_in_second': 310},
#    {'value': 71.0,
#     'record_date': '2022-03-24 18:24:07',
#     'interval_in_second': 670},
#    {'value': 17.0,
#     'record_date': '2022-03-24 19:03:03',
#     'interval_in_second': 2336},
#    {'value': 164.0,
#     'record_date': '2022-03-24 19:04:13',
#     'interval_in_second': 70},
#    {'value': 106.0,
#     'record_date': '2022-03-24 19:04:46',
#     'interval_in_second': 33},
#    {'value': 19.0,
#     'record_date': '2022-03-24 19:05:45',
#     'interval_in_second': 59},
#    {'value': 207.0,
#     'record_date': '2022-03-24 19:07:08',
#     'interval_in_second': 83},
#    {'value': 25.0,
#     'record_date': '2022-03-24 19:16:59',
#     'interval_in_second': 591},
#    {'value': 25.0,
#     'record_date': '2022-03-24 19:17:07',
#     'interval_in_second': 8},
#    {'value': 10.0,
#     'record_date': '2022-03-24 19:31:55',
#     'interval_in_second': 888},
#    {'value': 30.0,
#     'record_date': '2022-03-24 19:43:50',
#     'interval_in_second': 715},
#    {'value': 88.0,
#     'record_date': '2022-03-24 21:11:00',
#     'interval_in_second': 5230},
#    {'value': 9.0,
#     'record_date': '2022-03-24 21:34:22',
#     'interval_in_second': 1402},
#    {'value': 105.0,
#     'record_date': '2022-03-24 21:57:17',
#     'interval_in_second': 1375},
#    {'value': 79.0,
#     'record_date': '2022-03-24 21:57:28',
#     'interval_in_second': 11},
#    {'value': 26.0,
#     'record_date': '2022-03-24 22:13:44',
#     'interval_in_second': 976},
#    {'value': 30.0,
#     'record_date': '2022-03-24 22:13:47',
#     'interval_in_second': 3},
#    {'value': 58.0,
#     'record_date': '2022-03-24 23:08:38',
#     'interval_in_second': 3291},
#    {'value': 23.0,
#     'record_date': '2022-03-24 23:08:45',
#     'interval_in_second': 7},
#    {'value': 38.0,
#     'record_date': '2022-03-24 23:10:10',
#     'interval_in_second': 85},
#    {'value': 3.0,
#     'record_date': '2022-03-24 23:14:58',
#     'interval_in_second': 288},
#    {'value': 29.0,
#     'record_date': '2022-03-24 23:34:33',
#     'interval_in_second': 1175},
#    {'value': 1.0,
#     'record_date': '2022-03-24 23:53:48',
#     'interval_in_second': 1155}],
#   'application': 'HEALTHKIT'},
#  'stride_variability_anomaly': {'data': [{'value': 0.57,
#     'record_date': '2022-03-23 14:53:57',
#     'interval_in_second': 0},
#    {'value': 0.58,
#     'record_date': '2022-03-23 14:54:40',
#     'interval_in_second': 43},
#    {'value': 0.67,
#     'record_date': '2022-03-23 15:43:37',
#     'interval_in_second': 2937},
#    {'value': 0.43,
#     'record_date': '2022-03-24 16:14:17',
#     'interval_in_second': 88240},
#    {'value': 0.56,
#     'record_date': '2022-03-24 17:24:13',
#     'interval_in_second': 4196},
#    {'value': 0.46,
#     'record_date': '2022-03-24 17:43:56',
#     'interval_in_second': 1183},
#    {'value': 0.52,
#     'record_date': '2022-03-24 17:44:59',
#     'interval_in_second': 63},
#    {'value': 0.48,
#     'record_date': '2022-03-24 17:47:19',
#     'interval_in_second': 140},
#    {'value': 0.39,
#     'record_date': '2022-03-24 17:52:27',
#     'interval_in_second': 308},
#    {'value': 0.52,
#     'record_date': '2022-03-24 18:03:52',
#     'interval_in_second': 685},
#    {'value': 0.56,
#     'record_date': '2022-03-24 18:04:26',
#     'interval_in_second': 34},
#    {'value': 0.5,
#     'record_date': '2022-03-24 18:08:47',
#     'interval_in_second': 261},
#    {'value': 0.52,
#     'record_date': '2022-03-24 18:09:44',
#     'interval_in_second': 57},
#    {'value': 0.48,
#     'record_date': '2022-03-24 18:10:48',
#     'interval_in_second': 64},
#    {'value': 0.44,
#     'record_date': '2022-03-24 18:12:13',
#     'interval_in_second': 85},
#    {'value': 0.46,
#     'record_date': '2022-04-16 17:24:51',
#     'interval_in_second': 1984358},
#    {'value': 0.46,
#     'record_date': '2022-04-16 17:26:03',
#     'interval_in_second': 72},
#    {'value': 0.45,
#     'record_date': '2022-04-16 18:13:40',
#     'interval_in_second': 2857},
#    {'value': 0.49,
#     'record_date': '2022-04-17 13:31:10',
#     'interval_in_second': 69450},
#    {'value': 0.53,
#     'record_date': '2022-04-17 13:35:51',
#     'interval_in_second': 281},
#    {'value': 0.53,
#     'record_date': '2022-04-17 15:53:42',
#     'interval_in_second': 8271},
#    {'value': 0.41,
#     'record_date': '2022-04-17 15:55:34',
#     'interval_in_second': 112},
#    {'value': 0.4,
#     'record_date': '2022-04-17 15:55:51',
#     'interval_in_second': 17},
#    {'value': 0.49,
#     'record_date': '2022-04-17 15:56:12',
#     'interval_in_second': 21},
#    {'value': 0.47,
#     'record_date': '2022-04-17 15:57:00',
#     'interval_in_second': 48},
#    {'value': 0.48,
#     'record_date': '2022-04-17 16:08:28',
#     'interval_in_second': 688},
#    {'value': 0.49,
#     'record_date': '2022-04-17 16:17:42',
#     'interval_in_second': 554},
#    {'value': 0.57,
#     'record_date': '2022-04-19 10:06:29',
#     'interval_in_second': 150527},
#    {'value': 0.49,
#     'record_date': '2022-04-20 11:53:29',
#     'interval_in_second': 92820},
#    {'value': 0.55,
#     'record_date': '2022-04-20 21:48:44',
#     'interval_in_second': 35715}],
#   'application': 'HEALTHKIT'},
#  'heart_rate_variability_anomaly': {'data': [{'value': 80.0,
#     'record_date': '2022-03-24 22:58:09',
#     'interval_in_second': 0},
#    {'value': 79.0,
#     'record_date': '2022-03-24 23:04:05',
#     'interval_in_second': 356},
#    {'value': 80.0,
#     'record_date': '2022-03-24 23:06:20',
#     'interval_in_second': 135},
#    {'value': 73.0,
#     'record_date': '2022-03-24 23:14:09',
#     'interval_in_second': 469},
#    {'value': 74.0,
#     'record_date': '2022-03-24 23:20:35',
#     'interval_in_second': 386},
#    {'value': 76.0,
#     'record_date': '2022-03-24 23:21:40',
#     'interval_in_second': 65},
#    {'value': 79.0,
#     'record_date': '2022-03-24 23:27:19',
#     'interval_in_second': 339},
#    {'value': 79.0,
#     'record_date': '2022-03-24 23:32:51',
#     'interval_in_second': 332},
#    {'value': 84.0,
#     'record_date': '2022-03-24 23:36:43',
#     'interval_in_second': 232},
#    {'value': 80.0,
#     'record_date': '2022-03-24 23:45:06',
#     'interval_in_second': 503},
#    {'value': 80.0,
#     'record_date': '2022-03-24 23:46:13',
#     'interval_in_second': 67},
#    {'value': 86.0,
#     'record_date': '2022-03-24 23:52:26',
#     'interval_in_second': 373},
#    {'value': 84.0,
#     'record_date': '2022-03-24 23:52:52',
#     'interval_in_second': 26},
#    {'value': 79.0,
#     'record_date': '2022-03-24 23:57:21',
#     'interval_in_second': 269},
#    {'value': 85.0,
#     'record_date': '2022-04-22 00:03:19',
#     'interval_in_second': 2419558},
#    {'value': 85.0,
#     'record_date': '2022-04-22 00:03:21',
#     'interval_in_second': 2},
#    {'value': 85.0,
#     'record_date': '2022-04-22 00:03:34',
#     'interval_in_second': 13},
#    {'value': 78.0,
#     'record_date': '2022-04-22 00:06:02',
#     'interval_in_second': 148},
#    {'value': 80.0,
#     'record_date': '2022-04-22 00:08:20',
#     'interval_in_second': 138},
#    {'value': 81.0,
#     'record_date': '2022-04-22 00:08:21',
#     'interval_in_second': 1},
#    {'value': 80.0,
#     'record_date': '2022-04-22 00:08:25',
#     'interval_in_second': 4},
#    {'value': 88.0,
#     'record_date': '2022-04-22 00:08:44',
#     'interval_in_second': 19},
#    {'value': 78.0,
#     'record_date': '2022-04-22 00:14:10',
#     'interval_in_second': 326},
#    {'value': 79.0,
#     'record_date': '2022-04-22 00:17:45',
#     'interval_in_second': 215},
#    {'value': 80.0,
#     'record_date': '2022-04-22 00:21:47',
#     'interval_in_second': 242},
#    {'value': 79.0,
#     'record_date': '2022-04-22 00:23:51',
#     'interval_in_second': 124},
#    {'value': 76.0,
#     'record_date': '2022-04-22 00:24:41',
#     'interval_in_second': 50},
#    {'value': 73.0,
#     'record_date': '2022-04-22 00:29:05',
#     'interval_in_second': 264},
#    {'value': 76.0,
#     'record_date': '2022-04-22 00:37:45',
#     'interval_in_second': 520},
#    {'value': 75.0,
#     'record_date': '2022-04-22 00:42:05',
#     'interval_in_second': 260}],
#   'application': 'HEALTHKIT'},
#  'walking_speed_variability_anomaly': {'data': [{'value': 0.97,
#     'record_date': '2022-03-23 14:53:57',
#     'interval_in_second': 0},
#    {'value': 0.93,
#     'record_date': '2022-03-23 14:54:40',
#     'interval_in_second': 43},
#    {'value': 1.17,
#     'record_date': '2022-03-23 15:43:37',
#     'interval_in_second': 2937},
#    {'value': 0.76,
#     'record_date': '2022-03-24 16:14:17',
#     'interval_in_second': 88240},
#    {'value': 0.97,
#     'record_date': '2022-03-24 17:24:13',
#     'interval_in_second': 4196},
#    {'value': 0.78,
#     'record_date': '2022-03-24 17:43:56',
#     'interval_in_second': 1183},
#    {'value': 0.91,
#     'record_date': '2022-03-24 17:44:59',
#     'interval_in_second': 63},
#    {'value': 0.81,
#     'record_date': '2022-03-24 17:47:19',
#     'interval_in_second': 140},
#    {'value': 0.63,
#     'record_date': '2022-03-24 17:52:27',
#     'interval_in_second': 308},
#    {'value': 0.99,
#     'record_date': '2022-03-24 18:03:52',
#     'interval_in_second': 685},
#    {'value': 0.98,
#     'record_date': '2022-03-24 18:04:26',
#     'interval_in_second': 34},
#    {'value': 0.84,
#     'record_date': '2022-03-24 18:08:47',
#     'interval_in_second': 261},
#    {'value': 0.88,
#     'record_date': '2022-03-24 18:09:44',
#     'interval_in_second': 57},
#    {'value': 0.8,
#     'record_date': '2022-03-24 18:10:48',
#     'interval_in_second': 64},
#    {'value': 0.77,
#     'record_date': '2022-03-24 18:12:13',
#     'interval_in_second': 85},
#    {'value': 1.02,
#     'record_date': '2022-03-31 10:40:17',
#     'interval_in_second': 577684},
#    {'value': 1.05,
#     'record_date': '2022-03-31 10:46:43',
#     'interval_in_second': 386},
#    {'value': 0.87,
#     'record_date': '2022-03-31 10:56:55',
#     'interval_in_second': 612},
#    {'value': 0.94,
#     'record_date': '2022-03-31 10:58:04',
#     'interval_in_second': 69},
#    {'value': 0.87,
#     'record_date': '2022-03-31 16:29:56',
#     'interval_in_second': 19912},
#    {'value': 1.14,
#     'record_date': '2022-03-31 19:16:06',
#     'interval_in_second': 9970},
#    {'value': 0.74,
#     'record_date': '2022-04-01 19:27:47',
#     'interval_in_second': 87101},
#    {'value': 1.07,
#     'record_date': '2022-04-01 19:58:54',
#     'interval_in_second': 1867},
#    {'value': 0.94,
#     'record_date': '2022-04-01 20:05:22',
#     'interval_in_second': 388},
#    {'value': 0.73,
#     'record_date': '2022-04-02 09:42:38',
#     'interval_in_second': 49036},
#    {'value': 0.69,
#     'record_date': '2022-04-03 07:12:33',
#     'interval_in_second': 77395},
#    {'value': 0.94,
#     'record_date': '2022-04-03 07:18:39',
#     'interval_in_second': 366},
#    {'value': 0.94,
#     'record_date': '2022-04-03 07:24:37',
#     'interval_in_second': 358},
#    {'value': 0.96,
#     'record_date': '2022-04-03 07:26:18',
#     'interval_in_second': 101},
#    {'value': 0.85,
#     'record_date': '2022-04-03 10:55:51',
#     'interval_in_second': 12573}],
#   'application': 'HEALTHKIT'}}

# %%
if exists("bayesianNetwork.pkl"):
        infile = open("bayesianNetwork.pkl",'rb')
        bayesianNetwork = pickle.load(infile)
        infile.close()
else:
        # %time bayesianNetwork,outstr = longevity_bayes.longevity_bayes()
        print (outstr)
        outfile = open("bayesianNetwork.pkl",'wb')
        pickle.dump(bayesianNetwork,outfile)
        outfile.close()

# %%
var_positions = get_var_positions(bayesianNetwork)
var_positions
# Out:
# {'fake_variable': 0,
#  'age': 1,
#  'daily_aspirin_compliance': 2,
#  'high_blood_pressure_patient_prescription': 3,
#  'high_blood_pressure_medication_compliance': 4,
#  'diastolic': 5,
#  'systolic': 6,
#  'sun_exposure_half_hour': 7,
#  'time_spent_outdoors': 8,
#  'sun_exposure_use_sunscreen': 9,
#  'sunburn_last_year': 10,
#  'weight_at_25': 11,
#  'bmi': 12,
#  'dietary_energy': 13,
#  'shortness_of_breath_exertion': 14,
#  'daily_walk_or_bicycle_travel': 15,
#  'daily_time_sitting': 16,
#  'physical_work': 17,
#  'ten_minutes_daily_workout': 18,
#  'heart_rate_anomaly': 19,
#  'steps_anomaly': 20,
#  'workout_anomaly': 21,
#  'walking_speed_anomaly': 22,
#  'walking_speed_variability_anomaly': 23,
#  'stride_variability_anomaly': 24,
#  'step_asymmetry_anomaly': 25,
#  'double_support_stepping_anomaly': 26,
#  'step_variability_anomaly': 27,
#  'cumin_supplementation': 28,
#  'anxious_how_often': 29,
#  'marital_status': 30,
#  'birth_weight': 31,
#  'asthma_attack_last_year': 32,
#  'liver_condition': 33,
#  'fatiqued_in_2_weeks': 34,
#  'osteoporosis': 35,
#  'artificial_joints': 36,
#  'lymphocite_number': 37,
#  'mchc': 38,
#  'nucleated_red_blood_cells': 39,
#  'blood_urea_nitrogen': 40,
#  'chloride': 41,
#  'globulin': 42,
#  'bilirubin': 43,
#  'total_protein': 44,
#  'toxins_in_blood': 45,
#  'segmented_neutrophils': 46,
#  'cadmium': 47,
#  'cobalt': 48,
#  'chromium': 49,
#  'mercury': 50,
#  'manganese': 51,
#  'lead': 52,
#  'selenium': 53,
#  'cotinine': 54,
#  'eosinophils_percent': 55,
#  'ferritin': 56,
#  'hemoglobin': 57,
#  'serum_iron': 58,
#  'lymphocyte': 59,
#  'mean_cell_volume': 60,
#  'segmented_neutrophils_percent': 61,
#  'red_cell_distribution_width': 62,
#  'alkaline_phosphatase': 63,
#  'aspartate_aminotransferase': 64,
#  'alanine_aminotransferase': 65,
#  'creatine_phosphokinase': 66,
#  'creatinine': 67,
#  'gamma_glutamyl_transferase': 68,
#  'iron': 69,
#  'triglycerides': 70,
#  'uric_acid': 71,
#  'benzonitrile': 72,
#  'vitamin_C': 73,
#  'white_blood_cell_count': 74,
#  'albumin_creatinine_ratio': 75,
#  'volitile_organic_compound': 76,
#  'work_limiting_problem': 77,
#  'ten_stairs_difficulty': 78,
#  'chore_difficulty': 79,
#  'walking_difficulty': 80,
#  'stand_from_sit_difficulty': 81,
#  'two_hour_standing_difficulty': 82,
#  'two_hour_sitting_difficulty': 83,
#  'social_activity_difficulty': 84,
#  'urine_leakage_bother': 85,
#  'hearing_difficulty_how_often': 86,
#  'hearing_frustration_how_often': 87,
#  'wear_hearing_aid': 88,
#  'loud_noise_job': 89,
#  'loud_music': 90,
#  'average_oxygen_saturation': 91,
#  'garlic_supplementation': 92,
#  'nigella_sativa_supplementation': 93,
#  'coq10_supplementation': 94,
#  'spirulina_supplementation': 95,
#  'ginger_supplementation': 96,
#  'soy_isoflavones_supplementation': 97,
#  'dietary_folate': 98,
#  'folate': 99,
#  'folate_mefox': 100,
#  'second_hand_smoke': 101,
#  'five_days_smoke_cigarettes': 102,
#  'ever_vaped': 103,
#  'gender': 104,
#  'work_schedule': 105,
#  'weekend_sleep_hours_per_night': 106,
#  'fish_last_month': 107,
#  'tuna_eaten_times_per_month': 108,
#  'eat_out_how_many_times_per_week': 109,
#  'how_healthy_diet': 110,
#  'dietary_alpha_carotene': 111,
#  'dietary_alpha_tocopherol': 112,
#  'dietary_beta_carotene': 113,
#  'dietary_caffeine': 114,
#  'dietary_calcium': 115,
#  'dietary_carbohydrate': 116,
#  'dietary_choline': 117,
#  'dietary_cholesterol': 118,
#  'dietary_copper': 119,
#  'dietary_fiber': 120,
#  'dietary_iron': 121,
#  'dietary_lycopene': 122,
#  'dietary_lutein': 123,
#  'dietary_magnesium': 124,
#  'dietary_epa': 125,
#  'dietary_potassium': 126,
#  'dietary_retinol': 127,
#  'dietary_selenium': 128,
#  'sodium': 129,
#  'dietary_thiamin': 130,
#  'dietary_b12': 131,
#  'dietary_riboflavin': 132,
#  'dietary_vitamin_C': 133,
#  'dietary_zinc': 134,
#  'water_drank_yesterday': 135,
#  'dietary_pfa': 136,
#  'dietary_fat': 137,
#  'dietary_b6': 138,
#  'alcohol_consumption_last_year': 139,
#  'num_alcoholic_drinks_when_drinking': 140,
#  'race': 141,
#  'education_level': 142,
#  'have_health_insurance': 143,
#  'prescription_health_insurance': 144,
#  'how_many_times_saw_doctor_last_year': 145,
#  'how_long_since_saw_doctor': 146,
#  'what_is_your_annual_household_income': 147,
#  'employment': 148,
#  'age_at_first_child': 149,
#  'last_dentist_visit': 150,
#  'dental_bone_loss': 151,
#  'oral_cancer_exam': 152,
#  'immunocompromised': 153,
#  'glucose_serum': 154,
#  'daily_fruit_vegetable_servings': 155,
#  'daily_wholegrain_servings': 156,
#  'weekly_nut_servings': 157,
#  'weekly_fish_servings': 158,
#  'weekly_processed_meat_servings': 159,
#  'daily_plant_protein_servings': 160,
#  'dietary_d': 161,
#  'angina': 162,
#  'daily_asprin_prescription': 163,
#  'blood_relative_heart_attack_before_age_50': 164,
#  'chest_pain': 165,
#  'greatest_weight': 166,
#  'weight': 167,
#  'height': 168,
#  'hip': 169,
#  'waist': 170,
#  'lack_of_workout_reported': 171,
#  'lack_of_exercise_reported': 172,
#  'lack_of_exercise_signal': 173,
#  'lack_of_exercise': 174,
#  'workday_sleep_hours_per_night': 175,
#  'obesity_factors': 176,
#  'obesity': 177,
#  'dna_methylation': 178,
#  'LDL': 179,
#  'direct_HDL': 180,
#  'salt_how_often': 181,
#  'total_cholesterol': 182,
#  'dietary_sodium': 183,
#  'times_brush_teeth_daily': 184,
#  'floss_days_per_week': 185,
#  'teeth_health': 186,
#  'gum_disease': 187,
#  'mouth_pain_last_year': 188,
#  'smoking': 189,
#  'micro_nucleus_frequency': 190,
#  'cognitive_impairment': 191,
#  'interleukin_6': 192,
#  'tnf_alpha': 193,
#  'fasting_glucose': 194,
#  'lung_disease': 195,
#  'a1c': 196,
#  'heart_rate_variability_anomaly': 197,
#  'oxygen_anomaly': 198,
#  'sleep_anomaly': 199,
#  'blood_illness_indicators': 200,
#  'blood_metabolism_disorder_indicators': 201,
#  'reported_heart_symptoms': 202,
#  'blood_heart_disorder_indicators': 203,
#  'resting_heart_rate': 204,
#  'signal_heart_disorder_indicators': 205,
#  'heart_disorder_indicators': 206,
#  'blood_mild_liver_disorder_indicators': 207,
#  'severe_blood_liver_disorder_indicators': 208,
#  'liver_disorders': 209,
#  'blood_kidney_disorder_indicators': 210,
#  'medicated_hypertension': 211,
#  'reported_hypertension': 212,
#  'uv_exposure': 213,
#  'folate_labs': 214,
#  'mineral_labs': 215,
#  'iron_labs': 216,
#  'vitamin_and_mineral_labs': 217,
#  'toxic_compound_labs': 218,
#  'toxic_metal_labs': 219,
#  'toxin_labs': 220,
#  'red_blood_age_indicators': 221,
#  'white_blood_age_indicators': 222,
#  'blood_age_indicators': 223,
#  'poor_oral_health': 224,
#  'inflammation_from_illness': 225,
#  'c_reactive_protein': 226,
#  'poor_sleep_schedule': 227,
#  'poor_sleep': 228,
#  'inflammation_from_behavior': 229,
#  'low_socioeconomic_status_demography': 230,
#  'low_socioeconomic_status_health_insurance': 231,
#  'low_socioeconomic_status_healthcare': 232,
#  'low_socioeconomic_status_health': 233,
#  'low_socioeconomic_status': 234,
#  'poor_diet_minerals_1': 235,
#  'poor_diet_minerals_2': 236,
#  'poor_diet_minerals': 237,
#  'poor_diet_vitamin_a': 238,
#  'poor_diet_vitamin_b_1': 239,
#  'poor_diet_vitamin_b_2': 240,
#  'poor_diet_vitamin_b': 241,
#  'poor_diet_vitamin_other': 242,
#  'poor_diet_vitamins_and_minerals': 243,
#  'omega_3': 244,
#  'poor_diet_fats': 245,
#  'poor_diet_basics': 246,
#  'poor_diet_supplements': 247,
#  'poor_diet_substances': 248,
#  'poor_diet_quantity': 249,
#  'poor_diet_food': 250,
#  'poor_diet_flag': 251,
#  'diet_minerals_1': 252,
#  'diet_minerals_2': 253,
#  'diet_minerals': 254,
#  'diet_vitamin_a': 255,
#  'diet_vitamin_b_1': 256,
#  'diet_vitamin_b_2': 257,
#  'diet_vitamin_b': 258,
#  'diet_vitamin_other': 259,
#  'diet_vitamins_and_minerals': 260,
#  'diet_fats': 261,
#  'diet_basics': 262,
#  'diet_supplements': 263,
#  'diet_substances': 264,
#  'diet_quality_food': 265,
#  'diet_quantity': 266,
#  'diet_quality': 267,
#  'poor_diet': 268,
#  'inflammation_from_diet': 269,
#  'inflammation': 270,
#  'hypertension_from_behavior': 271,
#  'hypertension': 272,
#  'kidney_disease': 273,
#  'psychological_disorders': 274,
#  'age_acceleration_from_behavior': 275,
#  'age_acceleration_from_movement': 276,
#  'age_acceleration_from_nutrition': 277,
#  'age_acceleration': 278,
#  'hearing_difficulty': 279,
#  'general_aging_signs': 280,
#  'sarcopenia_movement': 281,
#  'sarcopenia_function': 282,
#  'sarcopenia_reported': 283,
#  'frailty_signals': 284,
#  'sarcopenia': 285,
#  'inactivated_sirtuins': 286,
#  'frailty_signs': 287,
#  'hallmark_1_genomic_instability': 288,
#  'hallmark_2_telomere_attrition': 289,
#  'age_related_macular_degeneration': 290,
#  'diabetes_from_behavior': 291,
#  'diabetes': 292,
#  'hallmark_6_mitochondrial_dysfunction': 293,
#  'cardiovascular_disease_from_behavior': 294,
#  'cardiovascular_disease': 295,
#  'metabolic_disease': 296,
#  'lung_or_kidney_or_liver_disease': 297,
#  'chronic_conditions': 298,
#  'comorbidities': 299,
#  'frailty_measures': 300,
#  'frailty': 301,
#  'hallmark_3_epigenetic_alterations': 302,
#  'cancer_from_behavior': 303,
#  'cancer': 304,
#  'hallmark_7_cellular_senescence': 305,
#  'mitochondrial_dysfunction_or_cellular_senescence': 306,
#  'hallmark_4_loss_of_proteostasis': 307,
#  'alzheimers_disease': 308,
#  'hallmark_5_deregulated_nutrient_sensing': 309,
#  'hallmark_8_stem_cell_exhaustion': 310,
#  'hallmark_9_altered_intercellular_communication': 311,
#  'hallmark_10_extracellular_matrix_dysfunction': 312,
#  'parkinsons_disease': 313}

# %%
var_val_positions = get_var_val_positions(bayesianNetwork)
var_val_positions
# Out:
# {'fake_variable': {'fake_variable_1': 0,
#   'fake_variable_2': 1,
#   'fake_variable_3': 2,
#   'fake_variable_4': 3,
#   'fake_variable_5': 4},
#  'age': {'elderly': 0, 'adult': 1, 'young_adult': 2, 'teen': 3, 'child': 4},
#  'daily_aspirin_compliance': {'daily_aspirin_compliance_no': 0,
#   'daily_aspirin_compliance_yes': 1},
#  'high_blood_pressure_patient_prescription': {'high_blood_pressure_patient_prescription_yes': 0,
#   'high_blood_pressure_patient_prescription_no': 1},
#  'high_blood_pressure_medication_compliance': {'high_blood_pressure_medication_compliance_no': 0,
#   'high_blood_pressure_medication_compliance_yes': 1},
#  'diastolic': {'diastolic_120_or_higher_crisis': 0,
#   'diastolic_90_to_119_high_stage_2': 1,
#   'diastolic_80_to_89_high_stage_1': 2,
#   'diastolic_less_than_80_normal': 3},
#  'systolic': {'systolic_180_over_crisis': 0,
#   'systolic_140_to_179_high_stage_2': 1,
#   'systolic_130_to_139_high_stage_1': 2,
#   'systolic_120_to_129_elevated': 3,
#   'systolic_less_than_120_normal': 4},
#  'sun_exposure_half_hour': {'sun_exposure_half_hour_severe_sunburn_blisters': 0,
#   'sun_exposure_half_hour_severe_sunburn_peeling': 1,
#   'sun_exposure_half_hour_mild_burn_tanning': 2,
#   'sun_exposure_half_hour_darker_no_burn': 3,
#   'sun_exposure_half_hour_no_tan_or_burn': 4,
#   '': 5},
#  'time_spent_outdoors': {'time_spent_outdoors_none': 0,
#   'time_spent_outdoors_a_half_hour_per_day': 1,
#   'time_spent_outdoors_1_hour_per_day': 2,
#   'time_spent_outdoors_2_or_3_hours_per_day': 3,
#   'time_spent_outdoors_4_to_6_hours_per_day': 4,
#   'time_spent_outdoors_7_or_more_hours_per_day': 5},
#  'sun_exposure_use_sunscreen': {'sun_exposure_use_sunscreen_never': 0,
#   'sun_exposure_use_sunscreen_rarely': 1,
#   'sun_exposure_use_sunscreen_sometimes': 2,
#   'sun_exposure_use_sunscreen_most_of_the_time': 3,
#   'sun_exposure_use_sunscreen_always': 4},
#  'sunburn_last_year': {'sunburn_last_year_yes': 0, 'sunburn_last_year_no': 1},
#  'weight_at_25': {'weight_at_25_above_300.00': 0,
#   'weight_at_25_above_180.00_to_300.00_and_below': 1,
#   'weight_at_25_above_150.00_to_180.00_and_below': 2,
#   'weight_at_25_above_125.00_to_150.00_and_below': 3,
#   'weight_at_25_125.00_and_below': 4},
#  'bmi': {'bmi_over_40_high_risk': 0,
#   'bmi_35_to_39_moderate_risk': 1,
#   'bmi_30_to_34_low_risk': 2,
#   'bmi_25_to_29_overweight': 3,
#   'bmi_under_25_healthy': 4},
#  'dietary_energy': {'dietary_energy_above_3939.00': 0,
#   'dietary_energy_above_2612.00_to_3939.00_and_below': 1,
#   'dietary_energy_above_1930.00_to_2612.00_and_below': 2,
#   'dietary_energy_above_1399.00_to_1930.00_and_below': 3,
#   'dietary_energy_1399.00_and_below': 4},
#  'shortness_of_breath_exertion': {'shortness_of_breath_exertion_yes': 0,
#   'shortness_of_breath_exertion_no': 1},
#  'daily_walk_or_bicycle_travel': {'daily_walk_or_bicycle_travel_less_than_30_minutes': 0,
#   'daily_walk_or_bicycle_travel_30_to_59_minutes': 1,
#   'daily_walk_or_bicycle_travel_60_minutes_or_more': 2},
#  'daily_time_sitting': {'daily_time_sitting_12_or_more_hours': 0,
#   'daily_time_sitting_over_6_but_less_than_12_hours': 1,
#   'daily_time_sitting_over_2_but_less_than_6_hours': 2,
#   'daily_time_sitting_less_than_2_hours': 3},
#  'physical_work': {'physical_work_no': 0, 'physical_work_yes': 1},
#  'ten_minutes_daily_workout': {'ten_minutes_daily_workout_no': 0,
#   'ten_minutes_daily_workout_yes': 1},
#  'heart_rate_anomaly': {'heart_rate_anomaly': 0, 'no_heart_rate_anomaly': 1},
#  'steps_anomaly': {'steps_anomaly': 0, 'no_steps_anomaly': 1},
#  'workout_anomaly': {'workout_anomaly': 0, 'no_workout_anomaly': 1},
#  'walking_speed_anomaly': {'walking_speed_anomaly': 0,
#   'no_walking_speed_anomaly': 1},
#  'walking_speed_variability_anomaly': {'walking_speed_variability_anomaly': 0,
#   'no_walking_speed_variability_anomaly': 1},
#  'stride_variability_anomaly': {'stride_variability_anomaly': 0,
#   'no_stride_variability_anomaly': 1},
#  'step_asymmetry_anomaly': {'step_asymmetry_anomaly': 0,
#   'no_step_asymmetry_anomaly': 1},
#  'double_support_stepping_anomaly': {'double_support_stepping__anomaly': 0,
#   'no_double_support_stepping_anomaly': 1},
#  'step_variability_anomaly': {'step_variability_anomaly': 0,
#   'no_step_variability_anomaly': 1},
#  'cumin_supplementation': {'cumin_supplementation_yes': 0,
#   'cumin_supplementation_no': 1},
#  'anxious_how_often': {'anxious_daily': 0,
#   'anxious_weekly': 1,
#   'anxious_monthly': 2,
#   'anxious_a_few_times_per_year': 3,
#   'anxious_never': 4},
#  'marital_status': {'widowed': 0,
#   'separated': 1,
#   'divorced': 2,
#   'never_married': 3,
#   'living_with_partner_or_married': 4},
#  'birth_weight': {'birth_weight_under_5_lbs': 0,
#   'birth_weight_5_to_6_lbs': 1,
#   'birth_weight_7_to_8_lbs': 2,
#   'birth_weight_9_to_11_lbs': 3,
#   'birth_weight_above_11_lbs': 4},
#  'asthma_attack_last_year': {'asthma_attack_last_year_yes': 0,
#   'asthma_attack_last_year_no': 1},
#  'liver_condition': {'liver_condition_yes': 0, 'liver_condition_no': 1},
#  'fatiqued_in_2_weeks': {'fatiqued_in_2_weeks_nearly_everyday': 0,
#   'fatiqued_in_2_weeks_more_than_half_the_days': 1,
#   'fatiqued_in_2_weeks_several_days': 2,
#   'fatiqued_in_2_weeks_none': 3},
#  'osteoporosis': {'osteoporosis_yes': 0, 'osteoporosis_no': 1},
#  'artificial_joints': {'artificial_joints_yes': 0, 'artificial_joints_no': 1},
#  'lymphocite_number': {'lymphocite_number_below_normal_under_1': 0,
#   'lymphocite_number_low_normal_1_to 1.9': 1,
#   'lymphocite_number_mid_normal_2_to_2.9': 2,
#   'lymphocite_number_high_normal_3_to_4.8': 3,
#   'lymphocite_number_above_normal_above_4.8': 4},
#  'mchc': {'mchc_34.6_and_above': 0,
#   'mchc_34.0_to_34.5': 1,
#   'mchc_33.4_to_33.9': 2,
#   'mchc_33.0_to_33.3': 3,
#   'mchc_below_33': 4},
#  'nucleated_red_blood_cells': {'nucleated_red_blood_cells_high_0.2': 0,
#   'nucleated_red_blood_cells_high_normal_0.1': 1,
#   'nucleated_red_blood_cells_low_normal_0.0': 2},
#  'blood_urea_nitrogen': {'blood_urea_nitrogen_20.0_and_above': 0,
#   'blood_urea_nitrogen_15.0_to_19.0': 1,
#   'blood_urea_nitrogen_10.0_to_14': 2,
#   'blood_urea_nitrogen_below_9.0': 3},
#  'chloride': {'chloride_normal_low_96.0_to_99.0': 0,
#   'chloride_normal_medium_100.0_to_103.0': 1,
#   'chloride_normal_high_104.0_to_106.0': 2,
#   'chloride_high_above_106.0': 3},
#  'globulin': {'globulin_high_3.6 and_higher': 0,
#   'globulin_3.1_to_3.5': 1,
#   'globulin_2.6_TO_3.0': 2,
#   'globulin_low_2.5_and_below': 3},
#  'bilirubin': {'bilirubin_0.6_and_above': 0,
#   'bilirubin_0.4_to_0.5': 1,
#   'bilirubin_0.3': 2,
#   'bilirubin_below_0.2': 3},
#  'total_protein': {'total_protein_below_6.9': 0,
#   'total_protein_6.9_to_7.1': 1,
#   'total_protein_7.2_to_7.4': 2,
#   'total_protein_7.5_and_above': 3},
#  'toxins_in_blood': {'toxins_in_blood_above_0.006': 0,
#   'toxins_in_blood_0.005_to_0.006': 1,
#   'toxins_in_blood_0.004_and_below': 2},
#  'segmented_neutrophils': {'segmented_neutrophils_high_above_6': 0,
#   'segmented_neutrophils_normal_2.5_to_6': 1,
#   'segmented_neutrophils_low_under_2.5': 2},
#  'cadmium': {'cadmium_high_above_5': 0,
#   'cadmium_high_normal_2_to_5': 1,
#   'cadmium_normal': 2,
#   'cadmium_low': 3},
#  'cobalt': {'cobalt_high_above_0.3': 0,
#   'cobalt_high_normal_0.12_to_0.3': 1,
#   'cobalt_normal_below_0.12': 2},
#  'chromium': {'chromium_0.29_and_below': 0,
#   'chromium_above_0.29_to_0.29_and_below': 3,
#   'chromium_above_0.29': 4},
#  'mercury': {'mercury_above_4.04': 0,
#   'mercury_above_1.07_to_4.04_and_below': 1,
#   'mercury_above_0.42_to_1.07_and_below': 2,
#   'mercury_above_0.18_to_0.42_and_below': 3,
#   'mercury_0.18_and_below': 4},
#  'manganese': {'manganese_high_above_36.6': 0,
#   'manganese_normal_high_18.3_to_36.6': 1,
#   'manganese_normal_4.7_to_below_18.3': 2,
#   'manganese_low_below_4.7': 3},
#  'lead': {'lead_above_2.95': 0,
#   'lead_above_1.38_to_2.95_and_below': 1,
#   'lead_above_0.83_to_1.38_and_below': 2,
#   'lead_above_0.48_to_0.83_and_below': 3,
#   'lead_0.48_and_below': 4},
#  'selenium': {'selenium_152.66_and_below': 0,
#   'selenium_above_152.66_to_173.56_and_below': 1,
#   'selenium_above_173.56_to_188.11_and_below': 2,
#   'selenium_above_188.11_to_204.17_and_below': 3,
#   'selenium_above_204.17': 4},
#  'cotinine': {'cotinine_above_323.00': 0,
#   'cotinine_above_1.01_to_323.00_and_below': 1,
#   'cotinine_above_0.03_to_1.01_and_below': 2,
#   'cotinine_above_0.01_to_0.03_and_below': 3,
#   'cotinine_0.01_and_below': 4},
#  'eosinophils_percent': {'eosinophils_percent_above_6.70': 0,
#   'eosinophils_percent_above_3.50_to_6.70_and_below': 1,
#   'eosinophils_percent_above_2.30_to_3.50_and_below': 2,
#   'eosinophils_percent_above_1.50_to_2.30_and_below': 3,
#   'eosinophils_percent_1.50_and_below': 4},
#  'ferritin': {'ferritin_low_below_11': 0,
#   'ferritin_normal_11_to_336': 1,
#   'ferritin_high_above_336': 2},
#  'hemoglobin': {'hemoglobin_severe_amemia_below_8': 0,
#   'hemoglobin_moderate_amemia_8_tto_10': 1,
#   'hemoglobin_slight_anemia_above_10_to_12': 2,
#   'hemoglobin_normal_above_12': 3},
#  'serum_iron': {'serum_iron_35.00_and_below': 0,
#   'serum_iron_above_35.00_to_61.00_and_below': 1,
#   'serum_iron_above_61.00_to_82.00_and_below': 2,
#   'serum_iron_above_82.00_to_106.00_and_below': 3,
#   'serum_iron_above_106.00': 4},
#  'lymphocyte': {'lymphocyte_18.00_and_below': 0,
#   'lymphocyte_above_18.00_to_25.60_and_below': 1,
#   'lymphocyte_above_25.60_to_31.30_and_below': 2,
#   'lymphocyte_above_31.30_to_37.40_and_below': 3,
#   'lymphocyte_above_37.40': 4},
#  'mean_cell_volume': {'mean_cell_volume_77.40_and_below': 0,
#   'mean_cell_volume_above_77.40_to_84.80_and_below': 1,
#   'mean_cell_volume_above_84.80_to_88.40_and_below': 2,
#   'mean_cell_volume_above_88.40_to_91.70_and_below': 3,
#   'mean_cell_volume_above_91.70': 4},
#  'segmented_neutrophils_percent': {'segmented_neutrophils_percent_above_71.90': 0,
#   'segmented_neutrophils_percent_above_63.10_to_71.90_and_below': 1,
#   'segmented_neutrophils_percent_above_57.00_to_63.10_and_below': 2,
#   'segmented_neutrophils_percent_above_50.40_to_57.00_and_below': 3,
#   'segmented_neutrophils_percent_50.40_and_below': 4},
#  'red_cell_distribution_width': {'red_cell_distribution_width_above_16.30': 0,
#   'red_cell_distribution_width_above_14.20_to_16.30_and_below': 1,
#   'red_cell_distribution_width_above_13.50_to_14.20_and_below': 2,
#   'red_cell_distribution_width_above_13.00_to_13.50_and_below': 3,
#   'red_cell_distribution_width_13.00_and_below': 4},
#  'alkaline_phosphatase': {'alkaline_phosphatase_high_above_147': 0,
#   'alkaline_phosphatase_normal_147_to_44': 1,
#   'alkaline_phosphatase_low_below_44': 2},
#  'aspartate_aminotransferase': {'aspartate_aminotransferase_high_above_33': 0,
#   'aspartate_aminotransferase_normal_8_to_33': 1,
#   'aspartate_aminotransferase_low_below_8': 2},
#  'alanine_aminotransferase': {'alanine_aminotransferase_high_above_36': 0,
#   'alanine_aminotransferase_medium_4_to_36': 1,
#   'alanine_aminotransferase_low_below_4': 2},
#  'creatine_phosphokinase': {'creatine_phosphokinase_high_above_192': 0,
#   'creatine_phosphokinase_normal_26_to_192': 1,
#   'creatine_phosphokinase_low_under_26': 2},
#  'creatinine': {'creatinine_high_above_1.2': 0,
#   'creatinine_normal_0.6_to_1.2': 1,
#   'creatinine_low_below_0.6': 2},
#  'gamma_glutamyl_transferase': {'gamma_glutamyl_transferase_high_above_30': 0,
#   'gamma_glutamyl_transferase_normal_30_to_10': 1,
#   'gamma_glutamyl_transferase_low_below_10': 2},
#  'iron': {'iron_36.00_and_below': 0,
#   'iron_above_36.00_to_62.00_and_below': 1,
#   'iron_above_62.00_to_83.00_and_below': 2,
#   'iron_above_83.00_to_107.00_and_below': 3,
#   'iron_above_107.00': 4},
#  'triglycerides': {'triglycerides_high_above_199': 0,
#   'triglycerides_medium_199_to_150': 1,
#   'triglycerides_low_below_150': 2},
#  'uric_acid': {'uric_acid_high_above_8.5': 0,
#   'uric_acid_medium_2.7_to_8.5': 1,
#   'uric_acid_low_below_2.7': 2},
#  'benzonitrile': {'benzonitrile_above_0.17': 0,
#   'benzonitrile_above_0.11_to_0.17_and_below': 1,
#   'benzonitrile_above_0.11_to_0.11_and_below': 3,
#   'benzonitrile_0.11_and_below': 4},
#  'vitamin_C': {'vitamin_C_low_below_0.6': 0,
#   'vitamin_C_medium_0.6_to_2': 1,
#   'vitamin_C_high_above_2': 2},
#  'white_blood_cell_count': {'white_blood_cell_count_low_below_3.4': 0,
#   'white_blood_cell_count_normal_3.4_to_9.6': 1,
#   'white_blood_cell_count_high_above_9.6': 2},
#  'albumin_creatinine_ratio': {'albumin_creatinine_ratio_high_above_300': 0,
#   'albumin_creatinine_ratio_elevated_30_to_300': 1,
#   'albumin_creatinine_ratio_normal_below_30': 2},
#  'volitile_organic_compound': {'volitile_organic_compound_above_309028.71': 0,
#   'volitile_organic_compound_above_93803.69_to_309028.71_and_below': 1,
#   'volitile_organic_compound_above_51906.89_to_93803.69_and_below': 2,
#   'volitile_organic_compound_above_29036.52_to_51906.89_and_below': 3,
#   'volitile_organic_compound_29036.52_and_below': 4},
#  'work_limiting_problem': {'work_limiting_problem_yes': 0,
#   'work_limiting_problem_no': 1},
#  'ten_stairs_difficulty': {'ten_stairs_difficulty_unable': 0,
#   'ten_stairs_difficulty_much': 1,
#   'ten_stairs_difficulty_some': 2,
#   'ten_stairs_difficulty_none': 3},
#  'chore_difficulty': {'chore_difficulty_unable': 0,
#   'chore_difficulty_much': 1,
#   'chore_difficulty_some': 2,
#   'chore_difficulty_none': 3},
#  'walking_difficulty': {'walking_difficulty_unable': 0,
#   'walking_difficulty_much': 1,
#   'walking_difficulty_some': 2,
#   'walking_difficulty_none': 3},
#  'stand_from_sit_difficulty': {'stand_from_sit_difficulty_unable': 0,
#   'stand_from_sit_difficulty_much': 1,
#   'stand_from_sit_difficulty_some': 2,
#   'stand_from_sit_difficulty_none': 3},
#  'two_hour_standing_difficulty': {'two_hour_standing_difficulty_unable': 0,
#   'two_hour_standing_difficulty_much': 1,
#   'two_hour_standing_difficulty_some': 2,
#   'two_hour_standing_difficulty_none': 3},
#  'two_hour_sitting_difficulty': {'two_hour_sitting_difficulty_unable': 0,
#   'two_hour_sitting_difficulty_much': 1,
#   'two_hour_sitting_difficulty_some': 2,
#   'two_hour_sitting_difficulty_none': 3},
#  'social_activity_difficulty': {'social_activity_difficulty_unable': 0,
#   'social_activity_difficulty_much': 1,
#   'social_activity_difficulty_some': 2,
#   'social_activity_difficulty_none': 3},
#  'urine_leakage_bother': {'urine_leakage_bother_greatly': 0,
#   'urine_leakage_bother_very_much': 1,
#   'urine_leakage_bother_somewhat': 2,
#   'urine_leakage_bother_none': 3},
#  'hearing_difficulty_how_often': {'hearing_difficulty_always': 0,
#   'hearing_difficulty_usually': 1,
#   'hearing_difficulty_about_half_the_time': 2,
#   'hearing_difficulty_seldom': 3,
#   'hearing_difficulty_never': 4},
#  'hearing_frustration_how_often': {'hearing_frustration_always': 0,
#   'hearing_frustration_usually': 1,
#   'hearing_frustration_about_half_the_time': 2,
#   'hearing_frustration_seldom': 3,
#   'hearing_frustration_never': 4},
#  'wear_hearing_aid': {'wear_hearing_aid_yes': 0, 'wear_hearing_aid_no': 1},
#  'loud_noise_job': {'loud_noise_job_yes': 0, 'loud_noise_job_no': 1},
#  'loud_music': {'loud_music_yes': 0, 'loud_music_no': 1},
#  'average_oxygen_saturation': {'average_oxygen_saturation_below_93': 0,
#   'average_oxygen_saturation_above_93': 1},
#  'garlic_supplementation': {'garlic_supplementation_yes': 0,
#   'garlic_supplementation_no': 1},
#  'nigella_sativa_supplementation': {'nigella_sativa_supplementation_yes': 0,
#   'nigella_sativa_supplementation_no': 1},
#  'coq10_supplementation': {'coq10_supplementation_yes': 0,
#   'coq10_supplementation_no': 1},
#  'spirulina_supplementation': {'spirulina_supplementation_yes': 0,
#   'spirulina_supplementation_no': 1},
#  'ginger_supplementation': {'ginger_supplementation_yes': 0,
#   'ginger_supplementation_no': 1},
#  'soy_isoflavones_supplementation': {'soy_isoflavones_supplementation_yes': 0,
#   'soy_isoflavones_supplementation_no': 1},
#  'dietary_folate': {'dietary_folate_119.00_and_below': 0,
#   'dietary_folate_above_119.00_to_264.00_and_below': 1,
#   'dietary_folate_above_264.00_to_410.00_and_below': 2,
#   'dietary_folate_above_410.00_to_622.00_and_below': 3,
#   'dietary_folate_above_622.00': 4},
#  'folate': {'folate_low_below_4.5': 0,
#   'folate_normal_4.5_to_45.3': 1,
#   'folate_high_above_45.3': 2},
#  'folate_mefox': {'folate_mefox_0.41_and_below': 0,
#   'folate_mefox_above_0.41_to_0.74_and_below': 1,
#   'folate_mefox_above_0.74_to_1.19_and_below': 2,
#   'folate_mefox_above_1.19_to_2.10_and_below': 3,
#   'folate_mefox_above_2.10': 4},
#  'second_hand_smoke': {'second_hand_smoke_yes': 0, 'second_hand_smoke_no': 1},
#  'five_days_smoke_cigarettes': {'five_days_smoke_cigarettes_yes': 0,
#   'five_days_smoke_cigarettes_no': 1},
#  'ever_vaped': {'ever_vaped_yes': 0, 'ever_vaped_no': 1},
#  'gender': {'male': 0, 'female': 1},
#  'work_schedule': {'work_schedule_evenings_or_nights': 0,
#   'work_schedule_variable': 1,
#   'work_schedule_early_mornings': 2,
#   'work_schedule_9_to_5': 3},
#  'weekend_sleep_hours_per_night': {'weekend_sleep_under_5': 0,
#   'weekend_sleep_5.0_to_6.5': 1,
#   'weekend_sleep_7.0_or_more': 2},
#  'fish_last_month': {'fish_last_month_no': 0, 'fish_last_month_yes': 1},
#  'tuna_eaten_times_per_month': {'tuna_eaten_per_month_8_or_more': 0,
#   'tuna_eaten_per_month_4_to_7': 1,
#   'tuna_eaten_per_month_2_to_3': 2,
#   'tuna_eaten_per_month_0_or_1': 3},
#  'eat_out_how_many_times_per_week': {'eat_out_more_than_7_times_per_week': 0,
#   'eat_out_5_to_7 times_per_week': 1,
#   'eat_out_3_or_4_times_per_week': 2,
#   'eat_out_1_or_2_times_per_week': 3,
#   'eat_out_no_times_per_week': 4},
#  'how_healthy_diet': {'how_healthy_diet_poor': 0,
#   'how_healthy_diet_fair': 1,
#   'how_healthy_diet_good': 2,
#   'how_healthy_diet_very_good': 3,
#   'how_healthy_diet_excellent': 4},
#  'dietary_alpha_carotene': {'dietary_alpha_carotene_0.00_and_below': 0,
#   'dietary_alpha_carotene_above_0.00_to_7.00_and_below': 1,
#   'dietary_alpha_carotene_above_7.00_to_39.00_and_below': 2,
#   'dietary_alpha_carotene_above_39.00_to_179.00_and_below': 3,
#   'dietary_alpha_carotene_above_179.00': 4},
#  'dietary_alpha_tocopherol': {'dietary_alpha_tocopherol_1.98_and_below': 0,
#   'dietary_alpha_tocopherol_above_1.98_to_4.58_and_below': 1,
#   'dietary_alpha_tocopherol_above_4.58_to_7.23_and_below': 2,
#   'dietary_alpha_tocopherol_above_7.23_to_11.07_and_below': 3,
#   'dietary_alpha_tocopherol_above_11.07': 4},
#  'dietary_beta_carotene': {'dietary_beta_carotene_46.00_and_below': 0,
#   'dietary_beta_carotene_above_46.00_to_257.00_and_below': 1,
#   'dietary_beta_carotene_above_257.00_to_726.00_and_below': 2,
#   'dietary_beta_carotene_above_726.00_to_2220.00_and_below': 3,
#   'dietary_beta_carotene_above_2220.00': 4},
#  'water_drank_yesterday': {'water_drank_yesterday_0.00_and_below': 0,
#   'water_drank_yesterday_above_0.00_to_330.00_and_below': 1,
#   'water_drank_yesterday_above_330.00_to_870.00_and_below': 2,
#   'water_drank_yesterday_above_870.00_to_1633.50_and_below': 3,
#   'water_drank_yesterday_above_1633.50': 4},
#  'dietary_pfa': {'dietary_pfa_3.79_and_below': 0,
#   'dietary_pfa_above_3.79_to_9.38_and_below': 1,
#   'dietary_pfa_above_9.38_to_15.26_and_below': 2,
#   'dietary_pfa_above_15.26_to_23.19_and_below': 3,
#   'dietary_pfa_above_23.19': 4},
#  'dietary_fat': {'dietary_fat_above_160.14': 0,
#   'dietary_fat_above_98.77_to_160.14_and_below': 1,
#   'dietary_fat_above_69.25_to_98.77_and_below': 2,
#   'dietary_fat_above_44.92_to_69.25_and_below': 3,
#   'dietary_fat_44.92_and_below': 4},
#  'dietary_b6': {'dietary_b6_0.47_and_below': 0,
#   'dietary_b6_above_0.47_to_1.04_and_below': 1,
#   'dietary_b6_above_1.04_to_1.63_and_below': 2,
#   'dietary_b6_above_1.63_to_2.40_and_below': 3,
#   'dietary_b6_above_2.40': 4},
#  'alcohol_consumption_last_year': {'alcohol_daily': 0,
#   'alcohol_2_to_4_times_per_week': 1,
#   'alcohol_once_per_week_to_once_per_year': 2,
#   'alcohol_never': 3},
#  'num_alcoholic_drinks_when_drinking': {'num_alcohol_8_or_more': 0,
#   'num_alcohol_5_to_7': 1,
#   'num_alcohol_3_to_4': 2,
#   'num_alcohol_1_to_2': 3},
#  'race': {'race_black': 0,
#   'race_hispanic': 1,
#   'race_other': 2,
#   'race_white': 3},
#  'education_level': {'education_level_less_than_9th_grade': 0,
#   'education_level_9th_to_11th_grade': 1,
#   'education_level_high_school_GED': 2,
#   'education_level_at_least_some_college': 3},
#  'have_health_insurance': {'have_health_insurance_no': 0,
#   'have_health_insurance_yes': 1},
#  'prescription_health_insurance': {'prescription_health_insurance_no': 0,
#   'prescription_health_insurance_yes': 1},
#  'how_many_times_saw_doctor_last_year': {'saw_doctor_none_last_year': 0,
#   'saw_doctor_1_or_2_times_last_year': 1,
#   'saw_doctor_3_or_4_times_last_year': 2,
#   'saw_doctor_over_4_times_last_year': 3},
#  'how_long_since_saw_doctor': {'never_saw_a_doctor': 0,
#   'saw_doctor_more_than_5_years_ago': 1,
#   'saw_doctor_2_to_5_years_ago': 2,
#   'saw_doctor_1_to_2_years_ago': 3,
#   'saw_doctor_6_to_12_months_ago': 4,
#   'saw_doctor_less_than_6_months_ago': 5},
#  'what_is_your_annual_household_income': {'under_20K': 0,
#   '20K_to_55K': 1,
#   '56K_to_100K': 2,
#   'over_100K': 3},
#  'employment': {'employment_unemployed': 0,
#   'employment_associated': 1,
#   'employment_not_working': 2,
#   'employment_working': 3},
#  'age_at_first_child': {'age_at_first_child_19_and_below': 0,
#   'age_at_first_child_20_through_24': 1,
#   'age_at_first_child_25_through_29': 2,
#   'age_at_first_child_30_through_33': 3,
#   'age_at_first_child_34_or_older': 4},
#  'last_dentist_visit': {'last_dentist_visit_never': 0,
#   'last_dentist_visit_2_or_more_years': 1,
#   'last_dentist_visit_more_than_1_year_less_than_2_years': 2,
#   'last_dentist_visit_7_months_to_a_year': 3,
#   'last_dentist_visit_6_months_or_less': 4},
#  'dental_bone_loss': {'dental_bone_loss_yes': 0, 'dental_bone_loss_no': 1},
#  'oral_cancer_exam': {'oral_cancer_exam_yes': 0, 'oral_cancer_exam_no': 1},
#  'immunocompromised': {'immunocompromised': 0, 'not_immunocompromised': 1},
#  'glucose_serum': {'glucose_serum_above_155.00': 0,
#   'glucose_serum_above_101.00_to_155.00_and_below': 1,
#   'glucose_serum_above_92.00_to_101.00_and_below': 2,
#   'glucose_serum_above_86.00_to_92.00_and_below': 3,
#   'glucose_serum_86.00_and_below': 4},
#  'daily_fruit_vegetable_servings': {'daily_fruit_vegetable_servings_over_4_no': 0,
#   'daily_fruit_vegetable_servings_over_4_yes': 1},
#  'daily_wholegrain_servings': {'daily_wholegrain_servings_over_2_no': 0,
#   'daily_wholegrain_servings_over_2_yes': 1},
#  'weekly_nut_servings': {'weekly_nut_servings_over_4_no': 0,
#   'weekly_nut_servings_over_4_yes': 1},
#  'weekly_fish_servings': {'weekly_fish_servings_over_2_no': 0,
#   'weekly_fish_servings_over_2_yes': 1},
#  'weekly_processed_meat_servings': {'weekly_processed_meat_servings_over_2_yes': 0,
#   'weekly_processed_meat_servings_over_2_no': 1},
#  'daily_plant_protein_servings': {'daily_plant_protein_servings_over_6': 0,
#   'daily_plant_protein_servings_over_6_no': 1},
#  'dietary_d': {'dietary_d_below_30': 0, 'dietary_d_below_30_no': 1},
#  'angina': {'angina_yes': 0, 'angina_no': 1},
#  'daily_asprin_prescription': {'daily_asprin_prescription_yes': 0,
#   'daily_asprin_prescription_no': 1},
#  'blood_relative_heart_attack_before_age_50': {'blood_relative_heart_attack_before_50_yes': 0,
#   'blood_relative_heart_attack_before_50_no': 1},
#  'chest_pain': {'chest_pain_yes': 0, 'chest_pain_no': 1},
#  'greatest_weight': {'greatest_weight_above_230.00': 0,
#   'no_greatest_weight_above_230.00': 1},
#  'weight': {'weight_above_92.60': 0, 'no_weight_above_92.60': 1},
#  'height': {'height_above_173.40': 0, 'no_height_above_173.40': 1},
#  'hip': {'hip_above_112.70': 0, 'no_hip_above_112.70': 1},
#  'waist': {'waist_above_109.00': 0, 'no_waist_above_109.00': 1},
#  'lack_of_workout_reported': {'lack_of_workout_reported': 0,
#   'no_lack_of_workout_reported': 1},
#  'lack_of_exercise_reported': {'lack_of_exercise_reported': 0,
#   'no_lack_of_exercise_reported': 1},
#  'lack_of_exercise_signal': {'lack_of_exercise_signal': 0,
#   'no_lack_of_exercise_signal': 1},
#  'lack_of_exercise': {'lack_of_exercise': 0, 'no_lack_of_exercise': 1},
#  'workday_sleep_hours_per_night': {'workday_sleep_under_5': 0,
#   'workday_sleep_under_5_no': 1},
#  'obesity_factors': {'obesity_factors': 0, 'no_obesity_factors': 1},
#  'obesity': {'obesity': 0, 'no_obesity': 1},
#  'dna_methylation': {'dna_methylation_above_.3': 0,
#   'dna_methylation_above_.3_no': 1},
#  'LDL': {'LDL_above_160': 0, 'LDL_above_160_no': 1},
#  'direct_HDL': {'direct_HDL_low_below_40': 0, 'direct_HDL_low_below_40_no': 1},
#  'salt_how_often': {'salt_very_often': 0, 'no_salt_very_often': 1},
#  'total_cholesterol': {'total_cholesterol_high_above_200': 0,
#   'no_total_cholesterol_high_above_200': 1},
#  'dietary_sodium': {'dietary_sodium_above_4297.00': 0,
#   'no_dietary_sodium_above_4297.00': 1},
#  'times_brush_teeth_daily': {'times_brush_teeth_daily_1_or_less': 0,
#   'no_times_brush_teeth_daily_1_or_less': 1},
#  'floss_days_per_week': {'floss_days_per_week_3_or_less': 0,
#   'no_floss_days_per_week_3_or_less': 1},
#  'teeth_health': {'teeth_health_poor': 0, 'no_teeth_health_poor': 1},
#  'gum_disease': {'gum_disease_yes': 0, 'gum_disease_no': 1},
#  'mouth_pain_last_year': {'mouth_pain_last_year_fairly_often': 0,
#   'no_mouth_pain_last_year_fairly_often': 1},
#  'smoking': {'smoking': 0, 'no_smoking': 1},
#  'micro_nucleus_frequency': {'micro_nucleus_frequency_above_6': 0,
#   'no_micro_nucleus_frequency_above_6': 1},
#  'cognitive_impairment': {'cognitive_impairment': 0,
#   'no_cognitive_impairment': 1},
#  'interleukin_6': {'interleukin_6_above_5': 0, 'interleukin_6_ab0ve_5_no': 1},
#  'tnf_alpha': {'tnf_alpha_above_9': 0, 'tnf_alpha_above_9_no': 1},
#  'fasting_glucose': {'fasting_glucose_high_above_100': 0,
#   'no_fasting_glucose_high_above_100': 1},
#  'lung_disease': {'lung_disease': 0, 'no_lung_disease': 1},
#  'a1c': {'a1c_diabetes_5.7_and_above': 0, 'no_a1c_diabetes_5.7_and_above': 1},
#  'heart_rate_variability_anomaly': {'heart_rate_variability_anomaly': 0,
#   'no_heart_rate_variability_anomaly': 1},
#  'oxygen_anomaly': {'oxygen_anomaly': 0, 'no_oxygen_anomaly': 1},
#  'sleep_anomaly': {'sleep_anomaly': 0, 'no_sleep_anomaly': 1},
#  'blood_illness_indicators': {'blood_illness_indicators': 0,
#   'no_blood_illness_indicators': 1},
#  'blood_metabolism_disorder_indicators': {'blood_metabolism_disorder_indicators': 0,
#   'no_blood_metabolism_disorder_indicators': 1},
#  'reported_heart_symptoms': {'reported_heart_symptoms': 0,
#   'no_reported_heart_symptoms': 1},
#  'blood_heart_disorder_indicators': {'blood_heart_disorder_indicators': 0,
#   'no_blood_heart_disorder_indicators': 1},
#  'resting_heart_rate': {'resting_heart_rate_very_high_91_and_above': 0,
#   'no_resting_heart_rate_very_high_91_and_above': 1},
#  'signal_heart_disorder_indicators': {'signal_heart_disorder_indicators': 0,
#   'no_signal_heart_disorder_indicators': 1},
#  'heart_disorder_indicators': {'heart_disorder_indicators': 0,
#   'no_heart_disorder_indicators': 1},
#  'blood_mild_liver_disorder_indicators': {'blood_mild_liver_disorder_indicators': 0,
#   'no_blood_mild_liver_disorder_indicators': 1},
#  'severe_blood_liver_disorder_indicators': {'severe_blood_liver_disorder_indicators': 0,
#   'no_severe_blood_liver_disorder_indicators': 1},
#  'liver_disorders': {'liver_disorders': 0, 'no_liver_disorders': 1},
#  'blood_kidney_disorder_indicators': {'blood_kidney_disorder_indicators': 0,
#   'no_blood_kidney_disorder_indicators': 1},
#  'medicated_hypertension': {'medicated_hypertension': 0,
#   'no_medicated_hypertension': 1},
#  'reported_hypertension': {'reported_hypertension': 0,
#   'no_reported_hypertension': 1},
#  'uv_exposure': {'uv_exposure': 0, 'no_uv_exposure': 1},
#  'folate_labs': {'deficient_folate_labs': 0, 'no_deficient_folate_labs': 1},
#  'mineral_labs': {'deficient_mineral_labs': 0,
#   'not_deficient_mineral_labs': 1},
#  'iron_labs': {'deficient_iron_labs': 0, 'no_deficient_iron_labs': 1},
#  'vitamin_and_mineral_labs': {'deficient_vitamin_and_mineral_labs': 0,
#   'no_deficient_vitamin_and_mineral_labs': 1},
#  'toxic_compound_labs': {'toxic_compund_labs': 0, 'no_toxic_compound_labs': 1},
#  'toxic_metal_labs': {'toxic_metal_labs': 0, 'no_toxic_metal_labs': 1},
#  'toxin_labs': {'toxin_labs': 0, 'no_toxin_labs': 1},
#  'red_blood_age_indicators': {'red_blood_age_indicators': 0,
#   'no_red_blood_age_indicators': 1},
#  'white_blood_age_indicators': {'white_blood_age_indicators': 0,
#   'no_white_blood_age_indicators': 1},
#  'blood_age_indicators': {'blood_age_indicators': 0,
#   'no_blood_age_indicators': 1},
#  'poor_oral_health': {'poor_oral_health': 0, 'no_poor_oral_health': 1},
#  'inflammation_from_illness': {'inflammation_from_illness': 0,
#   'no_inflammation_from_illness': 1},
#  'c_reactive_protein': {'c_reactive_protein_high_above_2': 0,
#   'no_c_reactive_protein_high_above_2': 1},
#  'poor_sleep_schedule': {'poor_sleep_schedule': 0,
#   'no_poor_sleep_schedule': 1},
#  'poor_sleep': {'poor_sleep': 0, 'no_poor_sleep': 1},
#  'inflammation_from_behavior': {'inflammation_from_behavior': 0,
#   'no_inflammation_from_behavior': 1},
#  'low_socioeconomic_status_demography': {'low_socioeconomic_status_demography': 0,
#   'middle_socioeconomic_status_demography': 1,
#   'high_low_socioeconomic_status_demography': 2},
#  'low_socioeconomic_status_health_insurance': {'low_socioeconomic_status_health_insurance': 0,
#   'no_low_socioeconomic_status_health_insurance': 1},
#  'low_socioeconomic_status_healthcare': {'low_socioeconomic_status_healthcare': 0,
#   'middle_socioeconomic_status_healthcare': 1,
#   'high_low_socioeconomic_status_healthcare': 2},
#  'low_socioeconomic_status_health': {'low_socioeconomic_status_health': 0,
#   'middle_socioeconomic_status_health': 1,
#   'high_low_socioeconomic_status_health': 2},
#  'low_socioeconomic_status': {'low_socioeconomic_status': 0,
#   'middle_socioeconomic_status': 1,
#   'high_low_socioeconomic_status': 2},
#  'poor_diet_minerals_1': {'poor_diet_minerals_1': 0,
#   'no_poor_diet_minerals_1': 1},
#  'poor_diet_minerals_2': {'poor_diet_minerals_2': 0,
#   'no_poor_diet_minerals_2': 1},
#  'poor_diet_minerals': {'poor_diet_minerals': 0, 'no_poor_diet_minerals': 1},
#  'poor_diet_vitamin_a': {'poor_diet_vitamin_a': 0,
#   'no_poor_diet_vitamin_a': 1},
#  'poor_diet_vitamin_b_1': {'poor_diet_vitamin_b_1': 0,
#   'no_poor_diet_vitamin_b_1': 1},
#  'poor_diet_vitamin_b_2': {'poor_diet_vitamin_b_2': 0,
#   'no_poor_diet_vitamin_b_2': 1},
#  'poor_diet_vitamin_b': {'poor_diet_vitamin_b': 0,
#   'no_poor_diet_vitamin_b': 1},
#  'poor_diet_vitamin_other': {'poor_diet_vitamin_other': 0,
#   'no_poor_diet_vitamin_other': 1},
#  'poor_diet_vitamins_and_minerals': {'poor_diet_vitamins_and_minerals': 0,
#   'no_poor_diet_vitamins_and_minerals': 1},
#  'omega_3': {'deficient_omega_3': 0, 'no_deficient_omega_3': 1},
#  'poor_diet_fats': {'poor_diet_fats': 0, 'no_poor_diet_fats': 1},
#  'poor_diet_basics': {'poor_diet_basics': 0, 'no_poor_diet_basics': 1},
#  'poor_diet_supplements': {'poor_diet_supplements': 0,
#   'no_poor_diet_supplements': 1},
#  'poor_diet_substances': {'poor_diet_substances': 0,
#   'no_poor_diet_substances': 1},
#  'poor_diet_quantity': {'poor_diet_quantity': 0, 'no_poor_diet_quantity': 1},
#  'poor_diet_food': {'poor_diet_food': 0, 'no_poor_diet_food': 1},
#  'poor_diet_flag': {'poor_diet_flag': 0, 'no_poor_diet_flag': 1},
#  'diet_minerals_1': {'deficient_diet_minerals_1': 0,
#   'below_average_diet_minerals_1': 1,
#   'average_diet_minerals_1': 2,
#   'above_average_diet_minerals_1': 3,
#   'excellent_diet_minerals_1': 4},
#  'diet_minerals_2': {'deficient_diet_minerals_2': 0,
#   'below_average_diet_minerals_2': 1,
#   'average_diet_minerals_2': 2,
#   'above_average_diet_minerals_2': 3,
#   'excellent_diet_minerals_2': 4},
#  'diet_minerals': {'deficient_diet_minerals': 0,
#   'below_average_diet_minerals': 1,
#   'average_diet_minerals': 2,
#   'above_average_diet_minerals': 3,
#   'excellent_diet_minerals': 4},
#  'diet_vitamin_a': {'deficient_diet_vitamin_a': 0,
#   'below_average_diet_vitamin_a': 1,
#   'average_diet_vitamin_a': 2,
#   'above_average_diet_vitamin_a': 3,
#   'excellent_diet_vitamin_a': 4},
#  'diet_vitamin_b_1': {'deficient_diet_vitamin_b_1': 0,
#   'below_average_diet_vitamin_b_1': 1,
#   'average_diet_vitamin_b_1': 2,
#   'above_average_diet_vitamin_b_1': 3,
#   'excellent_diet_vitamin_b_1': 4},
#  'diet_vitamin_b_2': {'deficient_diet_vitamin_b_2': 0,
#   'below_average_diet_vitamin_b_2': 1,
#   'average_diet_vitamin_b_2': 2,
#   'above_average_diet_vitamin_b_2': 3,
#   'excellent_diet_vitamin_b_2': 4},
#  'diet_vitamin_b': {'deficient_diet_vitamin_b': 0,
#   'below_average_diet_vitamin_b': 1,
#   'average_diet_vitamin_b': 2,
#   'above_average_diet_vitamin_b': 3,
#   'excellent_diet_vitamin_b': 4},
#  'diet_vitamin_other': {'deficient_diet_vitamin_other': 0,
#   'below_average_diet_vitamin_other': 1,
#   'average_diet_vitamin_other': 2,
#   'above_average_diet_vitamin_other': 3,
#   'excellent_diet_vitamin_other': 4},
#  'diet_vitamins_and_minerals': {'deficient_diet_vitamins_and_minerals': 0,
#   'below_average_diet_vitamins_and_minerals': 1,
#   'average_diet_vitamins_and_minerals': 2,
#   'above_average_diet_vitamins_and_minerals': 3,
#   'excellent_diet_vitamins_and_minerals': 4},
#  'diet_fats': {'deficient_diet_fats': 0,
#   'below_average_diet_fats': 1,
#   'avg_diet_fats': 2,
#   'above_average_diet_fats': 3,
#   'excellent_diet_fats': 4},
#  'diet_basics': {'deficient_diet_basics': 0,
#   'below_average_diet_basics': 1,
#   'avg_diet_basics': 2,
#   'above_average_diet_basics': 3,
#   'excellent_diet_basics': 4},
#  'diet_supplements': {'deficient_diet_supplements': 0,
#   'below_average_diet_supplements': 1,
#   'avg_diet_supplements': 2,
#   'above_average_diet_supplements': 3,
#   'excellent_diet_supplements': 4},
#  'diet_substances': {'deficient_diet_substances': 0,
#   'below_average_diet_substances': 1,
#   'avg_diet_substances': 2,
#   'above_average_diet_substances': 3,
#   'excellent_diet_substances': 4},
#  'diet_quality_food': {'deficient_diet_quality_food': 0,
#   'below_average_diet_quality_food': 1,
#   'avg_diet_quality_food': 2,
#   'above_average_diet_quality_food': 3,
#   'excellent_diet_quality_food': 4},
#  'diet_quantity': {'deficient_diet_quantity': 0,
#   'below_average_diet_quantity': 1,
#   'avg_diet_quantity': 2,
#   'above_average_diet_quantity': 3,
#   'excellent_diet_quantity': 4},
#  'diet_quality': {'deficient_diet_quality': 0,
#   'below_average_diet_quality': 1,
#   'avg_diet_quality': 2,
#   'above_average_diet_quality': 3,
#   'excellent_diet_quality': 4},
#  'poor_diet': {'poor_diet': 0, 'no_poor_diet': 1},
#  'inflammation_from_diet': {'inflammation_from_diet': 0,
#   'no_inflammation_from_diet': 1},
#  'inflammation': {'inflammation': 0, 'no_inflammation': 1},
#  'hypertension_from_behavior': {'hypertension_from_behavior': 0,
#   'no_hypertension_from_behavior': 1},
#  'hypertension': {'hypertension': 0, 'no_hypertension': 1},
#  'kidney_disease': {'kidney_disease': 0, 'no_kidney_disease': 1},
#  'psychological_disorders': {'psychological_disorders': 0,
#   'no_psychological_disorders': 1},
#  'age_acceleration_from_behavior': {'age_acceleration_from_behavior': 0,
#   'no_age_acceleration_from_behavior': 1},
#  'age_acceleration_from_movement': {'age_acceleration_from_movement': 0,
#   'no_age_acceleration_from_movement': 1},
#  'age_acceleration_from_nutrition': {'age_acceleration_from_nutrition': 0,
#   'no_age_acceleration_from_nutrition': 1},
#  'age_acceleration': {'age_acceleration': 0, 'no_age_acceleration': 1},
#  'hearing_difficulty': {'hearing_difficulty': 0, 'no_hearing_difficulty': 1},
#  'general_aging_signs': {'general_aging_signs': 0,
#   'no_general_aging_signs': 1},
#  'sarcopenia_movement': {'sarcopenia_movement': 0,
#   'no_sarcopenia_movement': 1},
#  'sarcopenia_function': {'sarcopenia_function': 0,
#   'no_sarcopenia_function': 1},
#  'sarcopenia_reported': {'sarcopenia_reported': 0,
#   'no_sarcopenia_reported': 1},
#  'frailty_signals': {'frailty_signals': 0, 'no_frailty_signals': 1},
#  'sarcopenia': {'sarcopenia': 0, 'no_sarcpenia': 1},
#  'inactivated_sirtuins': {'inactivated_sirtuins': 0,
#   'no_inactivated_sirtuins': 1},
#  'frailty_signs': {'frailty_signs': 0, 'no_frailty_signs': 1},
#  'hallmark_1_genomic_instability': {'hallmark_1_genomic_instability': 0,
#   'no_hallmark_1_genomic_instability': 1},
#  'hallmark_2_telomere_attrition': {'hallmark_2_telomere_attrition': 0,
#   'no_hallmark_2_telomere_attrition': 1},
#  'age_related_macular_degeneration': {'age_related_macular_degeneration': 0,
#   'no_age_related_macular_degeneration': 1},
#  'diabetes_from_behavior': {'diabetes_from_behavior': 0,
#   'no_diabetes_from_behavior': 1},
#  'diabetes': {'diabetes': 0, 'no_diabetes': 1},
#  'hallmark_6_mitochondrial_dysfunction': {'hallmark_6_mitochondrial_dysfunction': 0,
#   'no_hallmark_6_mitochondrial_dysfunction': 1},
#  'cardiovascular_disease_from_behavior': {'cardiovascular_disease_from_behavior': 0,
#   'no_cardiovascular_disease_from_behavior': 1},
#  'cardiovascular_disease': {'cardiovascular_disease': 0,
#   'no_cardiovascular_disease': 1},
#  'metabolic_disease': {'metabolic_disease': 0, 'no_metabolic_disease': 1},
#  'lung_or_kidney_or_liver_disease': {'lung_or_kidney_or_liver_disease': 0,
#   'no_lung_or_kidney_or_liver_disease': 1},
#  'chronic_conditions': {'chronic_conditions': 0, 'no_chronic_conditions': 1},
#  'comorbidities': {'comorbidities': 0, 'no_comorbidities': 1},
#  'frailty_measures': {'frailty_measures': 0, 'no_frailty_measures': 1},
#  'frailty': {'frailty': 0, 'no_frailty': 1},
#  'hallmark_3_epigenetic_alterations': {'hallmark_3_epigenetic_alterations': 0,
#   'no_hallmark_3_epigenetic_alterations': 1},
#  'cancer_from_behavior': {'cancer_from_behavior': 0,
#   'no_cancer_from_behavior': 1},
#  'cancer': {'cancer': 0, 'no_cancer': 1},
#  'hallmark_7_cellular_senescence': {'hallmark_7_cellular_senescence': 0,
#   'no_hallmark_7_cellular_senescence': 1},
#  'mitochondrial_dysfunction_or_cellular_senescence': {'mitochondrial_dysfunction_or_cellular_senescence': 0,
#   'no_mitochondrial_dysfunction_or_cellular_senescence': 1},
#  'hallmark_4_loss_of_proteostasis': {'hallmark_4_loss_of_proteostasis': 0,
#   'no_hallmark_4_loss_of_proteostasis': 1},
#  'alzheimers_disease': {'alzheimers_disease': 0, 'no_alzheimers_disease': 1},
#  'hallmark_5_deregulated_nutrient_sensing': {'hallmark_5_deregulated_nutrient_sensing': 0,
#   'no_hallmark_5_deregulated_nutrient_sensing': 1},
#  'hallmark_8_stem_cell_exhaustion': {'hallmark_8_stem_cell_exhaustion': 0,
#   'no_hallmark_8_stem_cell_exhaustion': 1},
#  'hallmark_9_altered_intercellular_communication': {'hallmark_9_altered_intercellular_communication': 0,
#   'no_hallmark_9_altered_intercellular_communication': 1},
#  'hallmark_10_extracellular_matrix_dysfunction': {'hallmark_10_extracellular_matrix_dysfunction': 0,
#   'no_hallmark_10_extracellular_matrix_dysfunction': 1},
#  'parkinsons_disease': {'parkinsons_disease': 0, 'no_parkinsons_disease': 1}}

# %%
original_outvars = ["hallmark_1_genomic_instability","hallmark_2_telomere_attrition","hallmark_3_epigenetic_alterations","hallmark_4_loss_of_proteostasis",
        "hallmark_5_deregulated_nutrient_sensing","hallmark_6_mitochondrial_dysfunction","hallmark_7_cellular_senescence","hallmark_8_stem_cell_exhaustion",
        "hallmark_9_altered_intercellular_communication","hallmark_10_extracellular_matrix_dysfunction","poor_diet",
        "poor_diet_flag","poor_sleep","psychological_disorders","obesity","lack_of_exercise","poor_diet_quantity","smoking"]
explainvars=outvars
include_list.extend(["lack_of_exercise_signal","resting_heart_rate","signal_heart_disorders_indicators","steps_anomaly","workout_anomaly","heart_rate_anomaly","step_asymmetry_anomaly","step_variability_anomaly",
 "stride_variability_anomaly","heart_rate_variability_anomaly","walking_speed_variability_anomaly"])
query = Query()
query.switch = "internal_query"
for v in include_list:
    if v in var_positions:
        outvar = query.include_list.add()
        outvar.var_num = var_positions[v]
for var,val  in  evidence.items():
    e= query.evidence.add()
    e.var_num = var_positions[var] if var in var_positions else 0
    e.response = var_val_positions[var][val] if var in var_positions and val in var_val_positions[var] else 0
for o in outvars:
    outvar = query.outvars.add()
    outvar.var_num = var_positions[o] if o in var_positions else 0
for v in explainvars:
    if v in var_positions:
        explainvar = query.explainvars.add()
        explainvar.var_num = var_positions[v]
for var,data_dict in data.items():
    print("var")
    print(var)
    timeseries = query.timeseries.add()
    timeseries.var_num = var_positions[var] if var in var_positions else 0
    for r in data_dict["data"]:
        time = timeseries.timevals.add()
        time.val = r["value"] if "value" in r else 0
        time.interval = r["interval_in_second"] if "interval_in_second" in r else 0
        last = time.interval
    # put anomaly in last timeframe    
    time = timeseries.timevals.add()
    time.interval = last
    if var == "steps_anomaly":
        time.val = 0
    elif var == "workout_anomaly":
        time.val = 0
    elif var == "heart_rate_anomaly":
        time.val = 125
    elif var == "step_asymmetry_anomaly":
        time.val = 0.99  
    elif var == "step_variability_anomaly":
        time.val = 1000000 #you cant really make variability change just by changing the last number
    elif var == "stride_variability_anomaly":
        time.val = 20.0
    elif var == "heart_rate_variability_anomaly":
        time.val = 125 # correct to hrv val when fixed
    elif var == "walking_speed_variability_anomaly":
        time.val = 50.0
# Out:
# var
# steps_anomaly
# var
# workout_anomaly
# var
# heart_rate_anomaly
# var
# step_asymmetry_anomaly
# var
# step_variability_anomaly
# var
# stride_variability_anomaly
# var
# heart_rate_variability_anomaly
# var
# walking_speed_variability_anomaly

# %%
query
# Out:
# evidence {
#   var_num: 1
#   response: 1
# }
# evidence {
#   var_num: 12
# }
# evidence {
#   var_num: 104
#   response: 1
# }
# evidence {
#   var_num: 168
#   response: 1
# }
# evidence {
#   var_num: 167
# }
# evidence {
#   var_num: 6
#   response: 2
# }
# evidence {
#   var_num: 5
#   response: 2
# }
# evidence {
#   var_num: 204
#   response: 1
# }
# outvars {
#   var_num: 288
# }
# outvars {
#   var_num: 289
# }
# outvars {
#   var_num: 302
# }
# outvars {
#   var_num: 307
# }
# outvars {
#   var_num: 309
# }
# outvars {
#   var_num: 293
# }
# outvars {
#   var_num: 305
# }
# outvars {
#   var_num: 310
# }
# outvars {
#   var_num: 311
# }
# outvars {
#   var_num: 312
# }
# outvars {
#   var_num: 268
# }
# outvars {
#   var_num: 251
# }
# outvars {
#   var_num: 228
# }
# outvars {
#   var_num: 274
# }
# outvars {
#   var_num: 177
# }
# outvars {
#   var_num: 174
# }
# outvars {
#   var_num: 249
# }
# outvars {
#   var_num: 189
# }
# outvars {
#   var_num: 13
# }
# outvars {
#   var_num: 12
# }
# outvars {
#   var_num: 174
# }
# outvars {
#   var_num: 29
# }
# outvars {
#   var_num: 16
# }
# outvars {
#   var_num: 15
# }
# outvars {
#   var_num: 120
# }
# outvars {
#   var_num: 109
# }
# outvars {
#   var_num: 102
# }
# outvars {
#   var_num: 104
# }
# outvars {
#   var_num: 19
# }
# outvars {
#   var_num: 30
# }
# outvars {
#   var_num: 27
# }
# outvars {
#   var_num: 20
# }
# outvars {
#   var_num: 18
# }
# outvars {
#   var_num: 21
# }
# outvars {
#   var_num: 223
# }
# outvars {
#   var_num: 226
# }
# outvars {
#   var_num: 304
# }
# outvars {
# }
# outvars {
#   var_num: 295
# }
# outvars {
#   var_num: 298
# }
# outvars {
#   var_num: 299
# }
# outvars {
#   var_num: 292
# }
# outvars {
#   var_num: 267
# }
# outvars {
#   var_num: 301
# }
# outvars {
#   var_num: 284
# }
# outvars {
#   var_num: 287
# }
# outvars {
#   var_num: 197
# }
# outvars {
#   var_num: 272
# }
# outvars {
#   var_num: 286
# }
# outvars {
#   var_num: 270
# }
# outvars {
#   var_num: 229
# }
# outvars {
#   var_num: 269
# }
# outvars {
#   var_num: 273
# }
# outvars {
#   var_num: 174
# }
# outvars {
#   var_num: 297
# }
# outvars {
#   var_num: 296
# }
# outvars {
#   var_num: 198
# }
# outvars {
#   var_num: 268
# }
# outvars {
#   var_num: 251
# }
# outvars {
#   var_num: 224
# }
# outvars {
#   var_num: 228
# }
# outvars {
#   var_num: 274
# }
# outvars {
#   var_num: 285
# }
# outvars {
#   var_num: 199
# }
# outvars {
#   var_num: 189
# }
# outvars {
#   var_num: 213
# }
# outvars {
#   var_num: 209
# }
# outvars {
#   var_num: 206
# }
# outvars {
#   var_num: 225
# }
# outvars {
#   var_num: 249
# }
# outvars {
#   var_num: 280
# }
# outvars {
#   var_num: 172
# }
# outvars {
#   var_num: 262
# }
# outvars {
#   var_num: 261
# }
# outvars {
#   var_num: 265
# }
# outvars {
#   var_num: 266
# }
# outvars {
#   var_num: 260
# }
# outvars {
#   var_num: 201
# }
# outvars {
#   var_num: 177
# }
# outvars {
#   var_num: 227
# }
# outvars {
#   var_num: 173
# }
# outvars {
#   var_num: 204
# }
# outvars {
# }
# outvars {
#   var_num: 20
# }
# outvars {
#   var_num: 21
# }
# outvars {
#   var_num: 19
# }
# outvars {
#   var_num: 25
# }
# outvars {
#   var_num: 27
# }
# outvars {
#   var_num: 24
# }
# outvars {
#   var_num: 197
# }
# outvars {
#   var_num: 23
# }
# explainvars {
#   var_num: 288
# }
# explainvars {
#   var_num: 289
# }
# explainvars {
#   var_num: 302
# }
# explainvars {
#   var_num: 307
# }
# explainvars {
#   var_num: 309
# }
# explainvars {
#   var_num: 293
# }
# explainvars {
#   var_num: 305
# }
# explainvars {
#   var_num: 310
# }
# explainvars {
#   var_num: 311
# }
# explainvars {
#   var_num: 312
# }
# explainvars {
#   var_num: 268
# }
# explainvars {
#   var_num: 251
# }
# explainvars {
#   var_num: 228
# }
# explainvars {
#   var_num: 274
# }
# explainvars {
#   var_num: 177
# }
# explainvars {
#   var_num: 174
# }
# explainvars {
#   var_num: 249
# }
# explainvars {
#   var_num: 189
# }
# explainvars {
#   var_num: 13
# }
# explainvars {
#   var_num: 12
# }
# explainvars {
#   var_num: 174
# }
# explainvars {
#   var_num: 29
# }
# explainvars {
#   var_num: 16
# }
# explainvars {
#   var_num: 15
# }
# explainvars {
#   var_num: 120
# }
# explainvars {
#   var_num: 109
# }
# explainvars {
#   var_num: 102
# }
# explainvars {
#   var_num: 104
# }
# explainvars {
#   var_num: 19
# }
# explainvars {
#   var_num: 30
# }
# explainvars {
#   var_num: 27
# }
# explainvars {
#   var_num: 20
# }
# explainvars {
#   var_num: 18
# }
# explainvars {
#   var_num: 21
# }
# explainvars {
#   var_num: 223
# }
# explainvars {
#   var_num: 226
# }
# explainvars {
#   var_num: 304
# }
# explainvars {
#   var_num: 295
# }
# explainvars {
#   var_num: 298
# }
# explainvars {
#   var_num: 299
# }
# explainvars {
#   var_num: 292
# }
# explainvars {
#   var_num: 267
# }
# explainvars {
#   var_num: 301
# }
# explainvars {
#   var_num: 284
# }
# explainvars {
#   var_num: 287
# }
# explainvars {
#   var_num: 197
# }
# explainvars {
#   var_num: 272
# }
# explainvars {
#   var_num: 286
# }
# explainvars {
#   var_num: 270
# }
# explainvars {
#   var_num: 229
# }
# explainvars {
#   var_num: 269
# }
# explainvars {
#   var_num: 273
# }
# explainvars {
#   var_num: 174
# }
# explainvars {
#   var_num: 297
# }
# explainvars {
#   var_num: 296
# }
# explainvars {
#   var_num: 198
# }
# explainvars {
#   var_num: 268
# }
# explainvars {
#   var_num: 251
# }
# explainvars {
#   var_num: 224
# }
# explainvars {
#   var_num: 228
# }
# explainvars {
#   var_num: 274
# }
# explainvars {
#   var_num: 285
# }
# explainvars {
#   var_num: 199
# }
# explainvars {
#   var_num: 189
# }
# explainvars {
#   var_num: 213
# }
# explainvars {
#   var_num: 209
# }
# explainvars {
#   var_num: 206
# }
# explainvars {
#   var_num: 225
# }
# explainvars {
#   var_num: 249
# }
# explainvars {
#   var_num: 280
# }
# explainvars {
#   var_num: 172
# }
# explainvars {
#   var_num: 262
# }
# explainvars {
#   var_num: 261
# }
# explainvars {
#   var_num: 265
# }
# explainvars {
#   var_num: 266
# }
# explainvars {
#   var_num: 260
# }
# explainvars {
#   var_num: 201
# }
# explainvars {
#   var_num: 177
# }
# explainvars {
#   var_num: 227
# }
# explainvars {
#   var_num: 173
# }
# explainvars {
#   var_num: 204
# }
# explainvars {
#   var_num: 20
# }
# explainvars {
#   var_num: 21
# }
# explainvars {
#   var_num: 19
# }
# explainvars {
#   var_num: 25
# }
# explainvars {
#   var_num: 27
# }
# explainvars {
#   var_num: 24
# }
# explainvars {
#   var_num: 197
# }
# explainvars {
#   var_num: 23
# }
# timeseries {
#   var_num: 20
#   timevals {
#     val: 4825.0
#   }
#   timevals {
#     val: 7783.0
#     interval: 87868.0
#   }
#   timevals {
#     val: 7594.0
#     interval: 82527.0
#   }
#   timevals {
#     val: 1137.0
#     interval: 86758.0
#   }
#   timevals {
#     val: 987.0
#     interval: 89220.0
#   }
#   timevals {
#     val: 3667.0
#     interval: 84852.0
#   }
#   timevals {
#     val: 6247.0
#     interval: 85791.0
#   }
#   timevals {
#     val: 5142.0
#     interval: 168067.0
#   }
#   timevals {
#     val: 4973.0
#     interval: 89427.0
#   }
#   timevals {
#     val: 3428.0
#     interval: 89698.0
#   }
#   timevals {
#     val: 6857.0
#     interval: 85390.0
#   }
#   timevals {
#     val: 4291.0
#     interval: 86510.0
#   }
#   timevals {
#     val: 9153.0
#     interval: 88121.0
#   }
#   timevals {
#     val: 3425.0
#     interval: 85719.0
#   }
#   timevals {
#     val: 2222.0
#     interval: 86950.0
#   }
#   timevals {
#     val: 3564.0
#     interval: 86654.0
#   }
#   timevals {
#     val: 7436.0
#     interval: 81407.0
#   }
#   timevals {
#     val: 3215.0
#     interval: 91464.0
#   }
#   timevals {
#     val: 3649.0
#     interval: 86510.0
#   }
#   timevals {
#     val: 2310.0
#     interval: 86696.0
#   }
#   timevals {
#     val: 8051.0
#     interval: 85810.0
#   }
#   timevals {
#     val: 4107.0
#     interval: 82772.0
#   }
#   timevals {
#     val: 4090.0
#     interval: 80169.0
#   }
#   timevals {
#     val: 11381.0
#     interval: 95415.0
#   }
#   timevals {
#     val: 10472.0
#     interval: 83412.0
#   }
#   timevals {
#     val: 4433.0
#     interval: 90790.0
#   }
#   timevals {
#     val: 2541.0
#     interval: 85980.0
#   }
#   timevals {
#     val: 4907.0
#     interval: 85379.0
#   }
#   timevals {
#     val: 2395.0
#     interval: 86197.0
#   }
#   timevals {
#     val: 39.0
#     interval: 3780.0
#   }
#   timevals {
#     interval: 3780.0
#   }
# }
# timeseries {
#   var_num: 21
#   timevals {
#     val: 1800.0
#   }
#   timevals {
#     val: 2100.0
#     interval: 79620.0
#   }
#   timevals {
#     val: 1800.0
#     interval: 84600.0
#   }
#   timevals {
#     val: 60.0
#     interval: 22680.0
#   }
#   timevals {
#     val: 60.0
#     interval: 148740.0
#   }
#   timevals {
#     val: 780.0
#     interval: 87240.0
#   }
#   timevals {
#     val: 1860.0
#     interval: 95340.0
#   }
#   timevals {
#     val: 2460.0
#     interval: 89640.0
#   }
#   timevals {
#     val: 1800.0
#     interval: 51840.0
#   }
#   timevals {
#     val: 1800.0
#     interval: 108420.0
#   }
#   timevals {
#     val: 900.0
#     interval: 95100.0
#   }
#   timevals {
#     val: 2460.0
#     interval: 86220.0
#   }
#   timevals {
#     val: 1560.0
#     interval: 76740.0
#   }
#   timevals {
#     val: 2340.0
#     interval: 95820.0
#   }
#   timevals {
#     val: 1200.0
#     interval: 87660.0
#   }
#   timevals {
#     val: 720.0
#     interval: 68760.0
#   }
#   timevals {
#     val: 480.0
#     interval: 92100.0
#   }
#   timevals {
#     val: 2820.0
#     interval: 87480.0
#   }
#   timevals {
#     val: 420.0
#     interval: 95100.0
#   }
#   timevals {
#     val: 1380.0
#     interval: 84360.0
#   }
#   timevals {
#     val: 180.0
#     interval: 90660.0
#   }
#   timevals {
#     val: 2760.0
#     interval: 87360.0
#   }
#   timevals {
#     val: 1560.0
#     interval: 63780.0
#   }
#   timevals {
#     val: 1800.0
#     interval: 93420.0
#   }
#   timevals {
#     val: 4320.0
#     interval: 83700.0
#   }
#   timevals {
#     val: 2760.0
#     interval: 99960.0
#   }
#   timevals {
#     val: 1440.0
#     interval: 93360.0
#   }
#   timevals {
#     val: 480.0
#     interval: 85800.0
#   }
#   timevals {
#     val: 1320.0
#     interval: 85620.0
#   }
#   timevals {
#     val: 540.0
#     interval: 63480.0
#   }
#   timevals {
#     interval: 63480.0
#   }
# }
# timeseries {
#   var_num: 19
#   timevals {
#     val: 94.53697967529297
#   }
#   timevals {
#     val: 90.43693542480469
#     interval: 86479.0
#   }
#   timevals {
#     val: 89.28541564941406
#     interval: 86525.0
#   }
#   timevals {
#     val: 82.4201889038086
#     interval: 31865.0
#   }
#   timevals {
#     val: 94.99578857421875
#     interval: 140760.0
#   }
#   timevals {
#     val: 85.72321319580078
#     interval: 86151.0
#   }
#   timevals {
#     val: 85.97811126708984
#     interval: 86347.0
#   }
#   timevals {
#     val: 86.36439514160156
#     interval: 86565.0
#   }
#   timevals {
#     val: 86.76026153564453
#     interval: 51658.0
#   }
#   timevals {
#     val: 92.28282165527344
#     interval: 121293.0
#   }
#   timevals {
#     val: 83.23304748535156
#     interval: 86510.0
#   }
#   timevals {
#     val: 83.72701263427734
#     interval: 86432.0
#   }
#   timevals {
#     val: 86.94314575195312
#     interval: 86265.0
#   }
#   timevals {
#     val: 93.31916809082031
#     interval: 86396.0
#   }
#   timevals {
#     val: 90.241943359375
#     interval: 86407.0
#   }
#   timevals {
#     val: 88.85833740234375
#     interval: 86344.0
#   }
#   timevals {
#     val: 88.22179412841797
#     interval: 86473.0
#   }
#   timevals {
#     val: 89.95833587646484
#     interval: 86357.0
#   }
#   timevals {
#     val: 84.48041534423828
#     interval: 86532.0
#   }
#   timevals {
#     val: 88.005859375
#     interval: 85729.0
#   }
#   timevals {
#     val: 88.18604278564453
#     interval: 87078.0
#   }
#   timevals {
#     val: 94.60328674316406
#     interval: 86354.0
#   }
#   timevals {
#     val: 90.29940032958984
#     interval: 86251.0
#   }
#   timevals {
#     val: 90.15767669677734
#     interval: 85317.0
#   }
#   timevals {
#     val: 95.7617416381836
#     interval: 87731.0
#   }
#   timevals {
#     val: 89.28096771240234
#     interval: 86414.0
#   }
#   timevals {
#     val: 84.03759765625
#     interval: 86086.0
#   }
#   timevals {
#     val: 84.53218078613281
#     interval: 86714.0
#   }
#   timevals {
#     val: 86.03901672363281
#     interval: 86400.0
#   }
#   timevals {
#     val: 79.875
#     interval: 88930.0
#   }
#   timevals {
#     val: 125.0
#     interval: 88930.0
#   }
# }
# timeseries {
#   var_num: 25
#   timevals {
#     val: 0.24500000476837158
#   }
#   timevals {
#     val: 0.04500000178813934
#     interval: 83892.0
#   }
#   timevals {
#     val: 0.22499999403953552
#     interval: 440412.0
#   }
#   timevals {
#     val: 0.1066666692495346
#     interval: 74508.0
#   }
#   timevals {
#     val: 0.09000000357627869
#     interval: 99326.0
#   }
#   timevals {
#     val: 0.6200000047683716
#     interval: 49036.0
#   }
#   timevals {
#     val: 0.1133333370089531
#     interval: 90793.0
#   }
#   timevals {
#     interval: 85417.0
#   }
#   timevals {
#     val: 0.38499999046325684
#     interval: 117316.0
#   }
#   timevals {
#     val: 0.18000000715255737
#     interval: 79867.0
#   }
#   timevals {
#     val: 0.3149999976158142
#     interval: 245276.0
#   }
#   timevals {
#     val: 0.550000011920929
#     interval: 418594.0
#   }
#   timevals {
#     val: 0.5385714173316956
#     interval: 200142.0
#   }
#   timevals {
#     val: 0.6000000238418579
#     interval: 81009.0
#   }
#   timevals {
#     val: 0.36000001430511475
#     interval: 151817.0
#   }
#   timevals {
#     val: 0.9900000095367432
#     interval: 151817.0
#   }
# }
# timeseries {
#   var_num: 27
#   timevals {
#     val: 299.0
#   }
#   timevals {
#     val: 639.0
#     interval: 375.0
#   }
#   timevals {
#     val: 464.0
#     interval: 226.0
#   }
#   timevals {
#     val: 233.0
#     interval: 420.0
#   }
#   timevals {
#     val: 295.0
#     interval: 335.0
#   }
#   timevals {
#     val: 684.0
#     interval: 344.0
#   }
#   timevals {
#     val: 355.0
#     interval: 290.0
#   }
#   timevals {
#     val: 64.0
#     interval: 310.0
#   }
#   timevals {
#     val: 71.0
#     interval: 670.0
#   }
#   timevals {
#     val: 17.0
#     interval: 2336.0
#   }
#   timevals {
#     val: 164.0
#     interval: 70.0
#   }
#   timevals {
#     val: 106.0
#     interval: 33.0
#   }
#   timevals {
#     val: 19.0
#     interval: 59.0
#   }
#   timevals {
#     val: 207.0
#     interval: 83.0
#   }
#   timevals {
#     val: 25.0
#     interval: 591.0
#   }
#   timevals {
#     val: 25.0
#     interval: 8.0
#   }
#   timevals {
#     val: 10.0
#     interval: 888.0
#   }
#   timevals {
#     val: 30.0
#     interval: 715.0
#   }
#   timevals {
#     val: 88.0
#     interval: 5230.0
#   }
#   timevals {
#     val: 9.0
#     interval: 1402.0
#   }
#   timevals {
#     val: 105.0
#     interval: 1375.0
#   }
#   timevals {
#     val: 79.0
#     interval: 11.0
#   }
#   timevals {
#     val: 26.0
#     interval: 976.0
#   }
#   timevals {
#     val: 30.0
#     interval: 3.0
#   }
#   timevals {
#     val: 58.0
#     interval: 3291.0
#   }
#   timevals {
#     val: 23.0
#     interval: 7.0
#   }
#   timevals {
#     val: 38.0
#     interval: 85.0
#   }
#   timevals {
#     val: 3.0
#     interval: 288.0
#   }
#   timevals {
#     val: 29.0
#     interval: 1175.0
#   }
#   timevals {
#     val: 1.0
#     interval: 1155.0
#   }
#   timevals {
#     val: 1000000.0
#     interval: 1155.0
#   }
# }
# timeseries {
#   var_num: 24
#   timevals {
#     val: 0.5699999928474426
#   }
#   timevals {
#     val: 0.5799999833106995
#     interval: 43.0
#   }
#   timevals {
#     val: 0.6700000166893005
#     interval: 2937.0
#   }
#   timevals {
#     val: 0.4300000071525574
#     interval: 88240.0
#   }
#   timevals {
#     val: 0.5600000023841858
#     interval: 4196.0
#   }
#   timevals {
#     val: 0.46000000834465027
#     interval: 1183.0
#   }
#   timevals {
#     val: 0.5199999809265137
#     interval: 63.0
#   }
#   timevals {
#     val: 0.47999998927116394
#     interval: 140.0
#   }
#   timevals {
#     val: 0.38999998569488525
#     interval: 308.0
#   }
#   timevals {
#     val: 0.5199999809265137
#     interval: 685.0
#   }
#   timevals {
#     val: 0.5600000023841858
#     interval: 34.0
#   }
#   timevals {
#     val: 0.5
#     interval: 261.0
#   }
#   timevals {
#     val: 0.5199999809265137
#     interval: 57.0
#   }
#   timevals {
#     val: 0.47999998927116394
#     interval: 64.0
#   }
#   timevals {
#     val: 0.4399999976158142
#     interval: 85.0
#   }
#   timevals {
#     val: 0.46000000834465027
#     interval: 1984358.0
#   }
#   timevals {
#     val: 0.46000000834465027
#     interval: 72.0
#   }
#   timevals {
#     val: 0.44999998807907104
#     interval: 2857.0
#   }
#   timevals {
#     val: 0.49000000953674316
#     interval: 69450.0
#   }
#   timevals {
#     val: 0.5299999713897705
#     interval: 281.0
#   }
#   timevals {
#     val: 0.5299999713897705
#     interval: 8271.0
#   }
#   timevals {
#     val: 0.4099999964237213
#     interval: 112.0
#   }
#   timevals {
#     val: 0.4000000059604645
#     interval: 17.0
#   }
#   timevals {
#     val: 0.49000000953674316
#     interval: 21.0
#   }
#   timevals {
#     val: 0.4699999988079071
#     interval: 48.0
#   }
#   timevals {
#     val: 0.47999998927116394
#     interval: 688.0
#   }
#   timevals {
#     val: 0.49000000953674316
#     interval: 554.0
#   }
#   timevals {
#     val: 0.5699999928474426
#     interval: 150527.0
#   }
#   timevals {
#     val: 0.49000000953674316
#     interval: 92820.0
#   }
#   timevals {
#     val: 0.550000011920929
#     interval: 35715.0
#   }
#   timevals {
#     val: 20.0
#     interval: 35715.0
#   }
# }
# timeseries {
#   var_num: 197
#   timevals {
#     val: 80.0
#   }
#   timevals {
#     val: 79.0
#     interval: 356.0
#   }
#   timevals {
#     val: 80.0
#     interval: 135.0
#   }
#   timevals {
#     val: 73.0
#     interval: 469.0
#   }
#   timevals {
#     val: 74.0
#     interval: 386.0
#   }
#   timevals {
#     val: 76.0
#     interval: 65.0
#   }
#   timevals {
#     val: 79.0
#     interval: 339.0
#   }
#   timevals {
#     val: 79.0
#     interval: 332.0
#   }
#   timevals {
#     val: 84.0
#     interval: 232.0
#   }
#   timevals {
#     val: 80.0
#     interval: 503.0
#   }
#   timevals {
#     val: 80.0
#     interval: 67.0
#   }
#   timevals {
#     val: 86.0
#     interval: 373.0
#   }
#   timevals {
#     val: 84.0
#     interval: 26.0
#   }
#   timevals {
#     val: 79.0
#     interval: 269.0
#   }
#   timevals {
#     val: 85.0
#     interval: 2419558.0
#   }
#   timevals {
#     val: 85.0
#     interval: 2.0
#   }
#   timevals {
#     val: 85.0
#     interval: 13.0
#   }
#   timevals {
#     val: 78.0
#     interval: 148.0
#   }
#   timevals {
#     val: 80.0
#     interval: 138.0
#   }
#   timevals {
#     val: 81.0
#     interval: 1.0
#   }
#   timevals {
#     val: 80.0
#     interval: 4.0
#   }
#   timevals {
#     val: 88.0
#     interval: 19.0
#   }
#   timevals {
#     val: 78.0
#     interval: 326.0
#   }
#   timevals {
#     val: 79.0
#     interval: 215.0
#   }
#   timevals {
#     val: 80.0
#     interval: 242.0
#   }
#   timevals {
#     val: 79.0
#     interval: 124.0
#   }
#   timevals {
#     val: 76.0
#     interval: 50.0
#   }
#   timevals {
#     val: 73.0
#     interval: 264.0
#   }
#   timevals {
#     val: 76.0
#     interval: 520.0
#   }
#   timevals {
#     val: 75.0
#     interval: 260.0
#   }
#   timevals {
#     val: 125.0
#     interval: 260.0
#   }
# }
# timeseries {
#   var_num: 23
#   timevals {
#     val: 0.9700000286102295
#   }
#   timevals {
#     val: 0.9300000071525574
#     interval: 43.0
#   }
#   timevals {
#     val: 1.1699999570846558
#     interval: 2937.0
#   }
#   timevals {
#     val: 0.7599999904632568
#     interval: 88240.0
#   }
#   timevals {
#     val: 0.9700000286102295
#     interval: 4196.0
#   }
#   timevals {
#     val: 0.7799999713897705
#     interval: 1183.0
#   }
#   timevals {
#     val: 0.9100000262260437
#     interval: 63.0
#   }
#   timevals {
#     val: 0.8100000023841858
#     interval: 140.0
#   }
#   timevals {
#     val: 0.6299999952316284
#     interval: 308.0
#   }
#   timevals {
#     val: 0.9900000095367432
#     interval: 685.0
#   }
#   timevals {
#     val: 0.9800000190734863
#     interval: 34.0
#   }
#   timevals {
#     val: 0.8399999737739563
#     interval: 261.0
#   }
#   timevals {
#     val: 0.8799999952316284
#     interval: 57.0
#   }
#   timevals {
#     val: 0.800000011920929
#     interval: 64.0
#   }
#   timevals {
#     val: 0.7699999809265137
#     interval: 85.0
#   }
#   timevals {
#     val: 1.0199999809265137
#     interval: 577684.0
#   }
#   timevals {
#     val: 1.0499999523162842
#     interval: 386.0
#   }
#   timevals {
#     val: 0.8700000047683716
#     interval: 612.0
#   }
#   timevals {
#     val: 0.9399999976158142
#     interval: 69.0
#   }
#   timevals {
#     val: 0.8700000047683716
#     interval: 19912.0
#   }
#   timevals {
#     val: 1.1399999856948853
#     interval: 9970.0
#   }
#   timevals {
#     val: 0.7400000095367432
#     interval: 87101.0
#   }
#   timevals {
#     val: 1.0700000524520874
#     interval: 1867.0
#   }
#   timevals {
#     val: 0.9399999976158142
#     interval: 388.0
#   }
#   timevals {
#     val: 0.7300000190734863
#     interval: 49036.0
#   }
#   timevals {
#     val: 0.6899999976158142
#     interval: 77395.0
#   }
#   timevals {
#     val: 0.9399999976158142
#     interval: 366.0
#   }
#   timevals {
#     val: 0.9399999976158142
#     interval: 358.0
#   }
#   timevals {
#     val: 0.9599999785423279
#     interval: 101.0
#   }
#   timevals {
#     val: 0.8500000238418579
#     interval: 12573.0
#   }
#   timevals {
#     val: 50.0
#     interval: 12573.0
#   }
# }
# include_list {
#   var_num: 13
# }
# include_list {
#   var_num: 12
# }
# include_list {
#   var_num: 174
# }
# include_list {
#   var_num: 29
# }
# include_list {
#   var_num: 16
# }
# include_list {
#   var_num: 15
# }
# include_list {
#   var_num: 120
# }
# include_list {
#   var_num: 109
# }
# include_list {
#   var_num: 102
# }
# include_list {
#   var_num: 104
# }
# include_list {
#   var_num: 19
# }
# include_list {
#   var_num: 30
# }
# include_list {
#   var_num: 27
# }
# include_list {
#   var_num: 20
# }
# include_list {
#   var_num: 18
# }
# include_list {
#   var_num: 21
# }
# include_list {
#   var_num: 223
# }
# include_list {
#   var_num: 226
# }
# include_list {
#   var_num: 304
# }
# include_list {
#   var_num: 295
# }
# include_list {
#   var_num: 298
# }
# include_list {
#   var_num: 299
# }
# include_list {
#   var_num: 292
# }
# include_list {
#   var_num: 267
# }
# include_list {
#   var_num: 301
# }
# include_list {
#   var_num: 284
# }
# include_list {
#   var_num: 287
# }
# include_list {
#   var_num: 197
# }
# include_list {
#   var_num: 272
# }
# include_list {
#   var_num: 286
# }
# include_list {
#   var_num: 270
# }
# include_list {
#   var_num: 229
# }
# include_list {
#   var_num: 269
# }
# include_list {
#   var_num: 273
# }
# include_list {
#   var_num: 174
# }
# include_list {
#   var_num: 297
# }
# include_list {
#   var_num: 296
# }
# include_list {
#   var_num: 198
# }
# include_list {
#   var_num: 268
# }
# include_list {
#   var_num: 251
# }
# include_list {
#   var_num: 224
# }
# include_list {
#   var_num: 228
# }
# include_list {
#   var_num: 274
# }
# include_list {
#   var_num: 285
# }
# include_list {
#   var_num: 199
# }
# include_list {
#   var_num: 189
# }
# include_list {
#   var_num: 213
# }
# include_list {
#   var_num: 209
# }
# include_list {
#   var_num: 206
# }
# include_list {
#   var_num: 225
# }
# include_list {
#   var_num: 249
# }
# include_list {
#   var_num: 280
# }
# include_list {
#   var_num: 172
# }
# include_list {
#   var_num: 262
# }
# include_list {
#   var_num: 261
# }
# include_list {
#   var_num: 265
# }
# include_list {
#   var_num: 266
# }
# include_list {
#   var_num: 260
# }
# include_list {
#   var_num: 201
# }
# include_list {
#   var_num: 177
# }
# include_list {
#   var_num: 227
# }
# include_list {
#   var_num: 173
# }
# include_list {
#   var_num: 204
# }
# include_list {
#   var_num: 20
# }
# include_list {
#   var_num: 21
# }
# include_list {
#   var_num: 19
# }
# include_list {
#   var_num: 25
# }
# include_list {
#   var_num: 27
# }
# include_list {
#   var_num: 24
# }
# include_list {
#   var_num: 197
# }
# include_list {
#   var_num: 23
# }
# switch: "internal_query"
