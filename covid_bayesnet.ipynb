# %% [markdown]
# ## Covid Bayes Net
#
#
# First we create a Pomegranate Bayesian Network using the protobuf interface and our utility package, bayes, that enables one to conveniently create a Bayesian network by hand without having to fill in every probability.  The same Baysian network can start with our hand entered guesses, but can later learn from data.  Any amount of questions can be answered, including no questions, to get the probabilities of having covid , the severity of illness, and the chances of going to the hospital.  The file the Bayesian net is written in is covid_bayes.py.  Our utility package can then be used to query the network with different patient states.  This is convenient for tuning hand entered parameters .

# %%
cd /home/opencog
# Out:
# /home/opencog

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install covid_bayesnet
#!{sys.executable} -m pip install protobuf
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (20.1.1)
# ERROR: Could not find a version that satisfies the requirement covid_bayesnet (from versions: none)
# ERROR: No matching distribution found for covid_bayesnet

# %%
cd ./covid-bayesnet
# Out:
# /home/opencog/covid-bayesnet

# %%
# !{sys.executable} -m pip install -r requirements.txt
# !sh buildproto.sh
# Out:
# Requirement already satisfied: grpcio>=1.14.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.30.0)
# Requirement already satisfied: grpcio-tools>=1.14.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.30.0)
# Requirement already satisfied: pomegranate>=0.13.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.13.4)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio>=1.14.2->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: protobuf>=3.5.0.post1 in /usr/local/lib/python3.6/dist-packages (from grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (3.12.2)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.18.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (2.4)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (5.1.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from protobuf>=3.5.0.post1->grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (39.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->pomegranate>=0.13.4->-r requirements.txt (line 3)) (4.4.2)

# %% [markdown]
# ### Covid net
# Here put the name of the network you have written with the protobuf and bayes utilities.  Our example is printed out.  We created 4 functions in our utility package: any, all, if_the_else, and avg, which can together be used to express almost any set of rules, documented elsewhere.  The last lines implement the creation of the description of the network,  bayesianNetwork , with the protobuf utilities, and then the creation of the Pomegranate network with the description.

# %%
text_file = open('./sn_bayes/covid_bayes.py')
#text_file = open('./sn_bayes/test.py')
file_content = text_file.read()
print(file_content)
text_file.close()
# Out:
# import sn_bayes
# from sn_bayes.utils import any
# from sn_bayes.utils import all
# from sn_bayes.utils import avg
# from sn_bayes.utils import if_then_else
# from sn_bayes.utils import bayesInitialize
# from sn_bayes.utils import addCpt
#
#
# import sn_service.service_spec.bayesian_pb2
# from sn_service.service_spec.bayesian_pb2 import BayesianNetwork
#
#
# def covid_bayes():
# 	bayesianNetwork = BayesianNetwork()
#
#
#
# 	#probabilities within distributions must sum to 1.0
# 	#questions left blank or "prefer not to answer" will be computed
#
#
#
# 	#basics/init
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "acute_medical_condition"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "acute_medical_condition"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_acute_medical_condition"
# 	variable.probability = 0.98
#
# 	# basics/demographics questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "age"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "elderly"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "adult"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "young_adult"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "teen"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "child"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sex"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "male"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "female"
# 	variable.probability = 0.5
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heterosome"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "other"
# 	variable.probability = 0.0005
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "X"
# 	variable.probability = 0.0005
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "XXY"
# 	variable.probability = 0.0005
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "XYY"
# 	variable.probability = 0.0005
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "XY"
# 	variable.probability = 0.499
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "XX"
# 	variable.probability = 0.499
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "height_in_feet"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_above_seven"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_six_to_seven"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_five_to_six"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_four_to_five"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_under_four"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "weight_in_pounds"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_over_250"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_175_to_220"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_125_to_175"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_100_to_125"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_under_100"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "ethnicity"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "african_american"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hispanic"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "ethnicity_other"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "african"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "middle_eastern"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "native_american"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "pacific_islander"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "asian"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "caucasian"
# 	variable.probability = 0.35
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "education"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "education_other"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "some_high_school"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_school"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "vocational"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "bachelors"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "masters"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "phd"
# 	variable.probability = 0.05
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "employment"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "unemployed"  #same as seeking opportunities
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "employment_other"  #added, covers children, those who dont want work
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "retired"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "part_time"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "full_time"
# 	variable.probability = 0.4
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "marital_status"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "single"
# 	variable.probability = 0.34
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "relationship"
# 	variable.probability = 0.33
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "married"
# 	variable.probability = 0.33
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "number_of_children"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "three_or_more"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "two_children"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_children"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_children"
# 	variable.probability = 0.70
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "income_in_USD"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "under_25k_USD"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "26_to_50k_USD"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "51_to_100k_USD"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "101_to_200k_USD"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_200k_USD"
# 	variable.probability = 0.05
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "community"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "rural"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "suburban"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "urban"
# 	variable.probability = 0.40
#
#
# 	# basics/women questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "pregnancy_in_months"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_six_months_pregnant"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "three_to_six_months_pregnant"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "under_three_months_pregnant"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_pregnant"
# 	variable.probability = 0.925
#
#
# 	# basics/sleep questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sleep_quickly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "dont_sleep_quickly"
# 	variable.probability = 0.35
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "sleep_quickly"
# 	variable.probability = 0.65
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sleep_in_hours"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "under_five_hours_sleep"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "five_or_six_hours_sleep"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "seven_or_eight_hours_sleep"
# 	variable.probability = 0.35
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "nine_or_ten_hours_sleep"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "eleven_to_thirteen_hours_sleep"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_thirteen_hours_sleep"
# 	variable.probability = 0.05
# 	# basics/lifestyle questions
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sex_per_month"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_twelve_sex_per_month"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "six_to_twelve_sex_per_month"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "three_to_five_sex_per_month"
# 	variable.probability = 0.35
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "two_sex_per_month"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_sex_per_month"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_sex_per_month"
# 	variable.probability = 0.05
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cigarettes_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifty_cigarettes_per_week"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "eleven_to_fifty_cigarettes_per_week"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_ten_cigarettes_per_week"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cigarettes_per_week"
# 	variable.probability = 0.85
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cigars_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifty_cigars_per_week"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "six_to_fifty_cigars_per_week"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_cigars_per_week"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cigars_per_week"
# 	variable.probability = 0.97
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hookah_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_six_hookah_per_week"
# 	variable.probability = 0.005
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_hookah_per_week"
# 	variable.probability = 0.055
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hookah_per_week"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "snuff_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifty_snuff_per_week"
# 	variable.probability = 0.001
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "six_to_fifty_snuff_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_snuff_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_snuff_per_week"
# 	variable.probability = 0.995
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "vapes_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifty_vapes_per_week"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "six_to_fifty_vapes_per_week"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_vapes_per_week"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_vapes_per_week"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "alchohol_glasses_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_twentyone_glasses_per_week"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "fifteen_to_twenty_glasses_per_week"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "six_to_fourteen_glasses_per_week"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "three_to_five_glasses_per_week"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_to_two_glasses_per_week"
# 	variable.probability = 0.35
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "adderall_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_adderall_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_adderall_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_adderall_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "ritalin_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_ritalin_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_ritalin_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_ritalin_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cocaine_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_cocaine_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_cocaine_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_cocaine_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "methamphetamine_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_methamphetamine_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_methamphetamine_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_methamphetamine_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "ecstasy_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_ecstasy_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_ecstasy_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_ecstasy_per_week"
# 	variable.probability = 0.99
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "speed_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_speed_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_speed_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_speed_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "amphetamines_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_amphetamines_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_amphetamines_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_amphetamines_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "other_substance_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_other_substance_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_other_substance_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_other_substance_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "opiods_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_opiods_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_opiods_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_opiods_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "depressants_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_depressants_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_depressants_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_depressants_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cannabis_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_cannabis_per_week"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_cannabis_per_week"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_cannabis_per_week"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hallucinogens_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_hallucinogens_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_hallucinogens_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_hallucinogens_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "dissociatives_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_five_dissociatives_per_week"
# 	variable.probability = 0.002
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_five_dissociatives_per_week"
# 	variable.probability = 0.008
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_dissociatives_per_week"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "inhalants_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "over_fifteen_inhalants_per_week"
# 	variable.probability = 0.004
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "one_to_fifteen_inhalants_per_week"
# 	variable.probability = 0.016
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "zero_inhalants_per_week"
# 	variable.probability = 0.98
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "activity_level"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "sedentary"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "somewhat_active"
# 	variable.probability = 0.4
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "very_active"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "intense_physical_exercise"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "lonely"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "often_lonely"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_often_lonely"
# 	variable.probability = 0.7
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "close_confidants"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_close_confidants"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "has_close_confidants"
# 	variable.probability = 0.7
#
#
# 	# basics/medical questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "regular_exams"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_regular_exams"
# 	variable.probability = 0.6
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "regular_exams"
# 	variable.probability = 0.4
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "blood_pressure"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "very_high_blood_pressure"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_blood_pressure"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "borderline_blood_pressure"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_blood_pressure"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_blood_pressure"
# 	variable.probability = 0.65
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "blood_pressure_medication"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "taking_blood_pressure_medication"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_taking_blood_pressure_medication"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cholesterol"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_cholesterol"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_cholesterol"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_attack"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_heart_attack"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_heart_attack"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "tiaa"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_tiaa"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_tiaa"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "stroke"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_stroke"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_stroke"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "peripheral_artery_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_peripheral_artery_disease"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_peripheral_artery_disease"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "angina"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_angina"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_angina"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "atherosclerotic_cardiovascular_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "had_atherosclerotic_cardiovascular_disease"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_atherosclerotic_cardiovascular_disease"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "diabetes"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "has_diabetes"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "prediabetes"
# 	variable.probability = 0.95
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_diabetes"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "diabetes_medication"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "insulin"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "oral_medication"
# 	variable.probability = 0.03
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_diabetes_medication"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "disability_walk_or_run"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_disability_walk_or_run"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_disability_walk_or_run"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "disability_equipment"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_disability_equipment"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_disability_equipment"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "mental_disability_cant_work"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_mental_disability_cant_work"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_mental_disability_cant_work"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "other_chronic_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_other_chronic_disease"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_other_chronic_disease"
# 	variable.probability = 0.95
#
#
# 	# covid symptoms questions in discrete distributions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "body_temperature"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_102F"
# 	variable.probability = 0.015
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_99F"
# 	variable.probability = 0.035
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_body_temperature"
# 	variable.probability = 0.95
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "low_oxygen_symptoms"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_low_oxygen_symptoms"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_low_oxygen_symptoms"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "shortness_of_breath"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_painful_shortness_of_breath"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath_after_activity"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_shortness_of_breath"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cough"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_up_blood"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "dry_cough"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_with_spitum"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cough"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "colored_spots_on_toes"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "colored_spots_on_toes"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_colored_spots_on_toes"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hx_lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hx_lung_disease"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hx_lung_disease"
# 	variable.probability = 0.90
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hx_family_lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hx_family_lung_disease"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hx_family_lung_disease"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "muscle_weakness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "muscle_weakness_cant_move"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_muscle_weakness"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_muscle_weakness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "difficulty_moving"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "difficulty_moving"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_difficulty_moving"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "neck_stiffness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "neck_stiffness"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_neck_stiffness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "low_urine"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_urine"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_urine"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "frequent_diarrhea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "frequent_diarrhea"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_frequent_diarrhea"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "nausea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "nausea"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_nausea"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "vomiting"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "vomiting"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_vomiting"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "decreased_smell_or_taste"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "decreased_smell_or_taste"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_decreased_smell_or_taste"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sore_throat"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "sore_throat"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_sore_throat"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "pink_eye"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "pink_eye"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_pink_eye"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "headache"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "headache"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_headache"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "bmi"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "morbidly_obese"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "obese"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "overweight"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "underweight"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "exposure"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_in_family_not_isolated"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_in_family"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_healthcare_worker"
# 	variable.probability = 0.03
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "known_exposure"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_high_risk_worker"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_exposure"
# 	variable.probability = 0.90
#
#
# 	# covid/social distance rules
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "isolation_space"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_isolation_space"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_isolation_space"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "leaving_house_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_more_than_twice_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_once_or_twice_per_day"
# 	variable.probability = 0.70
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_zero_per_day"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "high_risk_place_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "deliveries_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_no_sanitation_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveris_no_sanitation_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "mask"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_mask"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "surgical_mask"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "n95_mask"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "public_transportation_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_over_three_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_one_to_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_zero_per_week"
# 	variable.probability = 0.70
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "workplace_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_workplace_social_distancing"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "workplace_social_distancing"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "neighbors_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_neighbors_social_distancing"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "neighbors_social_distancing"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "visits_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_more_than_twice_per_week"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_once_or_twice_per_week"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_zero_per_week"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "local_govt_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_local_govt_social_distancing"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "local_govt_social_distancing"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "wash_hands_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_zero_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_once_or_twice_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_three_to_five_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_over_five_per_day"
# 	variable.probability = 0.20
#
#
# 	#wearable anomalies
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_rate_variability"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "abnormally_low_heart_rate_variability"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_heart_rate_variabiliity"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_heart_rate_variability"
# 	variable.probability = 0.66
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_heart_rate_variability"
# 	variable.probability = 0.17
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "oxygen"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "abnormally_low_oxygen"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_oxygen"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_oxygen"
# 	variable.probability = 0.83
#
#
# 	#hotspot anomaly
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hotspot"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "abnormally_high_hotspot"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_hotspot"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_hotspot"
# 	variable.probability = 0.66
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_hotspot"
# 	variable.probability = 0.17
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "severe_neck_pain"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "severe_neck_pain"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_severe_neck_pain"
# 	variable.probability = 0.98
#
#
# 	# conditional probability tables
#
# 	cpt ={}
#
# 	cpt["systemically_disadvantaged"] = avg(bayesianNetwork,cpt,
# 	[
# 	"education",
# 	"ethnicity",
# 	"community"
# 	],
# 	["very_systemically_disadvantaged","somewhat_systemically_disadvantaged","not_systemically_disadvantaged"]
#
# 	)
#
#
# 	cpt["economically_disadvantaged"] = avg(bayesianNetwork,cpt,
# 	[
# 	"employment",
# 	"income_in_USD",
# 	"regular_exams"
# 	],
# 	["very_economically_disadvantaged","somewhat_economically_disadvantaged","not_economically_disadvantaged"]
#
# 	)
#
#
# 	cpt["socially_disadvantaged"] = avg(bayesianNetwork,cpt,
# 	[
# 	"systemically_disadvantaged",
# 	"economically_disadvantaged"
# 	],
# 	["very_socially_disadvantaged","somewhat_socially_disadvantaged","not_socially_disadvantaged"]
#
# 	)
#
#
# 	cpt["tobacco"] = any(bayesianNetwork,cpt,
# 	{
# 	"cigarettes_per_week":{"over_fifty_cigarettes_per_week","eleven_to_fifty_cigarettes_per_week"},
# 	"cigars_per_week":{"over_fifty_cigars_per_week"},
# 	"vapes_per_week":{"over_fifty_vapes_per_week","six_to_fifty_vapes_per_week"}
# 	},
# 	["tobacco","no_tobacco"]
# 	)
#
# 	cpt["substance_smoking"] = any(bayesianNetwork,cpt,
# 	{
# 	"hookah_per_week":{ "over_six_hookah_per_week"},
# 	"cannabis_per_week":{"over_fifteen_cannabis_per_week"},
# 	"inhalants_per_week":{"over_fifteen_inhalants_per_week","one_to_fifteen_inhalants_per_week"}
# 	},
# 	["substance_smoking","no_substance_smoking"]
# 	)
#
# 	cpt["smoking"] = any(bayesianNetwork,cpt,
# 	{
# 	"tobacco":{"tobacco"},
# 	"substance_smoking":{"substance_smoking"}
# 	},
# 	["smoking","no_smoking"]
# 	)
#
#
# 	cpt["stimulant_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"adderall_per_week":{"over_fifteen_adderall_per_week","one_to_fifteen_adderall_per_week"},
# 	"ritalin_per_week":{"over_fifteen_ritalin_per_week"},
# 	"methamphetamine_per_week":{"over_five_methamphetamine_per_week","one_to_five_methamphetamine_per_week"},
# 	"amphetamines_per_week":{"over_fifteen_amphetamines_per_week","one_to_fifteen_amphetamines_per_week"},
# 	},
# 	["stimulant_abuse","no_stimulant_abuse"]
# 	)
#
#
# 	cpt["addictive_substance_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"opiods_per_week":{"over_fifteen_opiods_per_week"},
# 	"snuff_per_week":{"over_fifty_snuff_per_week"},
# 	"alchohol_glasses_per_week":{"over_twentyone_glasses_per_week"},
# 	"other_substance_per_week":{"over_fifteen_other_substance_per_week"}
# 	},
# 	["addictive_substance_abuse","no_addictive_substance_abuse"]
# 	)
#
#
#
# 	cpt["legal_substance_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"addictive_substance_abuse":{"addictive_substance_abuse"},
# 	"stimulant_abuse":{"stimulant_abuse"}
# 	},
# 	["legal_substance_abuse","no_legal_substance_abuse"]
# 	)
#
#
#
# 	cpt["illegal_upper_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"cocaine_per_week":{"over_five_cocaine_per_week","one_to_five_cocaine_per_week"},
# 	"ecstasy_per_week":{"over_five_ecstasy_per_week","one_to_five_ecstasy_per_week"},
# 	"speed_per_week":{"over_five_speed_per_week","one_to_five_speed_per_week"}
# 	},
# 	["illegal_upper_abuse","no_illegal_upper_abuse"]
# 	)
#
#
# 	cpt["illegal_downer_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"depressants_per_week":{ "over_five_depressants_per_week","one_to_five_depressants_per_week"},
# 	"hallucinogens_per_week":{"over_fifteen_hallucinogens_per_week","one_to_fifteen_hallucinogens_per_week"},
# 	"dissociatives_per_week":{"over_five_dissociatives_per_week","one_to_five_dissociatives_per_week"},
# 	},
# 	["illegal_downer_abuse","no_illegal_downer_abuse"]
# 	)
#
#
#
#
# 	cpt["illegal_substance_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"illegal_upper_abuse":{"illegal_upper_abuse"},
# 	"illegal_downer_abuse":{"illegal_downer_abuse"}
# 	},
# 	["illegal_substance_abuse","no_illegal_substance_abuse"]
# 	)
#
# 	cpt["substance_abuse"] = any(bayesianNetwork,cpt,
# 	{
# 	"legal_substance_abuse":{"heavy_substance_abuse"},
# 	"illegal_substance_abuse":{"heavy_substance_abuse","light_substance_abuse"}
# 	},
# 	["substance_abuse","no_substance_abuse"]
# 	)
#
#
# 	cpt["depression"] = avg(bayesianNetwork,cpt,
# 	[
# 	"sleep_quickly",
# 	"sleep_in_hours",
# 	"lonely",
# 	"close_confidants"
# 	],
# 	["high_depression","medium_depression","low_depression","depression_free"]
# 	)
#
#
# 	cpt["societal_stress"] = avg(bayesianNetwork,cpt,
# 	[
# 	"socially_disadvantaged",
# 	"pregnancy_in_months",
# 	"number_of_children",
# 	"activity_level"
# 	],
# 	["high_societal_stress","medium_societal_stress","low_societal_stress","societal_stress_free"]
# 	)
#
#
# 	cpt["stress"] = avg(bayesianNetwork,cpt,
# 	[
# 	"depression",
# 	"societal_stress"
# 	],
# 	["high_stress","medium_stress","low_stress","stress_free"]
# 	)
#
#
#
# 	cpt["heart_disease"] = avg(bayesianNetwork,cpt,
# 	[
# 	"heart_attack",
# 	"peripheral_artery_disease",
# 	"angina",
# 	"atherosclerotic_cardiovascular_disease",
# 	],
# 	["serious_heart_disease","some_heart_disease","no_heart_disease"]
#
# 	)
#
# 	cpt["disability"] = any(bayesianNetwork,cpt,
# 	{
# 	"disability_walk_or_run":{"have_disability_walk_or_run"},
# 	"disability_equipment":{"have_disability_equipment"},
# 	"mental_disability_cant_work":{"have_mental_disability_cant_work"},
# 	"heterosome":{"other","X","XXY","XYY"}
# 	},
# 	["disability","no_disability"]
#
# 	)
#
#
#
# 	cpt["neurological_cofactors"] = avg(bayesianNetwork,cpt,
# 	[
# 	"tiaa",
# 	"stroke",
# 	],
# 	["significant_neurological_cofactors","neurological_cofactors","no_neurological_cofactors"]
#
# 	)
#
#
# 	cpt["misc_health_cofactors"] = avg(bayesianNetwork,cpt,
# 	[
# 	"cholesterol",
# 	"hx_family_lung_disease",
# 	"other_chronic_disease"
# 	],
# 	["significant_misc_health_cofactors","misc_health_cofactors","no_misc_health_cofactors"]
#
# 	)
#
#
# 	cpt["health_cofactors"] = avg(bayesianNetwork,cpt,
# 	[
# 	"neurological_cofactors",
# 	"misc_health_cofactors"
# 	],
# 	["significant_health_cofactors","health_cofactors","no_health_cofactors"]
#
# 	)
#
#
# 	cpt["behavioral_cofactors"] = avg(bayesianNetwork,cpt,
# 	[
# 	"stress",
# 	"disability",
# 	"substance_abuse",
# 	"smoking"
# 	],
# 	["significant_behavioral_cofactors","behavioral_cofactors","no_behavioral_cofactors"]
#
# 	)
#
#
# 	cpt["other_cofactors"] = avg(bayesianNetwork,cpt,
# 	[
# 	"health_cofactors",
# 	"behavioral_cofactors"
# 	],
# 	["significant_other_cofactors","other_cofactors","no_other_cofactors"]
#
# 	)
#
#
# 	cpt["untreated_blood_pressure"] = all(bayesianNetwork,cpt,
# 		{
# 		 "blood_pressure":{"very_high_blood_pressure","high_blood_pressure"},
# 		 "blood_pressure_medication":{"not_taking_blood_pressure_medication"}
# 		},
# 		["untreated_blood_pressure", "other_blood_pressure"]
# 		)
#
#
# 	cpt["untreated_diabetes"] = all(bayesianNetwork,cpt,
# 		{
# 		 "diabetes":{"has_diabetes"},
# 		 "diabetes_medication":{"no_diabetes_medication"}
# 		},
# 		["untreated_diabetes", "other_diabetes"]
# 		)
#
#
# 	cpt["metabolic_disease"] = if_then_else(bayesianNetwork,cpt,
# 		{
# 		"untreated_diabetes":{"untreated_diabetes"},
# 		"diabetes_medication":{"insulin","oral_diabetes_medication"},
# 		"untreated_blood_pressure":{"untreated_blood_pressure"},
# 		"diabetes":{"prediabetes"}
# 		},
# 		["severe_metabolic_disease","high_metabolic_disease", "medium_metabolic_disease","low_metabolic_disease","no_metabolic_disease"]
# 		)
#
#
#
# 	cpt["other_comorbidities"] = any(bayesianNetwork,cpt,
# 	{
# 	"heart_disease":{"heart_disease"},
# 	"bmi":{"morbidly_obese"},
# 	"metabolic_disease":{"severe_metabolic_disease","high_metabolic_disease"},
# 	"other_cofactors":{"significant_other_cofactors"}
# 	},
# 	[ "other_comorbidities","no_other_comorbidities"]
# 	)
#
# 	cpt["specific_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"colored_spots_on_toes",
# 	"decreased_smell_or_taste"
# 	],
# 	[ "significant_specific_covid_symptoms","mild_specific_covid_symptoms","no_specific_covid_symptoms"]
# 	)
#
# 	cpt["head_and_neck_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"neck_stiffness",
# 	"sore_throat",
# 	"pink_eye",
# 	"headache"
# 	],
# 	[ "significant_head_and_neck_covid_symptoms","mild_head_and_neck_covid_symptoms","no_head_and_neck_covid_symptoms"]
# 	)
#
# 	cpt["gastrointestinal_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"low_urine",
# 	"nausea",
# 	"vomiting",
# 	],
# 	[ "significant_gastrointestinal_covid_symptoms","mild_gastrointestinal_covid_symptoms","no_gastrointestinal_covid_symptoms"]
# 	)
#
# 	cpt["covid_symptoms"] = any(bayesianNetwork,cpt,
# 	{
# 	"gastrointestinal_covid_symptoms":{"significant_gastrointestinal_covid_symptoms"},
# 	"specific_covid_symptoms":{"significant_specific_covid_symptoms"},
# 	"head_and_neck_covid_symptoms":{"significant_head_and_neck_covid_symptoms"}
# 	},
# 	[ "significant_covid_symptoms","no_significant_covid_symptoms"]
# 	)
#
# 	cpt["personal_social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"isolation_space",
# 	"deliveries_per_week",
# 	"mask",
# 	"wash_hands_per_day"
# 	],
# 	["no_personal_social_distancing","some_personal_social_distancing","safe_personal_social_distancing"]
# 	)
#
#
#
# 	cpt["social_distancing_connectedness"]= avg(bayesianNetwork,cpt,
# 	[
# 	"visits_per_week",
# 	"leaving_house_per_day",
# 	"high_risk_place_per_week",
# 	"public_transportation_per_week"
# 	],
# 	["no_social_distancing_connectedness","some_social_distancing_connectedness","safe_social_distancing_connectedness"]
# 	)
#
#
# 	cpt["social_distancing_environment"]= avg(bayesianNetwork,cpt,
# 	[
# 	"workplace_social_distancing",
# 	"neighbors_social_distancing",
# 	"local_govt_social_distancing"
# 	],
# 	["no_social_distancing_environnment","some_social_distancing_environment","safe_social_distancing_environment"]
# 	)
#
#
# 	cpt["social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"social_distancing_environment",
# 	"personal_social_distancing",
# 	"social_distancing_connectedness"
# 	],
# 	["no_social_distancing","some_social_distancing","safe_social_distancing"]
# 	)
#
#
#
# 	cpt["wearables"] = avg(bayesianNetwork,cpt,
# 	[
# 	"heart_rate_variability",
# 	"oxygen"
# 	],
# 	["anomalous","slight_anomaly","normal"]
# 	)
#
#
# 	cpt["possible_dehydration"] = any(bayesianNetwork,cpt,
# 	{
# 	"low_urine":{"low_urine"},
# 	"vomiting":{"vomiting"},
# 	"frequent_diarrhea":{"frequent_diarrhea"}
# 	},
# 	["possible_dehydration","no_dehydration"]
# 	)
#
#
# 	cpt["possible_meningitis"] = all(bayesianNetwork,cpt,
# 		{"neck_stiffness":{"neck_stiffness"},
# 		"severe_neck_pain":{"severe_neck_pain"},
# 		"body_temperature":{"body_temperature_above_102F","body_temperature_above_99F"}},
# 		["possible_meningitis","no_meningitis"]
# 		)
#
#
# 	cpt["serious_shortness_of_breath"] = all(bayesianNetwork,cpt,
# 		{"shortness_of_breath":{"new_or_worse_painful_shortness_of_breath","new_or_worse_shortness_of_breath"},
# 		"other_comorbidities":{"significant_other_comorbidities","some__other_comorbidities"}},
# 		["serious_shortness_of_breath","no_serious_shortness_of_breath"]
# 		)
#
#
# 	cpt["covid_vulnerabilities"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptoms",
# 		"social_distancing",
# 		"wearables"
# 		],
# 		["severe_covid_vulnerabilities", "moderate_covid_vulnerabilites","some_covid_vulnerabilites", "insignificant_covid_vulnerabilities"]
# 		)
#
#
# 	cpt["low_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"shortness_of_breath": {"new_or_worse_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_99F"},
# 		"covid_vulnerabilities":{"some_covid_vulnerabilites"}
# 		},
# 		["low_covid","other_covid"]
# 		)
#
#
# 	cpt["medium_covid"]= any(bayesianNetwork,cpt,
# 		{
# 		"serious_shortness_of_breath":{"serious_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_102F"},
# 		"muscle_weakness":{"new_or_worse_muscle_weakness"},
# 		"covid_vulnerabilities":{"moderate_covid_vulnerabilites"}
# 		},
# 		["medium_covid","other_covid"]
# 		)
#
#
# 	cpt["high_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"cough":{"cough_up_blood"},
# 		"muscle_weakness":{"muscle_weakness_cant_move"},
# 		"low_oxygen_symptoms":{"have_low_oxygen_symptoms"},
# 		"covid_vulnerabilities": {"severe_covid_vulnerabilites"}
# 		},
# 		["high_covid","other_covid"]
# 		)
#
#
# 	cpt["covid_environment"] = avg(bayesianNetwork,cpt,
# 		[
# 		"exposure",
# 		"hotspot"
# 		],
# 		["high_risk_covid_environment", "medium_risk_covid_environment", "low_risk_covid_environment","no_risk_covid_environment"]
# 		)
#
#
# 	cpt["covid_symptom_level"] = if_then_else(bayesianNetwork,cpt,
# 		{
# 		"high_covid":{"high_covid"},
# 		"medium_covid":{"medium_covid"},
# 		"low_covid":{"low_covid"},
# 		},
# 		["high_covid", "medium_covid","low_covid","no_covid"]
# 		)
#
#
#
#
# 	#output variable conditional probability distributions
#
#
# 	cpt["emergency_treatment"] = any(bayesianNetwork,cpt,
# 	{
# 	"possible_dehydration":{"possible_dehydration"},
# 	"possible_meningitis":{"possible_meningitis"},
# 	"acute_medical_condition":{"acute_medical_condition"}
# 	},
# 	["emergency_treatment","no_emergency_treatment"]
# 	)
#
#
#
# 	cpt["covid_risk"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptom_level",
# 		"covid_environment"
# 		],
# 		["high_covid_risk","medium_covid_risk","low_covid_risk","no_covid_risk"]
# 		)
#
#
#
# 	cpt["covid_severity"] = avg(bayesianNetwork,cpt,
# 		[
# 		"age",
# 		"other_comorbidities"
# 		],
# 		["high_covid_severity","medium_covid_severity","low_covid_severity","no_covid_severity"]
# 		)
#
#
# 	addCpt(bayesianNetwork,cpt)
# 	return(bayesianNetwork)
#
# if __name__ == '__main__':
# 	covid_bayes()

# %% [markdown]
#  Next run the file.  All routines are stateless.

# %%
import sn_bayes
from sn_bayes import covid_bayes
#%run -i './bayes/covid_bayes.py'
#%run -i './bayes/test.py'
bayesianNetwork = covid_bayes.covid_bayes()

# %% [markdown]
# For convenience of creating a table, here are all the variables in the net in order.  They should be mapped into the individual buckets of the rules.  The variables up to "systemically_disadvantaged" are the ones that the user may answer.  The rest are computed.

# %%
import sn_bayes
from sn_bayes.utils import get_var_positions
var_positions = get_var_positions(bayesianNetwork)
var_positions
# Out:
# {'acute_medical_condition': 0,
#  'age': 1,
#  'sex': 2,
#  'heterosome': 3,
#  'height_in_feet': 4,
#  'weight_in_pounds': 5,
#  'ethnicity': 6,
#  'education': 7,
#  'employment': 8,
#  'marital_status': 9,
#  'number_of_children': 10,
#  'income_in_USD': 11,
#  'community': 12,
#  'pregnancy_in_months': 13,
#  'sleep_quickly': 14,
#  'sleep_in_hours': 15,
#  'sex_per_month': 16,
#  'cigarettes_per_week': 17,
#  'cigars_per_week': 18,
#  'hookah_per_week': 19,
#  'snuff_per_week': 20,
#  'vapes_per_week': 21,
#  'alchohol_glasses_per_week': 22,
#  'adderall_per_week': 23,
#  'ritalin_per_week': 24,
#  'cocaine_per_week': 25,
#  'methamphetamine_per_week': 26,
#  'ecstasy_per_week': 27,
#  'speed_per_week': 28,
#  'amphetamines_per_week': 29,
#  'other_substance_per_week': 30,
#  'opiods_per_week': 31,
#  'depressants_per_week': 32,
#  'cannabis_per_week': 33,
#  'hallucinogens_per_week': 34,
#  'dissociatives_per_week': 35,
#  'inhalants_per_week': 36,
#  'activity_level': 37,
#  'lonely': 38,
#  'close_confidants': 39,
#  'regular_exams': 40,
#  'blood_pressure': 41,
#  'blood_pressure_medication': 42,
#  'cholesterol': 43,
#  'heart_attack': 44,
#  'tiaa': 45,
#  'stroke': 46,
#  'peripheral_artery_disease': 47,
#  'angina': 48,
#  'atherosclerotic_cardiovascular_disease': 49,
#  'diabetes': 50,
#  'diabetes_medication': 51,
#  'disability_walk_or_run': 52,
#  'disability_equipment': 53,
#  'mental_disability_cant_work': 54,
#  'other_chronic_disease': 55,
#  'body_temperature': 56,
#  'low_oxygen_symptoms': 57,
#  'shortness_of_breath': 58,
#  'cough': 59,
#  'colored_spots_on_toes': 60,
#  'hx_lung_disease': 61,
#  'hx_family_lung_disease': 62,
#  'muscle_weakness': 63,
#  'difficulty_moving': 64,
#  'neck_stiffness': 65,
#  'low_urine': 66,
#  'frequent_diarrhea': 67,
#  'nausea': 68,
#  'vomiting': 69,
#  'decreased_smell_or_taste': 70,
#  'sore_throat': 71,
#  'pink_eye': 72,
#  'headache': 73,
#  'bmi': 74,
#  'exposure': 75,
#  'isolation_space': 76,
#  'leaving_house_per_day': 77,
#  'high_risk_place_per_week': 78,
#  'deliveries_per_week': 79,
#  'mask': 80,
#  'public_transportation_per_week': 81,
#  'workplace_social_distancing': 82,
#  'neighbors_social_distancing': 83,
#  'visits_per_week': 84,
#  'local_govt_social_distancing': 85,
#  'wash_hands_per_day': 86,
#  'heart_rate_variability': 87,
#  'oxygen': 88,
#  'hotspot': 89,
#  'severe_neck_pain': 90,
#  'systemically_disadvantaged': 91,
#  'economically_disadvantaged': 92,
#  'socially_disadvantaged': 93,
#  'tobacco': 94,
#  'substance_smoking': 95,
#  'smoking': 96,
#  'stimulant_abuse': 97,
#  'addictive_substance_abuse': 98,
#  'legal_substance_abuse': 99,
#  'illegal_upper_abuse': 100,
#  'illegal_downer_abuse': 101,
#  'illegal_substance_abuse': 102,
#  'substance_abuse': 103,
#  'depression': 104,
#  'societal_stress': 105,
#  'stress': 106,
#  'heart_disease': 107,
#  'disability': 108,
#  'neurological_cofactors': 109,
#  'misc_health_cofactors': 110,
#  'health_cofactors': 111,
#  'behavioral_cofactors': 112,
#  'other_cofactors': 113,
#  'untreated_blood_pressure': 114,
#  'untreated_diabetes': 115,
#  'metabolic_disease': 116,
#  'other_comorbidities': 117,
#  'specific_covid_symptoms': 118,
#  'head_and_neck_covid_symptoms': 119,
#  'gastrointestinal_covid_symptoms': 120,
#  'covid_symptoms': 121,
#  'personal_social_distancing': 122,
#  'social_distancing_connectedness': 123,
#  'social_distancing_environment': 124,
#  'social_distancing': 125,
#  'wearables': 126,
#  'possible_dehydration': 127,
#  'possible_meningitis': 128,
#  'serious_shortness_of_breath': 129,
#  'covid_vulnerabilities': 130,
#  'low_covid': 131,
#  'medium_covid': 132,
#  'high_covid': 133,
#  'covid_environment': 134,
#  'covid_symptom_level': 135,
#  'emergency_treatment': 136,
#  'covid_risk': 137,
#  'covid_severity': 138}

# %% [markdown]
# Here are the positions of every bucketed response for each of the above variables:

# %%
import sn_bayes
from sn_bayes.utils import get_var_val_positions
var_val_positions = get_var_val_positions(bayesianNetwork)
var_val_positions
# Out:
# {'acute_medical_condition': {'acute_medical_condition': 0,
#   'no_acute_medical_condition': 1},
#  'age': {'elderly': 0, 'adult': 1, 'young_adult': 2, 'teen': 3, 'child': 4},
#  'sex': {'male': 0, 'female': 1},
#  'heterosome': {'other': 0, 'X': 1, 'XXY': 2, 'XYY': 3, 'XY': 4, 'XX': 5},
#  'height_in_feet': {'height_above_seven': 0,
#   'height_six_to_seven': 1,
#   'height_five_to_six': 2,
#   'height_four_to_five': 3,
#   'height_under_four': 4},
#  'weight_in_pounds': {'weight_over_250': 0,
#   'weight_175_to_220': 1,
#   'weight_125_to_175': 2,
#   'weight_100_to_125': 3,
#   'weight_under_100': 4},
#  'ethnicity': {'african_american': 0,
#   'hispanic': 1,
#   'ethnicity_other': 2,
#   'african': 3,
#   'middle_eastern': 4,
#   'native_american': 5,
#   'pacific_islander': 6,
#   'asian': 7,
#   'caucasian': 8},
#  'education': {'education_other': 0,
#   'some_high_school': 1,
#   'high_school': 2,
#   'vocational': 3,
#   'bachelors': 4,
#   'masters': 5,
#   'phd': 6},
#  'employment': {'unemployed': 0,
#   'employment_other': 1,
#   'retired': 2,
#   'part_time': 3,
#   'full_time': 4},
#  'marital_status': {'single': 0, 'relationship': 1, 'married': 2},
#  'number_of_children': {'three_or_more': 0,
#   'two_children': 1,
#   'one_children': 2,
#   'zero_children': 3},
#  'income_in_USD': {'under_25k_USD': 0,
#   '26_to_50k_USD': 1,
#   '51_to_100k_USD': 2,
#   '101_to_200k_USD': 3,
#   'over_200k_USD': 4},
#  'community': {'rural': 0, 'suburban': 1, 'urban': 2},
#  'pregnancy_in_months': {'over_six_months_pregnant': 0,
#   'three_to_six_months_pregnant': 1,
#   'under_three_months_pregnant': 2,
#   'not_pregnant': 3},
#  'sleep_quickly': {'dont_sleep_quickly': 0, 'sleep_quickly': 1},
#  'sleep_in_hours': {'under_five_hours_sleep': 0,
#   'five_or_six_hours_sleep': 1,
#   'seven_or_eight_hours_sleep': 2,
#   'nine_or_ten_hours_sleep': 3,
#   'eleven_to_thirteen_hours_sleep': 4,
#   'over_thirteen_hours_sleep': 5},
#  'sex_per_month': {'over_twelve_sex_per_month': 0,
#   'six_to_twelve_sex_per_month': 1,
#   'three_to_five_sex_per_month': 2,
#   'two_sex_per_month': 3,
#   'one_sex_per_month': 4,
#   'no_sex_per_month': 5},
#  'cigarettes_per_week': {'over_fifty_cigarettes_per_week': 0,
#   'eleven_to_fifty_cigarettes_per_week': 1,
#   'one_to_ten_cigarettes_per_week': 2,
#   'no_cigarettes_per_week': 3},
#  'cigars_per_week': {'over_fifty_cigars_per_week': 0,
#   'six_to_fifty_cigars_per_week': 1,
#   'one_to_five_cigars_per_week': 2,
#   'no_cigars_per_week': 3},
#  'hookah_per_week': {'over_six_hookah_per_week': 0,
#   'one_to_five_hookah_per_week': 1,
#   'no_hookah_per_week': 2},
#  'snuff_per_week': {'over_fifty_snuff_per_week': 0,
#   'six_to_fifty_snuff_per_week': 1,
#   'one_to_five_snuff_per_week': 2,
#   'no_snuff_per_week': 3},
#  'vapes_per_week': {'over_fifty_vapes_per_week': 0,
#   'six_to_fifty_vapes_per_week': 1,
#   'one_to_five_vapes_per_week': 2,
#   'no_vapes_per_week': 3},
#  'alchohol_glasses_per_week': {'over_twentyone_glasses_per_week': 0,
#   'fifteen_to_twenty_glasses_per_week': 1,
#   'six_to_fourteen_glasses_per_week': 2,
#   'three_to_five_glasses_per_week': 3,
#   'zero_to_two_glasses_per_week': 4},
#  'adderall_per_week': {'over_fifteen_adderall_per_week': 0,
#   'one_to_fifteen_adderall_per_week': 1,
#   'zero_adderall_per_week': 2},
#  'ritalin_per_week': {'over_fifteen_ritalin_per_week': 0,
#   'one_to_fifteen_ritalin_per_week': 1,
#   'zero_ritalin_per_week': 2},
#  'cocaine_per_week': {'over_five_cocaine_per_week': 0,
#   'one_to_five_cocaine_per_week': 1,
#   'zero_cocaine_per_week': 2},
#  'methamphetamine_per_week': {'over_five_methamphetamine_per_week': 0,
#   'one_to_five_methamphetamine_per_week': 1,
#   'zero_methamphetamine_per_week': 2},
#  'ecstasy_per_week': {'over_five_ecstasy_per_week': 0,
#   'one_to_five_ecstasy_per_week': 1,
#   'zero_ecstasy_per_week': 2},
#  'speed_per_week': {'over_five_speed_per_week': 0,
#   'one_to_five_speed_per_week': 1,
#   'zero_speed_per_week': 2},
#  'amphetamines_per_week': {'over_fifteen_amphetamines_per_week': 0,
#   'one_to_fifteen_amphetamines_per_week': 1,
#   'zero_amphetamines_per_week': 2},
#  'other_substance_per_week': {'over_fifteen_other_substance_per_week': 0,
#   'one_to_fifteen_other_substance_per_week': 1,
#   'zero_other_substance_per_week': 2},
#  'opiods_per_week': {'over_fifteen_opiods_per_week': 0,
#   'one_to_fifteen_opiods_per_week': 1,
#   'zero_opiods_per_week': 2},
#  'depressants_per_week': {'over_five_depressants_per_week': 0,
#   'one_to_five_depressants_per_week': 1,
#   'zero_depressants_per_week': 2},
#  'cannabis_per_week': {'over_fifteen_cannabis_per_week': 0,
#   'one_to_fifteen_cannabis_per_week': 1,
#   'zero_cannabis_per_week': 2},
#  'hallucinogens_per_week': {'over_fifteen_hallucinogens_per_week': 0,
#   'one_to_fifteen_hallucinogens_per_week': 1,
#   'zero_hallucinogens_per_week': 2},
#  'dissociatives_per_week': {'over_five_dissociatives_per_week': 0,
#   'one_to_five_dissociatives_per_week': 1,
#   'zero_dissociatives_per_week': 2},
#  'inhalants_per_week': {'over_fifteen_inhalants_per_week': 0,
#   'one_to_fifteen_inhalants_per_week': 1,
#   'zero_inhalants_per_week': 2},
#  'activity_level': {'sedentary': 0,
#   'somewhat_active': 1,
#   'very_active': 2,
#   'intense_physical_exercise': 3},
#  'lonely': {'often_lonely': 0, 'not_often_lonely': 1},
#  'close_confidants': {'no_close_confidants': 0, 'has_close_confidants': 1},
#  'regular_exams': {'no_regular_exams': 0, 'regular_exams': 1},
#  'blood_pressure': {'very_high_blood_pressure': 0,
#   'high_blood_pressure': 1,
#   'borderline_blood_pressure': 2,
#   'low_blood_pressure': 3,
#   'normal_blood_pressure': 4},
#  'blood_pressure_medication': {'taking_blood_pressure_medication': 0,
#   'not_taking_blood_pressure_medication': 1},
#  'cholesterol': {'high_cholesterol': 0, 'normal_cholesterol': 1},
#  'heart_attack': {'had_heart_attack': 0, 'no_heart_attack': 1},
#  'tiaa': {'had_tiaa': 0, 'no_tiaa': 1},
#  'stroke': {'had_stroke': 0, 'no_stroke': 1},
#  'peripheral_artery_disease': {'had_peripheral_artery_disease': 0,
#   'no_peripheral_artery_disease': 1},
#  'angina': {'had_angina': 0, 'no_angina': 1},
#  'atherosclerotic_cardiovascular_disease': {'had_atherosclerotic_cardiovascular_disease': 0,
#   'no_atherosclerotic_cardiovascular_disease': 1},
#  'diabetes': {'has_diabetes': 0, 'prediabetes': 1, 'no_diabetes': 2},
#  'diabetes_medication': {'insulin': 0,
#   'oral_medication': 1,
#   'no_diabetes_medication': 2},
#  'disability_walk_or_run': {'have_disability_walk_or_run': 0,
#   'no_disability_walk_or_run': 1},
#  'disability_equipment': {'have_disability_equipment': 0,
#   'no_disability_equipment': 1},
#  'mental_disability_cant_work': {'have_mental_disability_cant_work': 0,
#   'no_mental_disability_cant_work': 1},
#  'other_chronic_disease': {'have_other_chronic_disease': 0,
#   'no_other_chronic_disease': 1},
#  'body_temperature': {'body_temperature_above_102F': 0,
#   'body_temperature_above_99F': 1,
#   'normal_body_temperature': 2},
#  'low_oxygen_symptoms': {'have_low_oxygen_symptoms': 0,
#   'no_low_oxygen_symptoms': 1},
#  'shortness_of_breath': {'new_or_worse_painful_shortness_of_breath': 0,
#   'new_or_worse_shortness_of_breath': 1,
#   'new_or_worse_shortness_of_breath_after_activity': 2,
#   'no_shortness_of_breath': 3},
#  'cough': {'cough_up_blood': 0,
#   'dry_cough': 1,
#   'cough_with_spitum': 2,
#   'no_cough': 3},
#  'colored_spots_on_toes': {'colored_spots_on_toes': 0,
#   'no_colored_spots_on_toes': 1},
#  'hx_lung_disease': {'hx_lung_disease': 0, 'no_hx_lung_disease': 1},
#  'hx_family_lung_disease': {'hx_family_lung_disease': 0,
#   'no_hx_family_lung_disease': 1},
#  'muscle_weakness': {'muscle_weakness_cant_move': 0,
#   'new_or_worse_muscle_weakness': 1,
#   'no_muscle_weakness': 2},
#  'difficulty_moving': {'difficulty_moving': 0, 'no_difficulty_moving': 1},
#  'neck_stiffness': {'neck_stiffness': 0, 'no_neck_stiffness': 1},
#  'low_urine': {'low_urine': 0, 'normal_urine': 1},
#  'frequent_diarrhea': {'frequent_diarrhea': 0, 'not_frequent_diarrhea': 1},
#  'nausea': {'nausea': 0, 'no_nausea': 1},
#  'vomiting': {'vomiting': 0, 'no_vomiting': 1},
#  'decreased_smell_or_taste': {'decreased_smell_or_taste': 0,
#   'no_decreased_smell_or_taste': 1},
#  'sore_throat': {'sore_throat': 0, 'no_sore_throat': 1},
#  'pink_eye': {'pink_eye': 0, 'no_pink_eye': 1},
#  'headache': {'headache': 0, 'no_headache': 1},
#  'bmi': {'morbidly_obese': 0,
#   'obese': 1,
#   'overweight': 2,
#   'normal': 3,
#   'underweight': 4},
#  'exposure': {'exposure_in_family_not_isolated': 0,
#   'exposure_in_family': 1,
#   'exposure_healthcare_worker': 2,
#   'known_exposure': 3,
#   'exposure_high_risk_worker': 4,
#   'no_exposure': 5},
#  'isolation_space': {'no_isolation_space': 0, 'have_isolation_space': 1},
#  'leaving_house_per_day': {'leave_house_more_than_twice_per_day': 0,
#   'leave_house_once_or_twice_per_day': 1,
#   'leave_house_zero_per_day': 2},
#  'high_risk_place_per_week': {'high_risk_place_no_sanitizer_over_three_per_week': 0,
#   'high_risk_place_no_sanitizer_once_or_more_per_week': 1,
#   'high_risk_place_sanitizer_two_or_three_per_week': 2,
#   'high_risk_place_sanitizer_once_per_week': 3,
#   'high_risk_place_zero_per_week': 4},
#  'deliveries_per_week': {'deliveries_no_sanitation_over_three_per_week': 0,
#   'deliveris_no_sanitation_once_or_more_per_week': 1,
#   'deliveries_sanitation_two_or_three_per_week': 2,
#   'deliveries_sanitation_once_per_week': 3,
#   'deliveries_zero_per_week': 4},
#  'mask': {'no_mask': 0, 'surgical_mask': 1, 'n95_mask': 2},
#  'public_transportation_per_week': {'public_transportation_over_three_per_week': 0,
#   'public_transportation_one_to_three_per_week': 1,
#   'public_transportation_zero_per_week': 2},
#  'workplace_social_distancing': {'no_workplace_social_distancing': 0,
#   'workplace_social_distancing': 1},
#  'neighbors_social_distancing': {'no_neighbors_social_distancing': 0,
#   'neighbors_social_distancing': 1},
#  'visits_per_week': {'visits_more_than_twice_per_week': 0,
#   'visits_once_or_twice_per_week': 1,
#   'visits_zero_per_week': 2},
#  'local_govt_social_distancing': {'no_local_govt_social_distancing': 0,
#   'local_govt_social_distancing': 1},
#  'wash_hands_per_day': {'wash_hands_zero_per_day': 0,
#   'wash_hands_once_or_twice_per_day': 1,
#   'wash_hands_three_to_five_per_day': 2,
#   'wash_hands_over_five_per_day': 3},
#  'heart_rate_variability': {'abnormally_low_heart_rate_variability': 0,
#   'low_heart_rate_variabiliity': 1,
#   'normal_heart_rate_variability': 2,
#   'high_heart_rate_variability': 3},
#  'oxygen': {'abnormally_low_oxygen': 0, 'low_oxygen': 1, 'normal_oxygen': 2},
#  'hotspot': {'abnormally_high_hotspot': 0,
#   'high_hotspot': 1,
#   'normal_hotspot': 2,
#   'low_hotspot': 3},
#  'severe_neck_pain': {'severe_neck_pain': 0, 'no_severe_neck_pain': 1},
#  'systemically_disadvantaged': {'very_systemically_disadvantaged': 0,
#   'somewhat_systemically_disadvantaged': 1,
#   'not_systemically_disadvantaged': 2},
#  'economically_disadvantaged': {'very_economically_disadvantaged': 0,
#   'somewhat_economically_disadvantaged': 1,
#   'not_economically_disadvantaged': 2},
#  'socially_disadvantaged': {'very_socially_disadvantaged': 0,
#   'somewhat_socially_disadvantaged': 1,
#   'not_socially_disadvantaged': 2},
#  'tobacco': {'tobacco': 0, 'no_tobacco': 1},
#  'substance_smoking': {'substance_smoking': 0, 'no_substance_smoking': 1},
#  'smoking': {'smoking': 0, 'no_smoking': 1},
#  'stimulant_abuse': {'stimulant_abuse': 0, 'no_stimulant_abuse': 1},
#  'addictive_substance_abuse': {'addictive_substance_abuse': 0,
#   'no_addictive_substance_abuse': 1},
#  'legal_substance_abuse': {'legal_substance_abuse': 0,
#   'no_legal_substance_abuse': 1},
#  'illegal_upper_abuse': {'illegal_upper_abuse': 0,
#   'no_illegal_upper_abuse': 1},
#  'illegal_downer_abuse': {'illegal_downer_abuse': 0,
#   'no_illegal_downer_abuse': 1},
#  'illegal_substance_abuse': {'illegal_substance_abuse': 0,
#   'no_illegal_substance_abuse': 1},
#  'substance_abuse': {'substance_abuse': 0, 'no_substance_abuse': 1},
#  'depression': {'high_depression': 0,
#   'medium_depression': 1,
#   'low_depression': 2,
#   'depression_free': 3},
#  'societal_stress': {'high_societal_stress': 0,
#   'medium_societal_stress': 1,
#   'low_societal_stress': 2,
#   'societal_stress_free': 3},
#  'stress': {'high_stress': 0,
#   'medium_stress': 1,
#   'low_stress': 2,
#   'stress_free': 3},
#  'heart_disease': {'serious_heart_disease': 0,
#   'some_heart_disease': 1,
#   'no_heart_disease': 2},
#  'disability': {'disability': 0, 'no_disability': 1},
#  'neurological_cofactors': {'significant_neurological_cofactors': 0,
#   'neurological_cofactors': 1,
#   'no_neurological_cofactors': 2},
#  'misc_health_cofactors': {'significant_misc_health_cofactors': 0,
#   'misc_health_cofactors': 1,
#   'no_misc_health_cofactors': 2},
#  'health_cofactors': {'significant_health_cofactors': 0,
#   'health_cofactors': 1,
#   'no_health_cofactors': 2},
#  'behavioral_cofactors': {'significant_behavioral_cofactors': 0,
#   'behavioral_cofactors': 1,
#   'no_behavioral_cofactors': 2},
#  'other_cofactors': {'significant_other_cofactors': 0,
#   'other_cofactors': 1,
#   'no_other_cofactors': 2},
#  'untreated_blood_pressure': {'untreated_blood_pressure': 0,
#   'other_blood_pressure': 1},
#  'untreated_diabetes': {'untreated_diabetes': 0, 'other_diabetes': 1},
#  'metabolic_disease': {'severe_metabolic_disease': 0,
#   'high_metabolic_disease': 1,
#   'medium_metabolic_disease': 2,
#   'low_metabolic_disease': 3,
#   'no_metabolic_disease': 4},
#  'other_comorbidities': {'other_comorbidities': 0,
#   'no_other_comorbidities': 1},
#  'specific_covid_symptoms': {'significant_specific_covid_symptoms': 0,
#   'mild_specific_covid_symptoms': 1,
#   'no_specific_covid_symptoms': 2},
#  'head_and_neck_covid_symptoms': {'significant_head_and_neck_covid_symptoms': 0,
#   'mild_head_and_neck_covid_symptoms': 1,
#   'no_head_and_neck_covid_symptoms': 2},
#  'gastrointestinal_covid_symptoms': {'significant_gastrointestinal_covid_symptoms': 0,
#   'mild_gastrointestinal_covid_symptoms': 1,
#   'no_gastrointestinal_covid_symptoms': 2},
#  'covid_symptoms': {'significant_covid_symptoms': 0,
#   'no_significant_covid_symptoms': 1},
#  'personal_social_distancing': {'no_personal_social_distancing': 0,
#   'some_personal_social_distancing': 1,
#   'safe_personal_social_distancing': 2},
#  'social_distancing_connectedness': {'no_social_distancing_connectedness': 0,
#   'some_social_distancing_connectedness': 1,
#   'safe_social_distancing_connectedness': 2},
#  'social_distancing_environment': {'no_social_distancing_environnment': 0,
#   'some_social_distancing_environment': 1,
#   'safe_social_distancing_environment': 2},
#  'social_distancing': {'no_social_distancing': 0,
#   'some_social_distancing': 1,
#   'safe_social_distancing': 2},
#  'wearables': {'anomalous': 0, 'slight_anomaly': 1, 'normal': 2},
#  'possible_dehydration': {'possible_dehydration': 0, 'no_dehydration': 1},
#  'possible_meningitis': {'possible_meningitis': 0, 'no_meningitis': 1},
#  'serious_shortness_of_breath': {'serious_shortness_of_breath': 0,
#   'no_serious_shortness_of_breath': 1},
#  'covid_vulnerabilities': {'severe_covid_vulnerabilities': 0,
#   'moderate_covid_vulnerabilites': 1,
#   'some_covid_vulnerabilites': 2,
#   'insignificant_covid_vulnerabilities': 3},
#  'low_covid': {'low_covid': 0, 'other_covid': 1},
#  'medium_covid': {'medium_covid': 0, 'other_covid': 1},
#  'high_covid': {'high_covid': 0, 'other_covid': 1},
#  'covid_environment': {'high_risk_covid_environment': 0,
#   'medium_risk_covid_environment': 1,
#   'low_risk_covid_environment': 2,
#   'no_risk_covid_environment': 3},
#  'covid_symptom_level': {'high_covid': 0,
#   'medium_covid': 1,
#   'low_covid': 2,
#   'no_covid': 3},
#  'emergency_treatment': {'emergency_treatment': 0,
#   'no_emergency_treatment': 1},
#  'covid_risk': {'high_covid_risk': 0,
#   'medium_covid_risk': 1,
#   'low_covid_risk': 2,
#   'no_covid_risk': 3},
#  'covid_severity': {'high_covid_severity': 0,
#   'medium_covid_severity': 1,
#   'low_covid_severity': 2,
#   'no_covid_severity': 3}}

# %% [markdown]
# Here is the description of the Bayesian network in protobuf that we just created with the running of the python file.  Only the "leaves" have initial probabilities (DiscreteDistribution), the conditional probabilities (ConditionalProbabilityTable) are to be computed:

# %%
bayesianNetwork
# Out:
# discreteDistributions {
#   name: "acute_medical_condition"
#   variables {
#     name: "acute_medical_condition"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_acute_medical_condition"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "age"
#   variables {
#     name: "elderly"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "adult"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "young_adult"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "teen"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "child"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "sex"
#   variables {
#     name: "male"
#     probability: 0.5
#   }
#   variables {
#     name: "female"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "heterosome"
#   variables {
#     name: "other"
#     probability: 0.0005000000237487257
#   }
#   variables {
#     name: "X"
#     probability: 0.0005000000237487257
#   }
#   variables {
#     name: "XXY"
#     probability: 0.0005000000237487257
#   }
#   variables {
#     name: "XYY"
#     probability: 0.0005000000237487257
#   }
#   variables {
#     name: "XY"
#     probability: 0.49900001287460327
#   }
#   variables {
#     name: "XX"
#     probability: 0.49900001287460327
#   }
# }
# discreteDistributions {
#   name: "height_in_feet"
#   variables {
#     name: "height_above_seven"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "height_six_to_seven"
#     probability: 0.25
#   }
#   variables {
#     name: "height_five_to_six"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "height_four_to_five"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "height_under_four"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "weight_in_pounds"
#   variables {
#     name: "weight_over_250"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_175_to_220"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_125_to_175"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "weight_100_to_125"
#     probability: 0.25
#   }
#   variables {
#     name: "weight_under_100"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "ethnicity"
#   variables {
#     name: "african_american"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "hispanic"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "ethnicity_other"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "african"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "middle_eastern"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "native_american"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "pacific_islander"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "asian"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "caucasian"
#     probability: 0.3499999940395355
#   }
# }
# discreteDistributions {
#   name: "education"
#   variables {
#     name: "education_other"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "some_high_school"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "high_school"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "vocational"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "bachelors"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "masters"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "phd"
#     probability: 0.05000000074505806
#   }
# }
# discreteDistributions {
#   name: "employment"
#   variables {
#     name: "unemployed"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "employment_other"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "retired"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "part_time"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "full_time"
#     probability: 0.4000000059604645
#   }
# }
# discreteDistributions {
#   name: "marital_status"
#   variables {
#     name: "single"
#     probability: 0.3400000035762787
#   }
#   variables {
#     name: "relationship"
#     probability: 0.33000001311302185
#   }
#   variables {
#     name: "married"
#     probability: 0.33000001311302185
#   }
# }
# discreteDistributions {
#   name: "number_of_children"
#   variables {
#     name: "three_or_more"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "two_children"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "one_children"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "zero_children"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "income_in_USD"
#   variables {
#     name: "under_25k_USD"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "26_to_50k_USD"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "51_to_100k_USD"
#     probability: 0.25
#   }
#   variables {
#     name: "101_to_200k_USD"
#     probability: 0.25
#   }
#   variables {
#     name: "over_200k_USD"
#     probability: 0.05000000074505806
#   }
# }
# discreteDistributions {
#   name: "community"
#   variables {
#     name: "rural"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "suburban"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "urban"
#     probability: 0.4000000059604645
#   }
# }
# discreteDistributions {
#   name: "pregnancy_in_months"
#   variables {
#     name: "over_six_months_pregnant"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "three_to_six_months_pregnant"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "under_three_months_pregnant"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "not_pregnant"
#     probability: 0.925000011920929
#   }
# }
# discreteDistributions {
#   name: "sleep_quickly"
#   variables {
#     name: "dont_sleep_quickly"
#     probability: 0.3499999940395355
#   }
#   variables {
#     name: "sleep_quickly"
#     probability: 0.6499999761581421
#   }
# }
# discreteDistributions {
#   name: "sleep_in_hours"
#   variables {
#     name: "under_five_hours_sleep"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "five_or_six_hours_sleep"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "seven_or_eight_hours_sleep"
#     probability: 0.3499999940395355
#   }
#   variables {
#     name: "nine_or_ten_hours_sleep"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "eleven_to_thirteen_hours_sleep"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "over_thirteen_hours_sleep"
#     probability: 0.05000000074505806
#   }
# }
# discreteDistributions {
#   name: "sex_per_month"
#   variables {
#     name: "over_twelve_sex_per_month"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "six_to_twelve_sex_per_month"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "three_to_five_sex_per_month"
#     probability: 0.3499999940395355
#   }
#   variables {
#     name: "two_sex_per_month"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "one_sex_per_month"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_sex_per_month"
#     probability: 0.05000000074505806
#   }
# }
# discreteDistributions {
#   name: "cigarettes_per_week"
#   variables {
#     name: "over_fifty_cigarettes_per_week"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "eleven_to_fifty_cigarettes_per_week"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "one_to_ten_cigarettes_per_week"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_cigarettes_per_week"
#     probability: 0.8500000238418579
#   }
# }
# discreteDistributions {
#   name: "cigars_per_week"
#   variables {
#     name: "over_fifty_cigars_per_week"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "six_to_fifty_cigars_per_week"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "one_to_five_cigars_per_week"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_cigars_per_week"
#     probability: 0.9700000286102295
#   }
# }
# discreteDistributions {
#   name: "hookah_per_week"
#   variables {
#     name: "over_six_hookah_per_week"
#     probability: 0.004999999888241291
#   }
#   variables {
#     name: "one_to_five_hookah_per_week"
#     probability: 0.054999999701976776
#   }
#   variables {
#     name: "no_hookah_per_week"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "snuff_per_week"
#   variables {
#     name: "over_fifty_snuff_per_week"
#     probability: 0.0010000000474974513
#   }
#   variables {
#     name: "six_to_fifty_snuff_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_snuff_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "no_snuff_per_week"
#     probability: 0.9950000047683716
#   }
# }
# discreteDistributions {
#   name: "vapes_per_week"
#   variables {
#     name: "over_fifty_vapes_per_week"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "six_to_fifty_vapes_per_week"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "one_to_five_vapes_per_week"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_vapes_per_week"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "alchohol_glasses_per_week"
#   variables {
#     name: "over_twentyone_glasses_per_week"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "fifteen_to_twenty_glasses_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "six_to_fourteen_glasses_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "three_to_five_glasses_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "zero_to_two_glasses_per_week"
#     probability: 0.3499999940395355
#   }
# }
# discreteDistributions {
#   name: "adderall_per_week"
#   variables {
#     name: "over_fifteen_adderall_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_adderall_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_adderall_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "ritalin_per_week"
#   variables {
#     name: "over_fifteen_ritalin_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_ritalin_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_ritalin_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "cocaine_per_week"
#   variables {
#     name: "over_five_cocaine_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_cocaine_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_cocaine_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "methamphetamine_per_week"
#   variables {
#     name: "over_five_methamphetamine_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_methamphetamine_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_methamphetamine_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "ecstasy_per_week"
#   variables {
#     name: "over_five_ecstasy_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_ecstasy_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_ecstasy_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "speed_per_week"
#   variables {
#     name: "over_five_speed_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_speed_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_speed_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "amphetamines_per_week"
#   variables {
#     name: "over_fifteen_amphetamines_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_amphetamines_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_amphetamines_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "other_substance_per_week"
#   variables {
#     name: "over_fifteen_other_substance_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_other_substance_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_other_substance_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "opiods_per_week"
#   variables {
#     name: "over_fifteen_opiods_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_opiods_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_opiods_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "depressants_per_week"
#   variables {
#     name: "over_five_depressants_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_depressants_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_depressants_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "cannabis_per_week"
#   variables {
#     name: "over_fifteen_cannabis_per_week"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "one_to_fifteen_cannabis_per_week"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "zero_cannabis_per_week"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "hallucinogens_per_week"
#   variables {
#     name: "over_fifteen_hallucinogens_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_fifteen_hallucinogens_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_hallucinogens_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "dissociatives_per_week"
#   variables {
#     name: "over_five_dissociatives_per_week"
#     probability: 0.0020000000949949026
#   }
#   variables {
#     name: "one_to_five_dissociatives_per_week"
#     probability: 0.00800000037997961
#   }
#   variables {
#     name: "zero_dissociatives_per_week"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "inhalants_per_week"
#   variables {
#     name: "over_fifteen_inhalants_per_week"
#     probability: 0.004000000189989805
#   }
#   variables {
#     name: "one_to_fifteen_inhalants_per_week"
#     probability: 0.01600000075995922
#   }
#   variables {
#     name: "zero_inhalants_per_week"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "activity_level"
#   variables {
#     name: "sedentary"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "somewhat_active"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "very_active"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "intense_physical_exercise"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "lonely"
#   variables {
#     name: "often_lonely"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "not_often_lonely"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "close_confidants"
#   variables {
#     name: "no_close_confidants"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "has_close_confidants"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "regular_exams"
#   variables {
#     name: "no_regular_exams"
#     probability: 0.6000000238418579
#   }
#   variables {
#     name: "regular_exams"
#     probability: 0.4000000059604645
#   }
# }
# discreteDistributions {
#   name: "blood_pressure"
#   variables {
#     name: "very_high_blood_pressure"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "high_blood_pressure"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "borderline_blood_pressure"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "low_blood_pressure"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "normal_blood_pressure"
#     probability: 0.6499999761581421
#   }
# }
# discreteDistributions {
#   name: "blood_pressure_medication"
#   variables {
#     name: "taking_blood_pressure_medication"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "not_taking_blood_pressure_medication"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "cholesterol"
#   variables {
#     name: "high_cholesterol"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "normal_cholesterol"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "heart_attack"
#   variables {
#     name: "had_heart_attack"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_heart_attack"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "tiaa"
#   variables {
#     name: "had_tiaa"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_tiaa"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "stroke"
#   variables {
#     name: "had_stroke"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_stroke"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "peripheral_artery_disease"
#   variables {
#     name: "had_peripheral_artery_disease"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_peripheral_artery_disease"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "angina"
#   variables {
#     name: "had_angina"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_angina"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "atherosclerotic_cardiovascular_disease"
#   variables {
#     name: "had_atherosclerotic_cardiovascular_disease"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_atherosclerotic_cardiovascular_disease"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "diabetes"
#   variables {
#     name: "has_diabetes"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "prediabetes"
#     probability: 0.949999988079071
#   }
#   variables {
#     name: "no_diabetes"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "diabetes_medication"
#   variables {
#     name: "insulin"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "oral_medication"
#     probability: 0.029999999329447746
#   }
#   variables {
#     name: "no_diabetes_medication"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "disability_walk_or_run"
#   variables {
#     name: "have_disability_walk_or_run"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_disability_walk_or_run"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "disability_equipment"
#   variables {
#     name: "have_disability_equipment"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_disability_equipment"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "mental_disability_cant_work"
#   variables {
#     name: "have_mental_disability_cant_work"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_mental_disability_cant_work"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "other_chronic_disease"
#   variables {
#     name: "have_other_chronic_disease"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_other_chronic_disease"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "body_temperature"
#   variables {
#     name: "body_temperature_above_102F"
#     probability: 0.014999999664723873
#   }
#   variables {
#     name: "body_temperature_above_99F"
#     probability: 0.03500000014901161
#   }
#   variables {
#     name: "normal_body_temperature"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "low_oxygen_symptoms"
#   variables {
#     name: "have_low_oxygen_symptoms"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_low_oxygen_symptoms"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "shortness_of_breath"
#   variables {
#     name: "new_or_worse_painful_shortness_of_breath"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath_after_activity"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_shortness_of_breath"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "cough"
#   variables {
#     name: "cough_up_blood"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "dry_cough"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "cough_with_spitum"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_cough"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "colored_spots_on_toes"
#   variables {
#     name: "colored_spots_on_toes"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_colored_spots_on_toes"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "hx_lung_disease"
#   variables {
#     name: "hx_lung_disease"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_hx_lung_disease"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "hx_family_lung_disease"
#   variables {
#     name: "hx_family_lung_disease"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_hx_family_lung_disease"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "muscle_weakness"
#   variables {
#     name: "muscle_weakness_cant_move"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "new_or_worse_muscle_weakness"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "no_muscle_weakness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "difficulty_moving"
#   variables {
#     name: "difficulty_moving"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_difficulty_moving"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "neck_stiffness"
#   variables {
#     name: "neck_stiffness"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_neck_stiffness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "low_urine"
#   variables {
#     name: "low_urine"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "normal_urine"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "frequent_diarrhea"
#   variables {
#     name: "frequent_diarrhea"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "not_frequent_diarrhea"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "nausea"
#   variables {
#     name: "nausea"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_nausea"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "vomiting"
#   variables {
#     name: "vomiting"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_vomiting"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "decreased_smell_or_taste"
#   variables {
#     name: "decreased_smell_or_taste"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_decreased_smell_or_taste"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "sore_throat"
#   variables {
#     name: "sore_throat"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_sore_throat"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "pink_eye"
#   variables {
#     name: "pink_eye"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_pink_eye"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "headache"
#   variables {
#     name: "headache"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_headache"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "bmi"
#   variables {
#     name: "morbidly_obese"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "obese"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "overweight"
#     probability: 0.25
#   }
#   variables {
#     name: "normal"
#     probability: 0.5
#   }
#   variables {
#     name: "underweight"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "exposure"
#   variables {
#     name: "exposure_in_family_not_isolated"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "exposure_in_family"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "exposure_healthcare_worker"
#     probability: 0.029999999329447746
#   }
#   variables {
#     name: "known_exposure"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "exposure_high_risk_worker"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_exposure"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "isolation_space"
#   variables {
#     name: "no_isolation_space"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "have_isolation_space"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "leaving_house_per_day"
#   variables {
#     name: "leave_house_more_than_twice_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "leave_house_once_or_twice_per_day"
#     probability: 0.699999988079071
#   }
#   variables {
#     name: "leave_house_zero_per_day"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "high_risk_place_per_week"
#   variables {
#     name: "high_risk_place_no_sanitizer_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "high_risk_place_no_sanitizer_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "high_risk_place_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "deliveries_per_week"
#   variables {
#     name: "deliveries_no_sanitation_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "deliveris_no_sanitation_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "deliveries_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "mask"
#   variables {
#     name: "no_mask"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "surgical_mask"
#     probability: 0.5
#   }
#   variables {
#     name: "n95_mask"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "public_transportation_per_week"
#   variables {
#     name: "public_transportation_over_three_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "public_transportation_one_to_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "public_transportation_zero_per_week"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "workplace_social_distancing"
#   variables {
#     name: "no_workplace_social_distancing"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "workplace_social_distancing"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "neighbors_social_distancing"
#   variables {
#     name: "no_neighbors_social_distancing"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "neighbors_social_distancing"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "visits_per_week"
#   variables {
#     name: "visits_more_than_twice_per_week"
#     probability: 0.25
#   }
#   variables {
#     name: "visits_once_or_twice_per_week"
#     probability: 0.5
#   }
#   variables {
#     name: "visits_zero_per_week"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "local_govt_social_distancing"
#   variables {
#     name: "no_local_govt_social_distancing"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "local_govt_social_distancing"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "wash_hands_per_day"
#   variables {
#     name: "wash_hands_zero_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "wash_hands_once_or_twice_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_three_to_five_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_over_five_per_day"
#     probability: 0.20000000298023224
#   }
# }
# discreteDistributions {
#   name: "heart_rate_variability"
#   variables {
#     name: "abnormally_low_heart_rate_variability"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "low_heart_rate_variabiliity"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "normal_heart_rate_variability"
#     probability: 0.6600000262260437
#   }
#   variables {
#     name: "high_heart_rate_variability"
#     probability: 0.17000000178813934
#   }
# }
# discreteDistributions {
#   name: "oxygen"
#   variables {
#     name: "abnormally_low_oxygen"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "low_oxygen"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "normal_oxygen"
#     probability: 0.8299999833106995
#   }
# }
# discreteDistributions {
#   name: "hotspot"
#   variables {
#     name: "abnormally_high_hotspot"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "high_hotspot"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "normal_hotspot"
#     probability: 0.6600000262260437
#   }
#   variables {
#     name: "low_hotspot"
#     probability: 0.17000000178813934
#   }
# }
# discreteDistributions {
#   name: "severe_neck_pain"
#   variables {
#     name: "severe_neck_pain"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_severe_neck_pain"
#     probability: 0.9800000190734863
#   }
# }
# conditionalProbabilityTables {
#   name: "systemically_disadvantaged"
#   randomVariables {
#     name: "education"
#   }
#   randomVariables {
#     name: "ethnicity"
#   }
#   randomVariables {
#     name: "community"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "middle_eastern"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "native_american"
#     }
#     randomVariableValues {
#       name: "urban"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "pacific_islander"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "pacific_islander"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "somewhat_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "pacific_islander"
#     }
#     randomVariableValues {
#       name: "rural"
#     }
#     randomVariableValues {
#       name: "not_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
#     randomVariableValues {
#       name: "pacific_islander"
#     }
#     randomVariableValues {
#       name: "suburban"
#     }
#     randomVariableValues {
#       name: "very_systemically_disadvantaged"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "education_other"
#     }
# ...
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "low_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "high_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "medium_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "low_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "high_covid_risk"
#   }
#   outvars {
#     name: "medium_covid_risk"
#   }
#   outvars {
#     name: "low_covid_risk"
#   }
#   outvars {
#     name: "no_covid_risk"
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_severity"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "other_comorbidities"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_other_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "high_covid_severity"
#   }
#   outvars {
#     name: "medium_covid_severity"
#   }
#   outvars {
#     name: "low_covid_severity"
#   }
#   outvars {
#     name: "no_covid_severity"
#   }
# }

# %% [markdown]
# Here is the Pomegranate net we just made with the description.  Here we compile the net so we can compute probabilities with it.

# %%
from sn_bayes.utils import bayesInitialize
covid = bayesInitialize(bayesianNetwork)

# %%
covid.bake()

# %% [markdown]
# We we call a Pomegranate routine that shows the computed probabilities of every variable.  We have made our own utility that pulls out particular variables.

# %%
covid.predict_proba({})
# Out:
# array([{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "acute_medical_condition" :0.01999999918043658,
#             "no_acute_medical_condition" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "elderly" :0.12499999883584699,
#             "adult" :0.37500000582076554,
#             "young_adult" :0.2499999976716935,
#             "teen" :0.12499999883584699,
#             "child" :0.12499999883584699
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "male" :0.5,
#             "female" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other" :0.0005000000108270674,
#             "X" :0.0005000000108270674,
#             "XXY" :0.0005000000108270674,
#             "XYY" :0.0005000000108270674,
#             "XY" :0.4989999999783459,
#             "XX" :0.4989999999783459
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "height_above_seven" :0.04999999981373565,
#             "height_six_to_seven" :0.24999999534338715,
#             "height_five_to_six" :0.3000000063329933,
#             "height_four_to_five" :0.15000000316649675,
#             "height_under_four" :0.24999999534338715
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "weight_over_250" :0.15000000372529032,
#             "weight_175_to_220" :0.15000000372529032,
#             "weight_125_to_175" :0.2,
#             "weight_100_to_125" :0.2499999962747097,
#             "weight_under_100" :0.2499999962747097
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "african_american" :0.15000000484287718,
#             "hispanic" :0.20000000149011576,
#             "ethnicity_other" :0.05000000037252926,
#             "african" :0.05000000037252926,
#             "middle_eastern" :0.025000000186264856,
#             "native_american" :0.05000000037252926,
#             "pacific_islander" :0.025000000186264856,
#             "asian" :0.10000000074505809,
#             "caucasian" :0.3499999914318314
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "education_other" :0.05000000000000029,
#             "some_high_school" :0.1999999999999998,
#             "high_school" :0.1999999999999998,
#             "vocational" :0.1999999999999998,
#             "bachelors" :0.1999999999999998,
#             "masters" :0.10000000000000012,
#             "phd" :0.05000000000000029
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "unemployed" :0.09999999925494217,
#             "employment_other" :0.30000000521540604,
#             "retired" :0.09999999925494217,
#             "part_time" :0.09999999925494217,
#             "full_time" :0.39999999701976746
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "single" :0.33999999344348925,
#             "relationship" :0.33000000327825535,
#             "married" :0.33000000327825535
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "three_or_more" :0.04545454622423388,
#             "two_children" :0.13636364205932835,
#             "one_children" :0.18181818489693424,
#             "zero_children" :0.6363636268195036
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "under_25k_USD" :0.1904761904761905,
#             "26_to_50k_USD" :0.2857142928100765,
#             "51_to_100k_USD" :0.23809523454734258,
#             "101_to_200k_USD" :0.23809523454734258,
#             "over_200k_USD" :0.047619047619047956
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "rural" :0.2000000000000002,
#             "suburban" :0.3999999999999999,
#             "urban" :0.3999999999999999
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_six_months_pregnant" :0.025000000046566523,
#             "three_to_six_months_pregnant" :0.025000000046566523,
#             "under_three_months_pregnant" :0.025000000046566523,
#             "not_pregnant" :0.9249999998603005
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "dont_sleep_quickly" :0.3500000044703487,
#             "sleep_quickly" :0.6499999955296514
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "under_five_hours_sleep" :0.10000000111758726,
#             "five_or_six_hours_sleep" :0.2000000022351741,
#             "seven_or_eight_hours_sleep" :0.3499999927356835,
#             "nine_or_ten_hours_sleep" :0.2000000022351741,
#             "eleven_to_thirteen_hours_sleep" :0.10000000111758726,
#             "over_thirteen_hours_sleep" :0.05000000055879386
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_twelve_sex_per_month" :0.10526315913306057,
#             "six_to_twelve_sex_per_month" :0.21052631826612095,
#             "three_to_five_sex_per_month" :0.3684210452016368,
#             "two_sex_per_month" :0.21052631826612095,
#             "one_sex_per_month" :0.05263157956653041,
#             "no_sex_per_month" :0.05263157956653041
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_cigarettes_per_week" :0.04999999944120682,
#             "eleven_to_fifty_cigarettes_per_week" :0.04999999944120682,
#             "one_to_ten_cigarettes_per_week" :0.04999999944120682,
#             "no_cigarettes_per_week" :0.8500000016763796
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_cigars_per_week" :0.009999999497086248,
#             "six_to_fifty_cigars_per_week" :0.009999999497086248,
#             "one_to_five_cigars_per_week" :0.009999999497086248,
#             "no_cigars_per_week" :0.9700000015087413
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_six_hookah_per_week" :0.004950494999291934,
#             "one_to_five_hookah_per_week" :0.05445544591430842,
#             "no_hookah_per_week" :0.9405940590863996
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_snuff_per_week" :0.0010000000424920347,
#             "six_to_fifty_snuff_per_week" :0.002000000084983625,
#             "one_to_five_snuff_per_week" :0.002000000084983625,
#             "no_snuff_per_week" :0.9949999997875407
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_vapes_per_week" :0.009999999906868166,
#             "six_to_fifty_vapes_per_week" :0.01999999981373589,
#             "one_to_five_vapes_per_week" :0.01999999981373589,
#             "no_vapes_per_week" :0.9500000004656601
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_twentyone_glasses_per_week" :0.05000000018626486,
#             "fifteen_to_twenty_glasses_per_week" :0.10000000037252925,
#             "six_to_fourteen_glasses_per_week" :0.20000000074505808,
#             "three_to_five_glasses_per_week" :0.3000000085681674,
#             "zero_to_two_glasses_per_week" :0.34999999012798055
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_adderall_per_week" :0.002000000074971908,
#             "one_to_fifteen_adderall_per_week" :0.0080000002998863,
#             "zero_adderall_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_ritalin_per_week" :0.002000000074971908,
#             "one_to_fifteen_ritalin_per_week" :0.0080000002998863,
#             "zero_ritalin_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_cocaine_per_week" :0.002000000074971908,
#             "one_to_five_cocaine_per_week" :0.0080000002998863,
#             "zero_cocaine_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_methamphetamine_per_week" :0.002000000074971908,
#             "one_to_five_methamphetamine_per_week" :0.0080000002998863,
#             "zero_methamphetamine_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_ecstasy_per_week" :0.002000000074971908,
#             "one_to_five_ecstasy_per_week" :0.0080000002998863,
#             "zero_ecstasy_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_speed_per_week" :0.002000000074971908,
#             "one_to_five_speed_per_week" :0.0080000002998863,
#             "zero_speed_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_amphetamines_per_week" :0.002000000074971908,
#             "one_to_fifteen_amphetamines_per_week" :0.0080000002998863,
#             "zero_amphetamines_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_other_substance_per_week" :0.002000000074971908,
#             "one_to_fifteen_other_substance_per_week" :0.0080000002998863,
#             "zero_other_substance_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_opiods_per_week" :0.002000000074971908,
#             "one_to_fifteen_opiods_per_week" :0.0080000002998863,
#             "zero_opiods_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_depressants_per_week" :0.002000000074971908,
#             "one_to_five_depressants_per_week" :0.0080000002998863,
#             "zero_depressants_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_cannabis_per_week" :0.00999999998137398,
#             "one_to_fifteen_cannabis_per_week" :0.09000000542029783,
#             "zero_cannabis_per_week" :0.8999999945983282
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_hallucinogens_per_week" :0.002000000074971908,
#             "one_to_fifteen_hallucinogens_per_week" :0.0080000002998863,
#             "zero_hallucinogens_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_dissociatives_per_week" :0.002000000074971908,
#             "one_to_five_dissociatives_per_week" :0.0080000002998863,
#             "zero_dissociatives_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_inhalants_per_week" :0.0040000001098965,
#             "one_to_fifteen_inhalants_per_week" :0.016000000439584668,
#             "zero_inhalants_per_week" :0.9799999994505187
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "sedentary" :0.3000000052154062,
#             "somewhat_active" :0.3999999970197675,
#             "very_active" :0.19999999850988398,
#             "intense_physical_exercise" :0.09999999925494221
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "often_lonely" :0.3000000119209292,
#             "not_often_lonely" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_close_confidants" :0.3000000119209292,
#             "has_close_confidants" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_regular_exams" :0.6000000059604641,
#             "regular_exams" :0.3999999940395358
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "very_high_blood_pressure" :0.047619049139574626,
#             "high_blood_pressure" :0.09523809827914881,
#             "borderline_blood_pressure" :0.1904761965582972,
#             "low_blood_pressure" :0.047619049139574626,
#             "normal_blood_pressure" :0.6190476068834048
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "taking_blood_pressure_medication" :0.05000000130385202,
#             "not_taking_blood_pressure_medication" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_cholesterol" :0.10000000372529073,
#             "normal_cholesterol" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_heart_attack" :0.05000000130385202,
#             "no_heart_attack" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_tiaa" :0.05000000130385202,
#             "no_tiaa" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_stroke" :0.009999999683350764,
#             "no_stroke" :0.9900000003166493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_peripheral_artery_disease" :0.05000000130385202,
#             "no_peripheral_artery_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_angina" :0.10000000372529073,
#             "no_angina" :0.8999999962747093
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_atherosclerotic_cardiovascular_disease" :0.05000000130385202,
#             "no_atherosclerotic_cardiovascular_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "has_diabetes" :0.02564102632681268,
#             "prediabetes" :0.4871794868365936,
#             "no_diabetes" :0.4871794868365936
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "insulin" :0.019999999813736107,
#             "oral_medication" :0.029999999720603826,
#             "no_diabetes_medication" :0.9500000004656601
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_disability_walk_or_run" :0.05000000130385202,
#             "no_disability_walk_or_run" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_disability_equipment" :0.05000000130385202,
#             "no_disability_equipment" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_mental_disability_cant_work" :0.05000000130385202,
#             "no_mental_disability_cant_work" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_other_chronic_disease" :0.05000000130385202,
#             "no_other_chronic_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "body_temperature_above_102F" :0.014999999846332624,
#             "body_temperature_above_99F" :0.03500000057276418,
#             "normal_body_temperature" :0.9499999995809032
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_low_oxygen_symptoms" :0.05000000130385202,
#             "no_low_oxygen_symptoms" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_painful_shortness_of_breath" :0.010000000018627093,
#             "new_or_worse_shortness_of_breath" :0.040000000074506374,
#             "new_or_worse_shortness_of_breath_after_activity" :0.05000000195577799,
#             "no_shortness_of_breath" :0.8999999979510886
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cough_up_blood" :0.010000000018626878,
#             "dry_cough" :0.04000000007450618,
#             "cough_with_spitum" :0.0500000019557778,
#             "no_cough" :0.8999999979510891
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "colored_spots_on_toes" :0.01999999918043658,
#             "no_colored_spots_on_toes" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_lung_disease" :0.10000000372529055,
#             "no_hx_lung_disease" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_family_lung_disease" :0.10000000372529073,
#             "no_hx_family_lung_disease" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "muscle_weakness_cant_move" :0.009999999981374194,
#             "new_or_worse_muscle_weakness" :0.090000005420298,
#             "no_muscle_weakness" :0.8999999945983279
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "difficulty_moving" :0.10000000372529055,
#             "no_difficulty_moving" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "neck_stiffness" :0.10000000372529091,
#             "no_neck_stiffness" :0.8999999962747092
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_urine" :0.10000000372529089,
#             "normal_urine" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "frequent_diarrhea" :0.10000000372529073,
#             "not_frequent_diarrhea" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "nausea" :0.20000000000000026,
#             "no_nausea" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "vomiting" :0.10000000372529089,
#             "no_vomiting" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "decreased_smell_or_taste" :0.10000000372529073,
#             "no_decreased_smell_or_taste" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "sore_throat" :0.20000000000000026,
#             "no_sore_throat" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "pink_eye" :0.009999999683350764,
#             "no_pink_eye" :0.9900000003166493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "headache" :0.20000000000000026,
#             "no_headache" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "morbidly_obese" :0.05000000055879388,
#             "obese" :0.10000000111758732,
#             "overweight" :0.24999999906867731,
#             "normal" :0.4999999981373542,
#             "underweight" :0.10000000111758732
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "exposure_in_family_not_isolated" :0.01000000003725332,
#             "exposure_in_family" :0.020000000074506197,
#             "exposure_healthcare_worker" :0.030000000111759077,
#             "known_exposure" :0.020000000074506197,
#             "exposure_high_risk_worker" :0.020000000074506197,
#             "no_exposure" :0.8999999996274689
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_isolation_space" :0.20000000000000026,
#             "have_isolation_space" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "leave_house_more_than_twice_per_day" :0.20000000447034857,
#             "leave_house_once_or_twice_per_day" :0.6999999932944768,
#             "leave_house_zero_per_day" :0.1000000022351745
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_place_no_sanitizer_over_three_per_week" :0.09999999850988416,
#             "high_risk_place_no_sanitizer_once_or_more_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_two_or_three_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_once_per_week" :0.19999999701976787,
#             "high_risk_place_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "deliveries_no_sanitation_over_three_per_week" :0.09999999850988416,
#             "deliveris_no_sanitation_once_or_more_per_week" :0.30000000298023194,
#             "deliveries_sanitation_two_or_three_per_week" :0.30000000298023194,
#             "deliveries_sanitation_once_per_week" :0.19999999701976787,
#             "deliveries_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_mask" :0.4000000029802321,
#             "surgical_mask" :0.49999999627470954,
#             "n95_mask" :0.10000000074505835
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "public_transportation_over_three_per_week" :0.2000000044703486,
#             "public_transportation_one_to_three_per_week" :0.10000000223517451,
#             "public_transportation_zero_per_week" :0.6999999932944769
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_workplace_social_distancing" :0.20000000000000026,
#             "workplace_social_distancing" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_neighbors_social_distancing" :0.3999999940395358,
#             "neighbors_social_distancing" :0.6000000059604641
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "visits_more_than_twice_per_week" :0.2500000000000001,
#             "visits_once_or_twice_per_week" :0.49999999999999983,
#             "visits_zero_per_week" :0.2500000000000001
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_local_govt_social_distancing" :0.3999999940395358,
#             "local_govt_social_distancing" :0.6000000059604642
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "wash_hands_zero_per_day" :0.19999999701976795,
#             "wash_hands_once_or_twice_per_day" :0.30000000298023205,
#             "wash_hands_three_to_five_per_day" :0.30000000298023205,
#             "wash_hands_over_five_per_day" :0.19999999701976795
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abnormally_low_heart_rate_variability" :0.019999998882413352,
#             "low_heart_rate_variabiliity" :0.1500000009313227,
#             "normal_heart_rate_variability" :0.6600000040978184,
#             "high_heart_rate_variability" :0.16999999608844546
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abnormally_low_oxygen" :0.019999999776482997,
#             "low_oxygen" :0.15000000763684546,
#             "normal_oxygen" :0.8299999925866716
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abnormally_high_hotspot" :0.019999998882413356,
#             "high_hotspot" :0.1500000009313227,
#             "normal_hotspot" :0.6600000040978183,
#             "low_hotspot" :0.16999999608844543
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "severe_neck_pain" :0.01999999918043658,
#             "no_severe_neck_pain" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "very_systemically_disadvantaged" :0.2780000031515957,
#             "somewhat_systemically_disadvantaged" :0.40674999990127975,
#             "not_systemically_disadvantaged" :0.3152499969471245
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "not_economically_disadvantaged" :0.09142856910115242,
#             "somewhat_economically_disadvantaged" :0.5752380916050499,
#             "very_economically_disadvantaged" :0.3333333392937976
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "not_socially_disadvantaged" :0.02882285613001861,
#             "very_socially_disadvantaged" :0.38816619637817495,
#             "somewhat_socially_disadvantaged" :0.5830109474918065
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_tobacco" :0.8642700017612042,
#             "tobacco" :0.1357299982387958
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_substance_smoking" :0.9653970292285572,
#             "substance_smoking" :0.03460297077144283
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_smoking" :0.8343636921516264,
#             "smoking" :0.16563630784837363
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_stimulant_abuse" :0.9683584008272648,
#             "stimulant_abuse" :0.031641599172735305
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "addictive_substance_abuse" :0.05474240416756032,
#             "no_addictive_substance_abuse" :0.9452575958324397
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "legal_substance_abuse" :0.08465186612987377,
#             "no_legal_substance_abuse" :0.9153481338701261
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_illegal_upper_abuse" :0.9702989988978052,
#             "illegal_upper_abuse" :0.029701001102194723
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "illegal_downer_abuse" :0.029701001102194723,
#             "no_illegal_downer_abuse" :0.9702989988978052
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "illegal_substance_abuse" :0.058519852737916864,
#             "no_illegal_substance_abuse" :0.9414801472620831
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "substance_abuse" :0.0,
#             "no_substance_abuse" :1.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_depression" :0.08212500564521218,
#             "depression_free" :0.038149999807961736,
#             "medium_depression" :0.2882250084142201,
#             "low_depression" :0.591499986132606
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_societal_stress" :0.2801035978801169,
#             "low_societal_stress" :0.40963079125475593,
#             "societal_stress_free" :0.2363265522998744,
#             "high_societal_stress" :0.07393905856525275
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_stress" :0.47651234909299367,
#             "stress_free" :0.009015857924856856,
#             "medium_stress" :0.4640849520458179,
#             "high_stress" :0.05038684093633162
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_heart_disease" :0.9999874999985559,
#             "no_heart_disease" :0.0,
#             "serious_heart_disease" :1.2500001443994327e-05
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_disability" :0.8556602464397507,
#             "disability" :0.1443397535602494
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_neurological_cofactors" :0.000499999997206489,
#             "no_neurological_cofactors" :0.0,
#             "neurological_cofactors" :0.9995000000027934
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "misc_health_cofactors" :0.999499999949708,
#             "no_misc_health_cofactors" :0.0,
#             "significant_misc_health_cofactors" :0.0005000000502918694
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_health_cofactors" :0.0009997500474746087,
#             "health_cofactors" :0.9990002499525253,
#             "no_health_cofactors" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_behavioral_cofactors" :0.006436708059532294,
#             "behavioral_cofactors" :0.9923586481917809,
#             "significant_behavioral_cofactors" :0.0012046437486868012
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_other_cofactors" :0.002196754354328373,
#             "other_cofactors" :0.9978032456456715,
#             "no_other_cofactors" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "untreated_blood_pressure" :0.13571428986152279,
#             "other_blood_pressure" :0.8642857101384773
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "untreated_diabetes" :0.02435897502241231,
#             "other_diabetes" :0.9756410249775876
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_metabolic_disease" :0.019512820317825242,
#             "low_metabolic_disease" :0.4025895110655671,
#             "no_metabolic_disease" :0.42377843328222276,
#             "medium_metabolic_disease" :0.12976026031197244,
#             "severe_metabolic_disease" :0.024358975022412487
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_comorbidities" :0.09367356596336897,
#             "no_other_comorbidities" :0.906326434036631
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_specific_covid_symptoms" :0.0,
#             "mild_specific_covid_symptoms" :0.9980000000074499,
#             "significant_specific_covid_symptoms" :0.0019999999925498857
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_head_and_neck_covid_symptoms" :4.000000022396251e-05,
#             "mild_head_and_neck_covid_symptoms" :0.9999599999997759,
#             "no_head_and_neck_covid_symptoms" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_gastrointestinal_covid_symptoms" :0.9979999998509878,
#             "significant_gastrointestinal_covid_symptoms" :0.0020000001490120766,
#             "no_gastrointestinal_covid_symptoms" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_covid_symptoms" :0.004035840301496031,
#             "no_significant_covid_symptoms" :0.9959641596985039
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_personal_social_distancing" :0.17220000066608218,
#             "some_personal_social_distancing" :0.7564000002592793,
#             "safe_personal_social_distancing" :0.07139999907463836
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_social_distancing_connectedness" :0.1404999986179177,
#             "no_social_distancing_connectedness" :0.2127500033043328,
#             "some_social_distancing_connectedness" :0.6467499980777496
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_social_distancing_environment" :0.9680000009536737,
#             "no_social_distancing_environnment" :0.03199999904632618,
#             "safe_social_distancing_environment" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_social_distancing" :0.010031699771306418,
#             "some_social_distancing" :0.9433590249336508,
#             "no_social_distancing" :0.04660927529504287
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "normal" :0.6888999940015366,
#             "slight_anomaly" :0.30470000605508746,
#             "anomalous" :0.006399999943376095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_dehydration" :0.7289999909475436,
#             "possible_dehydration" :0.2710000090524564
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "possible_meningitis" :0.00010000000046610929,
#             "no_meningitis" :0.9998999999995339
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_serious_shortness_of_breath" :1.0,
#             "serious_shortness_of_breath" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "severe_covid_vulnerabilities" :0.0004281457905780252,
#             "some_covid_vulnerabilites" :0.9755372938560916,
#             "moderate_covid_vulnerabilites" :0.02403456035333006,
#             "insignificant_covid_vulnerabilities" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.022662250956506747,
#             "low_covid" :0.9773377490434932
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.8748066167530959,
#             "medium_covid" :0.125193383246904
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.9310949987220939,
#             "high_covid" :0.06890500127790622
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_covid_environment" :0.0026999999523167825,
#             "low_risk_covid_environment" :0.7669000043526274,
#             "medium_risk_covid_environment" :0.07399999934434993,
#             "no_risk_covid_environment" :0.15639999635070584
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid" :0.018459039436188495,
#             "high_covid" :0.06890500127790633,
#             "low_covid" :0.7960690262716144,
#             "medium_covid" :0.11656693301429075
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_emergency_treatment" :0.7143485497265493,
#             "emergency_treatment" :0.2856514502734508
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid_risk" :0.7687638067446652,
#             "no_covid_risk" :0.0028869937004576017,
#             "high_covid_risk" :0.0055997442631326895,
#             "medium_covid_risk" :0.2227494552917446
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_severity" :0.11329080319947629,
#             "high_covid_severity" :0.04683678341788609,
#             "low_covid_severity" :0.33987240959842824,
#             "medium_covid_severity" :0.5000000037842095
#         }
#     ],
#     "frozen" :false
# }], dtype=object)

# %% [markdown]
# Here we use our query util to enter patient states as evidence (evidence), and then see the probabilities of particular variables we are interested in (outvars), in this case, the output variables.  It needs the compiled Pomegranate Bayesian network as well as the description of the network.  This routine can be used to enter a particular patients state , one question at a time, to get a continual change in probability of all states. Below, we first look at the probability of emergency treatment, covid risk, and covid severity, in general.  Then, we look at it given the information that the patient is elderly. We see that the chance of severity has increased. Adding more risk factors increases risk more, and adding more severity factors increases severity more.

# %%
import sn_bayes
from sn_bayes.utils import query
evidence = {}
outvars= ["emergency_treatment","covid_risk","covid_severity"]
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7143485497265493,
#   'emergency_treatment': 0.2856514502734508},
#  'covid_risk': {'low_covid_risk': 0.7687638067446652,
#   'no_covid_risk': 0.0028869937004576017,
#   'high_covid_risk': 0.0055997442631326895,
#   'medium_covid_risk': 0.2227494552917446},
#  'covid_severity': {'no_covid_severity': 0.11329080319947629,
#   'high_covid_severity': 0.04683678341788609,
#   'low_covid_severity': 0.33987240959842824,
#   'medium_covid_severity': 0.5000000037842095}}

# %%
evidence["age"]= "elderly"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7143485497265493,
#   'emergency_treatment': 0.2856514502734508},
#  'covid_risk': {'low_covid_risk': 0.7687638067446652,
#   'no_covid_risk': 0.0028869937004576017,
#   'high_covid_risk': 0.0055997442631326895,
#   'medium_covid_risk': 0.2227494552917446},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 0.0936735659633689,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.9063264340366306}}

# %%
evidence["body_temperature"]= "body_temperature_above_102F"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7129911517479252,
#   'emergency_treatment': 0.2870088482520748},
#  'covid_risk': {'low_covid_risk': 0.14562325440229593,
#   'no_covid_risk': 0.0,
#   'high_covid_risk': 0.00779897000170426,
#   'medium_covid_risk': 0.8465777755959996},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 0.0936735659633689,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.9063264340366306}}

# %%
evidence["diabetes"]= "has_diabetes"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7129911517479252,
#   'emergency_treatment': 0.2870088482520748},
#  'covid_risk': {'low_covid_risk': 0.14562325440229593,
#   'no_covid_risk': 0.0,
#   'high_covid_risk': 0.00779897000170426,
#   'medium_covid_risk': 0.8465777755959996},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 0.9535522593662626,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.04644774063373701}}

# %%
evidence["diabetes_medication"]= "no_diabetes_medication"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7129911517479252,
#   'emergency_treatment': 0.2870088482520748},
#  'covid_risk': {'low_covid_risk': 0.14562325440229593,
#   'no_covid_risk': 0.0,
#   'high_covid_risk': 0.00779897000170426,
#   'medium_covid_risk': 0.8465777755959996},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 1.0,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.0}}

# %%
evidence["hotspot"]= "abnormally_high_hotspot"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7129911517479252,
#   'emergency_treatment': 0.2870088482520748},
#  'covid_risk': {'low_covid_risk': 0.0,
#   'no_covid_risk': 0.0,
#   'high_covid_risk': 0.12477070140934861,
#   'medium_covid_risk': 0.8752292985906509},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 1.0,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.0}}

# %%
evidence["exposure"]= "exposure_in_family_not_isolated"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7129911517479252,
#   'emergency_treatment': 0.2870088482520748},
#  'covid_risk': {'low_covid_risk': 0.0,
#   'no_covid_risk': 0.0,
#   'high_covid_risk': 1.0,
#   'medium_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'high_covid_severity': 1.0,
#   'low_covid_severity': 0.0,
#   'medium_covid_severity': 0.0}}

# %% [markdown]
# Here is an example of using querys to debug the rules we wrote in covid_bayes.py .  We reset the evidence, and see that things we thought would have made a difference in risk or severity do not.  This is important feedback:  the reason is the overuse of the routine "avg" and not enough use of the routine "any" in our creation of the conditional probability tables in covid_bayes.py.

# %%
evidence = {}
evidence["ethnicity"]= "african_american"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7143485497265493,
#   'emergency_treatment': 0.2856514502734508},
#  'covid_risk': {'low_covid_risk': 0.7687638067446652,
#   'no_covid_risk': 0.0028869937004576017,
#   'high_covid_risk': 0.0055997442631326895,
#   'medium_covid_risk': 0.2227494552917446},
#  'covid_severity': {'no_covid_severity': 0.11325280074670177,
#   'high_covid_severity': 0.04698879323181571,
#   'low_covid_severity': 0.3397584022401046,
#   'medium_covid_severity': 0.500000003781378}}

# %%
evidence["education"]= "some_high_school"
evidence["income_in_USD"]= "under_25k_USD"
evidence["employment"]= "unemployed"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7143485497265493,
#   'emergency_treatment': 0.2856514502734508},
#  'covid_risk': {'low_covid_risk': 0.7687638067446652,
#   'no_covid_risk': 0.0028869937004576017,
#   'high_covid_risk': 0.0055997442631326895,
#   'medium_covid_risk': 0.2227494552917446},
#  'covid_severity': {'no_covid_severity': 0.1131864608124822,
#   'high_covid_severity': 0.04725415297363656,
#   'low_covid_severity': 0.33955938243744593,
#   'medium_covid_severity': 0.5000000037764353}}

# %%
outvars.append("social_distancing")
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'emergency_treatment': {'no_emergency_treatment': 0.7143485497265493,
#   'emergency_treatment': 0.2856514502734508},
#  'covid_risk': {'low_covid_risk': 0.7687638067446652,
#   'no_covid_risk': 0.0028869937004576017,
#   'high_covid_risk': 0.0055997442631326895,
#   'medium_covid_risk': 0.2227494552917446},
#  'covid_severity': {'no_covid_severity': 0.1131864608124822,
#   'high_covid_severity': 0.04725415297363656,
#   'low_covid_severity': 0.33955938243744593,
#   'medium_covid_severity': 0.5000000037764353},
#  'social_distancing': {'safe_social_distancing': 0.010031699771306418,
#   'some_social_distancing': 0.9433590249336508,
#   'no_social_distancing': 0.04660927529504287}}

# %% [markdown]
# Now start the server from somewhere else than here.  Use the first command uncommented if you are running in a notebook , or the second command if you are running from command line.

# %%
#%run -i './sn_service/bayes_service.py' 
#python3 ./sn_service/bayes_service.py

# %% [markdown]
# Here is a test of the server.  It is saving an ID for the network sent to it, in a pickle file of json.  If you run the service again, it will start at another id.

# %%
#This script runs the baseline above, where evidence is {}, to get the priors:
# %run -i './test_bayes_service.py' auto
# Out:
# response.id
# 1
# response.error_msg
#
# response.varAnswers
# [var_num: 136
# varStates {
#   probability: 0.28565144538879395
# }
# varStates {
#   state_num: 1
#   probability: 0.714348554611206
# }
# , var_num: 137
# varStates {
#   state_num: 3
#   probability: 0.0028869938105344772
# }
# varStates {
#   probability: 0.005599744152277708
# }
# varStates {
#   state_num: 2
#   probability: 0.7687637805938721
# }
# varStates {
#   state_num: 1
#   probability: 0.22274945676326752
# }
# , var_num: 138
# varStates {
#   state_num: 3
#   probability: 0.11329080164432526
# }
# varStates {
#   state_num: 2
#   probability: 0.33987241983413696
# }
# varStates {
#   probability: 0.04683678224682808
# }
# varStates {
#   state_num: 1
#   probability: 0.5
# }
# ]
# response.error_msg

# %%
#to find an explanation before an explanation function is implemented :

evidence["hotspot"]= "abnormally_high_hotspot"
covid.predict_proba(evidence)
# Out:
# array([{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "acute_medical_condition" :0.01999999918043658,
#             "no_acute_medical_condition" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "elderly" :0.12499999883584699,
#             "adult" :0.37500000582076554,
#             "young_adult" :0.2499999976716935,
#             "teen" :0.12499999883584699,
#             "child" :0.12499999883584699
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "male" :0.5,
#             "female" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other" :0.0005000000108270674,
#             "X" :0.0005000000108270674,
#             "XXY" :0.0005000000108270674,
#             "XYY" :0.0005000000108270674,
#             "XY" :0.4989999999783459,
#             "XX" :0.4989999999783459
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "height_above_seven" :0.04999999981373565,
#             "height_six_to_seven" :0.24999999534338715,
#             "height_five_to_six" :0.3000000063329933,
#             "height_four_to_five" :0.15000000316649675,
#             "height_under_four" :0.24999999534338715
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "weight_over_250" :0.15000000372529032,
#             "weight_175_to_220" :0.15000000372529032,
#             "weight_125_to_175" :0.2,
#             "weight_100_to_125" :0.2499999962747097,
#             "weight_under_100" :0.2499999962747097
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "african_american" :0.15000000484287718,
#             "hispanic" :0.20000000149011576,
#             "ethnicity_other" :0.05000000037252926,
#             "african" :0.05000000037252926,
#             "middle_eastern" :0.025000000186264856,
#             "native_american" :0.05000000037252926,
#             "pacific_islander" :0.025000000186264856,
#             "asian" :0.10000000074505809,
#             "caucasian" :0.3499999914318314
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "education_other" :0.05000000000000029,
#             "some_high_school" :0.1999999999999998,
#             "high_school" :0.1999999999999998,
#             "vocational" :0.1999999999999998,
#             "bachelors" :0.1999999999999998,
#             "masters" :0.10000000000000012,
#             "phd" :0.05000000000000029
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "unemployed" :0.09999999925494217,
#             "employment_other" :0.30000000521540604,
#             "retired" :0.09999999925494217,
#             "part_time" :0.09999999925494217,
#             "full_time" :0.39999999701976746
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "single" :0.33999999344348925,
#             "relationship" :0.33000000327825535,
#             "married" :0.33000000327825535
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "three_or_more" :0.04545454622423388,
#             "two_children" :0.13636364205932835,
#             "one_children" :0.18181818489693424,
#             "zero_children" :0.6363636268195036
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "under_25k_USD" :0.1904761904761905,
#             "26_to_50k_USD" :0.2857142928100765,
#             "51_to_100k_USD" :0.23809523454734258,
#             "101_to_200k_USD" :0.23809523454734258,
#             "over_200k_USD" :0.047619047619047956
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "rural" :0.2000000000000002,
#             "suburban" :0.3999999999999999,
#             "urban" :0.3999999999999999
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_six_months_pregnant" :0.025000000046566523,
#             "three_to_six_months_pregnant" :0.025000000046566523,
#             "under_three_months_pregnant" :0.025000000046566523,
#             "not_pregnant" :0.9249999998603005
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "dont_sleep_quickly" :0.3500000044703487,
#             "sleep_quickly" :0.6499999955296514
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "under_five_hours_sleep" :0.10000000111758726,
#             "five_or_six_hours_sleep" :0.2000000022351741,
#             "seven_or_eight_hours_sleep" :0.3499999927356835,
#             "nine_or_ten_hours_sleep" :0.2000000022351741,
#             "eleven_to_thirteen_hours_sleep" :0.10000000111758726,
#             "over_thirteen_hours_sleep" :0.05000000055879386
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_twelve_sex_per_month" :0.10526315913306057,
#             "six_to_twelve_sex_per_month" :0.21052631826612095,
#             "three_to_five_sex_per_month" :0.3684210452016368,
#             "two_sex_per_month" :0.21052631826612095,
#             "one_sex_per_month" :0.05263157956653041,
#             "no_sex_per_month" :0.05263157956653041
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_cigarettes_per_week" :0.04999999944120682,
#             "eleven_to_fifty_cigarettes_per_week" :0.04999999944120682,
#             "one_to_ten_cigarettes_per_week" :0.04999999944120682,
#             "no_cigarettes_per_week" :0.8500000016763796
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_cigars_per_week" :0.009999999497086248,
#             "six_to_fifty_cigars_per_week" :0.009999999497086248,
#             "one_to_five_cigars_per_week" :0.009999999497086248,
#             "no_cigars_per_week" :0.9700000015087413
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_six_hookah_per_week" :0.004950494999291934,
#             "one_to_five_hookah_per_week" :0.05445544591430842,
#             "no_hookah_per_week" :0.9405940590863996
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_snuff_per_week" :0.0010000000424920347,
#             "six_to_fifty_snuff_per_week" :0.002000000084983625,
#             "one_to_five_snuff_per_week" :0.002000000084983625,
#             "no_snuff_per_week" :0.9949999997875407
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifty_vapes_per_week" :0.009999999906868166,
#             "six_to_fifty_vapes_per_week" :0.01999999981373589,
#             "one_to_five_vapes_per_week" :0.01999999981373589,
#             "no_vapes_per_week" :0.9500000004656601
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_twentyone_glasses_per_week" :0.05000000018626486,
#             "fifteen_to_twenty_glasses_per_week" :0.10000000037252925,
#             "six_to_fourteen_glasses_per_week" :0.20000000074505808,
#             "three_to_five_glasses_per_week" :0.3000000085681674,
#             "zero_to_two_glasses_per_week" :0.34999999012798055
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_adderall_per_week" :0.002000000074971908,
#             "one_to_fifteen_adderall_per_week" :0.0080000002998863,
#             "zero_adderall_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_ritalin_per_week" :0.002000000074971908,
#             "one_to_fifteen_ritalin_per_week" :0.0080000002998863,
#             "zero_ritalin_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_cocaine_per_week" :0.002000000074971908,
#             "one_to_five_cocaine_per_week" :0.0080000002998863,
#             "zero_cocaine_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_methamphetamine_per_week" :0.002000000074971908,
#             "one_to_five_methamphetamine_per_week" :0.0080000002998863,
#             "zero_methamphetamine_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_ecstasy_per_week" :0.002000000074971908,
#             "one_to_five_ecstasy_per_week" :0.0080000002998863,
#             "zero_ecstasy_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_speed_per_week" :0.002000000074971908,
#             "one_to_five_speed_per_week" :0.0080000002998863,
#             "zero_speed_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_amphetamines_per_week" :0.002000000074971908,
#             "one_to_fifteen_amphetamines_per_week" :0.0080000002998863,
#             "zero_amphetamines_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_other_substance_per_week" :0.002000000074971908,
#             "one_to_fifteen_other_substance_per_week" :0.0080000002998863,
#             "zero_other_substance_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_opiods_per_week" :0.002000000074971908,
#             "one_to_fifteen_opiods_per_week" :0.0080000002998863,
#             "zero_opiods_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_depressants_per_week" :0.002000000074971908,
#             "one_to_five_depressants_per_week" :0.0080000002998863,
#             "zero_depressants_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_cannabis_per_week" :0.00999999998137398,
#             "one_to_fifteen_cannabis_per_week" :0.09000000542029783,
#             "zero_cannabis_per_week" :0.8999999945983282
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_hallucinogens_per_week" :0.002000000074971908,
#             "one_to_fifteen_hallucinogens_per_week" :0.0080000002998863,
#             "zero_hallucinogens_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_five_dissociatives_per_week" :0.002000000074971908,
#             "one_to_five_dissociatives_per_week" :0.0080000002998863,
#             "zero_dissociatives_per_week" :0.9899999996251418
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "over_fifteen_inhalants_per_week" :0.0040000001098965,
#             "one_to_fifteen_inhalants_per_week" :0.016000000439584668,
#             "zero_inhalants_per_week" :0.9799999994505187
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "sedentary" :0.3000000052154062,
#             "somewhat_active" :0.3999999970197675,
#             "very_active" :0.19999999850988398,
#             "intense_physical_exercise" :0.09999999925494221
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "often_lonely" :0.3000000119209292,
#             "not_often_lonely" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_close_confidants" :0.3000000119209292,
#             "has_close_confidants" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_regular_exams" :0.6000000059604641,
#             "regular_exams" :0.3999999940395358
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "very_high_blood_pressure" :0.047619049139574626,
#             "high_blood_pressure" :0.09523809827914881,
#             "borderline_blood_pressure" :0.1904761965582972,
#             "low_blood_pressure" :0.047619049139574626,
#             "normal_blood_pressure" :0.6190476068834048
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "taking_blood_pressure_medication" :0.05000000130385202,
#             "not_taking_blood_pressure_medication" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_cholesterol" :0.10000000372529073,
#             "normal_cholesterol" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_heart_attack" :0.05000000130385202,
#             "no_heart_attack" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_tiaa" :0.05000000130385202,
#             "no_tiaa" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_stroke" :0.009999999683350764,
#             "no_stroke" :0.9900000003166493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_peripheral_artery_disease" :0.05000000130385202,
#             "no_peripheral_artery_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_angina" :0.10000000372529073,
#             "no_angina" :0.8999999962747093
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "had_atherosclerotic_cardiovascular_disease" :0.05000000130385202,
#             "no_atherosclerotic_cardiovascular_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "has_diabetes" :0.02564102632681268,
#             "prediabetes" :0.4871794868365936,
#             "no_diabetes" :0.4871794868365936
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "insulin" :0.019999999813736107,
#             "oral_medication" :0.029999999720603826,
#             "no_diabetes_medication" :0.9500000004656601
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_disability_walk_or_run" :0.05000000130385202,
#             "no_disability_walk_or_run" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_disability_equipment" :0.05000000130385202,
#             "no_disability_equipment" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_mental_disability_cant_work" :0.05000000130385202,
#             "no_mental_disability_cant_work" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_other_chronic_disease" :0.05000000130385202,
#             "no_other_chronic_disease" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "body_temperature_above_102F" :0.014999999846332624,
#             "body_temperature_above_99F" :0.03500000057276418,
#             "normal_body_temperature" :0.9499999995809032
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_low_oxygen_symptoms" :0.05000000130385202,
#             "no_low_oxygen_symptoms" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_painful_shortness_of_breath" :0.010000000018627093,
#             "new_or_worse_shortness_of_breath" :0.040000000074506374,
#             "new_or_worse_shortness_of_breath_after_activity" :0.05000000195577799,
#             "no_shortness_of_breath" :0.8999999979510886
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cough_up_blood" :0.010000000018626878,
#             "dry_cough" :0.04000000007450618,
#             "cough_with_spitum" :0.0500000019557778,
#             "no_cough" :0.8999999979510891
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "colored_spots_on_toes" :0.01999999918043658,
#             "no_colored_spots_on_toes" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_lung_disease" :0.10000000372529055,
#             "no_hx_lung_disease" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_family_lung_disease" :0.10000000372529073,
#             "no_hx_family_lung_disease" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "muscle_weakness_cant_move" :0.009999999981374194,
#             "new_or_worse_muscle_weakness" :0.090000005420298,
#             "no_muscle_weakness" :0.8999999945983279
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "difficulty_moving" :0.10000000372529055,
#             "no_difficulty_moving" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "neck_stiffness" :0.10000000372529091,
#             "no_neck_stiffness" :0.8999999962747092
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_urine" :0.10000000372529089,
#             "normal_urine" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "frequent_diarrhea" :0.10000000372529073,
#             "not_frequent_diarrhea" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "nausea" :0.20000000000000026,
#             "no_nausea" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "vomiting" :0.10000000372529089,
#             "no_vomiting" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "decreased_smell_or_taste" :0.10000000372529073,
#             "no_decreased_smell_or_taste" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "sore_throat" :0.20000000000000026,
#             "no_sore_throat" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "pink_eye" :0.009999999683350764,
#             "no_pink_eye" :0.9900000003166493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "headache" :0.20000000000000026,
#             "no_headache" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "morbidly_obese" :0.05000000055879388,
#             "obese" :0.10000000111758732,
#             "overweight" :0.24999999906867731,
#             "normal" :0.4999999981373542,
#             "underweight" :0.10000000111758732
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "exposure_in_family_not_isolated" :0.01000000003725332,
#             "exposure_in_family" :0.020000000074506197,
#             "exposure_healthcare_worker" :0.030000000111759077,
#             "known_exposure" :0.020000000074506197,
#             "exposure_high_risk_worker" :0.020000000074506197,
#             "no_exposure" :0.899999999627469
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_isolation_space" :0.20000000000000026,
#             "have_isolation_space" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "leave_house_more_than_twice_per_day" :0.20000000447034857,
#             "leave_house_once_or_twice_per_day" :0.6999999932944768,
#             "leave_house_zero_per_day" :0.1000000022351745
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_place_no_sanitizer_over_three_per_week" :0.09999999850988416,
#             "high_risk_place_no_sanitizer_once_or_more_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_two_or_three_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_once_per_week" :0.19999999701976787,
#             "high_risk_place_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "deliveries_no_sanitation_over_three_per_week" :0.09999999850988416,
#             "deliveris_no_sanitation_once_or_more_per_week" :0.30000000298023194,
#             "deliveries_sanitation_two_or_three_per_week" :0.30000000298023194,
#             "deliveries_sanitation_once_per_week" :0.19999999701976787,
#             "deliveries_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_mask" :0.4000000029802321,
#             "surgical_mask" :0.49999999627470954,
#             "n95_mask" :0.10000000074505835
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "public_transportation_over_three_per_week" :0.2000000044703486,
#             "public_transportation_one_to_three_per_week" :0.10000000223517451,
#             "public_transportation_zero_per_week" :0.6999999932944769
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_workplace_social_distancing" :0.20000000000000026,
#             "workplace_social_distancing" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_neighbors_social_distancing" :0.3999999940395358,
#             "neighbors_social_distancing" :0.6000000059604641
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "visits_more_than_twice_per_week" :0.2500000000000001,
#             "visits_once_or_twice_per_week" :0.49999999999999983,
#             "visits_zero_per_week" :0.2500000000000001
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_local_govt_social_distancing" :0.3999999940395358,
#             "local_govt_social_distancing" :0.6000000059604642
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "wash_hands_zero_per_day" :0.19999999701976795,
#             "wash_hands_once_or_twice_per_day" :0.30000000298023205,
#             "wash_hands_three_to_five_per_day" :0.30000000298023205,
#             "wash_hands_over_five_per_day" :0.19999999701976795
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abnormally_low_heart_rate_variability" :0.019999998882413352,
#             "low_heart_rate_variabiliity" :0.1500000009313227,
#             "normal_heart_rate_variability" :0.6600000040978184,
#             "high_heart_rate_variability" :0.16999999608844546
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abnormally_low_oxygen" :0.019999999776482997,
#             "low_oxygen" :0.15000000763684546,
#             "normal_oxygen" :0.8299999925866716
#         }
#     ],
#     "frozen" :false
# },
#        'abnormally_high_hotspot',
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "severe_neck_pain" :0.01999999918043658,
#             "no_severe_neck_pain" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "very_systemically_disadvantaged" :0.2780000031515957,
#             "somewhat_systemically_disadvantaged" :0.40674999990127975,
#             "not_systemically_disadvantaged" :0.3152499969471245
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "not_economically_disadvantaged" :0.09142856910115242,
#             "somewhat_economically_disadvantaged" :0.5752380916050499,
#             "very_economically_disadvantaged" :0.3333333392937976
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "not_socially_disadvantaged" :0.02882285613001861,
#             "very_socially_disadvantaged" :0.38816619637817495,
#             "somewhat_socially_disadvantaged" :0.5830109474918065
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_tobacco" :0.8642700017612042,
#             "tobacco" :0.1357299982387958
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_substance_smoking" :0.9653970292285572,
#             "substance_smoking" :0.03460297077144283
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_smoking" :0.8343636921516264,
#             "smoking" :0.16563630784837363
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_stimulant_abuse" :0.9683584008272648,
#             "stimulant_abuse" :0.031641599172735305
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "addictive_substance_abuse" :0.05474240416756032,
#             "no_addictive_substance_abuse" :0.9452575958324397
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "legal_substance_abuse" :0.08465186612987377,
#             "no_legal_substance_abuse" :0.9153481338701261
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_illegal_upper_abuse" :0.9702989988978052,
#             "illegal_upper_abuse" :0.029701001102194723
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "illegal_downer_abuse" :0.029701001102194723,
#             "no_illegal_downer_abuse" :0.9702989988978052
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "illegal_substance_abuse" :0.058519852737916864,
#             "no_illegal_substance_abuse" :0.9414801472620831
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "substance_abuse" :0.0,
#             "no_substance_abuse" :1.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_depression" :0.08212500564521218,
#             "depression_free" :0.038149999807961736,
#             "medium_depression" :0.2882250084142201,
#             "low_depression" :0.591499986132606
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_societal_stress" :0.2801035978801169,
#             "low_societal_stress" :0.40963079125475593,
#             "societal_stress_free" :0.2363265522998744,
#             "high_societal_stress" :0.07393905856525275
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_stress" :0.47651234909299367,
#             "stress_free" :0.009015857924856856,
#             "medium_stress" :0.4640849520458179,
#             "high_stress" :0.05038684093633162
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_heart_disease" :0.9999874999985559,
#             "no_heart_disease" :0.0,
#             "serious_heart_disease" :1.2500001443994327e-05
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_disability" :0.8556602464397507,
#             "disability" :0.1443397535602494
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_neurological_cofactors" :0.000499999997206489,
#             "no_neurological_cofactors" :0.0,
#             "neurological_cofactors" :0.9995000000027934
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "misc_health_cofactors" :0.999499999949708,
#             "no_misc_health_cofactors" :0.0,
#             "significant_misc_health_cofactors" :0.0005000000502918694
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_health_cofactors" :0.0009997500474746087,
#             "health_cofactors" :0.9990002499525253,
#             "no_health_cofactors" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_behavioral_cofactors" :0.006436708059532294,
#             "behavioral_cofactors" :0.9923586481917809,
#             "significant_behavioral_cofactors" :0.0012046437486868012
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_other_cofactors" :0.002196754354328373,
#             "other_cofactors" :0.9978032456456715,
#             "no_other_cofactors" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "untreated_blood_pressure" :0.13571428986152279,
#             "other_blood_pressure" :0.8642857101384773
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "untreated_diabetes" :0.02435897502241231,
#             "other_diabetes" :0.9756410249775876
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_metabolic_disease" :0.019512820317825242,
#             "low_metabolic_disease" :0.4025895110655671,
#             "no_metabolic_disease" :0.42377843328222276,
#             "medium_metabolic_disease" :0.12976026031197244,
#             "severe_metabolic_disease" :0.024358975022412487
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_comorbidities" :0.09367356596336897,
#             "no_other_comorbidities" :0.906326434036631
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_specific_covid_symptoms" :0.0,
#             "mild_specific_covid_symptoms" :0.9980000000074499,
#             "significant_specific_covid_symptoms" :0.0019999999925498857
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_head_and_neck_covid_symptoms" :4.000000022396251e-05,
#             "mild_head_and_neck_covid_symptoms" :0.9999599999997759,
#             "no_head_and_neck_covid_symptoms" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_gastrointestinal_covid_symptoms" :0.9979999998509878,
#             "significant_gastrointestinal_covid_symptoms" :0.0020000001490120766,
#             "no_gastrointestinal_covid_symptoms" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_covid_symptoms" :0.004035840301496031,
#             "no_significant_covid_symptoms" :0.9959641596985039
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_personal_social_distancing" :0.17220000066608218,
#             "some_personal_social_distancing" :0.7564000002592793,
#             "safe_personal_social_distancing" :0.07139999907463836
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_social_distancing_connectedness" :0.1404999986179177,
#             "no_social_distancing_connectedness" :0.2127500033043328,
#             "some_social_distancing_connectedness" :0.6467499980777496
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_social_distancing_environment" :0.9680000009536737,
#             "no_social_distancing_environnment" :0.03199999904632618,
#             "safe_social_distancing_environment" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_social_distancing" :0.010031699771306418,
#             "some_social_distancing" :0.9433590249336508,
#             "no_social_distancing" :0.04660927529504287
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "normal" :0.6888999940015366,
#             "slight_anomaly" :0.30470000605508746,
#             "anomalous" :0.006399999943376095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_dehydration" :0.7289999909475436,
#             "possible_dehydration" :0.2710000090524564
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "possible_meningitis" :0.00010000000046610929,
#             "no_meningitis" :0.9998999999995339
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_serious_shortness_of_breath" :1.0,
#             "serious_shortness_of_breath" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "severe_covid_vulnerabilities" :0.0004281457905780252,
#             "some_covid_vulnerabilites" :0.9755372938560916,
#             "moderate_covid_vulnerabilites" :0.02403456035333006,
#             "insignificant_covid_vulnerabilities" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.022662250956506747,
#             "low_covid" :0.9773377490434932
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.8748066167530959,
#             "medium_covid" :0.125193383246904
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.9310949987220939,
#             "high_covid" :0.06890500127790622
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_covid_environment" :0.060000000223518354,
#             "low_risk_covid_environment" :0.0,
#             "medium_risk_covid_environment" :0.9399999997764812,
#             "no_risk_covid_environment" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid" :0.018459039436188495,
#             "high_covid" :0.06890500127790633,
#             "low_covid" :0.7960690262716144,
#             "medium_covid" :0.11656693301429075
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_emergency_treatment" :0.7143485497265493,
#             "emergency_treatment" :0.2856514502734508
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid_risk" :0.017351497065891272,
#             "no_covid_risk" :0.0,
#             "high_covid_risk" :0.07589901728481863,
#             "medium_covid_risk" :0.9067494856492898
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_severity" :0.11329080319947629,
#             "high_covid_severity" :0.04683678341788609,
#             "low_covid_severity" :0.33987240959842824,
#             "medium_covid_severity" :0.5000000037842095
#         }
#     ],
#     "frozen" :false
# }], dtype=object)
