# %% [markdown]
# ## Covid Bayes Net
#
#
# First we create a Pomegranate Bayesian Network using the protobuf interface and our utility package, bayes, that enables one to conveniently create a Bayesian network by hand without having to fill in every probability.  The same Baysian network can start with our hand entered guesses, but can later learn from data.  Any amount of questions can be answered, including no questions, to get the probabilities of having covid , the severity of illness, and the chances of going to the hospital.  The file the Bayesian net is written in is covid_bayes.py.  Our utility package can then be used to query the network with different patient states.  This is convenient for tuning hand entered parameters .

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -e ../covid-bayesnet
#!{sys.executable} -m pip install protobuf
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (20.2.3)
# Obtaining file:///home/opencog/covid-bayesnet
# Installing collected packages: covid-bayes
#   Attempting uninstall: covid-bayes
#     Found existing installation: covid-bayes 1.0
#     Can't uninstall 'covid-bayes'. No files were found to uninstall.
#   Running setup.py develop for covid-bayes
# Successfully installed covid-bayes

# %%
pwd
# Out:
# '/home/opencog/covid-bayesnet'

# %%
# !{sys.executable} -m pip install -r requirements.txt
# !sh buildproto.sh
# Out:
# Requirement already satisfied: grpcio>=1.14.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.31.0)
# Requirement already satisfied: grpcio-tools>=1.14.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.31.0)
# Requirement already satisfied: pomegranate>=0.13.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio>=1.14.2->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in /usr/local/lib/python3.6/dist-packages (from grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (3.13.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (2.5)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.18.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (5.1.2)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 4)) (2019.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from protobuf<4.0dev,>=3.5.0.post1->grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (39.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->pomegranate>=0.13.4->-r requirements.txt (line 3)) (4.4.2)

# %% [markdown]
# ### Covid net
# Here put the name of the network you have written with the protobuf and bayes utilities.  Our example is printed out.  We created 4 functions in our utility package: any, all, if_the_else, and avg, which can together be used to express almost any set of rules, documented elsewhere.  The last lines implement the creation of the description of the network,  bayesianNetwork , with the protobuf utilities, and then the creation of the Pomegranate network with the description.

# %%
text_file = open('./sn_bayes/covid_bayes.py')
file_content = text_file.read()
print(file_content)
text_file.close()
# Out:
# import sn_bayes
# from sn_bayes.utils import any
# from sn_bayes.utils import all
# from sn_bayes.utils import avg
# from sn_bayes.utils import if_then_else
# from sn_bayes.utils import bayesInitialize
# from sn_bayes.utils import addCpt
#
#
# import sn_service.service_spec.bayesian_pb2
# from sn_service.service_spec.bayesian_pb2 import BayesianNetwork
#
#
# def covid_bayes():
# 	bayesianNetwork = BayesianNetwork()
#
#
#
# 	#probabilities within distributions must sum to 1.0
# 	#questions left blank or "prefer not to answer" will be computed
#
# 	#anomalies
#
# 	anomaly = bayesianNetwork.anomalies.add()
# 	anomaly.varName = "oxygen_anomaly"
# 	anomaly.high = 200
# 	anomaly.low =93
# 	anomaly.high_percent = 0.99
# 	anomaly.low_percent = 0.01
#
# 	anomaly = bayesianNetwork.anomalies.add()
# 	anomaly.varName = "heart_rate_anomaly"
#
# 	anomaly = bayesianNetwork.anomalies.add()
# 	anomaly.varName = "hotspot_anomaly"
# 	anomaly.low = -1
# 	anomaly.high = 0.00007 # percent new daily cases
#
# 	anomaly = bayesianNetwork.anomalies.add()
# 	anomaly.varName = "heart_rate_variability_anomaly"
#
#
#
#
# 	# basics/demographics questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "age"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "elderly"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "adult"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "young_adult"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "teen"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "child"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sex"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "male"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "female"
# 	variable.probability = 0.5
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "height_in_feet"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_above_seven"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_six_to_seven"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_five_to_six"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_four_to_five"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_under_four"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "weight_in_pounds"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_over_250"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_175_to_220"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_125_to_175"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_100_to_125"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_under_100"
# 	variable.probability = 0.25
#
#
#
# #cardiovascular_disease 9%
# #https://www.sciencedaily.com/releases/2019/01/190131084238.htm
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cardiovascular_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cardiovascular_disease"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cardiovascular_disease"
# 	variable.probability = 0.91
#
#
# #diabetes 12%
# #https://www.healio.com/news/endocrinology/20200730/prevalence-of-diabetes-hypertension-among-covid19-patients-likely-lower-than-reported
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "diabetes"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "diabetes"
# 	variable.probability = 0.12
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_diabetes"
# 	variable.probability = 0.88
#
# #hypertension 17%
# #https://www.healio.com/news/endocrinology/20200730/prevalence-of-diabetes-hypertension-among-covid19-patients-likely-lower-than-reported
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hypertension"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hypertension"
# 	variable.probability = 0.17
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hypertension"
# 	variable.probability = 0.83
#
# #37M/328M = 11%
# #https://www.lung.org/about-us/mission-impact-and-history/our-impact
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "lung_disease"
# 	variable.probability = 0.11
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_lung_disease"
# 	variable.probability = 0.89
#
# #kidney disease = 14%
# #https://www.niddk.nih.gov/health-information/health-statistics/kidney-disease#:~:text=The%20overall%20prevalence%20of%20CKD,661%2C000%20Americans%20have%20kidney%20failure.
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "kidney_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "kidney_disease"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_kidney_disase"
# 	variable.probability = 0.7
#
# #cancer = 5.5%
# #https://ourworldindata.org/cancer#:~:text=Prevalence%20of%20cancer%20ranges%20from,countries%20shown%20in%20light%20yellow.
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cancer"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cancer"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cancer"
# 	variable.probability = 0.7
#
# #immunocompromised=2.7%
# #https://www.healio.com/news/infectious-disease/20161101/nearly-3-of-us-adult-population-immunosuppressed#:~:text=Among%20them%2C%202.8%25%20(n,CI%2C%202.9%2D3.3).
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "immunocompromised"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "immunocompromised"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_immunocompromised"
# 	variable.probability = 0.7
#
# #psychiatric disorders 17.6%
# #https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3997379/#:~:text=Period%20prevalence%20of%20common%20mental,CI%2C%2025.9%E2%80%9332.6%25).
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "psychological_disorders"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "psychological_disorders"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_psychological_disorders"
# 	variable.probability = 0.7
#
#
# 	# covid symptoms questions in discrete distributions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "body_temperature"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_102F"
# 	variable.probability = 0.015
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_100F"
# 	variable.probability = 0.035
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_body_temperature"
# 	variable.probability = 0.95
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "shortness_of_breath"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_painful_shortness_of_breath"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath_after_activity"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_shortness_of_breath"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cough"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_up_blood"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "dry_cough"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_with_spitum"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cough"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "rash_or_skin_discoloration"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "rash_or_skin_discoloration"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_rash_or_skin_discoloration"
# 	variable.probability = 0.98
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "muscle_weakness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_muscle_weakness"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_muscle_weakness"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_muscle_weakness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "difficulty_moving"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_difficulty_moving"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_difficulty_moving"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_difficulty_moving"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "neck_stiffness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_neck_stiffness"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_neck_stiffness"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_neck_stiffness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "low_urine"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_low_urine"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_low_urine"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_urine"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "frequent_diarrhea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_frequent_diarrhea"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_frequent_diarrhea"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_frequent_diarrhea"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "nausea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_nausea"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_nausea"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_nausea"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "vomiting"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_vomiting"
# 	variable.probability =0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_vomiting"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_vomiting"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "decreased_smell_or_taste"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_decreased_smell_or_taste"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_decreased_smell_or_taste"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_decreased_smell_or_taste"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sore_throat"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_sore_throat"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_sore_throat"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_sore_throat"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "pink_eye"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_pink_eye"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_pink_eye"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_pink_eye"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "headache"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_or_severe_headache"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "moderate_headache"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_headache"
# 	variable.probability = 0.80
#
# 	####
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "feeling_well"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_feeling_well"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "feeling_well"
# 	variable.probability = 0.80
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "congestion"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "congestion"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_congestion"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "fatigue"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "fatigue"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_fatigue"
# 	variable.probability = 0.90
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "muscle_aches_or_body_pain"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "muscle_aches_or_body_pain"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_muscle_aches_or_body_pain"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "abdominal_pain"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "abdominal_pain"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_abdominal_pain"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "own_thermometer"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "dont_own_thermometer"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "own_thermometer"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "breathing_problems_at_night"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "breathing_problems_at_night"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "breathing_problems_at_night_relieved_with_pillows"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_breathing_problems_at_night"
# 	variable.probability = 0.98
#
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cough_phlegm_color"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "rust_colored_cough_phlegm"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "yellow_green_colored_phlegm"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "thin_clear_colored_phlegm"
# 	variable.probability = 0.9
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "bmi"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "morbidly_obese"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "obese"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "overweight"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "underweight"
# 	variable.probability = 0.1
#
#
# 	# covid/social distance rules
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "known_exposure"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "known_exposure"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_known_exposure"
# 	variable.probability = 0.02
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "employment_risk"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "health_care_worker_or_first_responder"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_volume_employment"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_employment_risk"
# 	variable.probability = 0.50
#
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "social_distancing_following"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_social_distancing_following"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "social_distance_following"
# 	variable.probability = 0.50
#
#
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "close_contact_unknown_exposure"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "close_contact_unknown_exposure"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_close_contact_unknown_exposure"
# 	variable.probability = 0.50
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "social_distancing_following"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_social_distancing_following"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "social_distancing_following"
# 	variable.probability = 0.50
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "self_quarantine_two_weeks"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_self_quarantine_two_weeks"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "self_quarantine_two_weeks"
# 	variable.probability = 0.50
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "isolation_space"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_isolation_space"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_isolation_space"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "leaving_house_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_more_than_twice_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_once_or_twice_per_day"
# 	variable.probability = 0.70
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_zero_per_day"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "high_risk_place_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "deliveries_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_no_sanitation_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_no_sanitation_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "mask"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_mask"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "surgical_mask_or_untrained_n95"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "n95_mask"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "public_transportation_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_over_three_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_one_to_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_zero_per_week"
# 	variable.probability = 0.70
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "workplace_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_workplace_social_distancing"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "workplace_social_distancing"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "daily_contacts_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_daily_contacts_social_distancing"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "daily_contacts_social_distancing"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "visits_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_more_than_twice_per_week"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_once_or_twice_per_week"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_zero_per_week"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "wash_hands_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_zero_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_once_or_twice_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_three_to_five_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_over_five_per_day"
# 	variable.probability = 0.20
#
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "tested"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "tested"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_tested"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "swab_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "swab_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "swab_test_negative"
# 	variable.probability = 0.98
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "antibody_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "antibody_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "antibody_test_negative"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "saliva_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "saliva_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "saliva_test_negative"
# 	variable.probability = 0.98
#
# 	#anomalies
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hotspot_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hotspot_anomaly"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hotspot_anomaly"
# 	variable.probability = 0.85
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_rate_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "heart_rate_anomaly"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_heart_rate_anomaly"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_rate_variability_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "heart_rate_variability_anomaly"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_heart_rate_variability_anomaly"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "oxygen_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "oxygen_anomaly"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_oxygen_anomaly"
# 	variable.probability = 0.95
#
# 	# conditional probability tables
#
# 	cpt ={}
#
#
# 	cpt["covid_test"] = any(bayesianNetwork,cpt,
# 	{
# 	"swab_test":{"swab_test_positive"},
# 	"antibody_test":{"antibody_test_positive"},
# 	"saliva_test":{"saliva_test_positive"}
# 	},
# 	["positive_covid_test","negative_covid_test"]
#
# 	)
#
#
# 	cpt["metabolic_disease"] = any(bayesianNetwork,cpt,
# 	{
# 	"cardiovascular_disease":{"cardiovascular_disease"},
# 	"diabetes":{"diabetes"},
# 	"hypertension":{"hypertension"}
# 	},
# 	["metabolic_disease","no_metabolic_disease"]
#
# 	)
#
#
# 	cpt["chronic_conditions"] = any(bayesianNetwork,cpt,
# 	{
# 	"lung_disease":{"lung_disease"},
# 	"cancer":{"cancer"},
# 	"kidney_disease":{"kidney_disease"},
# 	"immunocompromised":{"immunocompromised"}
# 	},
# 	["chronic_conditions","no_chronic_conditions"]
#
# 	)
#
#
# 	cpt["demographics"] = avg(bayesianNetwork,cpt,
# 	[
# 	"age",
# 	"bmi"
# 	],
# 	["demographics","no_demographics"]
#
# 	)
#
# 	cpt["comorbidities"] = any(bayesianNetwork,cpt,
# 	{
# 	"chronic_conditions":{"chronic_conditions"},
# 	"metabolic_disease":{"metabolic_disease"},
# 	"demographics":{"demographics"}
# 	},
# 	["comorbidities","no_comorbidities"]
#
# 	)
#
# 	cpt["cold_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"cough_phlegm_color",
# 	"fatigue",
# 	"congestion",
# 	"feeling_well",
# 	"muscle_aches_or_body_pain",
# 	"breathing_problems_at_night"
# 	],
# 	[ "significant_cold_symptoms","mild_cold_symptoms","no_cold_symptoms"]
# 	)
#
# 	cpt["specific_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"rash_or_skin_discoloration",
# 	"decreased_smell_or_taste"
# 	],
# 	[ "significant_specific_covid_symptoms","mild_specific_covid_symptoms","no_specific_covid_symptoms"]
# 	)
#
# 	cpt["head_and_neck_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"neck_stiffness",
# 	"sore_throat",
# 	"pink_eye",
# 	"headache"
# 	],
# 	[ "significant_head_and_neck_covid_symptoms","mild_head_and_neck_covid_symptoms","no_head_and_neck_covid_symptoms"]
# 	)
#
# 	cpt["gastrointestinal_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"low_urine",
# 	"nausea",
# 	"vomiting",
# 	"abdominal_pain"
# 	],
# 	[ "significant_gastrointestinal_covid_symptoms","mild_gastrointestinal_covid_symptoms","no_gastrointestinal_covid_symptoms"]
# 	)
#
#
#
# 	cpt["gastrointestinal_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"low_urine",
# 	"nausea",
# 	"vomiting",
# 	"abdominal_pain"
# 	],
# 	[ "significant_gastrointestinal_covid_symptoms","mild_gastrointestinal_covid_symptoms","no_gastrointestinal_covid_symptoms"]
# 	)
#
# 	cpt["covid_symptoms"] = any(bayesianNetwork,cpt,
# 	{
# 	"gastrointestinal_covid_symptoms":{"significant_gastrointestinal_covid_symptoms"},
# 	"specific_covid_symptoms":{"significant_specific_covid_symptoms"},
# 	"head_and_neck_covid_symptoms":{"significant_head_and_neck_covid_symptoms"}
# 	},
# 	[ "significant_covid_symptoms","no_significant_covid_symptoms"]
# 	)
#
# 	cpt["personal_social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"isolation_space",
# 	"deliveries_per_week",
# 	"mask",
# 	"wash_hands_per_day",
# 	"social_distancing_following",
# 	"close_contact_unknown_exposure"
# 	],
# 	["no_personal_social_distancing","some_personal_social_distancing","safe_personal_social_distancing"]
# 	)
#
#
#
# 	cpt["social_distancing_connectedness"]= avg(bayesianNetwork,cpt,
# 	[
# 	"visits_per_week",
# 	"leaving_house_per_day",
# 	"high_risk_place_per_week",
# 	"public_transportation_per_week"
# 	],
# 	["no_social_distancing_connectedness","some_social_distancing_connectedness","safe_social_distancing_connectedness"]
# 	)
#
#
# 	cpt["social_distancing_environment"]= avg(bayesianNetwork,cpt,
# 	[
# 	"workplace_social_distancing",
# 	"daily_contacts_social_distancing"
# 	],
# 	["no_social_distancing_environnment","some_social_distancing_environment","safe_social_distancing_environment"]
# 	)
#
#
# 	cpt["social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"social_distancing_environment",
# 	"personal_social_distancing",
# 	"social_distancing_connectedness"
# 	],
# 	["no_social_distancing","low_social_distancing","medium_social_distancing", "high_social_distancing"]
# 	)
#
# 	cpt["social_distancing_binary"]= avg(bayesianNetwork,cpt,
# 	[
# 	"social_distancing_environment",
# 	"personal_social_distancing",
# 	"social_distancing_connectedness"
# 	],
# 	["no_social_distancing", "social_distancing"]
# 	)
#
#
# 	cpt["wearables"] = any(bayesianNetwork,cpt,
# 	{
# 	"heart_rate_variability_anomaly":{"heart_rate_variability_anomaly"},
# 	"oxygen_anomaly":{"oxygen_anomaly"},
# 	"heart_rate_anomaly":{"heart_rate_anomaly"}
# 	},
# 	["anomalous","normal"]
# 	)
#
#
# 	cpt["possible_dehydration"] = any(bayesianNetwork,cpt,
# 	{
# 	"low_urine":{"low_urine"},
# 	"vomiting":{"vomiting"},
# 	"frequent_diarrhea":{"frequent_diarrhea"}
# 	},
# 	["possible_dehydration","no_dehydration"]
# 	)
#
#
# 	cpt["possible_meningitis"] = all(bayesianNetwork,cpt,
# 		{"neck_stiffness":{"neck_stiffness"},
# 		"body_temperature":{"body_temperature_above_102F","body_temperature_above_99F"}},
# 		["possible_meningitis","no_meningitis"]
# 		)
#
#
# 	cpt["serious_shortness_of_breath"] = all(bayesianNetwork,cpt,
# 		{"shortness_of_breath":{"new_or_worse_painful_shortness_of_breath","new_or_worse_shortness_of_breath"},
# 		"comorbidities":{"comorbidities"}},
# 		["serious_shortness_of_breath","no_serious_shortness_of_breath"]
# 		)
#
#
# 	cpt["covid_vulnerabilities"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptoms",
# 		"social_distancing",
# 		"wearables"
# 		],
# 		["severe_covid_vulnerabilities", "moderate_covid_vulnerabilites","some_covid_vulnerabilites", "insignificant_covid_vulnerabilities"]
# 		)
#
#
# 	cpt["low_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"shortness_of_breath": {"new_or_worse_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_99F"},
# 		"covid_vulnerabilities":{"some_covid_vulnerabilites"},
# 		"cold_symptoms":{"significant_cold_symptoms"}
#
# 		},
# 		["low_covid","other_covid"]
# 		)
#
#
# 	cpt["medium_covid"]= any(bayesianNetwork,cpt,
# 		{
# 		"serious_shortness_of_breath":{"serious_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_102F"},
# 		"muscle_weakness":{"new_or_worse_muscle_weakness"},
# 		"covid_vulnerabilities":{"moderate_covid_vulnerabilites"}
# 		},
# 		["medium_covid","other_covid"]
# 		)
#
#
# 	cpt["high_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"cough":{"cough_up_blood"},
# 		"muscle_weakness":{"muscle_weakness_cant_move"},
# 		"covid_vulnerabilities": {"severe_covid_vulnerabilites"}
# 		},
# 		["high_covid","other_covid"]
# 		)
#
# 	cpt["exposure"]= any(bayesianNetwork,cpt,
# 		{
# 		"known_exposure":{"known_exposure"},
# 		"employment_risk":{"health_care_worker_or_first_responder","high_volume_employment"}
# 		},
# 		["exposure","no_exposure"]
# 		)
#
#
# 	cpt["covid_environment"] = avg(bayesianNetwork,cpt,
# 		[
# 		"exposure",
# 		"hotspot_anomaly"
# 		],
# 		["high_risk_covid_environment", "medium_risk_covid_environment", "low_risk_covid_environment","no_risk_covid_environment"]
# 		)
#
#
# 	cpt["covid_symptom_level"] = if_then_else(bayesianNetwork,cpt,
# 		{
# 		"high_covid":{"high_covid"},
# 		"medium_covid":{"medium_covid"},
# 		"low_covid":{"low_covid"},
# 		},
# 		["high_covid", "medium_covid","low_covid","no_covid"]
# 		)
#
# 	cpt["high_covid_risk"] =any(bayesianNetwork,cpt,
# 		{
# 		"covid_symptom_level":{"high_covid"},
# 		"covid_test":{"positive_covid_test"},
# 		"covid_environment":{"high_risk_covid_environment"}
# 		},
# 		["high_covid_risk","other_covid_risk"]
# 		)
#
# 	cpt["medium_covid_risk"] =any(bayesianNetwork,cpt,
# 		{
# 		"covid_symptom_level":{"medium_covid"},
# 		"covid_environment":{"medium_risk_covid_environment"}
# 		},
# 		["medium_covid_risk","other_covid_risk"]
# 		)
#
# 	cpt["low_covid_risk"] =any(bayesianNetwork,cpt,
# 		{
# 		"covid_symptom_level":{"low_covid"},
# 		"covid_environment":{"low_risk_covid_environment"}
# 		},
# 		["low_covid_risk","other_covid_risk"]
# 		)
#
#
# 	#output variable conditional probability distributions
#
#
# 	cpt["emergency_treatment"] = any(bayesianNetwork,cpt,
# 	{
# 	"possible_dehydration":{"possible_dehydration"},
# 	"possible_meningitis":{"possible_meningitis"}
# 	},
# 	["emergency_treatment","no_emergency_treatment"]
# 	)
#
#
#
# 	cpt["covid_risk"] = if_then_else(bayesianNetwork,cpt,
# 		{
# 		"high_covid_risk":{"high_covid_risk"},
# 		"medium_covid_risk":{"medium_covid_risk"},
# 		"low_covid_risk":{"low_covid_risk"},
# 		},
# 		["high_covid_risk", "medium_covid_risk","low_covid_risk","no_covid_risk"]
# 		)
#
#
# 	cpt["covid_risk_binary"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptom_level",
# 		"covid_environment"
# 		],
# 		["covid_risk","no_covid_risk"]
# 		)
#
#
# 	cpt["covid_severity"] = avg(bayesianNetwork,cpt,
# 		[
# 		"age",
# 		"comorbidities"
# 		],
# 		["high_covid_severity","medium_covid_severity","low_covid_severity","no_covid_severity"]
# 		)
#
#
# 	cpt["covid_severity_binary"] = avg(bayesianNetwork,cpt,
# 		[
# 		"age",
# 		"comorbidities"
# 		],
# 		["covid_severity","no_covid_severity"]
# 		)
#
#
#
# 	addCpt(bayesianNetwork,cpt)
# 	return(bayesianNetwork)
#
# if __name__ == '__main__':
# 	covid_bayes()

# %% [markdown]
#  Next run the file.  All routines are stateless.

# %%
import sn_bayes
from sn_bayes import covid_bayes
#%run -i './bayes/covid_bayes.py'
#%run -i './bayes/test.py'
bayesianNetwork = covid_bayes.covid_bayes()

# %% [markdown]
# For convenience of creating a table, here are all the variables in the net in order.  They should be mapped into the individual buckets of the rules.  The variables up to "systemically_disadvantaged" are the ones that the user may answer.  The rest are computed.

# %%
import sn_bayes
from sn_bayes.utils import get_var_positions
var_positions = get_var_positions(bayesianNetwork)
var_positions
# Out:
# {'age': 0,
#  'sex': 1,
#  'height_in_feet': 2,
#  'weight_in_pounds': 3,
#  'cardiovascular_disease': 4,
#  'diabetes': 5,
#  'hypertension': 6,
#  'lung_disease': 7,
#  'kidney_disease': 8,
#  'cancer': 9,
#  'immunocompromised': 10,
#  'psychological_disorders': 11,
#  'body_temperature': 12,
#  'shortness_of_breath': 13,
#  'cough': 14,
#  'rash_or_skin_discoloration': 15,
#  'muscle_weakness': 16,
#  'difficulty_moving': 17,
#  'neck_stiffness': 18,
#  'low_urine': 19,
#  'frequent_diarrhea': 20,
#  'nausea': 21,
#  'vomiting': 22,
#  'decreased_smell_or_taste': 23,
#  'sore_throat': 24,
#  'pink_eye': 25,
#  'headache': 26,
#  'feeling_well': 27,
#  'congestion': 28,
#  'fatigue': 29,
#  'muscle_aches_or_body_pain': 30,
#  'abdominal_pain': 31,
#  'own_thermometer': 32,
#  'breathing_problems_at_night': 33,
#  'cough_phlegm_color': 34,
#  'bmi': 35,
#  'known_exposure': 36,
#  'employment_risk': 37,
#  'social_distancing_following': 40,
#  'close_contact_unknown_exposure': 39,
#  'self_quarantine_two_weeks': 41,
#  'isolation_space': 42,
#  'leaving_house_per_day': 43,
#  'high_risk_place_per_week': 44,
#  'deliveries_per_week': 45,
#  'mask': 46,
#  'public_transportation_per_week': 47,
#  'workplace_social_distancing': 48,
#  'daily_contacts_social_distancing': 49,
#  'visits_per_week': 50,
#  'wash_hands_per_day': 51,
#  'tested': 52,
#  'swab_test': 53,
#  'antibody_test': 54,
#  'saliva_test': 55,
#  'hotspot_anomaly': 56,
#  'heart_rate_anomaly': 57,
#  'heart_rate_variability_anomaly': 58,
#  'oxygen_anomaly': 59,
#  'covid_test': 59,
#  'metabolic_disease': 60,
#  'chronic_conditions': 61,
#  'demographics': 62,
#  'comorbidities': 63,
#  'cold_symptoms': 64,
#  'specific_covid_symptoms': 65,
#  'head_and_neck_covid_symptoms': 66,
#  'gastrointestinal_covid_symptoms': 67,
#  'covid_symptoms': 68,
#  'personal_social_distancing': 69,
#  'social_distancing_connectedness': 70,
#  'social_distancing_environment': 71,
#  'social_distancing': 72,
#  'social_distancing_binary': 73,
#  'wearables': 74,
#  'possible_dehydration': 75,
#  'possible_meningitis': 76,
#  'serious_shortness_of_breath': 77,
#  'covid_vulnerabilities': 78,
#  'low_covid': 79,
#  'medium_covid': 80,
#  'high_covid': 81,
#  'exposure': 82,
#  'covid_environment': 83,
#  'covid_symptom_level': 84,
#  'high_covid_risk': 85,
#  'medium_covid_risk': 86,
#  'low_covid_risk': 87,
#  'emergency_treatment': 88,
#  'covid_risk': 89,
#  'covid_risk_binary': 90,
#  'covid_severity': 91,
#  'covid_severity_binary': 92}

# %% [markdown]
# Here are the positions of every bucketed response for each of the above variables:

# %%
import sn_bayes
from sn_bayes.utils import get_var_val_positions
var_val_positions = get_var_val_positions(bayesianNetwork)
var_val_positions
# Out:
# {'age': {'elderly': 0, 'adult': 1, 'young_adult': 2, 'teen': 3, 'child': 4},
#  'sex': {'male': 0, 'female': 1},
#  'height_in_feet': {'height_above_seven': 0,
#   'height_six_to_seven': 1,
#   'height_five_to_six': 2,
#   'height_four_to_five': 3,
#   'height_under_four': 4},
#  'weight_in_pounds': {'weight_over_250': 0,
#   'weight_175_to_220': 1,
#   'weight_125_to_175': 2,
#   'weight_100_to_125': 3,
#   'weight_under_100': 4},
#  'cardiovascular_disease': {'cardiovascular_disease': 0,
#   'no_cardiovascular_disease': 1},
#  'diabetes': {'diabetes': 0, 'no_diabetes': 1},
#  'hypertension': {'hypertension': 0, 'no_hypertension': 1},
#  'lung_disease': {'lung_disease': 0, 'no_lung_disease': 1},
#  'kidney_disease': {'kidney_disease': 0, 'no_kidney_disase': 1},
#  'cancer': {'cancer': 0, 'no_cancer': 1},
#  'immunocompromised': {'immunocompromised': 0, 'not_immunocompromised': 1},
#  'psychological_disorders': {'psychological_disorders': 0,
#   'no_psychological_disorders': 1},
#  'body_temperature': {'body_temperature_above_102F': 0,
#   'body_temperature_above_100F': 1,
#   'normal_body_temperature': 2},
#  'shortness_of_breath': {'new_or_worse_painful_shortness_of_breath': 0,
#   'new_or_worse_shortness_of_breath': 1,
#   'new_or_worse_shortness_of_breath_after_activity': 2,
#   'no_shortness_of_breath': 3},
#  'cough': {'cough_up_blood': 0,
#   'dry_cough': 1,
#   'cough_with_spitum': 2,
#   'no_cough': 3},
#  'rash_or_skin_discoloration': {'rash_or_skin_discoloration': 0,
#   'no_rash_or_skin_discoloration': 1},
#  'muscle_weakness': {'new_or_worse_or_severe_muscle_weakness': 0,
#   'moderate_muscle_weakness': 1,
#   'no_muscle_weakness': 2},
#  'difficulty_moving': {'new_or_worse_or_severe_difficulty_moving': 0,
#   'moderate_difficulty_moving': 1,
#   'no_difficulty_moving': 2},
#  'neck_stiffness': {'new_or_worse_or_severe_neck_stiffness': 0,
#   'moderate_neck_stiffness': 1,
#   'no_neck_stiffness': 2},
#  'low_urine': {'new_or_worse_or_severe_low_urine': 0,
#   'moderate_low_urine': 1,
#   'normal_urine': 2},
#  'frequent_diarrhea': {'new_or_worse_or_severe_frequent_diarrhea': 0,
#   'moderate_frequent_diarrhea': 1,
#   'not_frequent_diarrhea': 2},
#  'nausea': {'new_or_worse_or_severe_nausea': 0,
#   'moderate_nausea': 1,
#   'no_nausea': 2},
#  'vomiting': {'new_or_worse_or_severe_vomiting': 0,
#   'moderate_vomiting': 1,
#   'no_vomiting': 2},
#  'decreased_smell_or_taste': {'new_or_worse_or_severe_decreased_smell_or_taste': 0,
#   'moderate_decreased_smell_or_taste': 1,
#   'no_decreased_smell_or_taste': 2},
#  'sore_throat': {'new_or_worse_or_severe_sore_throat': 0,
#   'moderate_sore_throat': 1,
#   'no_sore_throat': 2},
#  'pink_eye': {'new_or_worse_or_severe_pink_eye': 0,
#   'moderate_pink_eye': 1,
#   'no_pink_eye': 2},
#  'headache': {'new_or_worse_or_severe_headache': 0,
#   'moderate_headache': 1,
#   'no_headache': 2},
#  'feeling_well': {'not_feeling_well': 0, 'feeling_well': 1},
#  'congestion': {'congestion': 0, 'no_congestion': 1},
#  'fatigue': {'fatigue': 0, 'no_fatigue': 1},
#  'muscle_aches_or_body_pain': {'muscle_aches_or_body_pain': 0,
#   'no_muscle_aches_or_body_pain': 1},
#  'abdominal_pain': {'abdominal_pain': 0, 'no_abdominal_pain': 1},
#  'own_thermometer': {'dont_own_thermometer': 0, 'own_thermometer': 1},
#  'breathing_problems_at_night': {'breathing_problems_at_night': 0,
#   'breathing_problems_at_night_relieved_with_pillows': 1,
#   'no_breathing_problems_at_night': 2},
#  'cough_phlegm_color': {'rust_colored_cough_phlegm': 0,
#   'yellow_green_colored_phlegm': 1,
#   'thin_clear_colored_phlegm': 2},
#  'bmi': {'morbidly_obese': 0,
#   'obese': 1,
#   'overweight': 2,
#   'normal': 3,
#   'underweight': 4},
#  'known_exposure': {'known_exposure': 0, 'no_known_exposure': 1},
#  'employment_risk': {'health_care_worker_or_first_responder': 0,
#   'high_volume_employment': 1,
#   'low_employment_risk': 2},
#  'social_distancing_following': {'no_social_distancing_following': 0,
#   'social_distancing_following': 1},
#  'close_contact_unknown_exposure': {'close_contact_unknown_exposure': 0,
#   'no_close_contact_unknown_exposure': 1},
#  'self_quarantine_two_weeks': {'no_self_quarantine_two_weeks': 0,
#   'self_quarantine_two_weeks': 1},
#  'isolation_space': {'no_isolation_space': 0, 'have_isolation_space': 1},
#  'leaving_house_per_day': {'leave_house_more_than_twice_per_day': 0,
#   'leave_house_once_or_twice_per_day': 1,
#   'leave_house_zero_per_day': 2},
#  'high_risk_place_per_week': {'high_risk_place_no_sanitizer_over_three_per_week': 0,
#   'high_risk_place_no_sanitizer_once_or_more_per_week': 1,
#   'high_risk_place_sanitizer_two_or_three_per_week': 2,
#   'high_risk_place_sanitizer_once_per_week': 3,
#   'high_risk_place_zero_per_week': 4},
#  'deliveries_per_week': {'deliveries_no_sanitation_over_three_per_week': 0,
#   'deliveries_no_sanitation_once_or_more_per_week': 1,
#   'deliveries_sanitation_two_or_three_per_week': 2,
#   'deliveries_sanitation_once_per_week': 3,
#   'deliveries_zero_per_week': 4},
#  'mask': {'no_mask': 0, 'surgical_mask_or_untrained_n95': 1, 'n95_mask': 2},
#  'public_transportation_per_week': {'public_transportation_over_three_per_week': 0,
#   'public_transportation_one_to_three_per_week': 1,
#   'public_transportation_zero_per_week': 2},
#  'workplace_social_distancing': {'no_workplace_social_distancing': 0,
#   'workplace_social_distancing': 1},
#  'daily_contacts_social_distancing': {'no_daily_contacts_social_distancing': 0,
#   'daily_contacts_social_distancing': 1},
#  'visits_per_week': {'visits_more_than_twice_per_week': 0,
#   'visits_once_or_twice_per_week': 1,
#   'visits_zero_per_week': 2},
#  'wash_hands_per_day': {'wash_hands_zero_per_day': 0,
#   'wash_hands_once_or_twice_per_day': 1,
#   'wash_hands_three_to_five_per_day': 2,
#   'wash_hands_over_five_per_day': 3},
#  'tested': {'tested': 0, 'not_tested': 1},
#  'swab_test': {'swab_test_positive': 0, 'swab_test_negative': 1},
#  'antibody_test': {'antibody_test_positive': 0, 'antibody_test_negative': 1},
#  'saliva_test': {'saliva_test_positive': 0, 'saliva_test_negative': 1},
#  'hotspot_anomaly': {'hotspot_anomaly': 0, 'no_hotspot_anomaly': 1},
#  'heart_rate_anomaly': {'heart_rate_anomaly': 0, 'no_heart_rate_anomaly': 1},
#  'heart_rate_variability_anomaly': {'heart_rate_variability_anomaly': 0,
#   'no_heart_rate_variability_anomaly': 1},
#  'oxygen_anomaly': {'oxygen_anomaly': 0, 'no_oxygen_anomaly': 1},
#  'covid_test': {'positive_covid_test': 0, 'negative_covid_test': 1},
#  'metabolic_disease': {'metabolic_disease': 0, 'no_metabolic_disease': 1},
#  'chronic_conditions': {'chronic_conditions': 0, 'no_chronic_conditions': 1},
#  'demographics': {'demographics': 0, 'no_demographics': 1},
#  'comorbidities': {'comorbidities': 0, 'no_comorbidities': 1},
#  'cold_symptoms': {'significant_cold_symptoms': 0,
#   'mild_cold_symptoms': 1,
#   'no_cold_symptoms': 2},
#  'specific_covid_symptoms': {'significant_specific_covid_symptoms': 0,
#   'mild_specific_covid_symptoms': 1,
#   'no_specific_covid_symptoms': 2},
#  'head_and_neck_covid_symptoms': {'significant_head_and_neck_covid_symptoms': 0,
#   'mild_head_and_neck_covid_symptoms': 1,
#   'no_head_and_neck_covid_symptoms': 2},
#  'gastrointestinal_covid_symptoms': {'significant_gastrointestinal_covid_symptoms': 0,
#   'mild_gastrointestinal_covid_symptoms': 1,
#   'no_gastrointestinal_covid_symptoms': 2},
#  'covid_symptoms': {'significant_covid_symptoms': 0,
#   'no_significant_covid_symptoms': 1},
#  'personal_social_distancing': {'no_personal_social_distancing': 0,
#   'some_personal_social_distancing': 1,
#   'safe_personal_social_distancing': 2},
#  'social_distancing_connectedness': {'no_social_distancing_connectedness': 0,
#   'some_social_distancing_connectedness': 1,
#   'safe_social_distancing_connectedness': 2},
#  'social_distancing_environment': {'no_social_distancing_environnment': 0,
#   'some_social_distancing_environment': 1,
#   'safe_social_distancing_environment': 2},
#  'social_distancing': {'no_social_distancing': 0,
#   'low_social_distancing': 1,
#   'medium_social_distancing': 2,
#   'high_social_distancing': 3},
#  'social_distancing_binary': {'no_social_distancing': 0,
#   'social_distancing': 1},
#  'wearables': {'anomalous': 0, 'normal': 1},
#  'possible_dehydration': {'possible_dehydration': 0, 'no_dehydration': 1},
#  'possible_meningitis': {'possible_meningitis': 0, 'no_meningitis': 1},
#  'serious_shortness_of_breath': {'serious_shortness_of_breath': 0,
#   'no_serious_shortness_of_breath': 1},
#  'covid_vulnerabilities': {'severe_covid_vulnerabilities': 0,
#   'moderate_covid_vulnerabilites': 1,
#   'some_covid_vulnerabilites': 2,
#   'insignificant_covid_vulnerabilities': 3},
#  'low_covid': {'low_covid': 0, 'other_covid': 1},
#  'medium_covid': {'medium_covid': 0, 'other_covid': 1},
#  'high_covid': {'high_covid': 0, 'other_covid': 1},
#  'exposure': {'exposure': 0, 'no_exposure': 1},
#  'covid_environment': {'high_risk_covid_environment': 0,
#   'medium_risk_covid_environment': 1,
#   'low_risk_covid_environment': 2,
#   'no_risk_covid_environment': 3},
#  'covid_symptom_level': {'high_covid': 0,
#   'medium_covid': 1,
#   'low_covid': 2,
#   'no_covid': 3},
#  'high_covid_risk': {'high_covid_risk': 0, 'other_covid_risk': 1},
#  'medium_covid_risk': {'medium_covid_risk': 0, 'other_covid_risk': 1},
#  'low_covid_risk': {'low_covid_risk': 0, 'other_covid_risk': 1},
#  'emergency_treatment': {'emergency_treatment': 0,
#   'no_emergency_treatment': 1},
#  'covid_risk': {'high_covid_risk': 0,
#   'medium_covid_risk': 1,
#   'low_covid_risk': 2,
#   'no_covid_risk': 3},
#  'covid_risk_binary': {'covid_risk': 0, 'no_covid_risk': 1},
#  'covid_severity': {'high_covid_severity': 0,
#   'medium_covid_severity': 1,
#   'low_covid_severity': 2,
#   'no_covid_severity': 3},
#  'covid_severity_binary': {'covid_severity': 0, 'no_covid_severity': 1}}

# %% [markdown]
# We create a spreadsheet of the above for reference

# %%
import pandas as pd

rows_list = []
outname = "varvals.csv"
for var, valdict in var_val_positions.items():
    rowdict = {} 
    rows_list.append(rowdict)
    varstr= var +"("
    for val, pos in valdict.items():
        varstr += val
        varstr+= ","
            
    varstr=varstr[:-1]+")"
    rowdict["variable"] = varstr        

df = pd.DataFrame(rows_list)      
df.to_csv(outname, index = False)

# %% [markdown]
# Here we create a spreadsheet that makes a Cartesian product of desired outputs with the remainder of the variables. This can be used to, for example, fill in a treatment recommendation for variables that are returned as causing the output in the explanation module

# %%
import pandas as pd
#cols = ["leaves","internal","output"]
desired_output =['social_distancing',
                 'emergency_treatment',
                 'covid_risk',
                 'covid_severity']
rows_list = []
outname = "upshot.csv"

#put leaves in the first column, then internal vars along with the vars that feed them in the second.  
#and do a cartesian product with the outvars that are also internal vars (should be all of them)

for output in desired_output:
    for dist in bayesianNetwork.discreteDistributions:
        print(dist.name)
        rowdict = {} 
        rowdict["leaves"]= dist.name
        rowdict["internal"]=""
        rowdict["output"]= output
        rows_list.append(rowdict)
    for table in bayesianNetwork.conditionalProbabilityTables:
        print ("table: {}".format(table.name))
        rowdict = {}
        rowdict["leaves"]=""
        internal_str = table.name + " ("
        for var in table.randomVariables:
            print(var.name)
            internal_str += var.name
            internal_str+= ","
            
        internal_str=internal_str[:-1]+")"
        rowdict["internal"] = internal_str
        rowdict["output"]= output
        rows_list.append(rowdict)
df = pd.DataFrame(rows_list)      
df.to_csv(outname, index = False)
# Out:
# age
# sex
# height_in_feet
# weight_in_pounds
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# shortness_of_breath
# cough
# rash_or_skin_discoloration
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# feeling_well
# congestion
# fatigue
# muscle_aches_or_body_pain
# abdominal_pain
# own_thermometer
# breathing_problems_at_night
# cough_phlegm_color
# bmi
# known_exposure
# employment_risk
# social_distancing_following
# close_contact_unknown_exposure
# social_distancing_following
# self_quarantine_two_weeks
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# daily_contacts_social_distancing
# visits_per_week
# wash_hands_per_day
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: cold_symptoms
# cough_phlegm_color
# fatigue
# congestion
# feeling_well
# muscle_aches_or_body_pain
# breathing_problems_at_night
# table: specific_covid_symptoms
# rash_or_skin_discoloration
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# abdominal_pain
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# social_distancing_following
# close_contact_unknown_exposure
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# daily_contacts_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# cold_symptoms
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# covid_vulnerabilities
# table: exposure
# known_exposure
# employment_risk
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: high_covid_risk
# covid_symptom_level
# covid_test
# covid_environment
# table: medium_covid_risk
# covid_symptom_level
# covid_environment
# table: low_covid_risk
# covid_symptom_level
# covid_environment
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# table: covid_risk
# high_covid_risk
# medium_covid_risk
# low_covid_risk
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# age
# sex
# height_in_feet
# weight_in_pounds
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# shortness_of_breath
# cough
# rash_or_skin_discoloration
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# feeling_well
# congestion
# fatigue
# muscle_aches_or_body_pain
# abdominal_pain
# own_thermometer
# breathing_problems_at_night
# cough_phlegm_color
# bmi
# known_exposure
# employment_risk
# social_distancing_following
# close_contact_unknown_exposure
# social_distancing_following
# self_quarantine_two_weeks
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# daily_contacts_social_distancing
# visits_per_week
# wash_hands_per_day
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: cold_symptoms
# cough_phlegm_color
# fatigue
# congestion
# feeling_well
# muscle_aches_or_body_pain
# breathing_problems_at_night
# table: specific_covid_symptoms
# rash_or_skin_discoloration
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# abdominal_pain
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# social_distancing_following
# close_contact_unknown_exposure
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# daily_contacts_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# cold_symptoms
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# covid_vulnerabilities
# table: exposure
# known_exposure
# employment_risk
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: high_covid_risk
# covid_symptom_level
# covid_test
# covid_environment
# table: medium_covid_risk
# covid_symptom_level
# covid_environment
# table: low_covid_risk
# covid_symptom_level
# covid_environment
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# table: covid_risk
# high_covid_risk
# medium_covid_risk
# low_covid_risk
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# age
# sex
# height_in_feet
# weight_in_pounds
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# shortness_of_breath
# cough
# rash_or_skin_discoloration
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# feeling_well
# congestion
# fatigue
# muscle_aches_or_body_pain
# abdominal_pain
# own_thermometer
# breathing_problems_at_night
# cough_phlegm_color
# bmi
# known_exposure
# employment_risk
# social_distancing_following
# close_contact_unknown_exposure
# social_distancing_following
# self_quarantine_two_weeks
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# daily_contacts_social_distancing
# visits_per_week
# wash_hands_per_day
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: cold_symptoms
# cough_phlegm_color
# fatigue
# congestion
# feeling_well
# muscle_aches_or_body_pain
# breathing_problems_at_night
# table: specific_covid_symptoms
# rash_or_skin_discoloration
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# abdominal_pain
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# social_distancing_following
# close_contact_unknown_exposure
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# daily_contacts_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# cold_symptoms
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# covid_vulnerabilities
# table: exposure
# known_exposure
# employment_risk
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: high_covid_risk
# covid_symptom_level
# covid_test
# covid_environment
# table: medium_covid_risk
# covid_symptom_level
# covid_environment
# table: low_covid_risk
# covid_symptom_level
# covid_environment
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# table: covid_risk
# high_covid_risk
# medium_covid_risk
# low_covid_risk
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# age
# sex
# height_in_feet
# weight_in_pounds
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# shortness_of_breath
# cough
# rash_or_skin_discoloration
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# feeling_well
# congestion
# fatigue
# muscle_aches_or_body_pain
# abdominal_pain
# own_thermometer
# breathing_problems_at_night
# cough_phlegm_color
# bmi
# known_exposure
# employment_risk
# social_distancing_following
# close_contact_unknown_exposure
# social_distancing_following
# self_quarantine_two_weeks
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# daily_contacts_social_distancing
# visits_per_week
# wash_hands_per_day
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: cold_symptoms
# cough_phlegm_color
# fatigue
# congestion
# feeling_well
# muscle_aches_or_body_pain
# breathing_problems_at_night
# table: specific_covid_symptoms
# rash_or_skin_discoloration
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# abdominal_pain
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# social_distancing_following
# close_contact_unknown_exposure
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# daily_contacts_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# cold_symptoms
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# covid_vulnerabilities
# table: exposure
# known_exposure
# employment_risk
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: high_covid_risk
# covid_symptom_level
# covid_test
# covid_environment
# table: medium_covid_risk
# covid_symptom_level
# covid_environment
# table: low_covid_risk
# covid_symptom_level
# covid_environment
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# table: covid_risk
# high_covid_risk
# medium_covid_risk
# low_covid_risk
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities

# %% [markdown]
# Here is a one more csv that uses a utility function to express the net in  a tree form, in a data frame and then prints it out

# %%
import sn_bayes
from sn_bayes.utils import make_tree
import pandas as pd
df = make_tree(bayesianNetwork)
outname = "tree.csv"
df.to_csv(outname, index = False)

# %%
df
# Out:
#                                level0  \
# 0                                age)
# 1                                sex)
# 2                     height_in_feet)
# 3                   weight_in_pounds)
# 4             cardiovascular_disease)
# 5                           diabetes)
# 6                       hypertension)
# 7                       lung_disease)
# 8                     kidney_disease)
# 9                             cancer)
# 10                 immunocompromised)
# 11           psychological_disorders)
# 12                  body_temperature)
# 13               shortness_of_breath)
# 14                             cough)
# 15        rash_or_skin_discoloration)
# 16                   muscle_weakness)
# 17                 difficulty_moving)
# 18                    neck_stiffness)
# 19                         low_urine)
# 20                 frequent_diarrhea)
# 21                            nausea)
# 22                          vomiting)
# 23          decreased_smell_or_taste)
# 24                       sore_throat)
# 25                          pink_eye)
# 26                          headache)
# 27                      feeling_well)
# 28                        congestion)
# 29                           fatigue)
# 30         muscle_aches_or_body_pain)
# 31                    abdominal_pain)
# 32                   own_thermometer)
# 33       breathing_problems_at_night)
# 34                cough_phlegm_color)
# 35                               bmi)
# 36                    known_exposure)
# 37                   employment_risk)
# 38       social_distancing_following)
# 39    close_contact_unknown_exposure)
# 40         self_quarantine_two_weeks)
# 41                   isolation_space)
# 42             leaving_house_per_day)
# 43          high_risk_place_per_week)
# 44               deliveries_per_week)
# 45                              mask)
# 46    public_transportation_per_week)
# 47       workplace_social_distancing)
# 48  daily_contacts_social_distancing)
# 49                   visits_per_week)
# 50                wash_hands_per_day)
# 51                            tested)
# 52                         swab_test)
# 53                     antibody_test)
# 54                       saliva_test)
# 55                   hotspot_anomaly)
# 56                heart_rate_anomaly)
# 57    heart_rate_variability_anomaly)
# 58                    oxygen_anomaly)
#
#                                                level1  \
# 0     covid_test(swab_test,antibody_test,saliva_test)
# 1   metabolic_disease(cardiovascular_disease,diabe...
# 2   chronic_conditions(lung_disease,cancer,kidney_...
# 3                               demographics(age,bmi)
# 4   cold_symptoms(cough_phlegm_color,fatigue,conge...
# 5   specific_covid_symptoms(rash_or_skin_discolora...
# 6   head_and_neck_covid_symptoms(neck_stiffness,so...
# 7   gastrointestinal_covid_symptoms(low_urine,naus...
# 8   personal_social_distancing(isolation_space,del...
# 9   social_distancing_connectedness(visits_per_wee...
# 10  social_distancing_environment(workplace_social...
# 11  wearables(heart_rate_variability_anomaly,oxyge...
# 12  possible_dehydration(low_urine,vomiting,freque...
# 13  possible_meningitis(neck_stiffness,body_temper...
# 14           exposure(known_exposure,employment_risk)
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level2  \
# 0   comorbidities(chronic_conditions,metabolic_dis...
# 1   covid_symptoms(gastrointestinal_covid_symptoms...
# 2   social_distancing(social_distancing_environmen...
# 3   social_distancing_binary(social_distancing_env...
# 4         covid_environment(exposure,hotspot_anomaly)
# 5   emergency_treatment(possible_dehydration,possi...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level3  \
# 0   serious_shortness_of_breath(shortness_of_breat...
# 1   covid_vulnerabilities(covid_symptoms,social_di...
# 2                   covid_severity(age,comorbidities)
# 3            covid_severity_binary(age,comorbidities)
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level4  \
# 0   low_covid(shortness_of_breath,body_temperature...
# 1   medium_covid(serious_shortness_of_breath,body_...
# 2   high_covid(cough,muscle_weakness,covid_vulnera...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level5  \
# 0   covid_symptom_level(high_covid,medium_covid,lo...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level6  \
# 0   high_covid_risk(covid_symptom_level,covid_test...
# 1   medium_covid_risk(covid_symptom_level,covid_en...
# 2   low_covid_risk(covid_symptom_level,covid_envir...
# 3   covid_risk_binary(covid_symptom_level,covid_en...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
#
#                                                level7
# 0   covid_risk(high_covid_risk,medium_covid_risk,l...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None

# %% [markdown]
# Here is the description of the Bayesian network in protobuf that we just created with the running of the python file.  Only the "leaves" have initial probabilities (DiscreteDistribution), the conditional probabilities (ConditionalProbabilityTable) are to be computed:

# %%
bayesianNetwork
# Out:
# discreteDistributions {
#   name: "age"
#   variables {
#     name: "elderly"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "adult"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "young_adult"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "teen"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "child"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "sex"
#   variables {
#     name: "male"
#     probability: 0.5
#   }
#   variables {
#     name: "female"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "height_in_feet"
#   variables {
#     name: "height_above_seven"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "height_six_to_seven"
#     probability: 0.25
#   }
#   variables {
#     name: "height_five_to_six"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "height_four_to_five"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "height_under_four"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "weight_in_pounds"
#   variables {
#     name: "weight_over_250"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_175_to_220"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_125_to_175"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "weight_100_to_125"
#     probability: 0.25
#   }
#   variables {
#     name: "weight_under_100"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "cardiovascular_disease"
#   variables {
#     name: "cardiovascular_disease"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "no_cardiovascular_disease"
#     probability: 0.9100000262260437
#   }
# }
# discreteDistributions {
#   name: "diabetes"
#   variables {
#     name: "diabetes"
#     probability: 0.11999999731779099
#   }
#   variables {
#     name: "no_diabetes"
#     probability: 0.8799999952316284
#   }
# }
# discreteDistributions {
#   name: "hypertension"
#   variables {
#     name: "hypertension"
#     probability: 0.17000000178813934
#   }
#   variables {
#     name: "no_hypertension"
#     probability: 0.8299999833106995
#   }
# }
# discreteDistributions {
#   name: "lung_disease"
#   variables {
#     name: "lung_disease"
#     probability: 0.10999999940395355
#   }
#   variables {
#     name: "no_lung_disease"
#     probability: 0.8899999856948853
#   }
# }
# discreteDistributions {
#   name: "kidney_disease"
#   variables {
#     name: "kidney_disease"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_kidney_disase"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "cancer"
#   variables {
#     name: "cancer"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_cancer"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "immunocompromised"
#   variables {
#     name: "immunocompromised"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "not_immunocompromised"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "psychological_disorders"
#   variables {
#     name: "psychological_disorders"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_psychological_disorders"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "body_temperature"
#   variables {
#     name: "body_temperature_above_102F"
#     probability: 0.014999999664723873
#   }
#   variables {
#     name: "body_temperature_above_100F"
#     probability: 0.03500000014901161
#   }
#   variables {
#     name: "normal_body_temperature"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "shortness_of_breath"
#   variables {
#     name: "new_or_worse_painful_shortness_of_breath"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath_after_activity"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_shortness_of_breath"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "cough"
#   variables {
#     name: "cough_up_blood"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "dry_cough"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "cough_with_spitum"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_cough"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "rash_or_skin_discoloration"
#   variables {
#     name: "rash_or_skin_discoloration"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_rash_or_skin_discoloration"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "muscle_weakness"
#   variables {
#     name: "new_or_worse_or_severe_muscle_weakness"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "moderate_muscle_weakness"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "no_muscle_weakness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "difficulty_moving"
#   variables {
#     name: "new_or_worse_or_severe_difficulty_moving"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_difficulty_moving"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_difficulty_moving"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "neck_stiffness"
#   variables {
#     name: "new_or_worse_or_severe_neck_stiffness"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_neck_stiffness"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_neck_stiffness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "low_urine"
#   variables {
#     name: "new_or_worse_or_severe_low_urine"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_low_urine"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "normal_urine"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "frequent_diarrhea"
#   variables {
#     name: "new_or_worse_or_severe_frequent_diarrhea"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_frequent_diarrhea"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "not_frequent_diarrhea"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "nausea"
#   variables {
#     name: "new_or_worse_or_severe_nausea"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_nausea"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "no_nausea"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "vomiting"
#   variables {
#     name: "new_or_worse_or_severe_vomiting"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_vomiting"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_vomiting"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "decreased_smell_or_taste"
#   variables {
#     name: "new_or_worse_or_severe_decreased_smell_or_taste"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "moderate_decreased_smell_or_taste"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_decreased_smell_or_taste"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "sore_throat"
#   variables {
#     name: "new_or_worse_or_severe_sore_throat"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "moderate_sore_throat"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_sore_throat"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "pink_eye"
#   variables {
#     name: "new_or_worse_or_severe_pink_eye"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "moderate_pink_eye"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "no_pink_eye"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "headache"
#   variables {
#     name: "new_or_worse_or_severe_headache"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "moderate_headache"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_headache"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "feeling_well"
#   variables {
#     name: "not_feeling_well"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "feeling_well"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "congestion"
#   variables {
#     name: "congestion"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_congestion"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "fatigue"
#   variables {
#     name: "fatigue"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_fatigue"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "muscle_aches_or_body_pain"
#   variables {
#     name: "muscle_aches_or_body_pain"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_muscle_aches_or_body_pain"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "abdominal_pain"
#   variables {
#     name: "abdominal_pain"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_abdominal_pain"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "own_thermometer"
#   variables {
#     name: "dont_own_thermometer"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "own_thermometer"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "breathing_problems_at_night"
#   variables {
#     name: "breathing_problems_at_night"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "breathing_problems_at_night_relieved_with_pillows"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_breathing_problems_at_night"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "cough_phlegm_color"
#   variables {
#     name: "rust_colored_cough_phlegm"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "yellow_green_colored_phlegm"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "thin_clear_colored_phlegm"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "bmi"
#   variables {
#     name: "morbidly_obese"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "obese"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "overweight"
#     probability: 0.25
#   }
#   variables {
#     name: "normal"
#     probability: 0.5
#   }
#   variables {
#     name: "underweight"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "known_exposure"
#   variables {
#     name: "known_exposure"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_known_exposure"
#     probability: 0.019999999552965164
#   }
# }
# discreteDistributions {
#   name: "employment_risk"
#   variables {
#     name: "health_care_worker_or_first_responder"
#     probability: 0.5
#   }
#   variables {
#     name: "high_volume_employment"
#     probability: 0.5
#   }
#   variables {
#     name: "low_employment_risk"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "social_distancing_following"
#   variables {
#     name: "no_social_distancing_following"
#     probability: 0.5
#   }
#   variables {
#     name: "social_distance_following"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "close_contact_unknown_exposure"
#   variables {
#     name: "close_contact_unknown_exposure"
#     probability: 0.5
#   }
#   variables {
#     name: "no_close_contact_unknown_exposure"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "social_distancing_following"
#   variables {
#     name: "no_social_distancing_following"
#     probability: 0.5
#   }
#   variables {
#     name: "social_distancing_following"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "self_quarantine_two_weeks"
#   variables {
#     name: "no_self_quarantine_two_weeks"
#     probability: 0.5
#   }
#   variables {
#     name: "self_quarantine_two_weeks"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "isolation_space"
#   variables {
#     name: "no_isolation_space"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "have_isolation_space"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "leaving_house_per_day"
#   variables {
#     name: "leave_house_more_than_twice_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "leave_house_once_or_twice_per_day"
#     probability: 0.699999988079071
#   }
#   variables {
#     name: "leave_house_zero_per_day"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "high_risk_place_per_week"
#   variables {
#     name: "high_risk_place_no_sanitizer_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "high_risk_place_no_sanitizer_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "high_risk_place_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "deliveries_per_week"
#   variables {
#     name: "deliveries_no_sanitation_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "deliveries_no_sanitation_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "deliveries_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "mask"
#   variables {
#     name: "no_mask"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "surgical_mask_or_untrained_n95"
#     probability: 0.5
#   }
#   variables {
#     name: "n95_mask"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "public_transportation_per_week"
#   variables {
#     name: "public_transportation_over_three_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "public_transportation_one_to_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "public_transportation_zero_per_week"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "workplace_social_distancing"
#   variables {
#     name: "no_workplace_social_distancing"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "workplace_social_distancing"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "daily_contacts_social_distancing"
#   variables {
#     name: "no_daily_contacts_social_distancing"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "daily_contacts_social_distancing"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "visits_per_week"
#   variables {
#     name: "visits_more_than_twice_per_week"
#     probability: 0.25
#   }
#   variables {
#     name: "visits_once_or_twice_per_week"
#     probability: 0.5
#   }
#   variables {
#     name: "visits_zero_per_week"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "wash_hands_per_day"
#   variables {
#     name: "wash_hands_zero_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "wash_hands_once_or_twice_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_three_to_five_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_over_five_per_day"
#     probability: 0.20000000298023224
#   }
# }
# discreteDistributions {
#   name: "tested"
#   variables {
#     name: "tested"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "not_tested"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "swab_test"
#   variables {
#     name: "swab_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "swab_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "antibody_test"
#   variables {
#     name: "antibody_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "antibody_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "saliva_test"
#   variables {
#     name: "saliva_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "saliva_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "hotspot_anomaly"
#   variables {
#     name: "hotspot_anomaly"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "no_hotspot_anomaly"
#     probability: 0.8500000238418579
#   }
# }
# discreteDistributions {
#   name: "heart_rate_anomaly"
#   variables {
#     name: "heart_rate_anomaly"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_heart_rate_anomaly"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "heart_rate_variability_anomaly"
#   variables {
#     name: "heart_rate_variability_anomaly"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_heart_rate_variability_anomaly"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "oxygen_anomaly"
#   variables {
#     name: "oxygen_anomaly"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_oxygen_anomaly"
#     probability: 0.949999988079071
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_test"
#   randomVariables {
#     name: "swab_test"
#   }
#   randomVariables {
#     name: "antibody_test"
#   }
#   randomVariables {
#     name: "saliva_test"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "positive_covid_test"
#   }
#   outvars {
#     name: "negative_covid_test"
#   }
# }
# conditionalProbabilityTables {
#   name: "metabolic_disease"
#   randomVariables {
#     name: "cardiovascular_disease"
#   }
#   randomVariables {
#     name: "diabetes"
#   }
#   randomVariables {
#     name: "hypertension"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "metabolic_disease"
#   }
#   outvars {
#     name: "no_metabolic_disease"
#   }
# }
# conditionalProbabilityTables {
#   name: "chronic_conditions"
#   randomVariables {
#     name: "lung_disease"
#   }
#   randomVariables {
#     name: "cancer"
#   }
#   randomVariables {
#     name: "kidney_disease"
#   }
#   randomVariables {
#     name: "immunocompromised"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "chronic_conditions"
#   }
#   outvars {
#     name: "no_chronic_conditions"
#   }
# }
# conditionalProbabilityTables {
#   name: "demographics"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "bmi"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
# ...
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "covid_risk"
#   }
#   outvars {
#     name: "no_covid_risk"
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_severity"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "comorbidities"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "high_covid_severity"
#   }
#   outvars {
#     name: "medium_covid_severity"
#   }
#   outvars {
#     name: "low_covid_severity"
#   }
#   outvars {
#     name: "no_covid_severity"
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_severity_binary"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "comorbidities"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "covid_severity"
#   }
#   outvars {
#     name: "no_covid_severity"
#   }
# }
# anomalies {
#   varName: "oxygen_anomaly"
#   high: 200.0
#   low: 93.0
#   high_percent: 0.9900000095367432
#   low_percent: 0.009999999776482582
# }
# anomalies {
#   varName: "heart_rate_anomaly"
# }
# anomalies {
#   varName: "hotspot_anomaly"
#   high: 7.000000186963007e-05
#   low: -1.0
# }
# anomalies {
#   varName: "heart_rate_variability_anomaly"
# }

# %% [markdown]
# Here is the Pomegranate net we just made with the description.  Here we compile the net so we can compute probabilities with it.

# %%
from sn_bayes.utils import bayesInitialize
covid = bayesInitialize(bayesianNetwork)

# %%
covid.bake()

# %% [markdown]
# We we call a Pomegranate routine that shows the computed probabilities of every variable.  We have made our own utility that pulls out particular variables.

# %%
covid.predict_proba({})
# Out:
# array([{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "elderly" :0.12499999883584714,
#             "adult" :0.3750000058207651,
#             "young_adult" :0.24999999767169337,
#             "teen" :0.12499999883584714,
#             "child" :0.12499999883584714
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "male" :0.5,
#             "female" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "height_above_seven" :0.04999999981373565,
#             "height_six_to_seven" :0.24999999534338715,
#             "height_five_to_six" :0.3000000063329933,
#             "height_four_to_five" :0.15000000316649675,
#             "height_under_four" :0.24999999534338715
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "weight_over_250" :0.15000000372529032,
#             "weight_175_to_220" :0.15000000372529032,
#             "weight_125_to_175" :0.2,
#             "weight_100_to_125" :0.2499999962747097,
#             "weight_under_100" :0.2499999962747097
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cardiovascular_disease" :0.09000000089407001,
#             "no_cardiovascular_disease" :0.9099999991059301
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "diabetes" :0.11999999821186098,
#             "no_diabetes" :0.8800000017881391
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hypertension" :0.1700000043213371,
#             "no_hypertension" :0.8299999956786629
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "lung_disease" :0.11000000104308164,
#             "no_lung_disease" :0.8899999989569183
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "kidney_disease" :0.30000001192092907,
#             "no_kidney_disase" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cancer" :0.30000001192092907,
#             "no_cancer" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "immunocompromised" :0.30000001192092907,
#             "not_immunocompromised" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "psychological_disorders" :0.300000011920929,
#             "no_psychological_disorders" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "body_temperature_above_102F" :0.01499999984633262,
#             "body_temperature_above_100F" :0.035000000572764194,
#             "normal_body_temperature" :0.9499999995809032
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_painful_shortness_of_breath" :0.010000000018627091,
#             "new_or_worse_shortness_of_breath" :0.04000000007450637,
#             "new_or_worse_shortness_of_breath_after_activity" :0.05000000195577797,
#             "no_shortness_of_breath" :0.8999999979510885
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cough_up_blood" :0.010000000018626876,
#             "dry_cough" :0.04000000007450617,
#             "cough_with_spitum" :0.050000001955777806,
#             "no_cough" :0.8999999979510891
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "rash_or_skin_discoloration" :0.01999999918043658,
#             "no_rash_or_skin_discoloration" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_muscle_weakness" :0.009999999981374194,
#             "moderate_muscle_weakness" :0.090000005420298,
#             "no_muscle_weakness" :0.8999999945983279
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_difficulty_moving" :0.05000000186264538,
#             "moderate_difficulty_moving" :0.05000000186264538,
#             "no_difficulty_moving" :0.8999999962747092
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_neck_stiffness" :0.05000000186264577,
#             "moderate_neck_stiffness" :0.05000000186264577,
#             "no_neck_stiffness" :0.8999999962747084
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_low_urine" :0.05000000186264577,
#             "moderate_low_urine" :0.05000000186264577,
#             "normal_urine" :0.8999999962747084
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_frequent_diarrhea" :0.050000001862645575,
#             "moderate_frequent_diarrhea" :0.050000001862645575,
#             "not_frequent_diarrhea" :0.899999996274709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_nausea" :0.049999999813735874,
#             "moderate_nausea" :0.15000000316649695,
#             "no_nausea" :0.7999999970197673
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_vomiting" :0.050000001862645756,
#             "moderate_vomiting" :0.050000001862645756,
#             "no_vomiting" :0.8999999962747084
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_decreased_smell_or_taste" :0.050000001862645575,
#             "moderate_decreased_smell_or_taste" :0.050000001862645575,
#             "no_decreased_smell_or_taste" :0.899999996274709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_sore_throat" :0.1000000000000003,
#             "moderate_sore_throat" :0.1000000000000003,
#             "no_sore_throat" :0.7999999999999994
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_pink_eye" :0.02500000065192622,
#             "moderate_pink_eye" :0.02500000065192622,
#             "no_pink_eye" :0.9499999986961476
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_or_severe_headache" :0.1000000000000003,
#             "moderate_headache" :0.1000000000000003,
#             "no_headache" :0.7999999999999995
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "not_feeling_well" :0.20000000000000026,
#             "feeling_well" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "congestion" :0.20000000000000026,
#             "no_congestion" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "fatigue" :0.10000000372529073,
#             "no_fatigue" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "muscle_aches_or_body_pain" :0.10000000372529073,
#             "no_muscle_aches_or_body_pain" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "abdominal_pain" :0.10000000372529073,
#             "no_abdominal_pain" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "dont_own_thermometer" :0.39999999403953573,
#             "own_thermometer" :0.6000000059604642
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "breathing_problems_at_night" :0.009999999590218505,
#             "breathing_problems_at_night_relieved_with_pillows" :0.009999999590218505,
#             "no_breathing_problems_at_night" :0.980000000819563
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "rust_colored_cough_phlegm" :0.00999999998137398,
#             "yellow_green_colored_phlegm" :0.09000000542029783,
#             "thin_clear_colored_phlegm" :0.8999999945983281
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "morbidly_obese" :0.05000000055879388,
#             "obese" :0.1000000011175873,
#             "overweight" :0.24999999906867731,
#             "normal" :0.4999999981373542,
#             "underweight" :0.1000000011175873
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "known_exposure" :0.3333333333333359,
#             "no_known_exposure" :0.6666666666666642
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "health_care_worker_or_first_responder" :0.3333333333333333,
#             "high_volume_employment" :0.3333333333333333,
#             "low_employment_risk" :0.3333333333333333
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing_following" :0.5,
#             "social_distance_following" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "close_contact_unknown_exposure" :0.5,
#             "no_close_contact_unknown_exposure" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing_following" :0.5,
#             "social_distancing_following" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_self_quarantine_two_weeks" :0.5,
#             "self_quarantine_two_weeks" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_isolation_space" :0.20000000000000026,
#             "have_isolation_space" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "leave_house_more_than_twice_per_day" :0.20000000447034857,
#             "leave_house_once_or_twice_per_day" :0.6999999932944768,
#             "leave_house_zero_per_day" :0.1000000022351745
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_place_no_sanitizer_over_three_per_week" :0.09999999850988416,
#             "high_risk_place_no_sanitizer_once_or_more_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_two_or_three_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_once_per_week" :0.19999999701976787,
#             "high_risk_place_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "deliveries_no_sanitation_over_three_per_week" :0.09999999850988414,
#             "deliveries_no_sanitation_once_or_more_per_week" :0.3000000029802319,
#             "deliveries_sanitation_two_or_three_per_week" :0.3000000029802319,
#             "deliveries_sanitation_once_per_week" :0.19999999701976784,
#             "deliveries_zero_per_week" :0.09999999850988414
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_mask" :0.40000000298023214,
#             "surgical_mask_or_untrained_n95" :0.4999999962747096,
#             "n95_mask" :0.10000000074505837
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "public_transportation_over_three_per_week" :0.2000000044703486,
#             "public_transportation_one_to_three_per_week" :0.10000000223517451,
#             "public_transportation_zero_per_week" :0.6999999932944769
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_workplace_social_distancing" :0.20000000000000026,
#             "workplace_social_distancing" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_daily_contacts_social_distancing" :0.3999999940395358,
#             "daily_contacts_social_distancing" :0.6000000059604641
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "visits_more_than_twice_per_week" :0.2500000000000001,
#             "visits_once_or_twice_per_week" :0.49999999999999983,
#             "visits_zero_per_week" :0.2500000000000001
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "wash_hands_zero_per_day" :0.19999999701976792,
#             "wash_hands_once_or_twice_per_day" :0.30000000298023205,
#             "wash_hands_three_to_five_per_day" :0.30000000298023205,
#             "wash_hands_over_five_per_day" :0.19999999701976792
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "tested" :0.019999999180436365,
#             "not_tested" :0.9800000008195636
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "swab_test_positive" :0.01999999918043658,
#             "swab_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "antibody_test_positive" :0.01999999918043658,
#             "antibody_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "saliva_test_positive" :0.01999999918043658,
#             "saliva_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hotspot_anomaly" :0.15000000149011636,
#             "no_hotspot_anomaly" :0.8499999985098835
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "heart_rate_anomaly" :0.05000000130385202,
#             "no_heart_rate_anomaly" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "heart_rate_variability_anomaly" :0.10000000372529073,
#             "no_heart_rate_variability_anomaly" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "oxygen_anomaly" :0.05000000130385202,
#             "no_oxygen_anomaly" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "positive_covid_test" :0.05880799763867366,
#             "negative_covid_test" :0.9411920023613263
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_metabolic_disease" :0.6646639972370261,
#             "metabolic_disease" :0.3353360027629739
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_chronic_conditions" :0.30526998404607186,
#             "chronic_conditions" :0.694730015953928
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_demographics" :0.3624999960185963,
#             "demographics" :0.6375000039814037
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "comorbidities" :0.9264480374685363,
#             "no_comorbidities" :0.07355196253146376
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_cold_symptoms" :0.20223752665669567,
#             "no_cold_symptoms" :0.7971955133141528,
#             "significant_cold_symptoms" :0.0005669600291514441
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_specific_covid_symptoms" :0.11700000291690328,
#             "significant_specific_covid_symptoms" :0.0009999999962751675,
#             "no_specific_covid_symptoms" :0.8819999970868216
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_head_and_neck_covid_symptoms" :0.044762500852952435,
#             "no_head_and_neck_covid_symptoms" :0.9514999989997583,
#             "significant_head_and_neck_covid_symptoms" :0.003737500147289155
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_gastrointestinal_covid_symptoms" :0.9233999958559855,
#             "mild_gastrointestinal_covid_symptoms" :0.0730000038333247,
#             "significant_gastrointestinal_covid_symptoms" :0.003600000310689713
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_significant_covid_symptoms" :0.9916832785928665,
#             "significant_covid_symptoms" :0.008316721407133368
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_personal_social_distancing" :0.031049999503419475,
#             "no_personal_social_distancing" :0.10434999996610039,
#             "some_personal_social_distancing" :0.8646000005304801
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_social_distancing_connectedness" :0.6467499980777494,
#             "safe_social_distancing_connectedness" :0.14049999861791784,
#             "no_social_distancing_connectedness" :0.21275000330433289
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_social_distancing_environment" :0.0,
#             "no_social_distancing_environnment" :0.07999999880790774,
#             "some_social_distancing_environment" :0.920000001192092
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing" :0.0034774019630282346,
#             "high_social_distancing" :0.0,
#             "low_social_distancing" :0.8619268178620686,
#             "medium_social_distancing" :0.13459578017490303
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing" :0.8654042198250971,
#             "social_distancing" :0.13459578017490298
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "anomalous" :0.18775000559166152,
#             "normal" :0.8122499944083386
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_dehydration" :1.0,
#             "possible_dehydration" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_meningitis" :1.0,
#             "possible_meningitis" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "serious_shortness_of_breath" :0.04632240195971022,
#             "no_serious_shortness_of_breath" :0.9536775980402897
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "some_covid_vulnerabilites" :0.8314641585159595,
#             "moderate_covid_vulnerabilites" :0.1676493019710342,
#             "severe_covid_vulnerabilities" :0.0008865395130061384,
#             "insignificant_covid_vulnerabilities" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid" :0.8382973231500477,
#             "other_covid" :0.16170267684995218
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_covid" :0.21811269867094824,
#             "other_covid" :0.7818873013290518
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_covid" :0.010000000018627105,
#             "other_covid" :0.9899999999813729
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "exposure" :0.7777777777777783,
#             "no_exposure" :0.22222222222222174
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_risk_covid_environment" :0.18888888855775182,
#             "high_risk_covid_environment" :0.11666666782564668,
#             "no_risk_covid_environment" :0.0,
#             "medium_risk_covid_environment" :0.6944444436166013
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_covid" :0.21593157168017593,
#             "low_covid" :0.6488994913798567,
#             "no_covid" :0.12516893692133926,
#             "high_covid" :0.01000000001862795
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_covid_risk" :0.17692759503042157,
#             "other_covid_risk" :0.8230724049695785
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid_risk" :0.23957646485792075,
#             "medium_covid_risk" :0.7604235351420792
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid_risk" :0.7152184762251772,
#             "other_covid_risk" :0.2847815237748227
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "emergency_treatment" :0.0,
#             "no_emergency_treatment" :1.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_covid_risk" :0.1769275950304215,
#             "low_covid_risk" :0.14103305668954302,
#             "medium_covid_risk" :0.6258836278648597,
#             "no_covid_risk" :0.05615572041517576
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_risk" :0.1462129250894589,
#             "covid_risk" :0.8537870749105411
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid_severity" :0.027581985692421786,
#             "no_covid_severity" :0.009193995230807427,
#             "medium_covid_severity" :0.4999999960283934,
#             "high_covid_severity" :0.4632240230483774
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_severity" :0.03677598092322899,
#             "covid_severity" :0.963224019076771
#         }
#     ],
#     "frozen" :false
# }], dtype=object)

# %% [markdown]
# Here we use our query util to enter patient states as evidence (evidence), and then see the probabilities of particular variables we are interested in (outvars), in this case, the output variables.  It needs the compiled Pomegranate Bayesian network as well as the description of the network.  This routine can be used to enter a particular patients state , one question at a time, to get a continual change in probability of all states. Below, we first look at the probability of emergency treatment, covid risk, and covid severity, in general.  Then, we look at it given the information that the patient is elderly. We see that the chance of severity has increased. Adding more risk factors increases risk more, and adding more severity factors increases severity more.

# %%
import sn_bayes
from sn_bayes.utils import query
evidence = {}
outvars= ["social_distancing_binary",
          "covid_risk_binary",
          "covid_severity_binary"]
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.1769275950304215,
#   'low_covid_risk': 0.14103305668954302,
#   'medium_covid_risk': 0.6258836278648597,
#   'no_covid_risk': 0.05615572041517576},
#  'covid_severity_binary': {'low_covid_severity': 0.027581985692421786,
#   'no_covid_severity': 0.009193995230807427,
#   'medium_covid_severity': 0.4999999960283934,
#   'high_covid_severity': 0.4632240230483774}}

# %%
evidence["age"]= "elderly"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.17692759503042152,
#   'low_covid_risk': 0.1400974375079144,
#   'medium_covid_risk': 0.6266343345278542,
#   'no_covid_risk': 0.056340632933809955},
#  'covid_severity_binary': {'low_covid_severity': 0.0,
#   'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'high_covid_severity': 1.0}}

# %%
evidence["body_temperature"]= "body_temperature_above_102F"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.17692759503042135,
#   'low_covid_risk': 0.0004750448770471586,
#   'medium_covid_risk': 0.8205574614984503,
#   'no_covid_risk': 0.0020398985940812547},
#  'covid_severity_binary': {'low_covid_severity': 0.0,
#   'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'high_covid_severity': 1.0}}

# %%
evidence["diabetes"]= "diabetes"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.17692759503042135,
#   'low_covid_risk': 0.0004750448770471586,
#   'medium_covid_risk': 0.8205574614984503,
#   'no_covid_risk': 0.0020398985940812547},
#  'covid_severity_binary': {'low_covid_severity': 0.0,
#   'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'high_covid_severity': 1.0}}

# %% [markdown]
# The explain function will tell you which nodes, whether inner or leaf, when changed, change the output variable.  A variable is on the reverse explain list if we want to know what changes to other variables will increase it.  Otherwise we look to
# changes that decrease the variable to be explained.  One may select which explanations are relevant for their purposes, as this is just a measure of dependence.

# %%
from sn_bayes.utils import explain
explain_results =  explain(covid,bayesianNetwork,evidence,outvars,reverse_explain_list = ['social_distancing', 'social_distancing_binary'])
explain_results
# Out:
# {'social_distancing_binary': {},
#  'covid_risk_binary': {'body_temperature': 0.19687627100542404,
#   'covid_test': 0.32208523928321353,
#   'serious_shortness_of_breath': 0.12448970158658701,
#   'covid_vulnerabilities': 0.5001273377619395,
#   'low_covid': 0.3399122758936851,
#   'high_covid': 0.3399122758936851,
#   'exposure': 0.12696366273112947,
#   'covid_environment': 0.5705574614984503,
#   'covid_symptom_level': 0.5705574614984503,
#   'high_covid_risk': 0.5705574614984503,
#   'medium_covid_risk': 0.8205574614984503,
#   'low_covid_risk': 0.5705574614984503},
#  'covid_severity_binary': {'chronic_conditions': 0.5000000000000002}}

# %%
evidence["known_exposure"]= "known_exposure"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.20798693141630759,
#   'low_covid_risk': 0.0,
#   'medium_covid_risk': 0.7908250489668013,
#   'no_covid_risk': 0.0011880196168908706},
#  'covid_severity_binary': {'low_covid_severity': 0.0,
#   'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'high_covid_severity': 1.0}}

# %%
from sn_bayes.utils import explain
explain_results =  explain(covid,bayesianNetwork,evidence,outvars,reverse_explain_list = ['social_distancing', 'social_distancing_binary'])
explain_results
# Out:
# {'social_distancing_binary': {},
#  'covid_risk_binary': {'body_temperature': 0.09300124425850498,
#   'covid_test': 0.29157504897564923,
#   'serious_shortness_of_breath': 0.058806970925427526,
#   'covid_vulnerabilities': 0.4358191916455334,
#   'low_covid': 0.25831626298490074,
#   'high_covid': 0.25831626298490074,
#   'covid_environment': 0.5408250489668013,
#   'covid_symptom_level': 0.5408250489668013,
#   'high_covid_risk': 0.5408250489668013,
#   'medium_covid_risk': 0.7908250489668013},
#  'covid_severity_binary': {'chronic_conditions': 0.5000000000000002}}

# %%
evidence = {}
evidence["employment_risk"]= "health_care_worker_or_first_responder"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing_binary': {'no_social_distancing': 0.0034774019630282346,
#   'high_social_distancing': 0.0,
#   'low_social_distancing': 0.8619268178620686,
#   'medium_social_distancing': 0.13459578017490303},
#  'covid_risk_binary': {'high_covid_risk': 0.20798693141630745,
#   'low_covid_risk': 0.060444252554742964,
#   'medium_covid_risk': 0.6988642013743642,
#   'no_covid_risk': 0.03270461465458541},
#  'covid_severity_binary': {'low_covid_severity': 0.027581985692421786,
#   'no_covid_severity': 0.009193995230807427,
#   'medium_covid_severity': 0.4999999960283934,
#   'high_covid_severity': 0.4632240230483774}}

# %%
from sn_bayes.utils import explain
explain_results =  explain(covid,bayesianNetwork,evidence,outvars,reverse_explain_list = ['social_distancing', 'social_distancing_binary'])
explain_results
# Out:
# {'social_distancing_binary': {},
#  'covid_risk_binary': {'covid_test': 0.25766933408252807,
#   'covid_vulnerabilities': 0.34385834405309634,
#   'low_covid': 0.16635541539246368,
#   'medium_covid': 0.16635541539246368,
#   'covid_environment': 0.4488642013743642,
#   'covid_symptom_level': 0.4488642013743642,
#   'high_covid_risk': 0.4488642013743642,
#   'medium_covid_risk': 0.6988642013743642,
#   'low_covid_risk': 0.4488642013743642},
#  'covid_severity_binary': {'comorbidities': 0.2499999960283934}}

# %% [markdown]
# Now start the server from somewhere else than here.  Use the first command uncommented if you are running in a notebook , or the second command if you are running from command line.

# %%
#%run -i './sn_service/bayes_service.py' 
#python3 ./sn_service/bayes_service.py

# %% [markdown]
# Here is a test of the server.  It is saving an ID for the network sent to it, in a pickle file of json.  If you run the service again, it will start at another id.

# %%
# %run -i './test_bayes_service.py' auto
# Out:
# Exception
# <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1602594322.865440565","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":4089,"referenced_errors":[{"created":"@1602594322.865438482","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":393,"grpc_status":14}]}"
# >

# %% [markdown]
# Wearable values can be sent it, and if there is a seasonal anomaly it will be set in the bayesian network

# %% [markdown]
# Read in apple watch data.  Send in a proto of a value and an interval.   For synced data, make sure the interval of the first items all tell the distance from the same point.  An interval of zero (the default in proto) means that the same as the previous is repeated.  The following gives an example with synced data.

# %%
import os
import re
import fnmatch
import pandas as pd

id_re = re.compile(r'^(\d+)\_.+')

anomaly_tuples = {}

for root, dirs, files in os.walk("./data/sleep-accel/heart_rate"):
    for i, filename in enumerate(files):
        if i < 10:
            #print(filename)
            pid = id_re.match(filename)
            print (f'patient {pid[1]}')
            anomaly_tuples[pid[1]] = {}
            heart_rate_df = pd.read_csv(f'./data/sleep-accel/heart_rate/{filename}')
            anomaly_tuples[pid[1]]["heart_rate_anomaly"]=[]
            firstrow = None
            lastrow = None
            for index, row in heart_rate_df.iterrows():
                if firstrow is None:
                    firstrow= row[0]
                thisrow = row[0]-lastrow if lastrow is not None else row[0]-firstrow
                lastrow = row[0]
                anomaly_tuples[pid[1]]["heart_rate_anomaly"].append((row[1],thisrow))


            listOfFiles = os.listdir("./data/sleep-accel/steps/")
            pattern = (f"{pid[1]}*")
            for entry in listOfFiles:
                if fnmatch.fnmatch(entry,pattern):
                    #print(entry)
                    steps_df = pd.read_csv(f'./data/sleep-accel/steps/{entry}')
                    anomaly_tuples[pid[1]]["oxygen_anomaly"]=[] #fixme, use a steps_anomaly
                    lastrow = None
                    for index, row in steps_df.iterrows():

                        if firstrow < row[0]:
                            thisrow = row[0]-lastrow if lastrow is not None else row[0]-firstrow
                            lastrow = row[0]
                            if thisrow:
                                anomaly_tuples[pid[1]]["oxygen_anomaly"].append((row[1],thisrow))
threshold = {}
threshold['heart_rate_anomaly']={}
threshold['oxygen_anomaly']={}
threshold['heart_rate_anomaly']['high']= 100
threshold['heart_rate_anomaly']['low']=65
threshold['heart_rate_anomaly']['low_percent'] = 0.03
threshold['heart_rate_anomaly']['high_percent']= 0.97
threshold['oxygen_anomaly']['high']= 2000
threshold['oxygen_anomaly']['low']=-1
threshold['oxygen_anomaly']['low_percent'] = 0.03
threshold['oxygen_anomaly']['high_percent']= 0.97
# Out:
# patient 9106476
# patient 2638030
# patient 4426783
# patient 1449548
# patient 3997827
# patient 46343
# patient 1360686
# patient 759667
# patient 6220552
# patient 8000685

# %%
from sn_bayes.utils import detect_anomalies, detect_anomalies_threshold, detect_anomalies_threshold_and_baseline
from adtk.visualization import plot


for pid,at in anomaly_tuples.items():
    print(pid)
    wearable_evidence,anomaly_dict,signal_dict = detect_anomalies(at,bayesianNetwork)
    for var,anomalies_dict in anomaly_dict.items():
        for detector,anomalies in anomalies_dict.items():
            print (var)
            print(detector)
            plot(signal_dict[var], anomaly=anomalies, ts_markersize=1, anomaly_color='red', anomaly_tag="marker", anomaly_markersize=2);
    wearable_evidence,anomaly_dict,signal_dict = detect_anomalies_threshold(at,bayesianNetwork,threshold)
    for var,anomalies_dict in anomaly_dict.items():
        for detector,anomalies in anomalies_dict.items():
            print (var)
            print(detector)
            plot(signal_dict[var], anomaly=anomalies, ts_markersize=1, anomaly_color='red', anomaly_tag="marker", anomaly_markersize=2);
    wearable_evidence,anomaly_dict,signal_dict = detect_anomalies_threshold_and_baseline(at,bayesianNetwork,threshold)
    for var,anomalies_dict in anomaly_dict.items():
        for detector,anomalies in anomalies_dict.items():
            print (var)
            print(detector)
            plot(signal_dict[var], anomaly=anomalies, ts_markersize=1, anomaly_color='red', anomaly_tag="marker", anomaly_markersize=2);
   
    print(wearable_evidence)
    evidence.update(wearable_evidence)
    results = query(covid,bayesianNetwork,evidence,outvars)
    print (f'pid {pid} results {results}')
# Out:
# 9106476
# AutoregressionAD-oxygen_anomaly
# Series does not follow any known frequency (e.g. second, minute, hour, day, week, month, year, etc.
# heart_rate_anomaly
# autoregression
# heart_rate_anomaly
# interquartile
# oxygen_anomaly
# interquartile
# heart_rate_anomaly
# threshold
# oxygen_anomaly
# threshold
# heart_rate_anomaly
# quantile
# heart_rate_anomaly
# threshold
# oxygen_anomaly
# quantile
# oxygen_anomaly
# threshold
# {'heart_rate_anomaly': 'heart_rate_anomaly', 'oxygen_anomaly': 'no_oxygen_anomaly'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/opencog/covid-bayesnet/test_bayes_service.py in <module>
#      26     print(wearable_evidence)
#      27     evidence.update(wearable_evidence)
# ---> 28     results = query(covid,bayesianNetwork,evidence,outvars)
#      29     print (f'pid {pid} results {results}')
#
# TypeError: 'Query' object is not callable
