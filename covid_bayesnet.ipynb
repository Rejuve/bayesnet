# %% [markdown]
# ## Covid Bayes Net
#
#
# First we create a Pomegranate Bayesian Network using the protobuf interface and our utility package, bayes, that enables one to conveniently create a Bayesian network by hand without having to fill in every probability.  The same Baysian network can start with our hand entered guesses, but can later learn from data.  Any amount of questions can be answered, including no questions, to get the probabilities of having covid , the severity of illness, and the chances of going to the hospital.  The file the Bayesian net is written in is covid_bayes.py.  Our utility package can then be used to query the network with different patient states.  This is convenient for tuning hand entered parameters .

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -e ../covid-bayesnet
#!{sys.executable} -m pip install protobuf
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (20.2.2)
# Obtaining file:///home/opencog/covid-bayesnet
# Installing collected packages: covid-bayes
#   Running setup.py develop for covid-bayes
# Successfully installed covid-bayes

# %%
pwd
# Out:
# '/home/opencog/covid-bayesnet'

# %%
# !{sys.executable} -m pip install -r requirements.txt
# !sh buildproto.sh
# Out:
# Requirement already satisfied: grpcio>=1.14.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.30.0)
# Requirement already satisfied: grpcio-tools>=1.14.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.30.0)
# Requirement already satisfied: pomegranate>=0.13.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.13.4)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio>=1.14.2->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: protobuf>=3.5.0.post1 in /usr/local/lib/python3.6/dist-packages (from grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (5.1.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (2.4)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.18.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.6/dist-packages (from pomegranate>=0.13.4->-r requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from protobuf>=3.5.0.post1->grpcio-tools>=1.14.1->-r requirements.txt (line 2)) (39.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->pomegranate>=0.13.4->-r requirements.txt (line 3)) (4.4.2)

# %% [markdown]
# ### Covid net
# Here put the name of the network you have written with the protobuf and bayes utilities.  Our example is printed out.  We created 4 functions in our utility package: any, all, if_the_else, and avg, which can together be used to express almost any set of rules, documented elsewhere.  The last lines implement the creation of the description of the network,  bayesianNetwork , with the protobuf utilities, and then the creation of the Pomegranate network with the description.

# %%
text_file = open('./sn_bayes/covid_bayes.py')
file_content = text_file.read()
print(file_content)
text_file.close()
# Out:
# import sn_bayes
# from sn_bayes.utils import any
# from sn_bayes.utils import all
# from sn_bayes.utils import avg
# from sn_bayes.utils import if_then_else
# from sn_bayes.utils import bayesInitialize
# from sn_bayes.utils import addCpt
#
#
# import sn_service.service_spec.bayesian_pb2
# from sn_service.service_spec.bayesian_pb2 import BayesianNetwork
#
#
# def covid_bayes():
# 	bayesianNetwork = BayesianNetwork()
#
#
#
# 	#probabilities within distributions must sum to 1.0
# 	#questions left blank or "prefer not to answer" will be computed
#
#
#
# 	#basics/init
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "acute_medical_condition"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "acute_medical_condition"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_acute_medical_condition"
# 	variable.probability = 0.98
#
# 	# basics/demographics questions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "age"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "elderly"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "adult"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "young_adult"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "teen"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "child"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sex"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "male"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "female"
# 	variable.probability = 0.5
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "height_in_feet"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_above_seven"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_six_to_seven"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_five_to_six"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_four_to_five"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "height_under_four"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "weight_in_pounds"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_over_250"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_175_to_220"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_125_to_175"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_100_to_125"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "weight_under_100"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "ethnicity"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "african_american"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hispanic"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "ethnicity_other"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "african"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "middle_eastern"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "native_american"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "pacific_islander"
# 	variable.probability = 0.025
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "asian"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "caucasian"
# 	variable.probability = 0.35
#
#
# #cardiovascular_disease 9%
# #https://www.sciencedaily.com/releases/2019/01/190131084238.htm
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cardiovascular_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cardiovascular_disease"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cardiovascular_disease"
# 	variable.probability = 0.91
#
#
# #diabetes 12%
# #https://www.healio.com/news/endocrinology/20200730/prevalence-of-diabetes-hypertension-among-covid19-patients-likely-lower-than-reported
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "diabetes"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "diabetes"
# 	variable.probability = 0.12
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_diabetes"
# 	variable.probability = 0.88
#
# #hypertension 17%
# #https://www.healio.com/news/endocrinology/20200730/prevalence-of-diabetes-hypertension-among-covid19-patients-likely-lower-than-reported
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hypertension"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hypertension"
# 	variable.probability = 0.17
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hypertension"
# 	variable.probability = 0.83
#
# #37M/328M = 11%
# #https://www.lung.org/about-us/mission-impact-and-history/our-impact
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "lung_disease"
# 	variable.probability = 0.11
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_lung_disease"
# 	variable.probability = 0.89
#
# #kidney disease = 14%
# #https://www.niddk.nih.gov/health-information/health-statistics/kidney-disease#:~:text=The%20overall%20prevalence%20of%20CKD,661%2C000%20Americans%20have%20kidney%20failure.
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "kidney_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "kidney_disease"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_kidney_disase"
# 	variable.probability = 0.7
#
# #cancer = 5.5%
# #https://ourworldindata.org/cancer#:~:text=Prevalence%20of%20cancer%20ranges%20from,countries%20shown%20in%20light%20yellow.
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cancer"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cancer"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cancer"
# 	variable.probability = 0.7
#
# #immunocompromised=2.7%
# #https://www.healio.com/news/infectious-disease/20161101/nearly-3-of-us-adult-population-immunosuppressed#:~:text=Among%20them%2C%202.8%25%20(n,CI%2C%202.9%2D3.3).
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "immunocompromised"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "immunocompromised"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_immunocompromised"
# 	variable.probability = 0.7
#
# #psychiatric disorders 17.6%
# #https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3997379/#:~:text=Period%20prevalence%20of%20common%20mental,CI%2C%2025.9%E2%80%9332.6%25).
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "psychological_disorders"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "psychological_disorders"
# 	variable.probability = 0.3
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_psychological_disorders"
# 	variable.probability = 0.7
#
#
# 	# covid symptoms questions in discrete distributions
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "body_temperature"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_102F"
# 	variable.probability = 0.015
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "body_temperature_above_99F"
# 	variable.probability = 0.035
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_body_temperature"
# 	variable.probability = 0.95
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "low_oxygen_symptoms"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_low_oxygen_symptoms"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_low_oxygen_symptoms"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "shortness_of_breath"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_painful_shortness_of_breath"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_shortness_of_breath_after_activity"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_shortness_of_breath"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "cough"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_up_blood"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "dry_cough"
# 	variable.probability = 0.04
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "cough_with_spitum"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_cough"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "colored_spots_on_toes"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "colored_spots_on_toes"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_colored_spots_on_toes"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hx_lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hx_lung_disease"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hx_lung_disease"
# 	variable.probability = 0.90
#
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hx_family_lung_disease"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hx_family_lung_disease"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hx_family_lung_disease"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "muscle_weakness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "muscle_weakness_cant_move"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "new_or_worse_muscle_weakness"
# 	variable.probability = 0.09
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_muscle_weakness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "difficulty_moving"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "difficulty_moving"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_difficulty_moving"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "neck_stiffness"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "neck_stiffness"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_neck_stiffness"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "low_urine"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "low_urine"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal_urine"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "frequent_diarrhea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "frequent_diarrhea"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_frequent_diarrhea"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "nausea"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "nausea"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_nausea"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "vomiting"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "vomiting"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_vomiting"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "decreased_smell_or_taste"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "decreased_smell_or_taste"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_decreased_smell_or_taste"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "sore_throat"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "sore_throat"
# 	variable.probability = 0.2
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_sore_throat"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "pink_eye"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "pink_eye"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_pink_eye"
# 	variable.probability = 0.99
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "headache"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "headache"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_headache"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "bmi"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "morbidly_obese"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "obese"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "overweight"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "normal"
# 	variable.probability = 0.5
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "underweight"
# 	variable.probability = 0.1
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "exposure"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_in_family_not_isolated"
# 	variable.probability = 0.01
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_in_family"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_healthcare_worker"
# 	variable.probability = 0.03
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "known_exposure"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "exposure_high_risk_worker"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_exposure"
# 	variable.probability = 0.90
#
#
# 	# covid/social distance rules
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "isolation_space"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_isolation_space"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "have_isolation_space"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "leaving_house_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_more_than_twice_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_once_or_twice_per_day"
# 	variable.probability = 0.70
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "leave_house_zero_per_day"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "high_risk_place_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_no_sanitizer_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_sanitizer_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "high_risk_place_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "deliveries_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_no_sanitation_over_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveris_no_sanitation_once_or_more_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_two_or_three_per_week"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_sanitation_once_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "deliveries_zero_per_week"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "mask"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_mask"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "surgical_mask"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "n95_mask"
# 	variable.probability = 0.10
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "public_transportation_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_over_three_per_week"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_one_to_three_per_week"
# 	variable.probability = 0.10
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "public_transportation_zero_per_week"
# 	variable.probability = 0.70
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "workplace_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_workplace_social_distancing"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "workplace_social_distancing"
# 	variable.probability = 0.80
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "neighbors_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_neighbors_social_distancing"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "neighbors_social_distancing"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "visits_per_week"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_more_than_twice_per_week"
# 	variable.probability = 0.25
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_once_or_twice_per_week"
# 	variable.probability = 0.50
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "visits_zero_per_week"
# 	variable.probability = 0.25
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "local_govt_social_distancing"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_local_govt_social_distancing"
# 	variable.probability = 0.40
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "local_govt_social_distancing"
# 	variable.probability = 0.60
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "wash_hands_per_day"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_zero_per_day"
# 	variable.probability = 0.20
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_once_or_twice_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_three_to_five_per_day"
# 	variable.probability = 0.30
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "wash_hands_over_five_per_day"
# 	variable.probability = 0.20
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "severe_neck_pain"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "severe_neck_pain"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_severe_neck_pain"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "tested"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "tested"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "not_tested"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "swab_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "swab_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "swab_test_negative"
# 	variable.probability = 0.98
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "antibody_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "antibody_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "antibody_test_negative"
# 	variable.probability = 0.98
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "saliva_test"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "saliva_test_positive"
# 	variable.probability = 0.02
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "saliva_test_negative"
# 	variable.probability = 0.98
#
# 	#anomalies
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "hotspot_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "hotspot_anomaly"
# 	variable.probability = 0.15
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_hotspot_anomaly"
# 	variable.probability = 0.85
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_rate_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "heart_rate_anomaly"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_heart_rate_anomaly"
# 	variable.probability = 0.95
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "heart_rate_variability_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "heart_rate_variability_anomaly"
# 	variable.probability = 0.1
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_heart_rate_variability_anomaly"
# 	variable.probability = 0.90
#
#
# 	discreteDistribution = bayesianNetwork.discreteDistributions.add()
# 	discreteDistribution.name = "oxygen_anomaly"
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "oxygen_anomaly"
# 	variable.probability = 0.05
# 	variable = discreteDistribution.variables.add()
# 	variable.name = "no_oxygen_anomaly"
# 	variable.probability = 0.95
#
# 	# conditional probability tables
#
# 	cpt ={}
#
#
# 	cpt["covid_test"] = any(bayesianNetwork,cpt,
# 	{
# 	"swab_test":{"swab_test_positive"},
# 	"antibody_test":{"antibody_test_positive"},
# 	"saliva_test":{"saliva_test_positive"}
# 	},
# 	["positive_covid_test","negative_covid_test"]
#
# 	)
#
#
# 	cpt["metabolic_disease"] = any(bayesianNetwork,cpt,
# 	{
# 	"cardiovascular_disease":{"cardiovascular_disease"},
# 	"diabetes":{"diabetes"},
# 	"hypertension":{"hypertension"}
# 	},
# 	["metabolic_disease","no_metabolic_disease"]
#
# 	)
#
#
# 	cpt["chronic_conditions"] = any(bayesianNetwork,cpt,
# 	{
# 	"lung_disease":{"lung_disease"},
# 	"cancer":{"cancer"},
# 	"kidney_disease":{"kidney_disease"},
# 	"immunocompromised":{"immunocompromised"}
# 	},
# 	["chronic_conditions","no_chronic_conditions"]
#
# 	)
#
#
# 	cpt["demographics"] = avg(bayesianNetwork,cpt,
# 	[
# 	"age",
# 	"ethnicity",
# 	"bmi"
# 	],
# 	["demographics","no_demographics"]
#
# 	)
#
# 	cpt["comorbidities"] = any(bayesianNetwork,cpt,
# 	{
# 	"chronic_conditions":{"chronic_conditions"},
# 	"metabolic_disease":{"metabolic_disease"},
# 	"demographics":{"demographics"}
# 	},
# 	["comorbidities","no_comorbidities"]
#
# 	)
#
# 	cpt["specific_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"colored_spots_on_toes",
# 	"decreased_smell_or_taste"
# 	],
# 	[ "significant_specific_covid_symptoms","mild_specific_covid_symptoms","no_specific_covid_symptoms"]
# 	)
#
# 	cpt["head_and_neck_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"neck_stiffness",
# 	"sore_throat",
# 	"pink_eye",
# 	"headache"
# 	],
# 	[ "significant_head_and_neck_covid_symptoms","mild_head_and_neck_covid_symptoms","no_head_and_neck_covid_symptoms"]
# 	)
#
# 	cpt["gastrointestinal_covid_symptoms"] = avg(bayesianNetwork,cpt,
# 	[
# 	"low_urine",
# 	"nausea",
# 	"vomiting",
# 	],
# 	[ "significant_gastrointestinal_covid_symptoms","mild_gastrointestinal_covid_symptoms","no_gastrointestinal_covid_symptoms"]
# 	)
#
# 	cpt["covid_symptoms"] = any(bayesianNetwork,cpt,
# 	{
# 	"gastrointestinal_covid_symptoms":{"significant_gastrointestinal_covid_symptoms"},
# 	"specific_covid_symptoms":{"significant_specific_covid_symptoms"},
# 	"head_and_neck_covid_symptoms":{"significant_head_and_neck_covid_symptoms"}
# 	},
# 	[ "significant_covid_symptoms","no_significant_covid_symptoms"]
# 	)
#
# 	cpt["personal_social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"isolation_space",
# 	"deliveries_per_week",
# 	"mask",
# 	"wash_hands_per_day"
# 	],
# 	["no_personal_social_distancing","some_personal_social_distancing","safe_personal_social_distancing"]
# 	)
#
#
#
# 	cpt["social_distancing_connectedness"]= avg(bayesianNetwork,cpt,
# 	[
# 	"visits_per_week",
# 	"leaving_house_per_day",
# 	"high_risk_place_per_week",
# 	"public_transportation_per_week"
# 	],
# 	["no_social_distancing_connectedness","some_social_distancing_connectedness","safe_social_distancing_connectedness"]
# 	)
#
#
# 	cpt["social_distancing_environment"]= avg(bayesianNetwork,cpt,
# 	[
# 	"workplace_social_distancing",
# 	"neighbors_social_distancing",
# 	"local_govt_social_distancing"
# 	],
# 	["no_social_distancing_environnment","some_social_distancing_environment","safe_social_distancing_environment"]
# 	)
#
#
# 	cpt["social_distancing"]= avg(bayesianNetwork,cpt,
# 	[
# 	"social_distancing_environment",
# 	"personal_social_distancing",
# 	"social_distancing_connectedness"
# 	],
# 	["no_social_distancing","low_social_distancing","medium_social_distancing", "high_social_distancing"]
# 	)
#
# 	cpt["social_distancing_binary"]= avg(bayesianNetwork,cpt,
# 	[
# 	"social_distancing_environment",
# 	"personal_social_distancing",
# 	"social_distancing_connectedness"
# 	],
# 	["no_social_distancing", "social_distancing"]
# 	)
#
#
# 	cpt["wearables"] = any(bayesianNetwork,cpt,
# 	{
# 	"heart_rate_variability_anomaly":{"heart_rate_variability_anomaly"},
# 	"oxygen_anomaly":{"oxygen_anomaly"},
# 	"heart_rate_anomaly":{"heart_rate_anomaly"}
# 	},
# 	["anomalous","normal"]
# 	)
#
#
# 	cpt["possible_dehydration"] = any(bayesianNetwork,cpt,
# 	{
# 	"low_urine":{"low_urine"},
# 	"vomiting":{"vomiting"},
# 	"frequent_diarrhea":{"frequent_diarrhea"}
# 	},
# 	["possible_dehydration","no_dehydration"]
# 	)
#
#
# 	cpt["possible_meningitis"] = all(bayesianNetwork,cpt,
# 		{"neck_stiffness":{"neck_stiffness"},
# 		"severe_neck_pain":{"severe_neck_pain"},
# 		"body_temperature":{"body_temperature_above_102F","body_temperature_above_99F"}},
# 		["possible_meningitis","no_meningitis"]
# 		)
#
#
# 	cpt["serious_shortness_of_breath"] = all(bayesianNetwork,cpt,
# 		{"shortness_of_breath":{"new_or_worse_painful_shortness_of_breath","new_or_worse_shortness_of_breath"},
# 		"comorbidities":{"comorbidities"}},
# 		["serious_shortness_of_breath","no_serious_shortness_of_breath"]
# 		)
#
#
# 	cpt["covid_vulnerabilities"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptoms",
# 		"social_distancing",
# 		"wearables"
# 		],
# 		["severe_covid_vulnerabilities", "moderate_covid_vulnerabilites","some_covid_vulnerabilites", "insignificant_covid_vulnerabilities"]
# 		)
#
#
# 	cpt["low_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"shortness_of_breath": {"new_or_worse_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_99F"},
# 		"covid_vulnerabilities":{"some_covid_vulnerabilites"}
# 		},
# 		["low_covid","other_covid"]
# 		)
#
#
# 	cpt["medium_covid"]= any(bayesianNetwork,cpt,
# 		{
# 		"serious_shortness_of_breath":{"serious_shortness_of_breath"},
# 		"body_temperature":{"body_temperature_above_102F"},
# 		"muscle_weakness":{"new_or_worse_muscle_weakness"},
# 		"covid_vulnerabilities":{"moderate_covid_vulnerabilites"}
# 		},
# 		["medium_covid","other_covid"]
# 		)
#
#
# 	cpt["high_covid"] = any(bayesianNetwork,cpt,
# 		{
# 		"cough":{"cough_up_blood"},
# 		"muscle_weakness":{"muscle_weakness_cant_move"},
# 		"low_oxygen_symptoms":{"have_low_oxygen_symptoms"},
# 		"covid_vulnerabilities": {"severe_covid_vulnerabilites"}
# 		},
# 		["high_covid","other_covid"]
# 		)
#
#
# 	cpt["covid_environment"] = avg(bayesianNetwork,cpt,
# 		[
# 		"exposure",
# 		"hotspot_anomaly"
# 		],
# 		["high_risk_covid_environment", "medium_risk_covid_environment", "low_risk_covid_environment","no_risk_covid_environment"]
# 		)
#
#
# 	cpt["covid_symptom_level"] = if_then_else(bayesianNetwork,cpt,
# 		{
# 		"high_covid":{"high_covid"},
# 		"medium_covid":{"medium_covid"},
# 		"low_covid":{"low_covid"},
# 		},
# 		["high_covid", "medium_covid","low_covid","no_covid"]
# 		)
#
#
#
#
# 	#output variable conditional probability distributions
#
#
# 	cpt["emergency_treatment"] = any(bayesianNetwork,cpt,
# 	{
# 	"possible_dehydration":{"possible_dehydration"},
# 	"possible_meningitis":{"possible_meningitis"},
# 	"acute_medical_condition":{"acute_medical_condition"}
# 	},
# 	["emergency_treatment","no_emergency_treatment"]
# 	)
#
#
#
# 	cpt["covid_risk"] = any(bayesianNetwork,cpt,
# 		{
# 		"covid_symptom_level":{"high_covid"},
# 		"covid_environment":{"high_covid"},
# 		"covid_test":{"positive_covid_test"}
# 		},
# 		["covid_risk","no_covid_risk"]
# 		)
#
#
#
# 	cpt["covid_risk_binary"] = avg(bayesianNetwork,cpt,
# 		[
# 		"covid_symptom_level",
# 		"covid_environment"
# 		],
# 		["covid_risk","no_covid_risk"]
# 		)
#
#
# 	cpt["covid_severity"] = avg(bayesianNetwork,cpt,
# 		[
# 		"age",
# 		"comorbidities"
# 		],
# 		["high_covid_severity","medium_covid_severity","low_covid_severity","no_covid_severity"]
# 		)
#
#
# 	cpt["covid_severity_binary"] = avg(bayesianNetwork,cpt,
# 		[
# 		"age",
# 		"comorbidities"
# 		],
# 		["covid_severity","no_covid_severity"]
# 		)
#
#
#
# 	addCpt(bayesianNetwork,cpt)
# 	return(bayesianNetwork)
#
# if __name__ == '__main__':
# 	covid_bayes()

# %% [markdown]
#  Next run the file.  All routines are stateless.

# %%
import sn_bayes
from sn_bayes import covid_bayes
#%run -i './bayes/covid_bayes.py'
#%run -i './bayes/test.py'
bayesianNetwork = covid_bayes.covid_bayes()

# %% [markdown]
# For convenience of creating a table, here are all the variables in the net in order.  They should be mapped into the individual buckets of the rules.  The variables up to "systemically_disadvantaged" are the ones that the user may answer.  The rest are computed.

# %%
import sn_bayes
from sn_bayes.utils import get_var_positions
var_positions = get_var_positions(bayesianNetwork)
var_positions
# Out:
# {'acute_medical_condition': 0,
#  'age': 1,
#  'sex': 2,
#  'height_in_feet': 3,
#  'weight_in_pounds': 4,
#  'ethnicity': 5,
#  'cardiovascular_disease': 6,
#  'diabetes': 7,
#  'hypertension': 8,
#  'lung_disease': 9,
#  'kidney_disease': 10,
#  'cancer': 11,
#  'immunocompromised': 12,
#  'psychological_disorders': 13,
#  'body_temperature': 14,
#  'low_oxygen_symptoms': 15,
#  'shortness_of_breath': 16,
#  'cough': 17,
#  'colored_spots_on_toes': 18,
#  'hx_lung_disease': 19,
#  'hx_family_lung_disease': 20,
#  'muscle_weakness': 21,
#  'difficulty_moving': 22,
#  'neck_stiffness': 23,
#  'low_urine': 24,
#  'frequent_diarrhea': 25,
#  'nausea': 26,
#  'vomiting': 27,
#  'decreased_smell_or_taste': 28,
#  'sore_throat': 29,
#  'pink_eye': 30,
#  'headache': 31,
#  'bmi': 32,
#  'exposure': 33,
#  'isolation_space': 34,
#  'leaving_house_per_day': 35,
#  'high_risk_place_per_week': 36,
#  'deliveries_per_week': 37,
#  'mask': 38,
#  'public_transportation_per_week': 39,
#  'workplace_social_distancing': 40,
#  'neighbors_social_distancing': 41,
#  'visits_per_week': 42,
#  'local_govt_social_distancing': 43,
#  'wash_hands_per_day': 44,
#  'severe_neck_pain': 45,
#  'tested': 46,
#  'swab_test': 47,
#  'antibody_test': 48,
#  'saliva_test': 49,
#  'hotspot_anomaly': 50,
#  'heart_rate_anomaly': 51,
#  'heart_rate_variability_anomaly': 52,
#  'oxygen_anomaly': 53,
#  'covid_test': 54,
#  'metabolic_disease': 55,
#  'chronic_conditions': 56,
#  'demographics': 57,
#  'comorbidities': 58,
#  'specific_covid_symptoms': 59,
#  'head_and_neck_covid_symptoms': 60,
#  'gastrointestinal_covid_symptoms': 61,
#  'covid_symptoms': 62,
#  'personal_social_distancing': 63,
#  'social_distancing_connectedness': 64,
#  'social_distancing_environment': 65,
#  'social_distancing': 66,
#  'social_distancing_binary': 67,
#  'wearables': 68,
#  'possible_dehydration': 69,
#  'possible_meningitis': 70,
#  'serious_shortness_of_breath': 71,
#  'covid_vulnerabilities': 72,
#  'low_covid': 73,
#  'medium_covid': 74,
#  'high_covid': 75,
#  'covid_environment': 76,
#  'covid_symptom_level': 77,
#  'emergency_treatment': 78,
#  'covid_risk': 79,
#  'covid_risk_binary': 80,
#  'covid_severity': 81,
#  'covid_severity_binary': 82}

# %% [markdown]
# Here are the positions of every bucketed response for each of the above variables:

# %%
import sn_bayes
from sn_bayes.utils import get_var_val_positions
var_val_positions = get_var_val_positions(bayesianNetwork)
var_val_positions
# Out:
# {'acute_medical_condition': {'acute_medical_condition': 0,
#   'no_acute_medical_condition': 1},
#  'age': {'elderly': 0, 'adult': 1, 'young_adult': 2, 'teen': 3, 'child': 4},
#  'sex': {'male': 0, 'female': 1},
#  'height_in_feet': {'height_above_seven': 0,
#   'height_six_to_seven': 1,
#   'height_five_to_six': 2,
#   'height_four_to_five': 3,
#   'height_under_four': 4},
#  'weight_in_pounds': {'weight_over_250': 0,
#   'weight_175_to_220': 1,
#   'weight_125_to_175': 2,
#   'weight_100_to_125': 3,
#   'weight_under_100': 4},
#  'ethnicity': {'african_american': 0,
#   'hispanic': 1,
#   'ethnicity_other': 2,
#   'african': 3,
#   'middle_eastern': 4,
#   'native_american': 5,
#   'pacific_islander': 6,
#   'asian': 7,
#   'caucasian': 8},
#  'cardiovascular_disease': {'cardiovascular_disease': 0,
#   'no_cardiovascular_disease': 1},
#  'diabetes': {'diabetes': 0, 'no_diabetes': 1},
#  'hypertension': {'hypertension': 0, 'no_hypertension': 1},
#  'lung_disease': {'lung_disease': 0, 'no_lung_disease': 1},
#  'kidney_disease': {'kidney_disease': 0, 'no_kidney_disase': 1},
#  'cancer': {'cancer': 0, 'no_cancer': 1},
#  'immunocompromised': {'immunocompromised': 0, 'not_immunocompromised': 1},
#  'psychological_disorders': {'psychological_disorders': 0,
#   'no_psychological_disorders': 1},
#  'body_temperature': {'body_temperature_above_102F': 0,
#   'body_temperature_above_99F': 1,
#   'normal_body_temperature': 2},
#  'low_oxygen_symptoms': {'have_low_oxygen_symptoms': 0,
#   'no_low_oxygen_symptoms': 1},
#  'shortness_of_breath': {'new_or_worse_painful_shortness_of_breath': 0,
#   'new_or_worse_shortness_of_breath': 1,
#   'new_or_worse_shortness_of_breath_after_activity': 2,
#   'no_shortness_of_breath': 3},
#  'cough': {'cough_up_blood': 0,
#   'dry_cough': 1,
#   'cough_with_spitum': 2,
#   'no_cough': 3},
#  'colored_spots_on_toes': {'colored_spots_on_toes': 0,
#   'no_colored_spots_on_toes': 1},
#  'hx_lung_disease': {'hx_lung_disease': 0, 'no_hx_lung_disease': 1},
#  'hx_family_lung_disease': {'hx_family_lung_disease': 0,
#   'no_hx_family_lung_disease': 1},
#  'muscle_weakness': {'muscle_weakness_cant_move': 0,
#   'new_or_worse_muscle_weakness': 1,
#   'no_muscle_weakness': 2},
#  'difficulty_moving': {'difficulty_moving': 0, 'no_difficulty_moving': 1},
#  'neck_stiffness': {'neck_stiffness': 0, 'no_neck_stiffness': 1},
#  'low_urine': {'low_urine': 0, 'normal_urine': 1},
#  'frequent_diarrhea': {'frequent_diarrhea': 0, 'not_frequent_diarrhea': 1},
#  'nausea': {'nausea': 0, 'no_nausea': 1},
#  'vomiting': {'vomiting': 0, 'no_vomiting': 1},
#  'decreased_smell_or_taste': {'decreased_smell_or_taste': 0,
#   'no_decreased_smell_or_taste': 1},
#  'sore_throat': {'sore_throat': 0, 'no_sore_throat': 1},
#  'pink_eye': {'pink_eye': 0, 'no_pink_eye': 1},
#  'headache': {'headache': 0, 'no_headache': 1},
#  'bmi': {'morbidly_obese': 0,
#   'obese': 1,
#   'overweight': 2,
#   'normal': 3,
#   'underweight': 4},
#  'exposure': {'exposure_in_family_not_isolated': 0,
#   'exposure_in_family': 1,
#   'exposure_healthcare_worker': 2,
#   'known_exposure': 3,
#   'exposure_high_risk_worker': 4,
#   'no_exposure': 5},
#  'isolation_space': {'no_isolation_space': 0, 'have_isolation_space': 1},
#  'leaving_house_per_day': {'leave_house_more_than_twice_per_day': 0,
#   'leave_house_once_or_twice_per_day': 1,
#   'leave_house_zero_per_day': 2},
#  'high_risk_place_per_week': {'high_risk_place_no_sanitizer_over_three_per_week': 0,
#   'high_risk_place_no_sanitizer_once_or_more_per_week': 1,
#   'high_risk_place_sanitizer_two_or_three_per_week': 2,
#   'high_risk_place_sanitizer_once_per_week': 3,
#   'high_risk_place_zero_per_week': 4},
#  'deliveries_per_week': {'deliveries_no_sanitation_over_three_per_week': 0,
#   'deliveris_no_sanitation_once_or_more_per_week': 1,
#   'deliveries_sanitation_two_or_three_per_week': 2,
#   'deliveries_sanitation_once_per_week': 3,
#   'deliveries_zero_per_week': 4},
#  'mask': {'no_mask': 0, 'surgical_mask': 1, 'n95_mask': 2},
#  'public_transportation_per_week': {'public_transportation_over_three_per_week': 0,
#   'public_transportation_one_to_three_per_week': 1,
#   'public_transportation_zero_per_week': 2},
#  'workplace_social_distancing': {'no_workplace_social_distancing': 0,
#   'workplace_social_distancing': 1},
#  'neighbors_social_distancing': {'no_neighbors_social_distancing': 0,
#   'neighbors_social_distancing': 1},
#  'visits_per_week': {'visits_more_than_twice_per_week': 0,
#   'visits_once_or_twice_per_week': 1,
#   'visits_zero_per_week': 2},
#  'local_govt_social_distancing': {'no_local_govt_social_distancing': 0,
#   'local_govt_social_distancing': 1},
#  'wash_hands_per_day': {'wash_hands_zero_per_day': 0,
#   'wash_hands_once_or_twice_per_day': 1,
#   'wash_hands_three_to_five_per_day': 2,
#   'wash_hands_over_five_per_day': 3},
#  'severe_neck_pain': {'severe_neck_pain': 0, 'no_severe_neck_pain': 1},
#  'tested': {'tested': 0, 'not_tested': 1},
#  'swab_test': {'swab_test_positive': 0, 'swab_test_negative': 1},
#  'antibody_test': {'antibody_test_positive': 0, 'antibody_test_negative': 1},
#  'saliva_test': {'saliva_test_positive': 0, 'saliva_test_negative': 1},
#  'hotspot_anomaly': {'hotspot_anomaly': 0, 'no_hotspot_anomaly': 1},
#  'heart_rate_anomaly': {'heart_rate_anomaly': 0, 'no_heart_rate_anomaly': 1},
#  'heart_rate_variability_anomaly': {'heart_rate_variability_anomaly': 0,
#   'no_heart_rate_variability_anomaly': 1},
#  'oxygen_anomaly': {'oxygen_anomaly': 0, 'no_oxygen_anomaly': 1},
#  'covid_test': {'positive_covid_test': 0, 'negative_covid_test': 1},
#  'metabolic_disease': {'metabolic_disease': 0, 'no_metabolic_disease': 1},
#  'chronic_conditions': {'chronic_conditions': 0, 'no_chronic_conditions': 1},
#  'demographics': {'demographics': 0, 'no_demographics': 1},
#  'comorbidities': {'comorbidities': 0, 'no_comorbidities': 1},
#  'specific_covid_symptoms': {'significant_specific_covid_symptoms': 0,
#   'mild_specific_covid_symptoms': 1,
#   'no_specific_covid_symptoms': 2},
#  'head_and_neck_covid_symptoms': {'significant_head_and_neck_covid_symptoms': 0,
#   'mild_head_and_neck_covid_symptoms': 1,
#   'no_head_and_neck_covid_symptoms': 2},
#  'gastrointestinal_covid_symptoms': {'significant_gastrointestinal_covid_symptoms': 0,
#   'mild_gastrointestinal_covid_symptoms': 1,
#   'no_gastrointestinal_covid_symptoms': 2},
#  'covid_symptoms': {'significant_covid_symptoms': 0,
#   'no_significant_covid_symptoms': 1},
#  'personal_social_distancing': {'no_personal_social_distancing': 0,
#   'some_personal_social_distancing': 1,
#   'safe_personal_social_distancing': 2},
#  'social_distancing_connectedness': {'no_social_distancing_connectedness': 0,
#   'some_social_distancing_connectedness': 1,
#   'safe_social_distancing_connectedness': 2},
#  'social_distancing_environment': {'no_social_distancing_environnment': 0,
#   'some_social_distancing_environment': 1,
#   'safe_social_distancing_environment': 2},
#  'social_distancing': {'no_social_distancing': 0,
#   'low_social_distancing': 1,
#   'medium_social_distancing': 2,
#   'high_social_distancing': 3},
#  'social_distancing_binary': {'no_social_distancing': 0,
#   'social_distancing': 1},
#  'wearables': {'anomalous': 0, 'normal': 1},
#  'possible_dehydration': {'possible_dehydration': 0, 'no_dehydration': 1},
#  'possible_meningitis': {'possible_meningitis': 0, 'no_meningitis': 1},
#  'serious_shortness_of_breath': {'serious_shortness_of_breath': 0,
#   'no_serious_shortness_of_breath': 1},
#  'covid_vulnerabilities': {'severe_covid_vulnerabilities': 0,
#   'moderate_covid_vulnerabilites': 1,
#   'some_covid_vulnerabilites': 2,
#   'insignificant_covid_vulnerabilities': 3},
#  'low_covid': {'low_covid': 0, 'other_covid': 1},
#  'medium_covid': {'medium_covid': 0, 'other_covid': 1},
#  'high_covid': {'high_covid': 0, 'other_covid': 1},
#  'covid_environment': {'high_risk_covid_environment': 0,
#   'medium_risk_covid_environment': 1,
#   'low_risk_covid_environment': 2,
#   'no_risk_covid_environment': 3},
#  'covid_symptom_level': {'high_covid': 0,
#   'medium_covid': 1,
#   'low_covid': 2,
#   'no_covid': 3},
#  'emergency_treatment': {'emergency_treatment': 0,
#   'no_emergency_treatment': 1},
#  'covid_risk': {'covid_risk': 0, 'no_covid_risk': 1},
#  'covid_risk_binary': {'covid_risk': 0, 'no_covid_risk': 1},
#  'covid_severity': {'high_covid_severity': 0,
#   'medium_covid_severity': 1,
#   'low_covid_severity': 2,
#   'no_covid_severity': 3},
#  'covid_severity_binary': {'covid_severity': 0, 'no_covid_severity': 1}}

# %% [markdown]
# We create a spreadsheet of the above for reference

# %%
import pandas as pd

rows_list = []
outname = "varvals.csv"
for var, valdict in var_val_positions.items():
    rowdict = {} 
    rows_list.append(rowdict)
    varstr= var +"("
    for val, pos in valdict.items():
        varstr += val
        varstr+= ","
            
    varstr=varstr[:-1]+")"
    rowdict["variable"] = varstr        

df = pd.DataFrame(rows_list)      
df.to_csv(outname, index = False)

# %% [markdown]
# Here we create a spreadsheet that makes a Cartesian product of desired outputs with the remainder of the variables. This can be used to, for example, fill in a treatment recommendation for variables that are returned as causing the output in the explanation module

# %%
import pandas as pd
#cols = ["leaves","internal","output"]
desired_output =['social_distancing',
                 'emergency_treatment',
                 'covid_risk',
                 'covid_severity']
rows_list = []
outname = "upshot.csv"

#put leaves in the first column, then internal vars along with the vars that feed them in the second.  
#and do a cartesian product with the outvars that are also internal vars (should be all of them)

for output in desired_output:
    for dist in bayesianNetwork.discreteDistributions:
        print(dist.name)
        rowdict = {} 
        rowdict["leaves"]= dist.name
        rowdict["internal"]=""
        rowdict["output"]= output
        rows_list.append(rowdict)
    for table in bayesianNetwork.conditionalProbabilityTables:
        print ("table: {}".format(table.name))
        rowdict = {}
        rowdict["leaves"]=""
        internal_str = table.name + " ("
        for var in table.randomVariables:
            print(var.name)
            internal_str += var.name
            internal_str+= ","
            
        internal_str=internal_str[:-1]+")"
        rowdict["internal"] = internal_str
        rowdict["output"]= output
        rows_list.append(rowdict)
df = pd.DataFrame(rows_list)      
df.to_csv(outname, index = False)
# Out:
# acute_medical_condition
# age
# sex
# height_in_feet
# weight_in_pounds
# ethnicity
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# low_oxygen_symptoms
# shortness_of_breath
# cough
# colored_spots_on_toes
# hx_lung_disease
# hx_family_lung_disease
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# bmi
# exposure
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# neighbors_social_distancing
# visits_per_week
# local_govt_social_distancing
# wash_hands_per_day
# severe_neck_pain
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# ethnicity
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: specific_covid_symptoms
# colored_spots_on_toes
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# neighbors_social_distancing
# local_govt_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# severe_neck_pain
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# low_oxygen_symptoms
# covid_vulnerabilities
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# acute_medical_condition
# table: covid_risk
# covid_symptom_level
# covid_environment
# covid_test
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# acute_medical_condition
# age
# sex
# height_in_feet
# weight_in_pounds
# ethnicity
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# low_oxygen_symptoms
# shortness_of_breath
# cough
# colored_spots_on_toes
# hx_lung_disease
# hx_family_lung_disease
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# bmi
# exposure
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# neighbors_social_distancing
# visits_per_week
# local_govt_social_distancing
# wash_hands_per_day
# severe_neck_pain
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# ethnicity
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: specific_covid_symptoms
# colored_spots_on_toes
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# neighbors_social_distancing
# local_govt_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# severe_neck_pain
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# low_oxygen_symptoms
# covid_vulnerabilities
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# acute_medical_condition
# table: covid_risk
# covid_symptom_level
# covid_environment
# covid_test
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# acute_medical_condition
# age
# sex
# height_in_feet
# weight_in_pounds
# ethnicity
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# low_oxygen_symptoms
# shortness_of_breath
# cough
# colored_spots_on_toes
# hx_lung_disease
# hx_family_lung_disease
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# bmi
# exposure
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# neighbors_social_distancing
# visits_per_week
# local_govt_social_distancing
# wash_hands_per_day
# severe_neck_pain
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# ethnicity
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: specific_covid_symptoms
# colored_spots_on_toes
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# neighbors_social_distancing
# local_govt_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# severe_neck_pain
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# low_oxygen_symptoms
# covid_vulnerabilities
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# acute_medical_condition
# table: covid_risk
# covid_symptom_level
# covid_environment
# covid_test
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities
# acute_medical_condition
# age
# sex
# height_in_feet
# weight_in_pounds
# ethnicity
# cardiovascular_disease
# diabetes
# hypertension
# lung_disease
# kidney_disease
# cancer
# immunocompromised
# psychological_disorders
# body_temperature
# low_oxygen_symptoms
# shortness_of_breath
# cough
# colored_spots_on_toes
# hx_lung_disease
# hx_family_lung_disease
# muscle_weakness
# difficulty_moving
# neck_stiffness
# low_urine
# frequent_diarrhea
# nausea
# vomiting
# decreased_smell_or_taste
# sore_throat
# pink_eye
# headache
# bmi
# exposure
# isolation_space
# leaving_house_per_day
# high_risk_place_per_week
# deliveries_per_week
# mask
# public_transportation_per_week
# workplace_social_distancing
# neighbors_social_distancing
# visits_per_week
# local_govt_social_distancing
# wash_hands_per_day
# severe_neck_pain
# tested
# swab_test
# antibody_test
# saliva_test
# hotspot_anomaly
# heart_rate_anomaly
# heart_rate_variability_anomaly
# oxygen_anomaly
# table: covid_test
# swab_test
# antibody_test
# saliva_test
# table: metabolic_disease
# cardiovascular_disease
# diabetes
# hypertension
# table: chronic_conditions
# lung_disease
# cancer
# kidney_disease
# immunocompromised
# table: demographics
# age
# ethnicity
# bmi
# table: comorbidities
# chronic_conditions
# metabolic_disease
# demographics
# table: specific_covid_symptoms
# colored_spots_on_toes
# decreased_smell_or_taste
# table: head_and_neck_covid_symptoms
# neck_stiffness
# sore_throat
# pink_eye
# headache
# table: gastrointestinal_covid_symptoms
# low_urine
# nausea
# vomiting
# table: covid_symptoms
# gastrointestinal_covid_symptoms
# specific_covid_symptoms
# head_and_neck_covid_symptoms
# table: personal_social_distancing
# isolation_space
# deliveries_per_week
# mask
# wash_hands_per_day
# table: social_distancing_connectedness
# visits_per_week
# leaving_house_per_day
# high_risk_place_per_week
# public_transportation_per_week
# table: social_distancing_environment
# workplace_social_distancing
# neighbors_social_distancing
# local_govt_social_distancing
# table: social_distancing
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: social_distancing_binary
# social_distancing_environment
# personal_social_distancing
# social_distancing_connectedness
# table: wearables
# heart_rate_variability_anomaly
# oxygen_anomaly
# heart_rate_anomaly
# table: possible_dehydration
# low_urine
# vomiting
# frequent_diarrhea
# table: possible_meningitis
# neck_stiffness
# severe_neck_pain
# body_temperature
# table: serious_shortness_of_breath
# shortness_of_breath
# comorbidities
# table: covid_vulnerabilities
# covid_symptoms
# social_distancing
# wearables
# table: low_covid
# shortness_of_breath
# body_temperature
# covid_vulnerabilities
# table: medium_covid
# serious_shortness_of_breath
# body_temperature
# muscle_weakness
# covid_vulnerabilities
# table: high_covid
# cough
# muscle_weakness
# low_oxygen_symptoms
# covid_vulnerabilities
# table: covid_environment
# exposure
# hotspot_anomaly
# table: covid_symptom_level
# high_covid
# medium_covid
# low_covid
# table: emergency_treatment
# possible_dehydration
# possible_meningitis
# acute_medical_condition
# table: covid_risk
# covid_symptom_level
# covid_environment
# covid_test
# table: covid_risk_binary
# covid_symptom_level
# covid_environment
# table: covid_severity
# age
# comorbidities
# table: covid_severity_binary
# age
# comorbidities

# %% [markdown]
# Here is a one more csv that uses a utility function to express the net in  a tree form, in a data frame and then prints it out

# %%
import sn_bayes
from sn_bayes.utils import make_tree
import pandas as pd
df = make_tree(bayesianNetwork)
outname = "tree.csv"
df.to_csv(outname, index = False)

# %%
df
# Out:
#                              level0  \
# 0          acute_medical_condition)
# 1                              age)
# 2                              sex)
# 3                   height_in_feet)
# 4                 weight_in_pounds)
# 5                        ethnicity)
# 6           cardiovascular_disease)
# 7                         diabetes)
# 8                     hypertension)
# 9                     lung_disease)
# 10                  kidney_disease)
# 11                          cancer)
# 12               immunocompromised)
# 13         psychological_disorders)
# 14                body_temperature)
# 15             low_oxygen_symptoms)
# 16             shortness_of_breath)
# 17                           cough)
# 18           colored_spots_on_toes)
# 19                 hx_lung_disease)
# 20          hx_family_lung_disease)
# 21                 muscle_weakness)
# 22               difficulty_moving)
# 23                  neck_stiffness)
# 24                       low_urine)
# 25               frequent_diarrhea)
# 26                          nausea)
# 27                        vomiting)
# 28        decreased_smell_or_taste)
# 29                     sore_throat)
# 30                        pink_eye)
# 31                        headache)
# 32                             bmi)
# 33                        exposure)
# 34                 isolation_space)
# 35           leaving_house_per_day)
# 36        high_risk_place_per_week)
# 37             deliveries_per_week)
# 38                            mask)
# 39  public_transportation_per_week)
# 40     workplace_social_distancing)
# 41     neighbors_social_distancing)
# 42                 visits_per_week)
# 43    local_govt_social_distancing)
# 44              wash_hands_per_day)
# 45                severe_neck_pain)
# 46                          tested)
# 47                       swab_test)
# 48                   antibody_test)
# 49                     saliva_test)
# 50                 hotspot_anomaly)
# 51              heart_rate_anomaly)
# 52  heart_rate_variability_anomaly)
# 53                  oxygen_anomaly)
#
#                                                level1  \
# 0     covid_test(swab_test,antibody_test,saliva_test)
# 1   metabolic_disease(cardiovascular_disease,diabe...
# 2   chronic_conditions(lung_disease,cancer,kidney_...
# 3                     demographics(age,ethnicity,bmi)
# 4   specific_covid_symptoms(colored_spots_on_toes,...
# 5   head_and_neck_covid_symptoms(neck_stiffness,so...
# 6   gastrointestinal_covid_symptoms(low_urine,naus...
# 7   personal_social_distancing(isolation_space,del...
# 8   social_distancing_connectedness(visits_per_wee...
# 9   social_distancing_environment(workplace_social...
# 10  wearables(heart_rate_variability_anomaly,oxyge...
# 11  possible_dehydration(low_urine,vomiting,freque...
# 12  possible_meningitis(neck_stiffness,severe_neck...
# 13        covid_environment(exposure,hotspot_anomaly)
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                                level2  \
# 0   comorbidities(chronic_conditions,metabolic_dis...
# 1   covid_symptoms(gastrointestinal_covid_symptoms...
# 2   social_distancing(social_distancing_environmen...
# 3   social_distancing_binary(social_distancing_env...
# 4   emergency_treatment(possible_dehydration,possi...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                                level3  \
# 0   serious_shortness_of_breath(shortness_of_breat...
# 1   covid_vulnerabilities(covid_symptoms,social_di...
# 2                   covid_severity(age,comorbidities)
# 3            covid_severity_binary(age,comorbidities)
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                                level4  \
# 0   low_covid(shortness_of_breath,body_temperature...
# 1   medium_covid(serious_shortness_of_breath,body_...
# 2   high_covid(cough,muscle_weakness,low_oxygen_sy...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                                level5  \
# 0   covid_symptom_level(high_covid,medium_covid,lo...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
#
#                                                level6
# 0   covid_risk(covid_symptom_level,covid_environme...
# 1   covid_risk_binary(covid_symptom_level,covid_en...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None

# %% [markdown]
# Here is the description of the Bayesian network in protobuf that we just created with the running of the python file.  Only the "leaves" have initial probabilities (DiscreteDistribution), the conditional probabilities (ConditionalProbabilityTable) are to be computed:

# %%
bayesianNetwork
# Out:
# discreteDistributions {
#   name: "acute_medical_condition"
#   variables {
#     name: "acute_medical_condition"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_acute_medical_condition"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "age"
#   variables {
#     name: "elderly"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "adult"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "young_adult"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "teen"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "child"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "sex"
#   variables {
#     name: "male"
#     probability: 0.5
#   }
#   variables {
#     name: "female"
#     probability: 0.5
#   }
# }
# discreteDistributions {
#   name: "height_in_feet"
#   variables {
#     name: "height_above_seven"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "height_six_to_seven"
#     probability: 0.25
#   }
#   variables {
#     name: "height_five_to_six"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "height_four_to_five"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "height_under_four"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "weight_in_pounds"
#   variables {
#     name: "weight_over_250"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_175_to_220"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "weight_125_to_175"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "weight_100_to_125"
#     probability: 0.25
#   }
#   variables {
#     name: "weight_under_100"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "ethnicity"
#   variables {
#     name: "african_american"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "hispanic"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "ethnicity_other"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "african"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "middle_eastern"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "native_american"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "pacific_islander"
#     probability: 0.02500000037252903
#   }
#   variables {
#     name: "asian"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "caucasian"
#     probability: 0.3499999940395355
#   }
# }
# discreteDistributions {
#   name: "cardiovascular_disease"
#   variables {
#     name: "cardiovascular_disease"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "no_cardiovascular_disease"
#     probability: 0.9100000262260437
#   }
# }
# discreteDistributions {
#   name: "diabetes"
#   variables {
#     name: "diabetes"
#     probability: 0.11999999731779099
#   }
#   variables {
#     name: "no_diabetes"
#     probability: 0.8799999952316284
#   }
# }
# discreteDistributions {
#   name: "hypertension"
#   variables {
#     name: "hypertension"
#     probability: 0.17000000178813934
#   }
#   variables {
#     name: "no_hypertension"
#     probability: 0.8299999833106995
#   }
# }
# discreteDistributions {
#   name: "lung_disease"
#   variables {
#     name: "lung_disease"
#     probability: 0.10999999940395355
#   }
#   variables {
#     name: "no_lung_disease"
#     probability: 0.8899999856948853
#   }
# }
# discreteDistributions {
#   name: "kidney_disease"
#   variables {
#     name: "kidney_disease"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_kidney_disase"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "cancer"
#   variables {
#     name: "cancer"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_cancer"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "immunocompromised"
#   variables {
#     name: "immunocompromised"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "not_immunocompromised"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "psychological_disorders"
#   variables {
#     name: "psychological_disorders"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "no_psychological_disorders"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "body_temperature"
#   variables {
#     name: "body_temperature_above_102F"
#     probability: 0.014999999664723873
#   }
#   variables {
#     name: "body_temperature_above_99F"
#     probability: 0.03500000014901161
#   }
#   variables {
#     name: "normal_body_temperature"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "low_oxygen_symptoms"
#   variables {
#     name: "have_low_oxygen_symptoms"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_low_oxygen_symptoms"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "shortness_of_breath"
#   variables {
#     name: "new_or_worse_painful_shortness_of_breath"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "new_or_worse_shortness_of_breath_after_activity"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_shortness_of_breath"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "cough"
#   variables {
#     name: "cough_up_blood"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "dry_cough"
#     probability: 0.03999999910593033
#   }
#   variables {
#     name: "cough_with_spitum"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_cough"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "colored_spots_on_toes"
#   variables {
#     name: "colored_spots_on_toes"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_colored_spots_on_toes"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "hx_lung_disease"
#   variables {
#     name: "hx_lung_disease"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_hx_lung_disease"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "hx_family_lung_disease"
#   variables {
#     name: "hx_family_lung_disease"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_hx_family_lung_disease"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "muscle_weakness"
#   variables {
#     name: "muscle_weakness_cant_move"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "new_or_worse_muscle_weakness"
#     probability: 0.09000000357627869
#   }
#   variables {
#     name: "no_muscle_weakness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "difficulty_moving"
#   variables {
#     name: "difficulty_moving"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_difficulty_moving"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "neck_stiffness"
#   variables {
#     name: "neck_stiffness"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_neck_stiffness"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "low_urine"
#   variables {
#     name: "low_urine"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "normal_urine"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "frequent_diarrhea"
#   variables {
#     name: "frequent_diarrhea"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "not_frequent_diarrhea"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "nausea"
#   variables {
#     name: "nausea"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_nausea"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "vomiting"
#   variables {
#     name: "vomiting"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_vomiting"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "decreased_smell_or_taste"
#   variables {
#     name: "decreased_smell_or_taste"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_decreased_smell_or_taste"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "sore_throat"
#   variables {
#     name: "sore_throat"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_sore_throat"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "pink_eye"
#   variables {
#     name: "pink_eye"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "no_pink_eye"
#     probability: 0.9900000095367432
#   }
# }
# discreteDistributions {
#   name: "headache"
#   variables {
#     name: "headache"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "no_headache"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "bmi"
#   variables {
#     name: "morbidly_obese"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "obese"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "overweight"
#     probability: 0.25
#   }
#   variables {
#     name: "normal"
#     probability: 0.5
#   }
#   variables {
#     name: "underweight"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "exposure"
#   variables {
#     name: "exposure_in_family_not_isolated"
#     probability: 0.009999999776482582
#   }
#   variables {
#     name: "exposure_in_family"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "exposure_healthcare_worker"
#     probability: 0.029999999329447746
#   }
#   variables {
#     name: "known_exposure"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "exposure_high_risk_worker"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_exposure"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "isolation_space"
#   variables {
#     name: "no_isolation_space"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "have_isolation_space"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "leaving_house_per_day"
#   variables {
#     name: "leave_house_more_than_twice_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "leave_house_once_or_twice_per_day"
#     probability: 0.699999988079071
#   }
#   variables {
#     name: "leave_house_zero_per_day"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "high_risk_place_per_week"
#   variables {
#     name: "high_risk_place_no_sanitizer_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "high_risk_place_no_sanitizer_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "high_risk_place_sanitizer_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "high_risk_place_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "deliveries_per_week"
#   variables {
#     name: "deliveries_no_sanitation_over_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "deliveris_no_sanitation_once_or_more_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_two_or_three_per_week"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "deliveries_sanitation_once_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "deliveries_zero_per_week"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "mask"
#   variables {
#     name: "no_mask"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "surgical_mask"
#     probability: 0.5
#   }
#   variables {
#     name: "n95_mask"
#     probability: 0.10000000149011612
#   }
# }
# discreteDistributions {
#   name: "public_transportation_per_week"
#   variables {
#     name: "public_transportation_over_three_per_week"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "public_transportation_one_to_three_per_week"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "public_transportation_zero_per_week"
#     probability: 0.699999988079071
#   }
# }
# discreteDistributions {
#   name: "workplace_social_distancing"
#   variables {
#     name: "no_workplace_social_distancing"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "workplace_social_distancing"
#     probability: 0.800000011920929
#   }
# }
# discreteDistributions {
#   name: "neighbors_social_distancing"
#   variables {
#     name: "no_neighbors_social_distancing"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "neighbors_social_distancing"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "visits_per_week"
#   variables {
#     name: "visits_more_than_twice_per_week"
#     probability: 0.25
#   }
#   variables {
#     name: "visits_once_or_twice_per_week"
#     probability: 0.5
#   }
#   variables {
#     name: "visits_zero_per_week"
#     probability: 0.25
#   }
# }
# discreteDistributions {
#   name: "local_govt_social_distancing"
#   variables {
#     name: "no_local_govt_social_distancing"
#     probability: 0.4000000059604645
#   }
#   variables {
#     name: "local_govt_social_distancing"
#     probability: 0.6000000238418579
#   }
# }
# discreteDistributions {
#   name: "wash_hands_per_day"
#   variables {
#     name: "wash_hands_zero_per_day"
#     probability: 0.20000000298023224
#   }
#   variables {
#     name: "wash_hands_once_or_twice_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_three_to_five_per_day"
#     probability: 0.30000001192092896
#   }
#   variables {
#     name: "wash_hands_over_five_per_day"
#     probability: 0.20000000298023224
#   }
# }
# discreteDistributions {
#   name: "severe_neck_pain"
#   variables {
#     name: "severe_neck_pain"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "no_severe_neck_pain"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "tested"
#   variables {
#     name: "tested"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "not_tested"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "swab_test"
#   variables {
#     name: "swab_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "swab_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "antibody_test"
#   variables {
#     name: "antibody_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "antibody_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "saliva_test"
#   variables {
#     name: "saliva_test_positive"
#     probability: 0.019999999552965164
#   }
#   variables {
#     name: "saliva_test_negative"
#     probability: 0.9800000190734863
#   }
# }
# discreteDistributions {
#   name: "hotspot_anomaly"
#   variables {
#     name: "hotspot_anomaly"
#     probability: 0.15000000596046448
#   }
#   variables {
#     name: "no_hotspot_anomaly"
#     probability: 0.8500000238418579
#   }
# }
# discreteDistributions {
#   name: "heart_rate_anomaly"
#   variables {
#     name: "heart_rate_anomaly"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_heart_rate_anomaly"
#     probability: 0.949999988079071
#   }
# }
# discreteDistributions {
#   name: "heart_rate_variability_anomaly"
#   variables {
#     name: "heart_rate_variability_anomaly"
#     probability: 0.10000000149011612
#   }
#   variables {
#     name: "no_heart_rate_variability_anomaly"
#     probability: 0.8999999761581421
#   }
# }
# discreteDistributions {
#   name: "oxygen_anomaly"
#   variables {
#     name: "oxygen_anomaly"
#     probability: 0.05000000074505806
#   }
#   variables {
#     name: "no_oxygen_anomaly"
#     probability: 0.949999988079071
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_test"
#   randomVariables {
#     name: "swab_test"
#   }
#   randomVariables {
#     name: "antibody_test"
#   }
#   randomVariables {
#     name: "saliva_test"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_positive"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_positive"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_positive"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "positive_covid_test"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "swab_test_negative"
#     }
#     randomVariableValues {
#       name: "antibody_test_negative"
#     }
#     randomVariableValues {
#       name: "saliva_test_negative"
#     }
#     randomVariableValues {
#       name: "negative_covid_test"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "positive_covid_test"
#   }
#   outvars {
#     name: "negative_covid_test"
#   }
# }
# conditionalProbabilityTables {
#   name: "metabolic_disease"
#   randomVariables {
#     name: "cardiovascular_disease"
#   }
#   randomVariables {
#     name: "diabetes"
#   }
#   randomVariables {
#     name: "hypertension"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "metabolic_disease"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_cardiovascular_disease"
#     }
#     randomVariableValues {
#       name: "no_diabetes"
#     }
#     randomVariableValues {
#       name: "no_hypertension"
#     }
#     randomVariableValues {
#       name: "no_metabolic_disease"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "metabolic_disease"
#   }
#   outvars {
#     name: "no_metabolic_disease"
#   }
# }
# conditionalProbabilityTables {
#   name: "chronic_conditions"
#   randomVariables {
#     name: "lung_disease"
#   }
#   randomVariables {
#     name: "cancer"
#   }
#   randomVariables {
#     name: "kidney_disease"
#   }
#   randomVariables {
#     name: "immunocompromised"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "kidney_disease"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "chronic_conditions"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_lung_disease"
#     }
#     randomVariableValues {
#       name: "no_cancer"
#     }
#     randomVariableValues {
#       name: "no_kidney_disase"
#     }
#     randomVariableValues {
#       name: "not_immunocompromised"
#     }
#     randomVariableValues {
#       name: "no_chronic_conditions"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "chronic_conditions"
#   }
#   outvars {
#     name: "no_chronic_conditions"
#   }
# }
# conditionalProbabilityTables {
#   name: "demographics"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "ethnicity"
#   }
#   randomVariables {
#     name: "bmi"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african_american"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "hispanic"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "normal"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "ethnicity_other"
#     }
#     randomVariableValues {
#       name: "underweight"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "morbidly_obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "obese"
#     }
#     randomVariableValues {
#       name: "no_demographics"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "african"
#     }
#     randomVariableValues {
#       name: "overweight"
#     }
#     randomVariableValues {
#       name: "demographics"
#     }
# ...
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "high_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "medium_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "low_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "covid_risk"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "no_covid"
#     }
#     randomVariableValues {
#       name: "no_risk_covid_environment"
#     }
#     randomVariableValues {
#       name: "no_covid_risk"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "covid_risk"
#   }
#   outvars {
#     name: "no_covid_risk"
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_severity"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "comorbidities"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "high_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "medium_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "low_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "high_covid_severity"
#   }
#   outvars {
#     name: "medium_covid_severity"
#   }
#   outvars {
#     name: "low_covid_severity"
#   }
#   outvars {
#     name: "no_covid_severity"
#   }
# }
# conditionalProbabilityTables {
#   name: "covid_severity_binary"
#   randomVariables {
#     name: "age"
#   }
#   randomVariables {
#     name: "comorbidities"
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "elderly"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "young_adult"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "teen"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#     probability: 1.0
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "covid_severity"
#     }
#   }
#   conditionalProbabilityRows {
#     randomVariableValues {
#       name: "child"
#     }
#     randomVariableValues {
#       name: "no_comorbidities"
#     }
#     randomVariableValues {
#       name: "no_covid_severity"
#     }
#     probability: 1.0
#   }
#   outvars {
#     name: "covid_severity"
#   }
#   outvars {
#     name: "no_covid_severity"
#   }
# }

# %% [markdown]
# Here is the Pomegranate net we just made with the description.  Here we compile the net so we can compute probabilities with it.

# %%
from sn_bayes.utils import bayesInitialize
covid = bayesInitialize(bayesianNetwork)

# %%
covid.bake()

# %% [markdown]
# We we call a Pomegranate routine that shows the computed probabilities of every variable.  We have made our own utility that pulls out particular variables.

# %%
covid.predict_proba({})
# Out:
# array([{
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "acute_medical_condition" :0.01999999918043658,
#             "no_acute_medical_condition" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "elderly" :0.12499999883584717,
#             "adult" :0.3750000058207651,
#             "young_adult" :0.24999999767169342,
#             "teen" :0.12499999883584717,
#             "child" :0.12499999883584717
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "male" :0.5,
#             "female" :0.5
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "height_above_seven" :0.04999999981373565,
#             "height_six_to_seven" :0.24999999534338715,
#             "height_five_to_six" :0.3000000063329933,
#             "height_four_to_five" :0.15000000316649675,
#             "height_under_four" :0.24999999534338715
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "weight_over_250" :0.15000000372529032,
#             "weight_175_to_220" :0.15000000372529032,
#             "weight_125_to_175" :0.2,
#             "weight_100_to_125" :0.2499999962747097,
#             "weight_under_100" :0.2499999962747097
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "african_american" :0.15000000484287718,
#             "hispanic" :0.20000000149011576,
#             "ethnicity_other" :0.05000000037252926,
#             "african" :0.05000000037252926,
#             "middle_eastern" :0.025000000186264856,
#             "native_american" :0.05000000037252926,
#             "pacific_islander" :0.025000000186264856,
#             "asian" :0.10000000074505809,
#             "caucasian" :0.34999999143183147
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cardiovascular_disease" :0.09000000089407001,
#             "no_cardiovascular_disease" :0.9099999991059301
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "diabetes" :0.11999999821186098,
#             "no_diabetes" :0.8800000017881391
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hypertension" :0.1700000043213371,
#             "no_hypertension" :0.8299999956786629
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "lung_disease" :0.11000000104308164,
#             "no_lung_disease" :0.8899999989569183
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "kidney_disease" :0.30000001192092907,
#             "no_kidney_disase" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cancer" :0.30000001192092907,
#             "no_cancer" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "immunocompromised" :0.30000001192092907,
#             "not_immunocompromised" :0.6999999880790708
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "psychological_disorders" :0.300000011920929,
#             "no_psychological_disorders" :0.6999999880790709
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "body_temperature_above_102F" :0.014999999846332624,
#             "body_temperature_above_99F" :0.03500000057276418,
#             "normal_body_temperature" :0.9499999995809032
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "have_low_oxygen_symptoms" :0.05000000130385202,
#             "no_low_oxygen_symptoms" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "new_or_worse_painful_shortness_of_breath" :0.010000000018627091,
#             "new_or_worse_shortness_of_breath" :0.04000000007450637,
#             "new_or_worse_shortness_of_breath_after_activity" :0.05000000195577797,
#             "no_shortness_of_breath" :0.8999999979510885
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "cough_up_blood" :0.010000000018626878,
#             "dry_cough" :0.04000000007450618,
#             "cough_with_spitum" :0.0500000019557778,
#             "no_cough" :0.8999999979510891
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "colored_spots_on_toes" :0.01999999918043658,
#             "no_colored_spots_on_toes" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_lung_disease" :0.10000000372529055,
#             "no_hx_lung_disease" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hx_family_lung_disease" :0.10000000372529055,
#             "no_hx_family_lung_disease" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "muscle_weakness_cant_move" :0.009999999981374194,
#             "new_or_worse_muscle_weakness" :0.090000005420298,
#             "no_muscle_weakness" :0.8999999945983279
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "difficulty_moving" :0.10000000372529055,
#             "no_difficulty_moving" :0.8999999962747095
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "neck_stiffness" :0.10000000372529091,
#             "no_neck_stiffness" :0.8999999962747092
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_urine" :0.10000000372529089,
#             "normal_urine" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "frequent_diarrhea" :0.10000000372529073,
#             "not_frequent_diarrhea" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "nausea" :0.20000000000000026,
#             "no_nausea" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "vomiting" :0.10000000372529089,
#             "no_vomiting" :0.8999999962747091
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "decreased_smell_or_taste" :0.10000000372529073,
#             "no_decreased_smell_or_taste" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "sore_throat" :0.20000000000000026,
#             "no_sore_throat" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "pink_eye" :0.009999999683350764,
#             "no_pink_eye" :0.9900000003166493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "headache" :0.20000000000000026,
#             "no_headache" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "morbidly_obese" :0.05000000055879389,
#             "obese" :0.1000000011175873,
#             "overweight" :0.24999999906867731,
#             "normal" :0.4999999981373542,
#             "underweight" :0.1000000011175873
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "exposure_in_family_not_isolated" :0.01000000003725332,
#             "exposure_in_family" :0.020000000074506197,
#             "exposure_healthcare_worker" :0.030000000111759077,
#             "known_exposure" :0.020000000074506197,
#             "exposure_high_risk_worker" :0.020000000074506197,
#             "no_exposure" :0.8999999996274689
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_isolation_space" :0.20000000000000026,
#             "have_isolation_space" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "leave_house_more_than_twice_per_day" :0.20000000447034857,
#             "leave_house_once_or_twice_per_day" :0.6999999932944768,
#             "leave_house_zero_per_day" :0.1000000022351745
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "high_risk_place_no_sanitizer_over_three_per_week" :0.09999999850988416,
#             "high_risk_place_no_sanitizer_once_or_more_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_two_or_three_per_week" :0.30000000298023194,
#             "high_risk_place_sanitizer_once_per_week" :0.19999999701976787,
#             "high_risk_place_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "deliveries_no_sanitation_over_three_per_week" :0.09999999850988416,
#             "deliveris_no_sanitation_once_or_more_per_week" :0.30000000298023194,
#             "deliveries_sanitation_two_or_three_per_week" :0.30000000298023194,
#             "deliveries_sanitation_once_per_week" :0.19999999701976787,
#             "deliveries_zero_per_week" :0.09999999850988416
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_mask" :0.4000000029802321,
#             "surgical_mask" :0.49999999627470954,
#             "n95_mask" :0.10000000074505835
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "public_transportation_over_three_per_week" :0.2000000044703486,
#             "public_transportation_one_to_three_per_week" :0.10000000223517451,
#             "public_transportation_zero_per_week" :0.6999999932944769
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_workplace_social_distancing" :0.20000000000000026,
#             "workplace_social_distancing" :0.7999999999999997
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_neighbors_social_distancing" :0.3999999940395358,
#             "neighbors_social_distancing" :0.6000000059604641
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "visits_more_than_twice_per_week" :0.2500000000000001,
#             "visits_once_or_twice_per_week" :0.49999999999999983,
#             "visits_zero_per_week" :0.2500000000000001
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_local_govt_social_distancing" :0.3999999940395358,
#             "local_govt_social_distancing" :0.6000000059604641
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "wash_hands_zero_per_day" :0.19999999701976795,
#             "wash_hands_once_or_twice_per_day" :0.30000000298023205,
#             "wash_hands_three_to_five_per_day" :0.30000000298023205,
#             "wash_hands_over_five_per_day" :0.19999999701976795
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "severe_neck_pain" :0.01999999918043658,
#             "no_severe_neck_pain" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "tested" :0.019999999180436365,
#             "not_tested" :0.9800000008195636
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "swab_test_positive" :0.01999999918043658,
#             "swab_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "antibody_test_positive" :0.01999999918043658,
#             "antibody_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "saliva_test_positive" :0.01999999918043658,
#             "saliva_test_negative" :0.9800000008195634
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "hotspot_anomaly" :0.15000000149011636,
#             "no_hotspot_anomaly" :0.8499999985098835
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "heart_rate_anomaly" :0.05000000130385202,
#             "no_heart_rate_anomaly" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "heart_rate_variability_anomaly" :0.10000000372529073,
#             "no_heart_rate_variability_anomaly" :0.8999999962747094
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "oxygen_anomaly" :0.05000000130385202,
#             "no_oxygen_anomaly" :0.9499999986961479
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "negative_covid_test" :0.9411920023613264,
#             "positive_covid_test" :0.05880799763867367
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_metabolic_disease" :0.6646639972370261,
#             "metabolic_disease" :0.3353360027629739
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_chronic_conditions" :0.30526998404607186,
#             "chronic_conditions" :0.694730015953928
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_demographics" :0.4768749935680539,
#             "demographics" :0.5231250064319461
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_comorbidities" :0.0967588746050912,
#             "comorbidities" :0.9032411253949088
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "significant_specific_covid_symptoms" :0.0019999999925498857,
#             "no_specific_covid_symptoms" :0.0,
#             "mild_specific_covid_symptoms" :0.9980000000074499
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_head_and_neck_covid_symptoms" :0.0,
#             "significant_head_and_neck_covid_symptoms" :4.00000002239625e-05,
#             "mild_head_and_neck_covid_symptoms" :0.9999599999997758
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "mild_gastrointestinal_covid_symptoms" :0.9979999998509878,
#             "significant_gastrointestinal_covid_symptoms" :0.0020000001490120766,
#             "no_gastrointestinal_covid_symptoms" :0.0
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_significant_covid_symptoms" :0.9959641596985039,
#             "significant_covid_symptoms" :0.004035840301496031
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "safe_personal_social_distancing" :0.07139999907463854,
#             "no_personal_social_distancing" :0.1722000006660823,
#             "some_personal_social_distancing" :0.7564000002592792
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing_connectedness" :0.21275000330433286,
#             "safe_social_distancing_connectedness" :0.14049999861791784,
#             "some_social_distancing_connectedness" :0.6467499980777494
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing_environnment" :0.03199999904632639,
#             "safe_social_distancing_environment" :0.0,
#             "some_social_distancing_environment" :0.9680000009536733
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing" :0.002432639946873795,
#             "low_social_distancing" :0.8399619806253042,
#             "high_social_distancing" :0.0,
#             "medium_social_distancing" :0.15760537942782177
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_social_distancing" :0.8423946205721781,
#             "social_distancing" :0.1576053794278218
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "anomalous" :0.18775000559166152,
#             "normal" :0.8122499944083386
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "possible_dehydration" :0.2710000090524564,
#             "no_dehydration" :0.7289999909475436
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_meningitis" :0.9998999999995339,
#             "possible_meningitis" :0.00010000000046610929
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "serious_shortness_of_breath" :0.045162056353867504,
#             "no_serious_shortness_of_breath" :0.9548379436461325
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "insignificant_covid_vulnerabilities" :0.0,
#             "moderate_covid_vulnerabilites" :0.16045635538779512,
#             "severe_covid_vulnerabilities" :0.0005841248007582438,
#             "some_covid_vulnerabilites" :0.8389595198114463
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "low_covid" :0.8508120992534514,
#             "other_covid" :0.14918790074654867
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_covid" :0.2814606323317248,
#             "other_covid" :0.7185393676682751
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "other_covid" :0.931094998722094,
#             "high_covid" :0.06890500127790616
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_risk_covid_environment" :0.17100000147894073,
#             "no_risk_covid_environment" :0.7649999983422435,
#             "low_risk_covid_environment" :0.05950000011734764,
#             "high_risk_covid_environment" :0.004500000061468009
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "medium_covid" :0.26206658710122693,
#             "low_covid" :0.5692174673513514,
#             "no_covid" :0.09981094426951531,
#             "high_covid" :0.0689050012779064
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "emergency_treatment" :0.2856514502734508,
#             "no_emergency_treatment" :0.7143485497265493
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "covid_risk" :0.123660833764136,
#             "no_covid_risk" :0.8763391662358639
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "covid_risk" :0.44838607564917243,
#             "no_covid_risk" :0.5516139243508277
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_severity" :0.012094859212994448,
#             "medium_covid_severity" :0.49999999624452446,
#             "low_covid_severity" :0.036284577638982865,
#             "high_covid_severity" :0.4516205669034982
#         }
#     ],
#     "frozen" :false
# },
#        {
#     "class" :"Distribution",
#     "dtype" :"str",
#     "name" :"DiscreteDistribution",
#     "parameters" :[
#         {
#             "no_covid_severity" :0.048379436851977146,
#             "covid_severity" :0.9516205631480229
#         }
#     ],
#     "frozen" :false
# }], dtype=object)

# %% [markdown]
# Here we use our query util to enter patient states as evidence (evidence), and then see the probabilities of particular variables we are interested in (outvars), in this case, the output variables.  It needs the compiled Pomegranate Bayesian network as well as the description of the network.  This routine can be used to enter a particular patients state , one question at a time, to get a continual change in probability of all states. Below, we first look at the probability of emergency treatment, covid risk, and covid severity, in general.  Then, we look at it given the information that the patient is elderly. We see that the chance of severity has increased. Adding more risk factors increases risk more, and adding more severity factors increases severity more.

# %%
import sn_bayes
from sn_bayes.utils import query
evidence = {}
outvars= ["social_distancing", "social_distancing_binary",
          "emergency_treatment",
          "covid_risk","covid_risk_binary",
          "covid_severity","covid_severity_binary"]
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2856514502734508,
#   'no_emergency_treatment': 0.7143485497265493},
#  'covid_risk': {'covid_risk': 0.123660833764136,
#   'no_covid_risk': 0.8763391662358639},
#  'covid_risk_binary': {'covid_risk': 0.44838607564917243,
#   'no_covid_risk': 0.5516139243508277},
#  'covid_severity': {'no_covid_severity': 0.012094859212994448,
#   'medium_covid_severity': 0.49999999624452446,
#   'low_covid_severity': 0.036284577638982865,
#   'high_covid_severity': 0.4516205669034982},
#  'covid_severity_binary': {'no_covid_severity': 0.048379436851977146,
#   'covid_severity': 0.9516205631480229}}

# %%
evidence["age"]= "elderly"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2856514502734508,
#   'no_emergency_treatment': 0.7143485497265493},
#  'covid_risk': {'covid_risk': 0.12366083376413599,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 0.449334803375233,
#   'no_covid_risk': 0.550665196624767},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.06391411890351985,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 0.9360858810964796},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %%
evidence["body_temperature"]= "body_temperature_above_102F"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2870088482520748,
#   'no_emergency_treatment': 0.7129911517479252},
#  'covid_risk': {'covid_risk': 0.12366083376413599,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 1.0, 'no_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.06391411890351985,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 0.9360858810964796},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %%
evidence["diabetes"]= "diabetes"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2870088482520748,
#   'no_emergency_treatment': 0.7129911517479252},
#  'covid_risk': {'covid_risk': 0.12366083376413599,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 1.0, 'no_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 1.0},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %%
evidence["diabetes_medication"]= "no_diabetes_medication"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2870088482520748,
#   'no_emergency_treatment': 0.7129911517479252},
#  'covid_risk': {'covid_risk': 0.12366083376413599,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 1.0, 'no_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 1.0},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %%
evidence["hotspot_anomaly"]= "hotspot_anomaly"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2870088482520748,
#   'no_emergency_treatment': 0.7129911517479252},
#  'covid_risk': {'covid_risk': 0.12366083376413602,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 1.0, 'no_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 1.0},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %%
evidence["exposure"]= "exposure_in_family_not_isolated"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2870088482520748,
#   'no_emergency_treatment': 0.7129911517479252},
#  'covid_risk': {'covid_risk': 0.12366083376413599,
#   'no_covid_risk': 0.876339166235864},
#  'covid_risk_binary': {'covid_risk': 1.0, 'no_covid_risk': 0.0},
#  'covid_severity': {'no_covid_severity': 0.0,
#   'medium_covid_severity': 0.0,
#   'low_covid_severity': 0.0,
#   'high_covid_severity': 1.0},
#  'covid_severity_binary': {'no_covid_severity': 0.0, 'covid_severity': 1.0}}

# %% [markdown]
# Here is an example of using querys to debug the rules we wrote in covid_bayes.py .  We reset the evidence, and see that things we thought would have made a difference in risk or severity do not.  This is important feedback:  the reason is the overuse of the routine "avg" and not enough use of the routine "any" in our creation of the conditional probability tables in covid_bayes.py.

# %%
evidence = {}
evidence["ethnicity"]= "african_american"
results = query(covid,bayesianNetwork,evidence,outvars)
results
# Out:
# {'social_distancing': {'no_social_distancing': 0.002432639946873795,
#   'low_social_distancing': 0.8399619806253042,
#   'high_social_distancing': 0.0,
#   'medium_social_distancing': 0.15760537942782177},
#  'social_distancing_binary': {'no_social_distancing': 0.8423946205721781,
#   'social_distancing': 0.1576053794278218},
#  'emergency_treatment': {'emergency_treatment': 0.2856514502734508,
#   'no_emergency_treatment': 0.7143485497265493},
#  'covid_risk': {'covid_risk': 0.12366083376413603,
#   'no_covid_risk': 0.8763391662358638},
#  'covid_risk_binary': {'covid_risk': 0.45030184629985154,
#   'no_covid_risk': 0.5496981537001485},
#  'covid_severity': {'no_covid_severity': 0.0038044118212736703,
#   'medium_covid_severity': 0.4999999956268381,
#   'low_covid_severity': 0.011413235463820547,
#   'high_covid_severity': 0.4847823570880676},
#  'covid_severity_binary': {'no_covid_severity': 0.015217647285094003,
#   'covid_severity': 0.9847823527149059}}

# %% [markdown]
# Now start the server from somewhere else than here.  Use the first command uncommented if you are running in a notebook , or the second command if you are running from command line.

# %%
#%run -i './service/bayes_service.py' 
#python3 ./service/bayes_service.py

# %% [markdown]
# Here is a test of the server.  It is saving an ID for the network sent to it, in a pickle file of json.  If you run the service again, it will start at another id.

# %%
# %run -i './test_bayes_service.py' auto
# Out:
# Exception
# <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1598457046.317177605","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3948,"referenced_errors":[{"created":"@1598457046.317175517","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":394,"grpc_status":14}]}"
# >
